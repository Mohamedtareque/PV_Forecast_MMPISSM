# %% [markdown]
# ### 1) What data the framework expects
# a single CSV with a timestamp column (default: measurement_time) and a set of feature columns.

# %%
from src.data_preparation import load_data
import pvlib

# %%
# Read the processed dataset into a Pandas DataFrame in a notebook.
# Config file will be covered later.
# the code loads the CSV, parses the timestamp column, ensures UTC, sets it as the index, and sorts chronologically (data_preparation.load_data).
PROCESSED_DATA_PATH = "data/processed/dayTime_NAM_dayahead_features_processed.csv"

df = load_data(PROCESSED_DATA_PATH, date_col="measurement_time")
# Out:
# Loaded 15,078 records
# Date range: 2014-01-03 14:00:00+00:00 to 2016-12-31 03:00:00+00:00
# Timezone: UTC

# %%
df.head()
# Out:
#                                   ghi         dni  solar_zenith  \
# measurement_time
# 2014-01-03 14:00:00+00:00    0.000000    0.000000    100.276046
# 2014-01-03 15:00:00+00:00   12.914500   89.245833     89.724162
# 2014-01-03 16:00:00+00:00  143.775500  636.475000     80.146724
# 2014-01-03 17:00:00+00:00  289.955000  783.193333     71.988814
# 2014-01-03 18:00:00+00:00  402.643333  843.050000     65.816158
#
#                            time_gap_hours  time_gap_norm  day_boundary_flag  \
# measurement_time
# 2014-01-03 14:00:00+00:00        0.166667       0.006944                0.0
# 2014-01-03 15:00:00+00:00        0.016667       0.000694                0.0
# 2014-01-03 16:00:00+00:00        0.016667       0.000694                0.0
# 2014-01-03 17:00:00+00:00        0.016667       0.000694                0.0
# 2014-01-03 18:00:00+00:00        0.016667       0.000694                0.0
#
#                            hour_progression  absolute_hour      GHI_cs  \
# measurement_time
# 2014-01-03 14:00:00+00:00         14.491667      24.491667    0.000000
# 2014-01-03 15:00:00+00:00         15.491667      25.491667    0.000000
# 2014-01-03 16:00:00+00:00         16.491667      26.491667   35.159500
# 2014-01-03 17:00:00+00:00         17.491667      27.491667  184.554711
# 2014-01-03 18:00:00+00:00         18.491667      28.491667  321.992462
#
#                                DNI_cs  ...  CSI_dni  season_flag  hour_sin  \
# measurement_time                       ...
# 2014-01-03 14:00:00+00:00    0.000000  ...      NaN            2 -0.500000
# 2014-01-03 15:00:00+00:00    0.000000  ...      1.2            2 -0.707107
# 2014-01-03 16:00:00+00:00  182.297840  ...      1.2            2 -0.866025
# 2014-01-03 17:00:00+00:00  540.120302  ...      1.2            2 -0.965926
# 2014-01-03 18:00:00+00:00  692.514065  ...      1.2            2 -1.000000
#
#                                hour_cos  month_sin  month_cos  nam_ghi  \
# measurement_time
# 2014-01-03 14:00:00+00:00 -8.660254e-01        0.5   0.866025    0.000
# 2014-01-03 15:00:00+00:00 -7.071068e-01        0.5   0.866025   99.625
# 2014-01-03 16:00:00+00:00 -5.000000e-01        0.5   0.866025  274.750
# 2014-01-03 17:00:00+00:00 -2.588190e-01        0.5   0.866025  416.375
# 2014-01-03 18:00:00+00:00 -1.836970e-16        0.5   0.866025  510.875
#
#                               nam_dni  nam_cc            nam_target_time
# measurement_time
# 2014-01-03 14:00:00+00:00    0.000000     2.0  2014-01-03 15:00:00+00:00
# 2014-01-03 15:00:00+00:00  497.069277     2.0  2014-01-03 16:00:00+00:00
# 2014-01-03 16:00:00+00:00  760.162689     0.0  2014-01-03 17:00:00+00:00
# 2014-01-03 17:00:00+00:00  871.248807     2.0  2014-01-03 18:00:00+00:00
# 2014-01-03 18:00:00+00:00  919.980698     8.0  2014-01-03 19:00:00+00:00
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['ghi', 'dni', 'solar_zenith', 'time_gap_hours', 'time_gap_norm',
#        'day_boundary_flag', 'hour_progression', 'absolute_hour', 'GHI_cs',
#        'DNI_cs', 'CSI_ghi', 'CSI_dni', 'season_flag', 'hour_sin', 'hour_cos',
#        'month_sin', 'month_cos', 'nam_ghi', 'nam_dni', 'nam_cc',
#        'nam_target_time'],
#       dtype='object')

# %% [markdown]
# create three types of datasets based on feature selection.
#
# 1. Phase 1: Simple Baseline
#     - Inputs:
#         - GHI_CS, Elevation.
#     - Output:
#         - Day ahead (GHI -> GHI_kt)
#
# 2. Phase 2: Simple Baseline
#     - Inputs:
#         - Historical sequence: 3 Days (Before Issuing) × 3 features (ghi_kt , elevation)
#             - GHI_kt,
#             - Elevation
#             - Temporal and Geo Features.
#         - NAM: Nearest grid point only (26-39 horizons ahead  (1 day) × 2 features) (From Issue Time)
#             - NAM GHI forecast (DSWRF)
#             - NAM cloud cover (TCDC)
#     - Output:
#         - Day ahead (GHI -> GHI_kt)
#
# 2. Phase 3: Simple Baseline
#     - Inputs:
#         - Historical sequence: 3 Days (Before Issuing) × 3 features (ghi_kt , elevation)
#             - GHI_kt,
#             - Elevation
#         - NAM: Nearest grid point only (26-39 horizons ahead  (1 day) × 2 features) (From Issue Time)
#             - NAM GHI forecast (DSWRF)
#             - NAM cloud cover (TCDC)
#     - Output:
#         - Day ahead (GHI -> GHI_kt)

# %% [markdown]
# To control the features be fed into the models for different experiments, we edit `config.py`, add the set for example `"vaf_only": [...]`
#
# ```
# FEATURE_SETS = {
#     "all": [...],
#     "vaf_only": [...],
#     "weather_minimal": [...],
# }
#
# ```
#
# Then in any script we set `selected_columns = FEATURE_SETS["vaf_only"]`, and when we need to define this set into the model we set `config["feature_selection"] = "vaf_only"` in
#
# ```
# LSTM_CONFIG = {
#     "experiment_name": "solar_lstm_kbins",
#     "model_type": "LSTM",
#     "model_config": {
#         "hidden_size": 64,
#         "num_layers": 2,
#         "dropout": 0.2,
#         "bidirectional": True,
#     },
#     "data_prefix": DEFAULT_DATA_PREFIX,
#     --> "feature_cols": FEATURE_COLS,
#     --> "feature_selection": DEFAULT_FEATURE_SET,
#     "target_col": TARGET_COL,
#     "batch_size": 32,
#     "num_epochs": 50,
#     "learning_rate": 0.001,
#     "early_stopping_patience": 20,
#     "max_folds": 3,
# }
# ```
#
# This is will covered later.

# %% [markdown]
# ### 2) Prepare splits (once)
#
# Module: `data_preparation.py`
#
# 1. Fixed holdout (`fixed_holdout_split`): train/val/test by calendar ranges.
# 2. Rolling-origin evaluation (`rolling_origin_evaluation`): month-by-month rolling folds (train up to month t, validate on the next window), with fold metadata saved to `splits/rolling_origin_splits.json`.

# %% [markdown]
# #### Fixed Holdout Split

# %%
from src.data_preparation import fixed_holdout_split, rolling_origin_evaluation

# 1. Fixed Holdout split, use predefined calender dates for the splits. 
df_ph1_train_df, df_ph1_val_df, df_ph1_test_df, df_ph1_split_indices = fixed_holdout_split(df=df)
# Out:
# ============================================================
# FIXED HOLDOUT SPLIT
# ============================================================
# Training:   2014-01-01 to 2015-09-30 → 8,705 records
# Validation: 2015-10-01 to 2015-12-31 → 1,275 records
# Test:       2016-01-01 to 2016-12-31 → 5,079 records
# Total:      15,059 records
# Original:   15,078 records
# ============================================================

# %% [markdown]
# #### Rolling Origin Evaluation

# %%
# 2. Rolling Origin Split (More Suitable in TimeSeries) like K-Folds
from src.data_preparation import fixed_holdout_split, rolling_origin_evaluation,save_splits_info

rollingSplits_df = rolling_origin_evaluation(df=df, start_train = '2014-01-2',
    end_train = '2016-12-31')
save_splits_info({}, rollingSplits_df, experiment_name="exp-002")
# Out:
# ============================================================
# ROLLING ORIGIN EVALUATION
# ============================================================
# Total folds: 35
# Frequency: MS
# Data range: 2014-01-03 to 2016-12-31
#
# Fold Summary:
#   Fold 1: Train [2014-01-03 to 2014-02-01] (378 records) → Val [2014-02-02 to 2014-02-28] (235 records)
#   Fold 2: Train [2014-01-03 to 2014-03-01] (627 records) → Val [2014-03-02 to 2014-03-31] (407 records)
#   Fold 3: Train [2014-01-03 to 2014-04-01] (1,061 records) → Val [2014-04-02 to 2014-04-30] (393 records)
#   Fold 4: Train [2014-01-03 to 2014-05-01] (1,481 records) → Val [2014-05-02 to 2014-05-31] (407 records)
#   Fold 5: Train [2014-01-03 to 2014-06-01] (1,915 records) → Val [2014-06-02 to 2014-06-30] (393 records)
#   Fold 6: Train [2014-01-03 to 2014-07-01] (2,335 records) → Val [2014-07-02 to 2014-07-31] (407 records)
#   Fold 7: Train [2014-01-03 to 2014-08-01] (2,769 records) → Val [2014-08-02 to 2014-08-31] (407 records)
#   Fold 8: Train [2014-01-03 to 2014-09-01] (3,203 records) → Val [2014-09-02 to 2014-09-30] (393 records)
#   Fold 9: Train [2014-01-03 to 2014-10-01] (3,623 records) → Val [2014-10-02 to 2014-10-31] (407 records)
#   Fold 10: Train [2014-01-03 to 2014-11-01] (4,057 records) → Val [2014-11-02 to 2014-11-30] (393 records)
#   Fold 11: Train [2014-01-03 to 2014-12-01] (4,477 records) → Val [2014-12-02 to 2014-12-31] (407 records)
#   Fold 12: Train [2014-01-03 to 2015-01-01] (4,911 records) → Val [2015-01-02 to 2015-01-31] (407 records)
#   Fold 13: Train [2014-01-03 to 2015-02-01] (5,345 records) → Val [2015-02-02 to 2015-02-28] (365 records)
#   Fold 14: Train [2014-01-03 to 2015-03-01] (5,737 records) → Val [2015-03-02 to 2015-03-31] (407 records)
#   Fold 15: Train [2014-01-03 to 2015-04-01] (6,171 records) → Val [2015-04-02 to 2015-04-30] (393 records)
#   Fold 16: Train [2014-01-03 to 2015-05-01] (6,591 records) → Val [2015-05-02 to 2015-05-31] (407 records)
#   Fold 17: Train [2014-01-03 to 2015-06-01] (7,025 records) → Val [2015-06-02 to 2015-06-30] (393 records)
#   Fold 18: Train [2014-01-03 to 2015-07-01] (7,445 records) → Val [2015-07-02 to 2015-07-31] (407 records)
#   Fold 19: Train [2014-01-03 to 2015-08-01] (7,879 records) → Val [2015-08-02 to 2015-08-31] (393 records)
#   Fold 20: Train [2014-01-03 to 2015-09-01] (8,299 records) → Val [2015-09-02 to 2015-09-30] (393 records)
#   Fold 21: Train [2014-01-03 to 2015-10-01] (8,719 records) → Val [2015-10-02 to 2015-10-31] (407 records)
#   Fold 22: Train [2014-01-03 to 2015-11-01] (9,153 records) → Val [2015-11-02 to 2015-11-30] (393 records)
#   Fold 23: Train [2014-01-03 to 2015-12-01] (9,573 records) → Val [2015-12-02 to 2015-12-31] (407 records)
#   Fold 24: Train [2014-01-03 to 2016-01-01] (9,996 records) → Val [2016-01-02 to 2016-01-31] (407 records)
#   Fold 25: Train [2014-01-03 to 2016-02-01] (10,427 records) → Val [2016-02-02 to 2016-02-29] (379 records)
#   Fold 26: Train [2014-01-03 to 2016-03-01] (10,833 records) → Val [2016-03-02 to 2016-03-31] (407 records)
#   Fold 27: Train [2014-01-03 to 2016-04-01] (11,267 records) → Val [2016-04-02 to 2016-04-30] (393 records)
#   Fold 28: Train [2014-01-03 to 2016-05-01] (11,687 records) → Val [2016-05-02 to 2016-05-31] (407 records)
#   Fold 29: Train [2014-01-03 to 2016-06-01] (12,121 records) → Val [2016-06-02 to 2016-06-30] (393 records)
#   Fold 30: Train [2014-01-03 to 2016-07-01] (12,541 records) → Val [2016-07-02 to 2016-07-31] (379 records)
#   Fold 31: Train [2014-01-03 to 2016-08-01] (12,947 records) → Val [2016-08-02 to 2016-08-31] (407 records)
#   Fold 32: Train [2014-01-03 to 2016-09-01] (13,381 records) → Val [2016-09-02 to 2016-09-30] (393 records)
#   Fold 33: Train [2014-01-03 to 2016-10-01] (13,801 records) → Val [2016-10-02 to 2016-10-31] (407 records)
#   Fold 34: Train [2014-01-03 to 2016-11-01] (14,235 records) → Val [2016-11-02 to 2016-11-30] (393 records)
#   Fold 35: Train [2014-01-03 to 2016-12-01] (14,655 records) → Val [2016-12-02 to 2016-12-31] (407 records)
# ============================================================
#
# Split metadata saved to 'splits/exp-002/' directory

# %% [markdown]
# Meta data about the results of spliting stored into (splits/...json)
#
# ph1_rollingSplits_df is a list consists of Folds from 0 to N, and each fold has meta data about the train, test and validation
# - start, end, and size
# - indices

# %% [markdown]
# ### Data Preview, Does it concist with our expectations?
# Data has a fixed length bounded by the hours of day which choosed to match the CASIO forecast and NAM forecast Horizon.

# %% [markdown]
# Does the data met our expectations?
# - Does NAM records is one hour lag ahead from measurements.
# - Do sequences have the same length
# - Do we have zero values in features?

# %%
import pandas as pd
import numpy as np
df_noIndex = df.reset_index()
df_noIndex['nam_target_time'] = pd.to_datetime(df_noIndex['nam_target_time'])
df_noIndex['measurement_time'] = pd.to_datetime(df_noIndex['measurement_time'])
df_noIndex['time_diff'] = (df_noIndex['nam_target_time'] - df_noIndex['measurement_time']).dt.total_seconds() / 3600  # Calculate the time difference in hours
    
# Check if the time difference is exactly 1 hour
is_nam_lag_correct = np.allclose(df_noIndex['time_diff'], 1)  # All time differences should be 1 hour
print(f"Does NAM records have a 1-hour lag ahead from measurements? {'Yes' if is_nam_lag_correct else 'No'}")
# Out:
# Does NAM records have a 1-hour lag ahead from measurements? Yes

# %%
# 2. Check if sequences have the same length across each day
# Extract date from the 'measurement_time'
df_noIndex['date'] = df_noIndex['measurement_time'].dt.date
    
# Group by date and count records per day
daily_counts = df_noIndex.groupby('date').size()
    
# Find dates where the record count is not equal to 24 (assuming 24 records per day)
inconsistent_dates = daily_counts[daily_counts != 14]
    
# Print dates where records differ from 24
if not inconsistent_dates.empty:
    print("Dates with record counts different from 14 hours:")
    print(inconsistent_dates)
else:
    print("All dates have the expected 14-hour record count.")
# Out:
# Dates with record counts different from 14 hours:
# date
# 2014-01-03    10
# 2014-01-30     4
# 2014-02-05    10
# 2014-02-13     4
# 2014-02-19    10
# 2015-08-23     4
# 2015-08-24    10
# 2015-12-31     4
# 2016-01-01    10
# 2016-07-13     4
# 2016-07-15    10
# 2016-12-31     4
# dtype: int64

# %%
# Create a list of dates to drop
dates_to_drop = [
    '2014-01-03', '2014-01-30', '2014-02-05', '2014-02-13', '2014-02-19',
    '2015-08-23', '2015-08-24', '2015-12-31', '2016-01-01', '2016-07-13',
    '2016-07-15', '2016-12-31'
]

# Print the first few rows of the index to see its format
print("Index sample before processing:")
print(df.index[:5])
print("\nIndex timezone:", df.index.tz)

# Convert dates to datetime with UTC timezone
dates_to_drop = pd.to_datetime(dates_to_drop).tz_localize('UTC')

# Get the original size of the DataFrame
original_size = len(df)

df = df[~df.index.normalize().isin(dates_to_drop)]

# Print the number of rows dropped
print(f"\nOriginal number of records: {original_size}")
print(f"Number of records after dropping dates: {len(df)}")
print(f"Number of records dropped: {original_size - len(df)}")
# Out:
# Index sample before processing:
# DatetimeIndex(['2014-01-03 14:00:00+00:00', '2014-01-03 15:00:00+00:00',
#                '2014-01-03 16:00:00+00:00', '2014-01-03 17:00:00+00:00',
#                '2014-01-03 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='measurement_time', freq=None)
#
# Index timezone: UTC
#
# Original number of records: 15078
# Number of records after dropping dates: 14994
# Number of records dropped: 84

# %%
# 3. Check if there are zero values in any of the features
zero_values_in_features = (df[['ghi', 'dni', 'solar_zenith', 'GHI_cs', 'DNI_cs', 'CSI_ghi', 
                                   'CSI_dni', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 
                                   'nam_ghi', 'nam_dni', 'nam_cc']] == 0).sum().sum()
print(f"Do we have NaN values in features? {'Yes' if zero_values_in_features > 0 else 'No'}")


features_to_check = [
    'ghi', 'dni', 'solar_zenith', 'GHI_cs', 'DNI_cs', 'CSI_ghi', 
    'CSI_dni', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 
    'nam_ghi', 'nam_dni', 'nam_cc'
]

# 2. Calculate the number of NaN values for each feature
# We use .isna() instead of == 0
nans_per_feature = df[features_to_check].isna().sum()

# 3. Filter to get only features that actually have NaN values
features_with_nans = nans_per_feature[nans_per_feature > 0]

# 4. Report the findings for which features have NaNs
if features_with_nans.empty:
    print("No NaN (missing) values found in any of the specified features.")
else:
    print("--- Features With NaN Values ---")
    print("The following features have NaN values, with the total count for each:")
    # Sort for clearer output
    print(features_with_nans.sort_values(ascending=False))
    print("\n" + "="*40 + "\n")

    # 5. Analyze the distribution of hours for rows containing NaNs
    print("--- Distribution of NaN-Value Records by Hour ---")
    
    # Create a boolean mask for rows that contain *at least one* NaN
    # in the specified columns
    rows_with_any_nan = df[features_to_check].isna().any(axis=1)
    
    if rows_with_any_nan.sum() > 0:
        # Get the index for these rows
        nan_rows_index = df.index[rows_with_any_nan]
        
        # Extract the hour from the DatetimeIndex and get the value counts
        hour_distribution = nan_rows_index.hour.value_counts().sort_index()
        
        print("Distribution of records (rows) containing at least one NaN, by hour:")
        print(hour_distribution)
        
        # Optional: Print total number of affected rows
        print(f"\nTotal number of rows with at least one NaN: {rows_with_any_nan.sum()}")
    else:
        # This case shouldn't be hit if features_with_nans was not empty,
        # but it's good practice to include.
        print("No rows found with NaN values (this is unexpected, check logic).")
# Out:
# Do we have NaN values in features? Yes
# --- Features With NaN Values ---
# The following features have NaN values, with the total count for each:
# CSI_dni    1807
# CSI_ghi    1623
# nam_ghi     280
# nam_dni     280
# nam_cc      280
# dtype: int64
#
# ========================================
#
# --- Distribution of NaN-Value Records by Hour ---
# Distribution of records (rows) containing at least one NaN, by hour:
# measurement_time
# 0      20
# 1     207
# 2     471
# 3     777
# 14    335
# 15     48
# 16     20
# 17     20
# 18     20
# 19     20
# 20     20
# 21     20
# 22     20
# 23     20
# Name: count, dtype: int64
#
# Total number of rows with at least one NaN: 2018

# %%
df_interpolated = df.interpolate(method='linear')
# Out:
# /tmp/ipykernel_831122/931910069.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_interpolated = df.interpolate(method='linear')

# %%
# 3. Check if there are zero values in any of the features
zero_values_in_features = (df_interpolated[['ghi', 'dni', 'solar_zenith', 'GHI_cs', 'DNI_cs', 'CSI_ghi', 
                                   'CSI_dni', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 
                                   'nam_ghi', 'nam_dni', 'nam_cc']] == 0).sum().sum()
print(f"Do we have zero values in features? {'Yes' if zero_values_in_features > 0 else 'No'}")


features_to_check = [
    'ghi', 'dni', 'solar_zenith', 'GHI_cs', 'DNI_cs', 'CSI_ghi', 
    'CSI_dni', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 
    'nam_ghi', 'nam_dni', 'nam_cc'
]

# 2. Calculate the number of NaN values for each feature
# We use .isna() instead of == 0
nans_per_feature = df_interpolated[features_to_check].isna().sum()

# 3. Filter to get only features that actually have NaN values
features_with_nans = nans_per_feature[nans_per_feature > 0]

# 4. Report the findings for which features have NaNs
if features_with_nans.empty:
    print("No NaN (missing) values found in any of the specified features.")
else:
    print("--- Features With NaN Values ---")
    print("The following features have NaN values, with the total count for each:")
    # Sort for clearer output
    print(features_with_nans.sort_values(ascending=False))
    print("\n" + "="*40 + "\n")

    # 5. Analyze the distribution of hours for rows containing NaNs
    print("--- Distribution of NaN-Value Records by Hour ---")
    
    # Create a boolean mask for rows that contain *at least one* NaN
    # in the specified columns
    rows_with_any_nan = df_interpolated[features_to_check].isna().any(axis=1)
    
    if rows_with_any_nan.sum() > 0:
        # Get the index for these rows
        nan_rows_index = df_interpolated.index[rows_with_any_nan]
        
        # Extract the hour from the DatetimeIndex and get the value counts
        hour_distribution = nan_rows_index.hour.value_counts().sort_index()
        
        print("Distribution of records (rows) containing at least one NaN, by hour:")
        print(hour_distribution)
        
        # Optional: Print total number of affected rows
        print(f"\nTotal number of rows with at least one NaN: {rows_with_any_nan.sum()}")
    else:
        # This case shouldn't be hit if features_with_nans was not empty,
        # but it's good practice to include.
        print("No rows found with NaN values (this is unexpected, check logic).")
# Out:
# Do we have zero values in features? Yes
# No NaN (missing) values found in any of the specified features.

# %%
df_interpolated.head()
# Out:
#                                  ghi         dni  solar_zenith  \
# measurement_time
# 2014-01-04 00:00:00+00:00  43.827167  139.092167     86.467556
# 2014-01-04 01:00:00+00:00   0.000000    0.000000     96.742105
# 2014-01-04 02:00:00+00:00   0.000000    0.000000    107.755671
# 2014-01-04 03:00:00+00:00   0.000000    0.000000    119.225607
# 2014-01-04 14:00:00+00:00   0.000000    0.000000    100.295605
#
#                            time_gap_hours  time_gap_norm  day_boundary_flag  \
# measurement_time
# 2014-01-04 00:00:00+00:00        0.016667       0.000694           0.016667
# 2014-01-04 01:00:00+00:00        0.016667       0.000694           0.000000
# 2014-01-04 02:00:00+00:00        0.016667       0.000694           0.000000
# 2014-01-04 03:00:00+00:00        0.016667       0.000694           0.000000
# 2014-01-04 14:00:00+00:00        0.166667       0.006944           0.000000
#
#                            hour_progression  absolute_hour     GHI_cs  \
# measurement_time
# 2014-01-04 00:00:00+00:00          0.491667      34.491667  77.958793
# 2014-01-04 01:00:00+00:00          1.491667      35.491667   0.000000
# 2014-01-04 02:00:00+00:00          2.491667      36.491667   0.000000
# 2014-01-04 03:00:00+00:00          3.491667      37.491667   0.000000
# 2014-01-04 14:00:00+00:00         14.491667      48.491667   0.000000
#
#                                DNI_cs  ...   CSI_dni  season_flag  hour_sin  \
# measurement_time                       ...
# 2014-01-04 00:00:00+00:00  323.747434  ...  0.429632            2  0.000000
# 2014-01-04 01:00:00+00:00    0.000000  ...  0.583705            2  0.258819
# 2014-01-04 02:00:00+00:00    0.000000  ...  0.737779            2  0.500000
# 2014-01-04 03:00:00+00:00    0.000000  ...  0.891853            2  0.707107
# 2014-01-04 14:00:00+00:00    0.000000  ...  1.045926            2 -0.500000
#
#                            hour_cos  month_sin  month_cos     nam_ghi  \
# measurement_time
# 2014-01-04 00:00:00+00:00  1.000000        0.5   0.866025  107.083333
# 2014-01-04 01:00:00+00:00  0.965926        0.5   0.866025   53.541667
# 2014-01-04 02:00:00+00:00  0.866025        0.5   0.866025    0.000000
# 2014-01-04 03:00:00+00:00  0.707107        0.5   0.866025    0.000000
# 2014-01-04 14:00:00+00:00 -0.866025        0.5   0.866025    0.000000
#
#                               nam_dni     nam_cc            nam_target_time
# measurement_time
# 2014-01-04 00:00:00+00:00  403.544129  21.333333  2014-01-04 01:00:00+00:00
# 2014-01-04 01:00:00+00:00  201.772064  22.666667  2014-01-04 02:00:00+00:00
# 2014-01-04 02:00:00+00:00    0.000000  24.000000  2014-01-04 03:00:00+00:00
# 2014-01-04 03:00:00+00:00    0.000000  24.666667  2014-01-04 04:00:00+00:00
# 2014-01-04 14:00:00+00:00    0.000000   0.000000  2014-01-04 15:00:00+00:00
#
# [5 rows x 21 columns]

# %%
df_phase1 = df_interpolated[['CSI_ghi']]

df_phase2 = df_interpolated[['solar_zenith', 'time_gap_hours', 'time_gap_norm', 'day_boundary_flag',
       'hour_progression', 'absolute_hour', 'CSI_ghi', 'CSI_dni',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos']]

df_phase3 = df_interpolated[['solar_zenith', 'time_gap_hours', 'time_gap_norm', 'day_boundary_flag',
       'hour_progression', 'absolute_hour', 'CSI_ghi', 'CSI_dni',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos',
       'nam_ghi', 'nam_dni', 'nam_cc', 'nam_target_time']]

# %% [markdown]
# ----

# %% [markdown]
# ### 3. Convert daily series → K-bin tensors
#
# Modules: `preprocessing.process_splits_to_kbins` and `preprocessing.build_model_arrays`.
#
# - Why this kind of sequence formating?
#     - To solve the problem of variable length of sequences.
# - How?
#     - Normalize each day into K bins (default K_BINS = 60) aligned to solar phase (sunrise→sunset mapped to [0,1]).
#     - Handle different column “strategies” (`DEFAULT_STRATEGY`):
#
#         - We can define specific sampling stratigy for each kind of variables.
#             - Irradiance (ghi, dni, CSI_ghi, CSI_dni): resampled carefully to preserve daily energy (conservative method) or smooth & shape-preserving
#             - PCHIP interpolation with optional re-normalization (KBinConfig.irradiance_mode).
#             - Continuous signals: interpolated (linear/PCHIP).
#             - Categorical: nearest fill.
#             - Temporal recompute: recomputed from the new K-bin index (hour_sin/cos, month_sin/cos, etc.), so they stay consistent after re-binning.
#         - ```
#             DEFAULT_STRATEGY = {
#                 "ghi": "irradiance",
#                 "dni": "irradiance",
#                 "CSI_ghi": "irradiance",
#                 "CSI_dni": "irradiance",
#
#                 "air_temp": "continuous",
#                 "relhum": "continuous",
#                 "windsp": "continuous",
#
#                 "solar_zenith": "continuous",
#                 "solar_elevation": "continuous",
#                 "GHI_cs": "continuous",
#                 "DNI_cs": "continuous",
#
#                 "winddirection_sin": "windvec",
#                 "winddirection_cos": "windvec",
#
#                 "season_flag": "categorical",
#                 "is_daylight": "categorical",
#                 "day_boundary_flag": "categorical",
#
#                 "hour_sin": "temporal_recompute",
#                 "hour_cos": "temporal_recompute",
#                 "month_sin": "temporal_recompute",
#                 "month_cos": "temporal_recompute",
#                 "absolute_hour": "temporal_recompute",
#                 "hour_progression": "temporal_recompute",
#                 "time_gap_hours": "temporal_recompute",
#                 "time_gap_norm": "temporal_recompute",
#             }
#             ```
#     - Produces a normalized day-level MultiIndex [date, bin_id, target_time] with added metadata (solar_phase, sunrise, sunset, day_len_hours).
# 	    - Then build_model_arrays creates:
#             - X: shape (samples, history_days, K, F)
#             - Y: shape (samples, horizon_days, K)
#             - labels: list of datetime indices for each predicted day.
#     - `process_splits_to_kbins`(...): takes daily series and remaps each daylight period to a fixed K bins grid (sunrise→sunset → [0..K-1]), adds per-day metadata, and guarantees same length per day.
#     - `build_model_arrays`(...): slides a window of history_days past days to predict horizon_days ahead, packing tensors as:
#         - X: (N, history_days, K, F)
#         - Y: (N, horizon_days, K)
#         - labels: the target day timestamps
#         - meta: shapes, features, etc.

# %%
from src.preprocessing import KBinConfig, process_splits_to_kbins, build_model_arrays
USE_KBINS = True
k_bins = 60
selected_columns = df_phase1.columns
feature_cols = df_phase1.columns
TARGET_COL = "CSI_ghi"
history_days = 3
horizon_days = 1

if USE_KBINS:
        print("\n--- Step 2: Converting full dataset to K-Bins format ---")
        cfg = KBinConfig(K=k_bins)
        processed = process_splits_to_kbins({"full_data": df}, cfg, feature_cols=selected_columns)
        norm_df = processed.get("full_data")
        if norm_df is None or norm_df.empty:
            raise ValueError("Normalized dataframe is empty after K-bin processing.")

        print("\n--- Step 3: Building model arrays (X, Y) ---")
        ph1_kbins_X, ph1_kbins_Y, ph1_kbins_labels_list = build_model_arrays(
            norm_df,
            feature_cols=feature_cols,
            target_col=TARGET_COL,
            history_days=history_days,
            horizon_days=horizon_days,
        )
# Out:
# --- Step 2: Converting full dataset to K-Bins format ---
#
# --- Step 3: Building model arrays (X, Y) ---

# %% [markdown]
# -------
# ### No KBins

# %%
from src.preprocessing import KBinConfig, process_splits_to_kbins, build_model_arrays, to_fixedgrid_multiindex
USE_KBINS = False
k_bins = 60
selected_columns = df_phase1.columns
feature_cols = df_phase1.columns
TARGET_COL = "CSI_ghi"
history_days = 7
horizon_days = 1

if USE_KBINS:
        print("\n--- Step 2: Converting full dataset to K-Bins format ---")
        cfg = KBinConfig(K=k_bins)
        processed = process_splits_to_kbins({"full_data": df}, cfg, feature_cols=selected_columns)
        norm_df = processed.get("full_data")
        if norm_df is None or norm_df.empty:
            raise ValueError("Normalized dataframe is empty after K-bin processing.")

        print("\n--- Step 3: Building model arrays (X, Y) ---")
        ph1_kbins_X, ph1_kbins_Y, ph1_kbins_labels_list = build_model_arrays(
            norm_df,
            feature_cols=feature_cols,
            target_col=TARGET_COL,
            history_days=history_days,
            horizon_days=horizon_days,
        )
else:
    print("\n--- Step 2: Building model arrays (X, Y) ---")
    fixed_df = to_fixedgrid_multiindex(df_phase1, timestamp_col="measurement_time", expected_T=None)  # or set T
    ph1_X, ph1_Y, ph1_labels_list = build_model_arrays(
        fixed_df,
        feature_cols=selected_columns,  # must include your chosen inputs
        target_col=TARGET_COL,          # target must be present in columns
        history_days=history_days,
        horizon_days=horizon_days,
    )
# Out:
# --- Step 2: Building model arrays (X, Y) ---

# %%
ph1_X.shape, ph1_Y.shape
# Out:
# ((1064, 7, 14, 1), (1064, 1, 14))

# %% [markdown]
# 	•	1081 → number of training samples (sliding windows).
# 	•	3 → history_days: how many past days per sample.
# 	•	15 → T: fixed time steps per day (Resample grid; e.g., 15 bins/day).
# 	•	2 → F: number of features in feature_cols (excluding the target column).
# 	•	1 in Y → horizon_days: predict the next day only.
# 	•	15 in Y → same within-day grid as X.

# %%
# Controlling the selected features example
selected_columns = ['solar_zenith', 'time_gap_hours', 'time_gap_norm', 'day_boundary_flag',
       'hour_progression', 'absolute_hour', 'CSI_ghi', 'CSI_dni',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos',
       'nam_ghi', 'nam_dni', 'nam_cc']
print("\n--- Step 2: Building model arrays (X, Y) ---")
fixed_df = to_fixedgrid_multiindex(df, timestamp_col="measurement_time", expected_T=None)  # or set T
# Zero-impute everything (features + target)
fixed_df = fixed_df.fillna(0.0)
ph1_X, ph1_Y, ph1_labels_list = build_model_arrays(
        fixed_df,
        feature_cols=selected_columns,  # must include your chosen inputs
        target_col=TARGET_COL,          # target must be present in columns
        history_days=history_days,
        horizon_days=horizon_days,
    )
# Out:
# --- Step 2: Building model arrays (X, Y) ---

# %%
ph1_X.shape, ph1_Y.shape
# Out:
# ((1064, 7, 14, 1), (1064, 1, 14))

# %%
TARGET_COL = 'CSI_ghi'
feature_cols = [c for c in df_phase1.columns.tolist() if c != TARGET_COL]
import pandas as pd
from src.utils import DataManager
data_manager = DataManager()
data_manager.save_arrays(
    ph1_X, ph1_Y,
    pd.DataFrame(index=pd.to_datetime(ph1_labels_list, utc=True)),
    filename_prefix='phas1_data',
    feature_cols=feature_cols,
    target_col=TARGET_COL,
    metadata={
        "input_csv": "data/processed/dayTime_NAM_dayahead_features_processed.csv",
        "timestamp_col": "measurement_time",
        "feature_set": feature_cols,     # for traceability
        "history_days": 7,
        "horizon_days": 1,
        "k_bins": None,
    }
)
# Out:
# INFO:src.utils:Saved arrays to data/phas1_data_*.npy
# INFO:src.utils:X shape: (1064, 7, 14, 1), Y shape: (1064, 1, 14)

# %% [markdown]
# Data has saved as npy file in `data/..X|Y.npy`files

# %% [markdown]
# ## Running Experiment on Models

# %%
import torch
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if hasattr(torch.backends, "mps") and torch.backends.mps.is_available()
    else "cpu"
)

# %%
device
# Out:
# 'cuda'

# %%
df_phase1.head()
# Out:
#                             CSI_ghi
# measurement_time
# 2014-01-04 00:00:00+00:00  0.562184
# 2014-01-04 01:00:00+00:00  0.689747
# 2014-01-04 02:00:00+00:00  0.817310
# 2014-01-04 03:00:00+00:00  0.944874
# 2014-01-04 14:00:00+00:00  1.072437

# %%
#feature_cols = df_phase1.columns.tolist()   
#FEATURE_COLS= feature_cols
#DEFAULT_FEATURE_SET = feature_cols
feature_cols = [c for c in df_phase1.columns.tolist() if c != TARGET_COL]  # e.g., ['solar_zenith']


LSTM_CONFIG = {
    "experiment_name": "phas1_exp01_overfitting_solve",
    "model_type": "LSTM",
    "model_config": {
        "hidden_size": 64,
        "num_layers": 2,
        "dropout": 0.25,
        "bidirectional": True,
    },
    "data_prefix": "phas1_data",
    "splits_file": "exp-001/exp-001rolling_origin_splits.json",
    "feature_cols": feature_cols,
    "feature_selection": feature_cols,
    "target_col": TARGET_COL,
    "batch_size": 32,
    "num_epochs": 50,
    "learning_rate": 0.001,
    "loss_function": "Huber",
    "early_stopping_patience": 20,
    "max_folds": 35,
}

# %% [markdown]
# Incase of update config

# %%
FEATURE_COLS = feature_cols
DEFAULT_FEATURE_SET = feature_cols  # ok if your resolver accepts raw lists

LSTM_CONFIG.update({
    "feature_cols": FEATURE_COLS,
    "feature_selection": DEFAULT_FEATURE_SET,
})

# %%
from src.pipeline import SolarForecastingPipeline

pipeline = SolarForecastingPipeline(LSTM_CONFIG)
_, summary = pipeline.run()
# Out:
# INFO:src.pipeline:Loading data...
# INFO:src.utils:Loaded arrays from data/phas1_data_*.npy
# INFO:src.utils:X shape: (1064, 7, 14, 1), Y shape: (1064, 1, 14)
# INFO:src.pipeline:Reference dataframe prepared for NAM comparison (15162 rows).
# INFO:src.utils:Loaded 35 folds from exp-001/exp-001rolling_origin_splits.json
# INFO:src.pipeline:
# === Running Fold 1 ===
# INFO:src.pipeline:Train samples: 19, Val samples: 16
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.034855, Val Loss: 0.085353, Train MAE: 0.185549, Val MAE: 0.312215, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.023681, Val Loss: 0.054794, Train MAE: 0.151009, Val MAE: 0.276369, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.019172, Val Loss: 0.089405, Train MAE: 0.130675, Val MAE: 0.322971, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.015449, Val Loss: 0.130248, Train MAE: 0.118386, Val MAE: 0.393226, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 41
# INFO:src.pipeline:Fold 1 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.270389
# INFO:src.pipeline:  rmse: 0.519990
# INFO:src.pipeline:  mae: 0.398563
# INFO:src.pipeline:  r2: -0.814329
# INFO:src.pipeline:  mape: 108.072639
# INFO:src.pipeline:  model_rmse_ghi: 56.681473
# INFO:src.pipeline:  nam_rmse_ghi: 47.325744
# INFO:src.pipeline:  model_mae_ghi: 36.756056
# INFO:src.pipeline:  nam_mae_ghi: 39.566995
# INFO:src.pipeline:  model_mape_ghi: 119.020270
# INFO:src.pipeline:  nam_mape_ghi: 337.824906
# INFO:src.pipeline:  model_rmse_csi: 0.519990
# INFO:src.pipeline:  model_mae_csi: 0.398563
# INFO:src.pipeline:  model_mape_csi: 108.072639
# INFO:src.pipeline:  nam_rmse_csi: 59.491574
# INFO:src.pipeline:  nam_mae_csi: 17.255400
# INFO:src.pipeline:  nam_mape_csi: 8727.254750
# INFO:src.pipeline:  rmse_skill_ghi_pct: -19.768795
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.125944
# INFO:src.pipeline:  mae_skill_ghi_pct: 7.104250
# INFO:src.pipeline:  mae_skill_csi_pct: 97.690214
# INFO:src.pipeline:  mape_skill_ghi_pct: 64.768652
# INFO:src.pipeline:  mape_skill_csi_pct: 98.761665
# INFO:src.pipeline:  n_rows: 224.000000
# INFO:src.pipeline:  n_daylight_rows: 25.000000
# INFO:src.pipeline:
# === Running Fold 2 ===
# INFO:src.pipeline:Train samples: 36, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.035617, Val Loss: 0.037282, Train MAE: 0.218450, Val MAE: 0.231174, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.028233, Val Loss: 0.040443, Train MAE: 0.186633, Val MAE: 0.232506, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.031737, Val Loss: 0.033075, Train MAE: 0.192371, Val MAE: 0.210168, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Fold 2 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.073592
# INFO:src.pipeline:  rmse: 0.271278
# INFO:src.pipeline:  mae: 0.218436
# INFO:src.pipeline:  r2: 0.355869
# INFO:src.pipeline:  mape: 55.615108
# INFO:src.pipeline:  model_rmse_ghi: 43.570877
# INFO:src.pipeline:  nam_rmse_ghi: 28.918516
# INFO:src.pipeline:  model_mae_ghi: 32.604794
# INFO:src.pipeline:  nam_mae_ghi: 18.172979
# INFO:src.pipeline:  model_mape_ghi: 74.486547
# INFO:src.pipeline:  nam_mape_ghi: 73.857357
# INFO:src.pipeline:  model_rmse_csi: 0.271278
# INFO:src.pipeline:  model_mae_csi: 0.218436
# INFO:src.pipeline:  model_mape_csi: 55.615108
# INFO:src.pipeline:  nam_rmse_csi: 0.342068
# INFO:src.pipeline:  nam_mae_csi: 0.203361
# INFO:src.pipeline:  nam_mape_csi: 73.857357
# INFO:src.pipeline:  rmse_skill_ghi_pct: -50.667749
# INFO:src.pipeline:  rmse_skill_csi_pct: 20.694783
# INFO:src.pipeline:  mae_skill_ghi_pct: -79.413594
# INFO:src.pipeline:  mae_skill_csi_pct: -7.413001
# INFO:src.pipeline:  mape_skill_ghi_pct: -0.851899
# INFO:src.pipeline:  mape_skill_csi_pct: 24.699297
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 3 ===
# INFO:src.pipeline:Train samples: 67, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.033836, Val Loss: 0.044807, Train MAE: 0.213281, Val MAE: 0.260413, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.047575, Val Loss: 0.037991, Train MAE: 0.217710, Val MAE: 0.225774, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 26
# INFO:src.pipeline:Fold 3 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.070354
# INFO:src.pipeline:  rmse: 0.265243
# INFO:src.pipeline:  mae: 0.217286
# INFO:src.pipeline:  r2: 0.088899
# INFO:src.pipeline:  mape: 36.041405
# INFO:src.pipeline:  model_rmse_ghi: 53.164665
# INFO:src.pipeline:  nam_rmse_ghi: 82.375138
# INFO:src.pipeline:  model_mae_ghi: 38.153054
# INFO:src.pipeline:  nam_mae_ghi: 46.609284
# INFO:src.pipeline:  model_mape_ghi: 37.417178
# INFO:src.pipeline:  nam_mape_ghi: 247.917462
# INFO:src.pipeline:  model_rmse_csi: 0.265243
# INFO:src.pipeline:  model_mae_csi: 0.217286
# INFO:src.pipeline:  model_mape_csi: 36.041405
# INFO:src.pipeline:  nam_rmse_csi: 4233.970265
# INFO:src.pipeline:  nam_mae_csi: 520.457473
# INFO:src.pipeline:  nam_mape_csi: 61476.609638
# INFO:src.pipeline:  rmse_skill_ghi_pct: 35.460302
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.993735
# INFO:src.pipeline:  mae_skill_ghi_pct: 18.142802
# INFO:src.pipeline:  mae_skill_csi_pct: 99.958251
# INFO:src.pipeline:  mape_skill_ghi_pct: 84.907405
# INFO:src.pipeline:  mape_skill_csi_pct: 99.941374
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 71.000000
# INFO:src.pipeline:
# === Running Fold 4 ===
# INFO:src.pipeline:Train samples: 97, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.070246, Val Loss: 0.016444, Train MAE: 0.278811, Val MAE: 0.150796, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.023821, Val Loss: 0.013573, Train MAE: 0.141912, Val MAE: 0.126948, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.020930, Val Loss: 0.017738, Train MAE: 0.154930, Val MAE: 0.157640, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 39
# INFO:src.pipeline:Fold 4 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.029609
# INFO:src.pipeline:  rmse: 0.172072
# INFO:src.pipeline:  mae: 0.125034
# INFO:src.pipeline:  r2: 0.406834
# INFO:src.pipeline:  mape: 18.159719
# INFO:src.pipeline:  model_rmse_ghi: 33.831713
# INFO:src.pipeline:  nam_rmse_ghi: 177.658241
# INFO:src.pipeline:  model_mae_ghi: 22.546541
# INFO:src.pipeline:  nam_mae_ghi: 119.355573
# INFO:src.pipeline:  model_mape_ghi: 26.558106
# INFO:src.pipeline:  nam_mape_ghi: 404.329564
# INFO:src.pipeline:  model_rmse_csi: 0.172072
# INFO:src.pipeline:  model_mae_csi: 0.125034
# INFO:src.pipeline:  model_mape_csi: 18.159719
# INFO:src.pipeline:  nam_rmse_csi: 6.393005
# INFO:src.pipeline:  nam_mae_csi: 3.094590
# INFO:src.pipeline:  nam_mape_csi: 404.329564
# INFO:src.pipeline:  rmse_skill_ghi_pct: 80.956857
# INFO:src.pipeline:  rmse_skill_csi_pct: 97.308432
# INFO:src.pipeline:  mae_skill_ghi_pct: 81.109771
# INFO:src.pipeline:  mae_skill_csi_pct: 95.959601
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.431570
# INFO:src.pipeline:  mape_skill_csi_pct: 95.508684
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 5 ===
# INFO:src.pipeline:Train samples: 128, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.028149, Val Loss: 0.010661, Train MAE: 0.181030, Val MAE: 0.126924, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.021995, Val Loss: 0.008912, Train MAE: 0.148056, Val MAE: 0.113295, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.017879, Val Loss: 0.006930, Train MAE: 0.135285, Val MAE: 0.072584, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.017750, Val Loss: 0.005769, Train MAE: 0.126710, Val MAE: 0.069620, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.014382, Val Loss: 0.006895, Train MAE: 0.120989, Val MAE: 0.100574, LR: 0.001000
# INFO:src.pipeline:Fold 5 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.013791
# INFO:src.pipeline:  rmse: 0.117434
# INFO:src.pipeline:  mae: 0.100574
# INFO:src.pipeline:  r2: 0.645353
# INFO:src.pipeline:  mape: 12.212562
# INFO:src.pipeline:  model_rmse_ghi: 24.926774
# INFO:src.pipeline:  nam_rmse_ghi: 183.386569
# INFO:src.pipeline:  model_mae_ghi: 18.726292
# INFO:src.pipeline:  nam_mae_ghi: 126.617010
# INFO:src.pipeline:  model_mape_ghi: 13.855997
# INFO:src.pipeline:  nam_mape_ghi: 203.539202
# INFO:src.pipeline:  model_rmse_csi: 0.117434
# INFO:src.pipeline:  model_mae_csi: 0.100574
# INFO:src.pipeline:  model_mape_csi: 12.212562
# INFO:src.pipeline:  nam_rmse_csi: 1827.663220
# INFO:src.pipeline:  nam_mae_csi: 405.586491
# INFO:src.pipeline:  nam_mape_csi: 72924.087870
# INFO:src.pipeline:  rmse_skill_ghi_pct: 86.407525
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.993575
# INFO:src.pipeline:  mae_skill_ghi_pct: 85.210287
# INFO:src.pipeline:  mae_skill_csi_pct: 99.975203
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.192468
# INFO:src.pipeline:  mape_skill_csi_pct: 99.983253
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 6 ===
# INFO:src.pipeline:Train samples: 158, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020752, Val Loss: 0.014810, Train MAE: 0.149751, Val MAE: 0.109864, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017320, Val Loss: 0.015161, Train MAE: 0.130344, Val MAE: 0.101754, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.014984, Val Loss: 0.015277, Train MAE: 0.115086, Val MAE: 0.101559, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 39
# INFO:src.pipeline:Fold 6 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.030535
# INFO:src.pipeline:  rmse: 0.174741
# INFO:src.pipeline:  mae: 0.102669
# INFO:src.pipeline:  r2: 0.423832
# INFO:src.pipeline:  mape: 21.587042
# INFO:src.pipeline:  model_rmse_ghi: 44.378398
# INFO:src.pipeline:  nam_rmse_ghi: 171.994205
# INFO:src.pipeline:  model_mae_ghi: 18.351833
# INFO:src.pipeline:  nam_mae_ghi: 119.377076
# INFO:src.pipeline:  model_mape_ghi: 32.541695
# INFO:src.pipeline:  nam_mape_ghi: 405.336845
# INFO:src.pipeline:  model_rmse_csi: 0.174741
# INFO:src.pipeline:  model_mae_csi: 0.102669
# INFO:src.pipeline:  model_mape_csi: 21.587042
# INFO:src.pipeline:  nam_rmse_csi: 1700.885180
# INFO:src.pipeline:  nam_mae_csi: 308.745768
# INFO:src.pipeline:  nam_mape_csi: 76197.389556
# INFO:src.pipeline:  rmse_skill_ghi_pct: 74.197737
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.989726
# INFO:src.pipeline:  mae_skill_ghi_pct: 84.627004
# INFO:src.pipeline:  mae_skill_csi_pct: 99.966746
# INFO:src.pipeline:  mape_skill_ghi_pct: 91.971691
# INFO:src.pipeline:  mape_skill_csi_pct: 99.971670
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 7 ===
# INFO:src.pipeline:Train samples: 189, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021363, Val Loss: 0.018953, Train MAE: 0.142102, Val MAE: 0.138592, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.016118, Val Loss: 0.019119, Train MAE: 0.126633, Val MAE: 0.137716, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.014931, Val Loss: 0.020037, Train MAE: 0.120435, Val MAE: 0.132445, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 36
# INFO:src.pipeline:Fold 7 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.043826
# INFO:src.pipeline:  rmse: 0.209347
# INFO:src.pipeline:  mae: 0.137289
# INFO:src.pipeline:  r2: 0.395888
# INFO:src.pipeline:  mape: 32.857567
# INFO:src.pipeline:  model_rmse_ghi: 47.253216
# INFO:src.pipeline:  nam_rmse_ghi: 88.975472
# INFO:src.pipeline:  model_mae_ghi: 23.646433
# INFO:src.pipeline:  nam_mae_ghi: 57.500647
# INFO:src.pipeline:  model_mape_ghi: 48.821542
# INFO:src.pipeline:  nam_mape_ghi: 721.274585
# INFO:src.pipeline:  model_rmse_csi: 0.209347
# INFO:src.pipeline:  model_mae_csi: 0.137289
# INFO:src.pipeline:  model_mape_csi: 32.857567
# INFO:src.pipeline:  nam_rmse_csi: 29388.587128
# INFO:src.pipeline:  nam_mae_csi: 2977.618492
# INFO:src.pipeline:  nam_mape_csi: 351278.956119
# INFO:src.pipeline:  rmse_skill_ghi_pct: 46.891863
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.999288
# INFO:src.pipeline:  mae_skill_ghi_pct: 58.876232
# INFO:src.pipeline:  mae_skill_csi_pct: 99.995389
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.231213
# INFO:src.pipeline:  mape_skill_csi_pct: 99.990646
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 89.000000
# INFO:src.pipeline:
# === Running Fold 8 ===
# INFO:src.pipeline:Train samples: 220, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.018895, Val Loss: 0.022513, Train MAE: 0.131594, Val MAE: 0.139946, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.015358, Val Loss: 0.022796, Train MAE: 0.115863, Val MAE: 0.126627, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 24
# INFO:src.pipeline:Fold 8 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.046206
# INFO:src.pipeline:  rmse: 0.214955
# INFO:src.pipeline:  mae: 0.127552
# INFO:src.pipeline:  r2: 0.301899
# INFO:src.pipeline:  mape: 27.041540
# INFO:src.pipeline:  model_rmse_ghi: 12.778840
# INFO:src.pipeline:  nam_rmse_ghi: 29.103083
# INFO:src.pipeline:  model_mae_ghi: 7.400631
# INFO:src.pipeline:  nam_mae_ghi: 22.579527
# INFO:src.pipeline:  model_mape_ghi: 14.022447
# INFO:src.pipeline:  nam_mape_ghi: 80.821695
# INFO:src.pipeline:  model_rmse_csi: 0.214955
# INFO:src.pipeline:  model_mae_csi: 0.127552
# INFO:src.pipeline:  model_mape_csi: 27.041540
# INFO:src.pipeline:  nam_rmse_csi: 0.716143
# INFO:src.pipeline:  nam_mae_csi: 0.371663
# INFO:src.pipeline:  nam_mape_csi: 81.764890
# INFO:src.pipeline:  rmse_skill_ghi_pct: 56.091112
# INFO:src.pipeline:  rmse_skill_csi_pct: 69.984324
# INFO:src.pipeline:  mae_skill_ghi_pct: 67.224154
# INFO:src.pipeline:  mae_skill_csi_pct: 65.680822
# INFO:src.pipeline:  mape_skill_ghi_pct: 82.650145
# INFO:src.pipeline:  mape_skill_csi_pct: 66.927687
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 9 ===
# INFO:src.pipeline:Train samples: 250, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.019371, Val Loss: 0.021622, Train MAE: 0.131881, Val MAE: 0.150599, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.015672, Val Loss: 0.022063, Train MAE: 0.119706, Val MAE: 0.150849, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# INFO:src.pipeline:Fold 9 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.050684
# INFO:src.pipeline:  rmse: 0.225132
# INFO:src.pipeline:  mae: 0.169847
# INFO:src.pipeline:  r2: 0.370223
# INFO:src.pipeline:  mape: 34.430485
# INFO:src.pipeline:  model_rmse_ghi: 11.990779
# INFO:src.pipeline:  nam_rmse_ghi: 32.796185
# INFO:src.pipeline:  model_mae_ghi: 8.434621
# INFO:src.pipeline:  nam_mae_ghi: 30.029067
# INFO:src.pipeline:  model_mape_ghi: 33.361763
# INFO:src.pipeline:  nam_mape_ghi: 119.777834
# INFO:src.pipeline:  model_rmse_csi: 0.225132
# INFO:src.pipeline:  model_mae_csi: 0.169847
# INFO:src.pipeline:  model_mape_csi: 34.430485
# INFO:src.pipeline:  nam_rmse_csi: 372.061651
# INFO:src.pipeline:  nam_mae_csi: 75.969811
# INFO:src.pipeline:  nam_mape_csi: 19967.417197
# INFO:src.pipeline:  rmse_skill_ghi_pct: 63.438494
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.939491
# INFO:src.pipeline:  mae_skill_ghi_pct: 71.911811
# INFO:src.pipeline:  mae_skill_csi_pct: 99.776428
# INFO:src.pipeline:  mape_skill_ghi_pct: 72.146964
# INFO:src.pipeline:  mape_skill_csi_pct: 99.827567
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 10 ===
# INFO:src.pipeline:Train samples: 281, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020594, Val Loss: 0.045398, Train MAE: 0.136217, Val MAE: 0.216043, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.016110, Val Loss: 0.038233, Train MAE: 0.118802, Val MAE: 0.205221, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.014179, Val Loss: 0.039915, Train MAE: 0.108083, Val MAE: 0.204970, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# INFO:src.pipeline:Fold 10 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.078776
# INFO:src.pipeline:  rmse: 0.280671
# INFO:src.pipeline:  mae: 0.202374
# INFO:src.pipeline:  r2: 0.368522
# INFO:src.pipeline:  mape: 54.536934
# INFO:src.pipeline:  model_rmse_ghi: 3.781539
# INFO:src.pipeline:  nam_rmse_ghi: 32.120222
# INFO:src.pipeline:  model_mae_ghi: 3.404266
# INFO:src.pipeline:  nam_mae_ghi: 30.741089
# INFO:src.pipeline:  model_mape_ghi: 98.558399
# INFO:src.pipeline:  nam_mape_ghi: 1061.061250
# INFO:src.pipeline:  model_rmse_csi: 0.280671
# INFO:src.pipeline:  model_mae_csi: 0.202374
# INFO:src.pipeline:  model_mape_csi: 54.536934
# INFO:src.pipeline:  nam_rmse_csi: 3.625350
# INFO:src.pipeline:  nam_mae_csi: 3.027441
# INFO:src.pipeline:  nam_mape_csi: 1229.109594
# INFO:src.pipeline:  rmse_skill_ghi_pct: 88.226923
# INFO:src.pipeline:  rmse_skill_csi_pct: 92.258107
# INFO:src.pipeline:  mae_skill_ghi_pct: 88.926006
# INFO:src.pipeline:  mae_skill_csi_pct: 93.315331
# INFO:src.pipeline:  mape_skill_ghi_pct: 90.711337
# INFO:src.pipeline:  mape_skill_csi_pct: 95.562891
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 24.000000
# INFO:src.pipeline:
# === Running Fold 11 ===
# INFO:src.pipeline:Train samples: 311, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020475, Val Loss: 0.041610, Train MAE: 0.142192, Val MAE: 0.227824, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017439, Val Loss: 0.046534, Train MAE: 0.124942, Val MAE: 0.230791, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.014175, Val Loss: 0.052030, Train MAE: 0.112976, Val MAE: 0.242564, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 31
# INFO:src.pipeline:Fold 11 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.110326
# INFO:src.pipeline:  rmse: 0.332153
# INFO:src.pipeline:  mae: 0.247749
# INFO:src.pipeline:  r2: 0.187202
# INFO:src.pipeline:  mape: 117.687813
# INFO:src.pipeline:  model_rmse_ghi: 1.107886
# INFO:src.pipeline:  nam_rmse_ghi: 29.946906
# INFO:src.pipeline:  model_mae_ghi: 0.958533
# INFO:src.pipeline:  nam_mae_ghi: 27.822608
# INFO:src.pipeline:  model_mape_ghi: 53.688037
# INFO:src.pipeline:  nam_mape_ghi: 1340.377721
# INFO:src.pipeline:  model_rmse_csi: 0.332153
# INFO:src.pipeline:  model_mae_csi: 0.247749
# INFO:src.pipeline:  model_mape_csi: 117.687813
# INFO:src.pipeline:  nam_rmse_csi: 4.982339
# INFO:src.pipeline:  nam_mae_csi: 4.351954
# INFO:src.pipeline:  nam_mape_csi: 2454.787116
# INFO:src.pipeline:  rmse_skill_ghi_pct: 96.300498
# INFO:src.pipeline:  rmse_skill_csi_pct: 93.333389
# INFO:src.pipeline:  mae_skill_ghi_pct: 96.554842
# INFO:src.pipeline:  mae_skill_csi_pct: 94.307183
# INFO:src.pipeline:  mape_skill_ghi_pct: 95.994559
# INFO:src.pipeline:  mape_skill_csi_pct: 95.205783
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 11.000000
# INFO:src.pipeline:
# === Running Fold 12 ===
# INFO:src.pipeline:Train samples: 342, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021432, Val Loss: 0.032878, Train MAE: 0.142946, Val MAE: 0.202248, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018654, Val Loss: 0.035906, Train MAE: 0.128189, Val MAE: 0.202351, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015433, Val Loss: 0.041061, Train MAE: 0.118183, Val MAE: 0.211852, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 33
# INFO:src.pipeline:Fold 12 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.091324
# INFO:src.pipeline:  rmse: 0.302198
# INFO:src.pipeline:  mae: 0.223891
# INFO:src.pipeline:  r2: 0.095041
# INFO:src.pipeline:  mape: 41.379883
# INFO:src.pipeline:  model_rmse_ghi: 12.296692
# INFO:src.pipeline:  nam_rmse_ghi: 34.512881
# INFO:src.pipeline:  model_mae_ghi: 8.572801
# INFO:src.pipeline:  nam_mae_ghi: 33.201618
# INFO:src.pipeline:  model_mape_ghi: 46.415441
# INFO:src.pipeline:  nam_mape_ghi: 279.598407
# INFO:src.pipeline:  model_rmse_csi: 0.302198
# INFO:src.pipeline:  model_mae_csi: 0.223891
# INFO:src.pipeline:  model_mape_csi: 41.379883
# INFO:src.pipeline:  nam_rmse_csi: 1.282367
# INFO:src.pipeline:  nam_mae_csi: 1.096885
# INFO:src.pipeline:  nam_mape_csi: 279.598407
# INFO:src.pipeline:  rmse_skill_ghi_pct: 64.370717
# INFO:src.pipeline:  rmse_skill_csi_pct: 76.434349
# INFO:src.pipeline:  mae_skill_ghi_pct: 74.179569
# INFO:src.pipeline:  mae_skill_csi_pct: 79.588456
# INFO:src.pipeline:  mape_skill_ghi_pct: 83.399247
# INFO:src.pipeline:  mape_skill_csi_pct: 85.200244
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 30.000000
# INFO:src.pipeline:
# === Running Fold 13 ===
# INFO:src.pipeline:Train samples: 373, Val samples: 27
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021603, Val Loss: 0.026328, Train MAE: 0.145065, Val MAE: 0.175445, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018540, Val Loss: 0.026376, Train MAE: 0.129786, Val MAE: 0.179211, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015179, Val Loss: 0.032562, Train MAE: 0.117719, Val MAE: 0.184162, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.012397, Val Loss: 0.035159, Train MAE: 0.106535, Val MAE: 0.191045, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 43
# INFO:src.pipeline:Fold 13 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.068759
# INFO:src.pipeline:  rmse: 0.262219
# INFO:src.pipeline:  mae: 0.185755
# INFO:src.pipeline:  r2: 0.428769
# INFO:src.pipeline:  mape: 65.137093
# INFO:src.pipeline:  model_rmse_ghi: 29.969279
# INFO:src.pipeline:  nam_rmse_ghi: 34.915795
# INFO:src.pipeline:  model_mae_ghi: 19.488631
# INFO:src.pipeline:  nam_mae_ghi: 28.073101
# INFO:src.pipeline:  model_mape_ghi: 38.448935
# INFO:src.pipeline:  nam_mape_ghi: 235.612876
# INFO:src.pipeline:  model_rmse_csi: 0.262219
# INFO:src.pipeline:  model_mae_csi: 0.185755
# INFO:src.pipeline:  model_mape_csi: 65.137093
# INFO:src.pipeline:  nam_rmse_csi: 40.391397
# INFO:src.pipeline:  nam_mae_csi: 12.919904
# INFO:src.pipeline:  nam_mape_csi: 13492.524929
# INFO:src.pipeline:  rmse_skill_ghi_pct: 14.166987
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.350804
# INFO:src.pipeline:  mae_skill_ghi_pct: 30.578990
# INFO:src.pipeline:  mae_skill_csi_pct: 98.562260
# INFO:src.pipeline:  mape_skill_ghi_pct: 83.681310
# INFO:src.pipeline:  mape_skill_csi_pct: 99.517236
# INFO:src.pipeline:  n_rows: 378.000000
# INFO:src.pipeline:  n_daylight_rows: 37.000000
# INFO:src.pipeline:
# === Running Fold 14 ===
# INFO:src.pipeline:Train samples: 401, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.023005, Val Loss: 0.019674, Train MAE: 0.150719, Val MAE: 0.148153, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019918, Val Loss: 0.020073, Train MAE: 0.139201, Val MAE: 0.151842, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.017938, Val Loss: 0.022818, Train MAE: 0.129382, Val MAE: 0.167768, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 39
# INFO:src.pipeline:Fold 14 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.100340
# INFO:src.pipeline:  rmse: 0.316766
# INFO:src.pipeline:  mae: 0.235339
# INFO:src.pipeline:  r2: -0.175107
# INFO:src.pipeline:  mape: 31.773537
# INFO:src.pipeline:  model_rmse_ghi: 35.979144
# INFO:src.pipeline:  nam_rmse_ghi: 27.314497
# INFO:src.pipeline:  model_mae_ghi: 24.977572
# INFO:src.pipeline:  nam_mae_ghi: 20.237865
# INFO:src.pipeline:  model_mape_ghi: 29.901445
# INFO:src.pipeline:  nam_mape_ghi: 49.977180
# INFO:src.pipeline:  model_rmse_csi: 0.316766
# INFO:src.pipeline:  model_mae_csi: 0.235339
# INFO:src.pipeline:  model_mape_csi: 31.773537
# INFO:src.pipeline:  nam_rmse_csi: 0.320300
# INFO:src.pipeline:  nam_mae_csi: 0.209284
# INFO:src.pipeline:  nam_mape_csi: 49.977180
# INFO:src.pipeline:  rmse_skill_ghi_pct: -31.721789
# INFO:src.pipeline:  rmse_skill_csi_pct: 1.103403
# INFO:src.pipeline:  mae_skill_ghi_pct: -23.419995
# INFO:src.pipeline:  mae_skill_csi_pct: -12.449926
# INFO:src.pipeline:  mape_skill_ghi_pct: 40.169803
# INFO:src.pipeline:  mape_skill_csi_pct: 36.423910
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 15 ===
# INFO:src.pipeline:Train samples: 432, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.022265, Val Loss: 0.019569, Train MAE: 0.152553, Val MAE: 0.105951, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019332, Val Loss: 0.016307, Train MAE: 0.136823, Val MAE: 0.130893, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015738, Val Loss: 0.017447, Train MAE: 0.122629, Val MAE: 0.109322, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 36
# INFO:src.pipeline:Fold 15 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.032383
# INFO:src.pipeline:  rmse: 0.179952
# INFO:src.pipeline:  mae: 0.112817
# INFO:src.pipeline:  r2: 0.601266
# INFO:src.pipeline:  mape: 27.913315
# INFO:src.pipeline:  model_rmse_ghi: 39.707471
# INFO:src.pipeline:  nam_rmse_ghi: 82.344226
# INFO:src.pipeline:  model_mae_ghi: 24.402866
# INFO:src.pipeline:  nam_mae_ghi: 55.958252
# INFO:src.pipeline:  model_mape_ghi: 24.278655
# INFO:src.pipeline:  nam_mape_ghi: 282.624050
# INFO:src.pipeline:  model_rmse_csi: 0.179952
# INFO:src.pipeline:  model_mae_csi: 0.112817
# INFO:src.pipeline:  model_mape_csi: 27.913315
# INFO:src.pipeline:  nam_rmse_csi: 694.038902
# INFO:src.pipeline:  nam_mae_csi: 112.763228
# INFO:src.pipeline:  nam_mape_csi: 12988.119143
# INFO:src.pipeline:  rmse_skill_ghi_pct: 51.778682
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.974072
# INFO:src.pipeline:  mae_skill_ghi_pct: 56.390944
# INFO:src.pipeline:  mae_skill_csi_pct: 99.899952
# INFO:src.pipeline:  mape_skill_ghi_pct: 91.409558
# INFO:src.pipeline:  mape_skill_csi_pct: 99.785086
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 71.000000
# INFO:src.pipeline:
# === Running Fold 16 ===
# INFO:src.pipeline:Train samples: 462, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021804, Val Loss: 0.020159, Train MAE: 0.148830, Val MAE: 0.136650, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019024, Val Loss: 0.022482, Train MAE: 0.134536, Val MAE: 0.153301, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015527, Val Loss: 0.021052, Train MAE: 0.120911, Val MAE: 0.129712, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 36
# INFO:src.pipeline:Fold 16 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.046355
# INFO:src.pipeline:  rmse: 0.215302
# INFO:src.pipeline:  mae: 0.136335
# INFO:src.pipeline:  r2: 0.251063
# INFO:src.pipeline:  mape: 83.103844
# INFO:src.pipeline:  model_rmse_ghi: 43.884050
# INFO:src.pipeline:  nam_rmse_ghi: 134.580713
# INFO:src.pipeline:  model_mae_ghi: 21.906007
# INFO:src.pipeline:  nam_mae_ghi: 100.844359
# INFO:src.pipeline:  model_mape_ghi: 174.411622
# INFO:src.pipeline:  nam_mape_ghi: 422.612681
# INFO:src.pipeline:  model_rmse_csi: 0.215302
# INFO:src.pipeline:  model_mae_csi: 0.136335
# INFO:src.pipeline:  model_mape_csi: 83.103844
# INFO:src.pipeline:  nam_rmse_csi: 5.061521
# INFO:src.pipeline:  nam_mae_csi: 2.303061
# INFO:src.pipeline:  nam_mape_csi: 422.612681
# INFO:src.pipeline:  rmse_skill_ghi_pct: 67.392021
# INFO:src.pipeline:  rmse_skill_csi_pct: 95.746301
# INFO:src.pipeline:  mae_skill_ghi_pct: 78.277410
# INFO:src.pipeline:  mae_skill_csi_pct: 94.080284
# INFO:src.pipeline:  mape_skill_ghi_pct: 58.730149
# INFO:src.pipeline:  mape_skill_csi_pct: 80.335696
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 17 ===
# INFO:src.pipeline:Train samples: 493, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021125, Val Loss: 0.015217, Train MAE: 0.143084, Val MAE: 0.121266, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019642, Val Loss: 0.010880, Train MAE: 0.136328, Val MAE: 0.094396, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.018098, Val Loss: 0.011675, Train MAE: 0.129951, Val MAE: 0.100685, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.013564, Val Loss: 0.013051, Train MAE: 0.113434, Val MAE: 0.100563, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 40
# INFO:src.pipeline:Fold 17 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.026102
# INFO:src.pipeline:  rmse: 0.161562
# INFO:src.pipeline:  mae: 0.100563
# INFO:src.pipeline:  r2: 0.659202
# INFO:src.pipeline:  mape: 25.201115
# INFO:src.pipeline:  model_rmse_ghi: 41.243069
# INFO:src.pipeline:  nam_rmse_ghi: 168.224025
# INFO:src.pipeline:  model_mae_ghi: 20.678157
# INFO:src.pipeline:  nam_mae_ghi: 131.772201
# INFO:src.pipeline:  model_mape_ghi: 38.765511
# INFO:src.pipeline:  nam_mape_ghi: 245.421946
# INFO:src.pipeline:  model_rmse_csi: 0.161562
# INFO:src.pipeline:  model_mae_csi: 0.100563
# INFO:src.pipeline:  model_mape_csi: 25.201115
# INFO:src.pipeline:  nam_rmse_csi: 1233.440798
# INFO:src.pipeline:  nam_mae_csi: 238.135074
# INFO:src.pipeline:  nam_mape_csi: 50045.008041
# INFO:src.pipeline:  rmse_skill_ghi_pct: 75.483247
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.986901
# INFO:src.pipeline:  mae_skill_ghi_pct: 84.307648
# INFO:src.pipeline:  mae_skill_csi_pct: 99.957770
# INFO:src.pipeline:  mape_skill_ghi_pct: 84.204546
# INFO:src.pipeline:  mape_skill_csi_pct: 99.949643
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 18 ===
# INFO:src.pipeline:Train samples: 523, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021702, Val Loss: 0.016284, Train MAE: 0.147090, Val MAE: 0.106644, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019461, Val Loss: 0.017548, Train MAE: 0.135671, Val MAE: 0.100511, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015292, Val Loss: 0.016500, Train MAE: 0.121265, Val MAE: 0.104109, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# INFO:src.pipeline:Fold 18 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.034212
# INFO:src.pipeline:  rmse: 0.184964
# INFO:src.pipeline:  mae: 0.103630
# INFO:src.pipeline:  r2: 0.446133
# INFO:src.pipeline:  mape: 24.399128
# INFO:src.pipeline:  model_rmse_ghi: 36.939684
# INFO:src.pipeline:  nam_rmse_ghi: 145.080492
# INFO:src.pipeline:  model_mae_ghi: 16.621495
# INFO:src.pipeline:  nam_mae_ghi: 116.494217
# INFO:src.pipeline:  model_mape_ghi: 23.937462
# INFO:src.pipeline:  nam_mape_ghi: 332.422119
# INFO:src.pipeline:  model_rmse_csi: 0.184964
# INFO:src.pipeline:  model_mae_csi: 0.103630
# INFO:src.pipeline:  model_mape_csi: 24.399128
# INFO:src.pipeline:  nam_rmse_csi: 8750.312585
# INFO:src.pipeline:  nam_mae_csi: 898.589462
# INFO:src.pipeline:  nam_mape_csi: 375090.739203
# INFO:src.pipeline:  rmse_skill_ghi_pct: 74.538490
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.997886
# INFO:src.pipeline:  mae_skill_ghi_pct: 85.731914
# INFO:src.pipeline:  mae_skill_csi_pct: 99.988468
# INFO:src.pipeline:  mape_skill_ghi_pct: 92.799077
# INFO:src.pipeline:  mape_skill_csi_pct: 99.993495
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 19 ===
# INFO:src.pipeline:Train samples: 554, Val samples: 28
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021138, Val Loss: 0.009558, Train MAE: 0.142826, Val MAE: 0.105993, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018876, Val Loss: 0.012962, Train MAE: 0.135345, Val MAE: 0.103111, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.014972, Val Loss: 0.013821, Train MAE: 0.117488, Val MAE: 0.102039, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.013257, Val Loss: 0.008336, Train MAE: 0.109303, Val MAE: 0.092073, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.011495, Val Loss: 0.007557, Train MAE: 0.103285, Val MAE: 0.076395, LR: 0.000500
# INFO:src.pipeline:Fold 19 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.015114
# INFO:src.pipeline:  rmse: 0.122937
# INFO:src.pipeline:  mae: 0.076395
# INFO:src.pipeline:  r2: 0.711336
# INFO:src.pipeline:  mape: 11.062781
# INFO:src.pipeline:  model_rmse_ghi: 25.756211
# INFO:src.pipeline:  nam_rmse_ghi: 79.936071
# INFO:src.pipeline:  model_mae_ghi: 14.625608
# INFO:src.pipeline:  nam_mae_ghi: 62.381378
# INFO:src.pipeline:  model_mape_ghi: 17.007582
# INFO:src.pipeline:  nam_mape_ghi: 352.071316
# INFO:src.pipeline:  model_rmse_csi: 0.122937
# INFO:src.pipeline:  model_mae_csi: 0.076395
# INFO:src.pipeline:  model_mape_csi: 11.062781
# INFO:src.pipeline:  nam_rmse_csi: 5332.954517
# INFO:src.pipeline:  nam_mae_csi: 653.905014
# INFO:src.pipeline:  nam_mape_csi: 80875.360650
# INFO:src.pipeline:  rmse_skill_ghi_pct: 67.778988
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.997695
# INFO:src.pipeline:  mae_skill_ghi_pct: 76.554529
# INFO:src.pipeline:  mae_skill_csi_pct: 99.988317
# INFO:src.pipeline:  mape_skill_ghi_pct: 95.169279
# INFO:src.pipeline:  mape_skill_csi_pct: 99.986321
# INFO:src.pipeline:  n_rows: 392.000000
# INFO:src.pipeline:  n_daylight_rows: 83.000000
# INFO:src.pipeline:
# === Running Fold 20 ===
# INFO:src.pipeline:Train samples: 583, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020622, Val Loss: 0.015155, Train MAE: 0.142040, Val MAE: 0.132915, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017325, Val Loss: 0.014527, Train MAE: 0.127341, Val MAE: 0.113508, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.016854, Val Loss: 0.015676, Train MAE: 0.123656, Val MAE: 0.120668, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.013516, Val Loss: 0.021737, Train MAE: 0.113089, Val MAE: 0.127922, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 42
# INFO:src.pipeline:Fold 20 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.044983
# INFO:src.pipeline:  rmse: 0.212091
# INFO:src.pipeline:  mae: 0.130738
# INFO:src.pipeline:  r2: 0.433583
# INFO:src.pipeline:  mape: 23.112007
# INFO:src.pipeline:  model_rmse_ghi: 12.203603
# INFO:src.pipeline:  nam_rmse_ghi: 28.517076
# INFO:src.pipeline:  model_mae_ghi: 8.727865
# INFO:src.pipeline:  nam_mae_ghi: 23.786153
# INFO:src.pipeline:  model_mape_ghi: 20.960087
# INFO:src.pipeline:  nam_mape_ghi: 76.292014
# INFO:src.pipeline:  model_rmse_csi: 0.212091
# INFO:src.pipeline:  model_mae_csi: 0.130738
# INFO:src.pipeline:  model_mape_csi: 23.112007
# INFO:src.pipeline:  nam_rmse_csi: 0.570128
# INFO:src.pipeline:  nam_mae_csi: 0.342846
# INFO:src.pipeline:  nam_mape_csi: 77.457980
# INFO:src.pipeline:  rmse_skill_ghi_pct: 57.205979
# INFO:src.pipeline:  rmse_skill_csi_pct: 62.799372
# INFO:src.pipeline:  mae_skill_ghi_pct: 63.306950
# INFO:src.pipeline:  mae_skill_csi_pct: 61.866789
# INFO:src.pipeline:  mape_skill_ghi_pct: 72.526500
# INFO:src.pipeline:  mape_skill_csi_pct: 70.161877
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 21 ===
# INFO:src.pipeline:Train samples: 613, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.019899, Val Loss: 0.019546, Train MAE: 0.136286, Val MAE: 0.147993, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017701, Val Loss: 0.017722, Train MAE: 0.125772, Val MAE: 0.131292, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015787, Val Loss: 0.019950, Train MAE: 0.120414, Val MAE: 0.132716, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 39
# INFO:src.pipeline:Fold 21 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.038514
# INFO:src.pipeline:  rmse: 0.196250
# INFO:src.pipeline:  mae: 0.129316
# INFO:src.pipeline:  r2: 0.485860
# INFO:src.pipeline:  mape: 21.459904
# INFO:src.pipeline:  model_rmse_ghi: 19.168955
# INFO:src.pipeline:  nam_rmse_ghi: 34.752485
# INFO:src.pipeline:  model_mae_ghi: 11.181076
# INFO:src.pipeline:  nam_mae_ghi: 32.612153
# INFO:src.pipeline:  model_mape_ghi: 28.972588
# INFO:src.pipeline:  nam_mape_ghi: 106.273663
# INFO:src.pipeline:  model_rmse_csi: 0.196250
# INFO:src.pipeline:  model_mae_csi: 0.129316
# INFO:src.pipeline:  model_mape_csi: 21.459904
# INFO:src.pipeline:  nam_rmse_csi: 209.719011
# INFO:src.pipeline:  nam_mae_csi: 47.320725
# INFO:src.pipeline:  nam_mape_csi: 13109.370468
# INFO:src.pipeline:  rmse_skill_ghi_pct: 44.841483
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.906422
# INFO:src.pipeline:  mae_skill_ghi_pct: 65.715003
# INFO:src.pipeline:  mae_skill_csi_pct: 99.726725
# INFO:src.pipeline:  mape_skill_ghi_pct: 72.737754
# INFO:src.pipeline:  mape_skill_csi_pct: 99.836301
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 22 ===
# INFO:src.pipeline:Train samples: 644, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021825, Val Loss: 0.034072, Train MAE: 0.145146, Val MAE: 0.163572, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018340, Val Loss: 0.036761, Train MAE: 0.129956, Val MAE: 0.186188, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 27
# INFO:src.pipeline:Fold 22 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.073695
# INFO:src.pipeline:  rmse: 0.271467
# INFO:src.pipeline:  mae: 0.193714
# INFO:src.pipeline:  r2: 0.213252
# INFO:src.pipeline:  mape: 45.137753
# INFO:src.pipeline:  model_rmse_ghi: 3.699955
# INFO:src.pipeline:  nam_rmse_ghi: 32.161632
# INFO:src.pipeline:  model_mae_ghi: 2.290278
# INFO:src.pipeline:  nam_mae_ghi: 30.497916
# INFO:src.pipeline:  model_mape_ghi: 52.898028
# INFO:src.pipeline:  nam_mape_ghi: 522.430553
# INFO:src.pipeline:  model_rmse_csi: 0.271467
# INFO:src.pipeline:  model_mae_csi: 0.193714
# INFO:src.pipeline:  model_mape_csi: 45.137753
# INFO:src.pipeline:  nam_rmse_csi: 4.082251
# INFO:src.pipeline:  nam_mae_csi: 3.331544
# INFO:src.pipeline:  nam_mape_csi: 869.897528
# INFO:src.pipeline:  rmse_skill_ghi_pct: 88.495749
# INFO:src.pipeline:  rmse_skill_csi_pct: 93.350055
# INFO:src.pipeline:  mae_skill_ghi_pct: 92.490380
# INFO:src.pipeline:  mae_skill_csi_pct: 94.185452
# INFO:src.pipeline:  mape_skill_ghi_pct: 89.874630
# INFO:src.pipeline:  mape_skill_csi_pct: 94.811141
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 24.000000
# INFO:src.pipeline:
# === Running Fold 23 ===
# INFO:src.pipeline:Train samples: 674, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020657, Val Loss: 0.030882, Train MAE: 0.141231, Val MAE: 0.190585, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019411, Val Loss: 0.032811, Train MAE: 0.131744, Val MAE: 0.188594, LR: 0.000500
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015987, Val Loss: 0.035306, Train MAE: 0.120610, Val MAE: 0.198060, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.015114, Val Loss: 0.047193, Train MAE: 0.115934, Val MAE: 0.213573, LR: 0.000250
# INFO:src.engine:Early stopping at epoch 45
# INFO:src.pipeline:Fold 23 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.081604
# INFO:src.pipeline:  rmse: 0.285664
# INFO:src.pipeline:  mae: 0.199061
# INFO:src.pipeline:  r2: 0.285121
# INFO:src.pipeline:  mape: 59.935318
# INFO:src.pipeline:  model_rmse_ghi: 1.372440
# INFO:src.pipeline:  nam_rmse_ghi: 24.819546
# INFO:src.pipeline:  model_mae_ghi: 1.136961
# INFO:src.pipeline:  nam_mae_ghi: 20.876294
# INFO:src.pipeline:  model_mape_ghi: 114.234381
# INFO:src.pipeline:  nam_mape_ghi: 1072.683416
# INFO:src.pipeline:  model_rmse_csi: 0.285664
# INFO:src.pipeline:  model_mae_csi: 0.199061
# INFO:src.pipeline:  model_mape_csi: 59.935318
# INFO:src.pipeline:  nam_rmse_csi: 5.386778
# INFO:src.pipeline:  nam_mae_csi: 4.706144
# INFO:src.pipeline:  nam_mape_csi: 2108.689560
# INFO:src.pipeline:  rmse_skill_ghi_pct: 94.470324
# INFO:src.pipeline:  rmse_skill_csi_pct: 94.696943
# INFO:src.pipeline:  mae_skill_ghi_pct: 94.553819
# INFO:src.pipeline:  mae_skill_csi_pct: 95.770188
# INFO:src.pipeline:  mape_skill_ghi_pct: 89.350597
# INFO:src.pipeline:  mape_skill_csi_pct: 97.157698
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 10.000000
# INFO:src.pipeline:
# === Running Fold 24 ===
# INFO:src.pipeline:Train samples: 703, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020784, Val Loss: 0.044898, Train MAE: 0.140838, Val MAE: 0.231938, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018285, Val Loss: 0.045913, Train MAE: 0.130717, Val MAE: 0.231111, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015733, Val Loss: 0.044661, Train MAE: 0.121640, Val MAE: 0.226715, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.011846, Val Loss: 0.050803, Train MAE: 0.103760, Val MAE: 0.228469, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 42
# INFO:src.pipeline:Fold 24 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.099410
# INFO:src.pipeline:  rmse: 0.315293
# INFO:src.pipeline:  mae: 0.226194
# INFO:src.pipeline:  r2: 0.274019
# INFO:src.pipeline:  mape: 75.985344
# INFO:src.pipeline:  model_rmse_ghi: 7.408062
# INFO:src.pipeline:  nam_rmse_ghi: nan
# INFO:src.pipeline:  model_mae_ghi: 5.251617
# INFO:src.pipeline:  nam_mae_ghi: nan
# INFO:src.pipeline:  model_mape_ghi: 42.947995
# INFO:src.pipeline:  nam_mape_ghi: nan
# INFO:src.pipeline:  model_rmse_csi: 0.315293
# INFO:src.pipeline:  model_mae_csi: 0.226194
# INFO:src.pipeline:  model_mape_csi: 75.985344
# INFO:src.pipeline:  nam_rmse_csi: 29.010329
# INFO:src.pipeline:  nam_mae_csi: 6.930307
# INFO:src.pipeline:  nam_mape_csi: 6018.644154
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 98.913171
# INFO:src.pipeline:  mae_skill_ghi_pct: nan
# INFO:src.pipeline:  mae_skill_csi_pct: 96.736157
# INFO:src.pipeline:  mape_skill_ghi_pct: nan
# INFO:src.pipeline:  mape_skill_csi_pct: 98.737501
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 30.000000
# INFO:src.pipeline:
# === Running Fold 25 ===
# INFO:src.pipeline:Train samples: 734, Val samples: 28
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021618, Val Loss: 0.021100, Train MAE: 0.144937, Val MAE: 0.161074, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019295, Val Loss: 0.023340, Train MAE: 0.135628, Val MAE: 0.160959, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.016962, Val Loss: 0.016916, Train MAE: 0.124840, Val MAE: 0.135601, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.013737, Val Loss: 0.023992, Train MAE: 0.112269, Val MAE: 0.163384, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.010209, Val Loss: 0.019871, Train MAE: 0.097278, Val MAE: 0.147136, LR: 0.000500
# INFO:src.pipeline:Fold 25 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.039742
# INFO:src.pipeline:  rmse: 0.199353
# INFO:src.pipeline:  mae: 0.147136
# INFO:src.pipeline:  r2: 0.512125
# INFO:src.pipeline:  mape: 23.251703
# INFO:src.pipeline:  model_rmse_ghi: 23.686613
# INFO:src.pipeline:  nam_rmse_ghi: nan
# INFO:src.pipeline:  model_mae_ghi: 16.363960
# INFO:src.pipeline:  nam_mae_ghi: nan
# INFO:src.pipeline:  model_mape_ghi: 26.368555
# INFO:src.pipeline:  nam_mape_ghi: nan
# INFO:src.pipeline:  model_rmse_csi: 0.199354
# INFO:src.pipeline:  model_mae_csi: 0.147136
# INFO:src.pipeline:  model_mape_csi: 23.251703
# INFO:src.pipeline:  nam_rmse_csi: 327.138316
# INFO:src.pipeline:  nam_mae_csi: 67.335748
# INFO:src.pipeline:  nam_mape_csi: 15615.030707
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.939061
# INFO:src.pipeline:  mae_skill_ghi_pct: nan
# INFO:src.pipeline:  mae_skill_csi_pct: 99.781489
# INFO:src.pipeline:  mape_skill_ghi_pct: nan
# INFO:src.pipeline:  mape_skill_csi_pct: 99.851094
# INFO:src.pipeline:  n_rows: 392.000000
# INFO:src.pipeline:  n_daylight_rows: 39.000000
# INFO:src.pipeline:
# === Running Fold 26 ===
# INFO:src.pipeline:Train samples: 763, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021292, Val Loss: 0.031704, Train MAE: 0.143367, Val MAE: 0.180538, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018855, Val Loss: 0.035926, Train MAE: 0.132902, Val MAE: 0.193759, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 27
# INFO:src.pipeline:Fold 26 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.076304
# INFO:src.pipeline:  rmse: 0.276231
# INFO:src.pipeline:  mae: 0.199112
# INFO:src.pipeline:  r2: 0.454613
# INFO:src.pipeline:  mape: 108.257057
# INFO:src.pipeline:  model_rmse_ghi: 28.066153
# INFO:src.pipeline:  nam_rmse_ghi: 31.422142
# INFO:src.pipeline:  model_mae_ghi: 19.352503
# INFO:src.pipeline:  nam_mae_ghi: 22.106956
# INFO:src.pipeline:  model_mape_ghi: 127.000955
# INFO:src.pipeline:  nam_mape_ghi: 139.671723
# INFO:src.pipeline:  model_rmse_csi: 0.276231
# INFO:src.pipeline:  model_mae_csi: 0.199112
# INFO:src.pipeline:  model_mape_csi: 108.257057
# INFO:src.pipeline:  nam_rmse_csi: 0.292047
# INFO:src.pipeline:  nam_mae_csi: 0.183863
# INFO:src.pipeline:  nam_mape_csi: 139.671723
# INFO:src.pipeline:  rmse_skill_ghi_pct: 10.680331
# INFO:src.pipeline:  rmse_skill_csi_pct: 5.415595
# INFO:src.pipeline:  mae_skill_ghi_pct: 12.459667
# INFO:src.pipeline:  mae_skill_csi_pct: -8.293691
# INFO:src.pipeline:  mape_skill_ghi_pct: 9.071821
# INFO:src.pipeline:  mape_skill_csi_pct: 22.491787
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 27 ===
# INFO:src.pipeline:Train samples: 794, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.022551, Val Loss: 0.025374, Train MAE: 0.149098, Val MAE: 0.145914, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019788, Val Loss: 0.025688, Train MAE: 0.136040, Val MAE: 0.148446, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.016765, Val Loss: 0.024784, Train MAE: 0.125774, Val MAE: 0.137997, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 31
# INFO:src.pipeline:Fold 27 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.049017
# INFO:src.pipeline:  rmse: 0.221399
# INFO:src.pipeline:  mae: 0.144893
# INFO:src.pipeline:  r2: 0.507234
# INFO:src.pipeline:  mape: 46.440170
# INFO:src.pipeline:  model_rmse_ghi: 35.597317
# INFO:src.pipeline:  nam_rmse_ghi: 85.922416
# INFO:src.pipeline:  model_mae_ghi: 22.475892
# INFO:src.pipeline:  nam_mae_ghi: 58.849218
# INFO:src.pipeline:  model_mape_ghi: 46.117500
# INFO:src.pipeline:  nam_mape_ghi: 610.394847
# INFO:src.pipeline:  model_rmse_csi: 0.221399
# INFO:src.pipeline:  model_mae_csi: 0.144893
# INFO:src.pipeline:  model_mape_csi: 46.440170
# INFO:src.pipeline:  nam_rmse_csi: 961.257659
# INFO:src.pipeline:  nam_mae_csi: 147.993450
# INFO:src.pipeline:  nam_mape_csi: 16902.462358
# INFO:src.pipeline:  rmse_skill_ghi_pct: 58.570396
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.976968
# INFO:src.pipeline:  mae_skill_ghi_pct: 61.807662
# INFO:src.pipeline:  mae_skill_csi_pct: 99.902095
# INFO:src.pipeline:  mape_skill_ghi_pct: 92.444645
# INFO:src.pipeline:  mape_skill_csi_pct: 99.725246
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 73.000000
# INFO:src.pipeline:
# === Running Fold 28 ===
# INFO:src.pipeline:Train samples: 824, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.022395, Val Loss: 0.023476, Train MAE: 0.148234, Val MAE: 0.151854, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019681, Val Loss: 0.029226, Train MAE: 0.137892, Val MAE: 0.160830, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.016464, Val Loss: 0.028275, Train MAE: 0.124425, Val MAE: 0.150230, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 38
# INFO:src.pipeline:Fold 28 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.058866
# INFO:src.pipeline:  rmse: 0.242624
# INFO:src.pipeline:  mae: 0.154560
# INFO:src.pipeline:  r2: 0.294145
# INFO:src.pipeline:  mape: 44.045444
# INFO:src.pipeline:  model_rmse_ghi: 34.705422
# INFO:src.pipeline:  nam_rmse_ghi: 133.168581
# INFO:src.pipeline:  model_mae_ghi: 19.195501
# INFO:src.pipeline:  nam_mae_ghi: 98.274114
# INFO:src.pipeline:  model_mape_ghi: 53.919846
# INFO:src.pipeline:  nam_mape_ghi: 406.928246
# INFO:src.pipeline:  model_rmse_csi: 0.242624
# INFO:src.pipeline:  model_mae_csi: 0.154560
# INFO:src.pipeline:  model_mape_csi: 44.045444
# INFO:src.pipeline:  nam_rmse_csi: 4.165013
# INFO:src.pipeline:  nam_mae_csi: 1.947558
# INFO:src.pipeline:  nam_mape_csi: 406.928246
# INFO:src.pipeline:  rmse_skill_ghi_pct: 73.938731
# INFO:src.pipeline:  rmse_skill_csi_pct: 94.174713
# INFO:src.pipeline:  mae_skill_ghi_pct: 80.467388
# INFO:src.pipeline:  mae_skill_csi_pct: 92.063889
# INFO:src.pipeline:  mape_skill_ghi_pct: 86.749544
# INFO:src.pipeline:  mape_skill_csi_pct: 89.176115
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 29 ===
# INFO:src.pipeline:Train samples: 855, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.022079, Val Loss: 0.011658, Train MAE: 0.148906, Val MAE: 0.119049, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019972, Val Loss: 0.009668, Train MAE: 0.138801, Val MAE: 0.108259, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.017036, Val Loss: 0.011687, Train MAE: 0.126074, Val MAE: 0.110446, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.014113, Val Loss: 0.008491, Train MAE: 0.114509, Val MAE: 0.096337, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.010750, Val Loss: 0.007470, Train MAE: 0.101378, Val MAE: 0.079662, LR: 0.000500
# INFO:src.pipeline:Fold 29 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.014939
# INFO:src.pipeline:  rmse: 0.122227
# INFO:src.pipeline:  mae: 0.079662
# INFO:src.pipeline:  r2: 0.744201
# INFO:src.pipeline:  mape: 12.372052
# INFO:src.pipeline:  model_rmse_ghi: 24.274014
# INFO:src.pipeline:  nam_rmse_ghi: 166.941379
# INFO:src.pipeline:  model_mae_ghi: 16.839685
# INFO:src.pipeline:  nam_mae_ghi: 130.514742
# INFO:src.pipeline:  model_mape_ghi: 16.467192
# INFO:src.pipeline:  nam_mape_ghi: 202.740561
# INFO:src.pipeline:  model_rmse_csi: 0.122227
# INFO:src.pipeline:  model_mae_csi: 0.079662
# INFO:src.pipeline:  model_mape_csi: 12.372052
# INFO:src.pipeline:  nam_rmse_csi: 1742.136105
# INFO:src.pipeline:  nam_mae_csi: 314.197475
# INFO:src.pipeline:  nam_mape_csi: 159449.823308
# INFO:src.pipeline:  rmse_skill_ghi_pct: 85.459559
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.992984
# INFO:src.pipeline:  mae_skill_ghi_pct: 87.097484
# INFO:src.pipeline:  mae_skill_csi_pct: 99.974646
# INFO:src.pipeline:  mape_skill_ghi_pct: 91.877702
# INFO:src.pipeline:  mape_skill_csi_pct: 99.992241
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 30 ===
# INFO:src.pipeline:Train samples: 885, Val samples: 27
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020969, Val Loss: 0.001244, Train MAE: 0.142699, Val MAE: 0.042272, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019072, Val Loss: 0.001543, Train MAE: 0.134602, Val MAE: 0.049354, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015212, Val Loss: 0.000853, Train MAE: 0.119402, Val MAE: 0.033710, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.012333, Val Loss: 0.001032, Train MAE: 0.108173, Val MAE: 0.034930, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.011134, Val Loss: 0.001266, Train MAE: 0.101607, Val MAE: 0.044682, LR: 0.000250
# INFO:src.pipeline:Fold 30 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.002533
# INFO:src.pipeline:  rmse: 0.050327
# INFO:src.pipeline:  mae: 0.044682
# INFO:src.pipeline:  r2: 0.932667
# INFO:src.pipeline:  mape: 4.990386
# INFO:src.pipeline:  model_rmse_ghi: 9.567741
# INFO:src.pipeline:  nam_rmse_ghi: 158.851647
# INFO:src.pipeline:  model_mae_ghi: 6.521037
# INFO:src.pipeline:  nam_mae_ghi: 128.009580
# INFO:src.pipeline:  model_mape_ghi: 5.271530
# INFO:src.pipeline:  nam_mape_ghi: 368.703288
# INFO:src.pipeline:  model_rmse_csi: 0.050327
# INFO:src.pipeline:  model_mae_csi: 0.044682
# INFO:src.pipeline:  model_mape_csi: 4.990386
# INFO:src.pipeline:  nam_rmse_csi: 2324.382922
# INFO:src.pipeline:  nam_mae_csi: 343.365065
# INFO:src.pipeline:  nam_mape_csi: 68595.502221
# INFO:src.pipeline:  rmse_skill_ghi_pct: 93.976933
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.997835
# INFO:src.pipeline:  mae_skill_ghi_pct: 94.905821
# INFO:src.pipeline:  mae_skill_csi_pct: 99.986987
# INFO:src.pipeline:  mape_skill_ghi_pct: 98.570251
# INFO:src.pipeline:  mape_skill_csi_pct: 99.992725
# INFO:src.pipeline:  n_rows: 378.000000
# INFO:src.pipeline:  n_daylight_rows: 108.000000
# INFO:src.pipeline:
# === Running Fold 31 ===
# INFO:src.pipeline:Train samples: 913, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020884, Val Loss: 0.004260, Train MAE: 0.139389, Val MAE: 0.048778, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018792, Val Loss: 0.004718, Train MAE: 0.131192, Val MAE: 0.068174, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015999, Val Loss: 0.004611, Train MAE: 0.120115, Val MAE: 0.062784, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.013271, Val Loss: 0.004100, Train MAE: 0.110385, Val MAE: 0.046816, LR: 0.000250
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.012238, Val Loss: 0.004234, Train MAE: 0.105814, Val MAE: 0.055118, LR: 0.000250
# INFO:src.pipeline:Fold 31 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.008469
# INFO:src.pipeline:  rmse: 0.092025
# INFO:src.pipeline:  mae: 0.055118
# INFO:src.pipeline:  r2: 0.798293
# INFO:src.pipeline:  mape: 7.150607
# INFO:src.pipeline:  model_rmse_ghi: 18.197380
# INFO:src.pipeline:  nam_rmse_ghi: 89.471777
# INFO:src.pipeline:  model_mae_ghi: 9.023945
# INFO:src.pipeline:  nam_mae_ghi: 65.181749
# INFO:src.pipeline:  model_mape_ghi: 7.816552
# INFO:src.pipeline:  nam_mape_ghi: 330.764257
# INFO:src.pipeline:  model_rmse_csi: 0.092025
# INFO:src.pipeline:  model_mae_csi: 0.055118
# INFO:src.pipeline:  model_mape_csi: 7.150607
# INFO:src.pipeline:  nam_rmse_csi: 2868.743811
# INFO:src.pipeline:  nam_mae_csi: 420.722030
# INFO:src.pipeline:  nam_mape_csi: 47629.901026
# INFO:src.pipeline:  rmse_skill_ghi_pct: 79.661318
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.996792
# INFO:src.pipeline:  mae_skill_ghi_pct: 86.155717
# INFO:src.pipeline:  mae_skill_csi_pct: 99.986899
# INFO:src.pipeline:  mape_skill_ghi_pct: 97.636821
# INFO:src.pipeline:  mape_skill_csi_pct: 99.984987
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 88.000000
# INFO:src.pipeline:
# === Running Fold 32 ===
# INFO:src.pipeline:Train samples: 944, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020239, Val Loss: 0.006064, Train MAE: 0.139110, Val MAE: 0.072523, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.019053, Val Loss: 0.005183, Train MAE: 0.131988, Val MAE: 0.058077, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.016302, Val Loss: 0.005108, Train MAE: 0.122886, Val MAE: 0.059534, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.012607, Val Loss: 0.004334, Train MAE: 0.106510, Val MAE: 0.052101, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.010650, Val Loss: 0.010530, Train MAE: 0.097667, Val MAE: 0.090478, LR: 0.001000
# INFO:src.pipeline:Fold 32 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.021059
# INFO:src.pipeline:  rmse: 0.145117
# INFO:src.pipeline:  mae: 0.090478
# INFO:src.pipeline:  r2: 0.542117
# INFO:src.pipeline:  mape: 9.803397
# INFO:src.pipeline:  model_rmse_ghi: 21.142451
# INFO:src.pipeline:  nam_rmse_ghi: 20.938126
# INFO:src.pipeline:  model_mae_ghi: 9.066451
# INFO:src.pipeline:  nam_mae_ghi: 16.693148
# INFO:src.pipeline:  model_mape_ghi: 6.895260
# INFO:src.pipeline:  nam_mape_ghi: 67.489418
# INFO:src.pipeline:  model_rmse_csi: 0.145117
# INFO:src.pipeline:  model_mae_csi: 0.090478
# INFO:src.pipeline:  model_mape_csi: 9.803397
# INFO:src.pipeline:  nam_rmse_csi: 0.817794
# INFO:src.pipeline:  nam_mae_csi: 0.380120
# INFO:src.pipeline:  nam_mape_csi: 68.573104
# INFO:src.pipeline:  rmse_skill_ghi_pct: -0.975851
# INFO:src.pipeline:  rmse_skill_csi_pct: 82.255037
# INFO:src.pipeline:  mae_skill_ghi_pct: 45.687589
# INFO:src.pipeline:  mae_skill_csi_pct: 76.197421
# INFO:src.pipeline:  mape_skill_ghi_pct: 89.783199
# INFO:src.pipeline:  mape_skill_csi_pct: 85.703728
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 33 ===
# INFO:src.pipeline:Train samples: 974, Val samples: 30
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020092, Val Loss: 0.039202, Train MAE: 0.136840, Val MAE: 0.189253, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017861, Val Loss: 0.041459, Train MAE: 0.125898, Val MAE: 0.188431, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.014757, Val Loss: 0.044351, Train MAE: 0.114450, Val MAE: 0.191521, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Fold 33 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.096772
# INFO:src.pipeline:  rmse: 0.311081
# INFO:src.pipeline:  mae: 0.191201
# INFO:src.pipeline:  r2: 0.263596
# INFO:src.pipeline:  mape: 85.089630
# INFO:src.pipeline:  model_rmse_ghi: 11.245812
# INFO:src.pipeline:  nam_rmse_ghi: 33.710817
# INFO:src.pipeline:  model_mae_ghi: 7.727814
# INFO:src.pipeline:  nam_mae_ghi: 28.381508
# INFO:src.pipeline:  model_mape_ghi: 45.084332
# INFO:src.pipeline:  nam_mape_ghi: 147.636336
# INFO:src.pipeline:  model_rmse_csi: 0.311081
# INFO:src.pipeline:  model_mae_csi: 0.191201
# INFO:src.pipeline:  model_mape_csi: 85.089630
# INFO:src.pipeline:  nam_rmse_csi: 141.727556
# INFO:src.pipeline:  nam_mae_csi: 34.996511
# INFO:src.pipeline:  nam_mape_csi: 9581.218096
# INFO:src.pipeline:  rmse_skill_ghi_pct: 66.640345
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.780508
# INFO:src.pipeline:  mae_skill_ghi_pct: 72.771660
# INFO:src.pipeline:  mae_skill_csi_pct: 99.453656
# INFO:src.pipeline:  mape_skill_ghi_pct: 69.462577
# INFO:src.pipeline:  mape_skill_csi_pct: 99.111912
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 34 ===
# INFO:src.pipeline:Train samples: 1005, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020450, Val Loss: 0.031032, Train MAE: 0.137089, Val MAE: 0.195638, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018498, Val Loss: 0.032258, Train MAE: 0.130619, Val MAE: 0.201453, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# INFO:src.pipeline:Fold 34 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.083690
# INFO:src.pipeline:  rmse: 0.289293
# INFO:src.pipeline:  mae: 0.226429
# INFO:src.pipeline:  r2: 0.223868
# INFO:src.pipeline:  mape: 44.013344
# INFO:src.pipeline:  model_rmse_ghi: 2.035825
# INFO:src.pipeline:  nam_rmse_ghi: 31.695118
# INFO:src.pipeline:  model_mae_ghi: 1.748464
# INFO:src.pipeline:  nam_mae_ghi: 29.942103
# INFO:src.pipeline:  model_mape_ghi: 53.962752
# INFO:src.pipeline:  nam_mape_ghi: 760.523498
# INFO:src.pipeline:  model_rmse_csi: 0.289293
# INFO:src.pipeline:  model_mae_csi: 0.226429
# INFO:src.pipeline:  model_mape_csi: 44.013344
# INFO:src.pipeline:  nam_rmse_csi: 3.844745
# INFO:src.pipeline:  nam_mae_csi: 3.126345
# INFO:src.pipeline:  nam_mape_csi: 986.974761
# INFO:src.pipeline:  rmse_skill_ghi_pct: 93.576851
# INFO:src.pipeline:  rmse_skill_csi_pct: 92.475626
# INFO:src.pipeline:  mae_skill_ghi_pct: 94.160518
# INFO:src.pipeline:  mae_skill_csi_pct: 92.757387
# INFO:src.pipeline:  mape_skill_ghi_pct: 92.904525
# INFO:src.pipeline:  mape_skill_csi_pct: 95.540581
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 23.000000
# INFO:src.pipeline:
# === Running Fold 35 ===
# INFO:src.pipeline:Train samples: 1035, Val samples: 29
# INFO:src.pipeline:Model parameters: 242,062
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020349, Val Loss: 0.028831, Train MAE: 0.137913, Val MAE: 0.183059, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017843, Val Loss: 0.029874, Train MAE: 0.126947, Val MAE: 0.178179, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# INFO:src.pipeline:Fold 35 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.067102
# INFO:src.pipeline:  rmse: 0.259040
# INFO:src.pipeline:  mae: 0.185879
# INFO:src.pipeline:  r2: 0.444969
# INFO:src.pipeline:  mape: 80.845352
# INFO:src.pipeline:  model_rmse_ghi: 0.970636
# INFO:src.pipeline:  nam_rmse_ghi: 30.345306
# INFO:src.pipeline:  model_mae_ghi: 0.721003
# INFO:src.pipeline:  nam_mae_ghi: 29.192504
# INFO:src.pipeline:  model_mape_ghi: 44.033555
# INFO:src.pipeline:  nam_mape_ghi: 1053.923847
# INFO:src.pipeline:  model_rmse_csi: 0.259040
# INFO:src.pipeline:  model_mae_csi: 0.185879
# INFO:src.pipeline:  model_mape_csi: 80.845352
# INFO:src.pipeline:  nam_rmse_csi: 4216.288381
# INFO:src.pipeline:  nam_mae_csi: 902.986886
# INFO:src.pipeline:  nam_mape_csi: 334509.545063
# INFO:src.pipeline:  rmse_skill_ghi_pct: 96.801365
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.993856
# INFO:src.pipeline:  mae_skill_ghi_pct: 97.530177
# INFO:src.pipeline:  mae_skill_csi_pct: 99.979415
# INFO:src.pipeline:  mape_skill_ghi_pct: 95.821942
# INFO:src.pipeline:  mape_skill_csi_pct: 99.975832
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 11.000000
# INFO:src.pipeline:
# === Experiment Summary ===
# INFO:src.pipeline:Average Validation Metrics:
# INFO:src.pipeline:  mse: 0.059696 ± 0.046145
# INFO:src.pipeline:  rmse: 0.229097 ± 0.084917
# INFO:src.pipeline:  mae: 0.160579 ± 0.068064
# INFO:src.pipeline:  r2: 0.375930 ± 0.296049
# INFO:src.pipeline:  mape: 43.431514 ± 30.054156
# INFO:src.pipeline:  model_rmse_ghi: 24.359547 ± 16.064997
# INFO:src.pipeline:  nam_rmse_ghi: nan ± nan
# INFO:src.pipeline:  model_mae_ghi: 14.853721 ± 9.878624
# INFO:src.pipeline:  nam_mae_ghi: nan ± nan
# INFO:src.pipeline:  model_mape_ghi: 46.812850 ± 37.294485
# INFO:src.pipeline:  nam_mape_ghi: nan ± nan
# INFO:src.pipeline:  model_rmse_csi: 0.229097 ± 0.084917
# INFO:src.pipeline:  model_mae_csi: 0.160579 ± 0.068064
# INFO:src.pipeline:  model_mape_csi: 43.431514 ± 30.054156
# INFO:src.pipeline:  nam_rmse_csi: 1899.888090 ± 5082.770758
# INFO:src.pipeline:  nam_mae_csi: 243.899171 ± 530.892522
# INFO:src.pipeline:  nam_mape_csi: 51546.548405 ± 98706.806975
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 87.682204 ± 25.721407
# INFO:src.pipeline:  mae_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  mae_skill_csi_pct: 85.682950 ± 30.549785
# INFO:src.pipeline:  mape_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  mape_skill_csi_pct: 89.423512 ± 20.589807
# INFO:src.pipeline:  n_rows: 404.800000 ± 33.023628
# INFO:src.pipeline:  n_daylight_rows: 64.057143 ± 37.604668

# %% [markdown]
# -----
#
# ### EXP 02

# %%
df_phase2.head()
# Out:
#                            solar_zenith  time_gap_hours  time_gap_norm  \
# measurement_time
# 2014-01-04 00:00:00+00:00     86.467556        0.016667       0.000694
# 2014-01-04 01:00:00+00:00     96.742105        0.016667       0.000694
# 2014-01-04 02:00:00+00:00    107.755671        0.016667       0.000694
# 2014-01-04 03:00:00+00:00    119.225607        0.016667       0.000694
# 2014-01-04 14:00:00+00:00    100.295605        0.166667       0.006944
#
#                            day_boundary_flag  hour_progression  absolute_hour  \
# measurement_time
# 2014-01-04 00:00:00+00:00           0.016667          0.491667      34.491667
# 2014-01-04 01:00:00+00:00           0.000000          1.491667      35.491667
# 2014-01-04 02:00:00+00:00           0.000000          2.491667      36.491667
# 2014-01-04 03:00:00+00:00           0.000000          3.491667      37.491667
# 2014-01-04 14:00:00+00:00           0.000000         14.491667      48.491667
#
#                             CSI_ghi   CSI_dni  season_flag  hour_sin  \
# measurement_time
# 2014-01-04 00:00:00+00:00  0.562184  0.429632            2  0.000000
# 2014-01-04 01:00:00+00:00  0.689747  0.583705            2  0.258819
# 2014-01-04 02:00:00+00:00  0.817310  0.737779            2  0.500000
# 2014-01-04 03:00:00+00:00  0.944874  0.891853            2  0.707107
# 2014-01-04 14:00:00+00:00  1.072437  1.045926            2 -0.500000
#
#                            hour_cos  month_sin  month_cos
# measurement_time
# 2014-01-04 00:00:00+00:00  1.000000        0.5   0.866025
# 2014-01-04 01:00:00+00:00  0.965926        0.5   0.866025
# 2014-01-04 02:00:00+00:00  0.866025        0.5   0.866025
# 2014-01-04 03:00:00+00:00  0.707107        0.5   0.866025
# 2014-01-04 14:00:00+00:00 -0.866025        0.5   0.866025

# %%
# Controlling the selected features example
selected_columns = ['solar_zenith',
       'hour_progression', 'absolute_hour', 'CSI_ghi',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos']

TARGET_COL = 'CSI_ghi'
print("\n--- Step 2: Building model arrays (X, Y) ---")
fixed_df = to_fixedgrid_multiindex(df_phase2, timestamp_col="measurement_time", expected_T=None)  # or set T
# Zero-impute everything (features + target)
ph2_X, ph2_Y, ph2_labels_list = build_model_arrays(
        fixed_df,
        feature_cols=selected_columns,  # must include your chosen inputs
        target_col=TARGET_COL,          # target must be present in columns
        history_days=7,
        horizon_days=1,
    )
# Out:
# --- Step 2: Building model arrays (X, Y) ---

# %%
ph2_X.shape, ph2_Y.shape
# Out:
# ((1064, 7, 14, 9), (1064, 1, 14))

# %%
import pandas as pd
from src.utils import DataManager
from src.pipeline import SolarForecastingPipeline


TARGET_COL = 'CSI_ghi'
feature_cols = [c for c in df_phase2.columns.tolist() if c != TARGET_COL]

data_manager = DataManager()
data_manager.save_arrays(
    ph2_X, ph2_Y,
    pd.DataFrame(index=pd.to_datetime(ph2_labels_list, utc=True)),
    filename_prefix='phas2_data',
    feature_cols=feature_cols,
    target_col=TARGET_COL,
    metadata={
        "input_csv": "data/processed/dayTime_NAM_dayahead_features_processed.csv",
        "timestamp_col": "measurement_time",
        "feature_set": feature_cols,     # for traceability
        "history_days": 7,
        "horizon_days": 1,
        "k_bins": None,
    }
)



LSTM_CONFIG = {
    "experiment_name": "phas2_exp_test",
    "model_type": "LSTM",
    "model_config": {
        "hidden_size": 128,
        "num_layers": 2,
        "dropout": 0.2,
        "bidirectional": True,
    },
    "data_prefix": "phas2_data",
    "splits_file": "exp-001/exp-001rolling_origin_splits.json",
    "feature_cols": feature_cols,
    "feature_selection": feature_cols,
    "target_col": TARGET_COL,
    "batch_size": 32,
    "num_epochs": 50,
    "learning_rate": 0.001,
    "early_stopping_patience": 20,
    "max_folds": 35,
}


pipeline = SolarForecastingPipeline(LSTM_CONFIG)
_, summary = pipeline.run()
# Out:
# INFO:src.utils:Saved arrays to data/phas2_data_*.npy
# INFO:src.utils:X shape: (1064, 7, 14, 9), Y shape: (1064, 1, 14)
# INFO:src.pipeline:Loading data...
# INFO:src.utils:Loaded arrays from data/phas2_data_*.npy
# INFO:src.utils:X shape: (1064, 7, 14, 9), Y shape: (1064, 1, 14)
# INFO:src.pipeline:Reference dataframe prepared for NAM comparison (15162 rows).
# INFO:src.utils:Loaded 35 folds from exp-001/exp-001rolling_origin_splits.json
# INFO:src.pipeline:
# === Running Fold 1 ===
# INFO:src.pipeline:Train samples: 19, Val samples: 16
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.052913, Val Loss: 0.197582, Train MAE: 0.145659, Val MAE: 0.375049, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.032827, Val Loss: 0.643124, Train MAE: 0.120945, Val MAE: 0.648740, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 26
# INFO:src.pipeline:Fold 1 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.592511
# INFO:src.pipeline:  rmse: 0.769748
# INFO:src.pipeline:  mae: 0.593655
# INFO:src.pipeline:  r2: -2.975791
# INFO:src.pipeline:  mape: 123.364006
# INFO:src.pipeline:  model_rmse_ghi: 103.254215
# INFO:src.pipeline:  nam_rmse_ghi: 47.325744
# INFO:src.pipeline:  model_mae_ghi: 70.207410
# INFO:src.pipeline:  nam_mae_ghi: 39.566995
# INFO:src.pipeline:  model_mape_ghi: 124.881805
# INFO:src.pipeline:  nam_mape_ghi: 337.824906
# INFO:src.pipeline:  model_rmse_csi: 0.769748
# INFO:src.pipeline:  model_mae_csi: 0.593655
# INFO:src.pipeline:  model_mape_csi: 123.364006
# INFO:src.pipeline:  nam_rmse_csi: 59.491574
# INFO:src.pipeline:  nam_mae_csi: 17.255400
# INFO:src.pipeline:  nam_mape_csi: 8727.254750
# INFO:src.pipeline:  rmse_skill_ghi_pct: -118.177692
# INFO:src.pipeline:  rmse_skill_csi_pct: 98.706123
# INFO:src.pipeline:  mae_skill_ghi_pct: -77.439329
# INFO:src.pipeline:  mae_skill_csi_pct: 96.559598
# INFO:src.pipeline:  mape_skill_ghi_pct: 63.033571
# INFO:src.pipeline:  mape_skill_csi_pct: 98.586451
# INFO:src.pipeline:  n_rows: 224.000000
# INFO:src.pipeline:  n_daylight_rows: 25.000000
# INFO:src.pipeline:
# === Running Fold 2 ===
# INFO:src.pipeline:Train samples: 36, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.081409, Val Loss: 0.095379, Train MAE: 0.233056, Val MAE: 0.262816, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.049163, Val Loss: 0.079201, Train MAE: 0.174496, Val MAE: 0.228570, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.033195, Val Loss: 0.073383, Train MAE: 0.138705, Val MAE: 0.183959, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.030724, Val Loss: 0.081613, Train MAE: 0.120146, Val MAE: 0.192311, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 46
# INFO:src.pipeline:Fold 2 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.071837
# INFO:src.pipeline:  rmse: 0.268025
# INFO:src.pipeline:  mae: 0.197934
# INFO:src.pipeline:  r2: 0.371225
# INFO:src.pipeline:  mape: 68.263115
# INFO:src.pipeline:  model_rmse_ghi: 49.211032
# INFO:src.pipeline:  nam_rmse_ghi: 28.918516
# INFO:src.pipeline:  model_mae_ghi: 33.879782
# INFO:src.pipeline:  nam_mae_ghi: 18.172979
# INFO:src.pipeline:  model_mape_ghi: 92.360678
# INFO:src.pipeline:  nam_mape_ghi: 73.857357
# INFO:src.pipeline:  model_rmse_csi: 0.268025
# INFO:src.pipeline:  model_mae_csi: 0.197934
# INFO:src.pipeline:  model_mape_csi: 68.263115
# INFO:src.pipeline:  nam_rmse_csi: 0.342068
# INFO:src.pipeline:  nam_mae_csi: 0.203361
# INFO:src.pipeline:  nam_mape_csi: 73.857357
# INFO:src.pipeline:  rmse_skill_ghi_pct: -70.171361
# INFO:src.pipeline:  rmse_skill_csi_pct: 21.645811
# INFO:src.pipeline:  mae_skill_ghi_pct: -86.429439
# INFO:src.pipeline:  mae_skill_csi_pct: 2.668697
# INFO:src.pipeline:  mape_skill_ghi_pct: -25.052780
# INFO:src.pipeline:  mape_skill_csi_pct: 7.574386
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 3 ===
# INFO:src.pipeline:Train samples: 67, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.066499, Val Loss: 0.059062, Train MAE: 0.191430, Val MAE: 0.206446, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.066234, Val Loss: 0.104625, Train MAE: 0.200055, Val MAE: 0.278989, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# INFO:src.pipeline:Fold 3 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.139116
# INFO:src.pipeline:  rmse: 0.372983
# INFO:src.pipeline:  mae: 0.312051
# INFO:src.pipeline:  r2: -0.801589
# INFO:src.pipeline:  mape: 39.795815
# INFO:src.pipeline:  model_rmse_ghi: 85.536540
# INFO:src.pipeline:  nam_rmse_ghi: 82.375138
# INFO:src.pipeline:  model_mae_ghi: 63.273519
# INFO:src.pipeline:  nam_mae_ghi: 46.609284
# INFO:src.pipeline:  model_mape_ghi: 44.457503
# INFO:src.pipeline:  nam_mape_ghi: 247.917462
# INFO:src.pipeline:  model_rmse_csi: 0.372983
# INFO:src.pipeline:  model_mae_csi: 0.312051
# INFO:src.pipeline:  model_mape_csi: 39.795815
# INFO:src.pipeline:  nam_rmse_csi: 4233.970265
# INFO:src.pipeline:  nam_mae_csi: 520.457473
# INFO:src.pipeline:  nam_mape_csi: 61476.609638
# INFO:src.pipeline:  rmse_skill_ghi_pct: -3.837810
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.991191
# INFO:src.pipeline:  mae_skill_ghi_pct: -35.753038
# INFO:src.pipeline:  mae_skill_csi_pct: 99.940043
# INFO:src.pipeline:  mape_skill_ghi_pct: 82.067619
# INFO:src.pipeline:  mape_skill_csi_pct: 99.935267
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 71.000000
# INFO:src.pipeline:
# === Running Fold 4 ===
# INFO:src.pipeline:Train samples: 97, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.073062, Val Loss: 0.038356, Train MAE: 0.201748, Val MAE: 0.165688, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.043998, Val Loss: 0.030962, Train MAE: 0.159625, Val MAE: 0.142550, LR: 0.000500
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.045120, Val Loss: 0.032152, Train MAE: 0.144897, Val MAE: 0.129500, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.039710, Val Loss: 0.033828, Train MAE: 0.139483, Val MAE: 0.146309, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.033706, Val Loss: 0.030040, Train MAE: 0.121358, Val MAE: 0.125560, LR: 0.000250
# INFO:src.pipeline:Fold 4 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.030040
# INFO:src.pipeline:  rmse: 0.173321
# INFO:src.pipeline:  mae: 0.125560
# INFO:src.pipeline:  r2: 0.398192
# INFO:src.pipeline:  mape: 18.187281
# INFO:src.pipeline:  model_rmse_ghi: 36.439891
# INFO:src.pipeline:  nam_rmse_ghi: 177.658241
# INFO:src.pipeline:  model_mae_ghi: 23.537395
# INFO:src.pipeline:  nam_mae_ghi: 119.355573
# INFO:src.pipeline:  model_mape_ghi: 27.061684
# INFO:src.pipeline:  nam_mape_ghi: 404.329564
# INFO:src.pipeline:  model_rmse_csi: 0.173321
# INFO:src.pipeline:  model_mae_csi: 0.125560
# INFO:src.pipeline:  model_mape_csi: 18.187281
# INFO:src.pipeline:  nam_rmse_csi: 6.393005
# INFO:src.pipeline:  nam_mae_csi: 3.094590
# INFO:src.pipeline:  nam_mape_csi: 404.329564
# INFO:src.pipeline:  rmse_skill_ghi_pct: 79.488770
# INFO:src.pipeline:  rmse_skill_csi_pct: 97.288894
# INFO:src.pipeline:  mae_skill_ghi_pct: 80.279601
# INFO:src.pipeline:  mae_skill_csi_pct: 95.942605
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.307023
# INFO:src.pipeline:  mape_skill_csi_pct: 95.501867
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 5 ===
# INFO:src.pipeline:Train samples: 128, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.050546, Val Loss: 0.058154, Train MAE: 0.157453, Val MAE: 0.220114, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038889, Val Loss: 0.102566, Train MAE: 0.134632, Val MAE: 0.295145, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 24
# INFO:src.pipeline:Fold 5 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.123208
# INFO:src.pipeline:  rmse: 0.351010
# INFO:src.pipeline:  mae: 0.320804
# INFO:src.pipeline:  r2: -2.168469
# INFO:src.pipeline:  mape: 33.914448
# INFO:src.pipeline:  model_rmse_ghi: 83.996466
# INFO:src.pipeline:  nam_rmse_ghi: 183.386569
# INFO:src.pipeline:  model_mae_ghi: 62.290172
# INFO:src.pipeline:  nam_mae_ghi: 126.617010
# INFO:src.pipeline:  model_mape_ghi: 33.199205
# INFO:src.pipeline:  nam_mape_ghi: 203.539202
# INFO:src.pipeline:  model_rmse_csi: 0.351010
# INFO:src.pipeline:  model_mae_csi: 0.320804
# INFO:src.pipeline:  model_mape_csi: 33.914448
# INFO:src.pipeline:  nam_rmse_csi: 1827.663220
# INFO:src.pipeline:  nam_mae_csi: 405.586491
# INFO:src.pipeline:  nam_mape_csi: 72924.087870
# INFO:src.pipeline:  rmse_skill_ghi_pct: 54.197046
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.980795
# INFO:src.pipeline:  mae_skill_ghi_pct: 50.804263
# INFO:src.pipeline:  mae_skill_csi_pct: 99.920904
# INFO:src.pipeline:  mape_skill_ghi_pct: 83.689037
# INFO:src.pipeline:  mape_skill_csi_pct: 99.953493
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 6 ===
# INFO:src.pipeline:Train samples: 158, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041433, Val Loss: 0.028951, Train MAE: 0.144757, Val MAE: 0.091741, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036976, Val Loss: 0.027714, Train MAE: 0.130824, Val MAE: 0.087114, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.031380, Val Loss: 0.027696, Train MAE: 0.114825, Val MAE: 0.088681, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 39
# INFO:src.pipeline:Fold 6 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.025986
# INFO:src.pipeline:  rmse: 0.161201
# INFO:src.pipeline:  mae: 0.083260
# INFO:src.pipeline:  r2: 0.509666
# INFO:src.pipeline:  mape: 19.612463
# INFO:src.pipeline:  model_rmse_ghi: 45.420218
# INFO:src.pipeline:  nam_rmse_ghi: 171.994205
# INFO:src.pipeline:  model_mae_ghi: 16.951016
# INFO:src.pipeline:  nam_mae_ghi: 119.377076
# INFO:src.pipeline:  model_mape_ghi: 32.781612
# INFO:src.pipeline:  nam_mape_ghi: 405.336845
# INFO:src.pipeline:  model_rmse_csi: 0.161201
# INFO:src.pipeline:  model_mae_csi: 0.083260
# INFO:src.pipeline:  model_mape_csi: 19.612463
# INFO:src.pipeline:  nam_rmse_csi: 1700.885180
# INFO:src.pipeline:  nam_mae_csi: 308.745768
# INFO:src.pipeline:  nam_mape_csi: 76197.389556
# INFO:src.pipeline:  rmse_skill_ghi_pct: 73.592007
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.990523
# INFO:src.pipeline:  mae_skill_ghi_pct: 85.800443
# INFO:src.pipeline:  mae_skill_csi_pct: 99.973033
# INFO:src.pipeline:  mape_skill_ghi_pct: 91.912501
# INFO:src.pipeline:  mape_skill_csi_pct: 99.974261
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 7 ===
# INFO:src.pipeline:Train samples: 189, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.039542, Val Loss: 0.051229, Train MAE: 0.130205, Val MAE: 0.154151, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.032136, Val Loss: 0.054810, Train MAE: 0.121346, Val MAE: 0.186077, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.028190, Val Loss: 0.053157, Train MAE: 0.109883, Val MAE: 0.168331, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 33
# INFO:src.pipeline:Fold 7 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.056663
# INFO:src.pipeline:  rmse: 0.238040
# INFO:src.pipeline:  mae: 0.167501
# INFO:src.pipeline:  r2: 0.218941
# INFO:src.pipeline:  mape: 37.697037
# INFO:src.pipeline:  model_rmse_ghi: 53.092270
# INFO:src.pipeline:  nam_rmse_ghi: 88.975472
# INFO:src.pipeline:  model_mae_ghi: 26.537836
# INFO:src.pipeline:  nam_mae_ghi: 57.500647
# INFO:src.pipeline:  model_mape_ghi: 58.149618
# INFO:src.pipeline:  nam_mape_ghi: 721.274585
# INFO:src.pipeline:  model_rmse_csi: 0.238040
# INFO:src.pipeline:  model_mae_csi: 0.167501
# INFO:src.pipeline:  model_mape_csi: 37.697037
# INFO:src.pipeline:  nam_rmse_csi: 29388.587128
# INFO:src.pipeline:  nam_mae_csi: 2977.618492
# INFO:src.pipeline:  nam_mape_csi: 351278.956119
# INFO:src.pipeline:  rmse_skill_ghi_pct: 40.329319
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.999190
# INFO:src.pipeline:  mae_skill_ghi_pct: 53.847762
# INFO:src.pipeline:  mae_skill_csi_pct: 99.994375
# INFO:src.pipeline:  mape_skill_ghi_pct: 91.937936
# INFO:src.pipeline:  mape_skill_csi_pct: 99.989269
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 89.000000
# INFO:src.pipeline:
# === Running Fold 8 ===
# INFO:src.pipeline:Train samples: 220, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.037980, Val Loss: 0.047832, Train MAE: 0.127854, Val MAE: 0.152361, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.029072, Val Loss: 0.047031, Train MAE: 0.109642, Val MAE: 0.122595, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 24
# INFO:src.pipeline:Fold 8 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.044189
# INFO:src.pipeline:  rmse: 0.210213
# INFO:src.pipeline:  mae: 0.115410
# INFO:src.pipeline:  r2: 0.332363
# INFO:src.pipeline:  mape: 27.446259
# INFO:src.pipeline:  model_rmse_ghi: 19.799397
# INFO:src.pipeline:  nam_rmse_ghi: 29.103083
# INFO:src.pipeline:  model_mae_ghi: 14.810046
# INFO:src.pipeline:  nam_mae_ghi: 22.579527
# INFO:src.pipeline:  model_mape_ghi: 17.119664
# INFO:src.pipeline:  nam_mape_ghi: 80.821695
# INFO:src.pipeline:  model_rmse_csi: 0.210213
# INFO:src.pipeline:  model_mae_csi: 0.115410
# INFO:src.pipeline:  model_mape_csi: 27.446259
# INFO:src.pipeline:  nam_rmse_csi: 0.716143
# INFO:src.pipeline:  nam_mae_csi: 0.371663
# INFO:src.pipeline:  nam_mape_csi: 81.764890
# INFO:src.pipeline:  rmse_skill_ghi_pct: 31.968040
# INFO:src.pipeline:  rmse_skill_csi_pct: 70.646536
# INFO:src.pipeline:  mae_skill_ghi_pct: 34.409406
# INFO:src.pipeline:  mae_skill_csi_pct: 68.947816
# INFO:src.pipeline:  mape_skill_ghi_pct: 78.817985
# INFO:src.pipeline:  mape_skill_csi_pct: 66.432709
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 9 ===
# INFO:src.pipeline:Train samples: 250, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.037074, Val Loss: 0.042091, Train MAE: 0.129827, Val MAE: 0.158129, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034392, Val Loss: 0.039281, Train MAE: 0.120654, Val MAE: 0.143176, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.026031, Val Loss: 0.043768, Train MAE: 0.103368, Val MAE: 0.168484, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.021685, Val Loss: 0.045223, Train MAE: 0.093324, Val MAE: 0.162017, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.018395, Val Loss: 0.035563, Train MAE: 0.085631, Val MAE: 0.140608, LR: 0.000500
# INFO:src.pipeline:Fold 9 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.035563
# INFO:src.pipeline:  rmse: 0.188582
# INFO:src.pipeline:  mae: 0.140608
# INFO:src.pipeline:  r2: 0.558111
# INFO:src.pipeline:  mape: 30.436602
# INFO:src.pipeline:  model_rmse_ghi: 14.479259
# INFO:src.pipeline:  nam_rmse_ghi: 32.796185
# INFO:src.pipeline:  model_mae_ghi: 8.978610
# INFO:src.pipeline:  nam_mae_ghi: 30.029067
# INFO:src.pipeline:  model_mape_ghi: 44.217893
# INFO:src.pipeline:  nam_mape_ghi: 119.777834
# INFO:src.pipeline:  model_rmse_csi: 0.188582
# INFO:src.pipeline:  model_mae_csi: 0.140608
# INFO:src.pipeline:  model_mape_csi: 30.436602
# INFO:src.pipeline:  nam_rmse_csi: 372.061651
# INFO:src.pipeline:  nam_mae_csi: 75.969811
# INFO:src.pipeline:  nam_mape_csi: 19967.417197
# INFO:src.pipeline:  rmse_skill_ghi_pct: 55.850781
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.949314
# INFO:src.pipeline:  mae_skill_ghi_pct: 70.100270
# INFO:src.pipeline:  mae_skill_csi_pct: 99.814916
# INFO:src.pipeline:  mape_skill_ghi_pct: 63.083409
# INFO:src.pipeline:  mape_skill_csi_pct: 99.847569
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 10 ===
# INFO:src.pipeline:Train samples: 281, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.039599, Val Loss: 0.081832, Train MAE: 0.132847, Val MAE: 0.208456, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.032078, Val Loss: 0.080462, Train MAE: 0.116428, Val MAE: 0.210977, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.026209, Val Loss: 0.100379, Train MAE: 0.103802, Val MAE: 0.215009, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.021581, Val Loss: 0.126388, Train MAE: 0.093886, Val MAE: 0.245085, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 41
# INFO:src.pipeline:Fold 10 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.129775
# INFO:src.pipeline:  rmse: 0.360243
# INFO:src.pipeline:  mae: 0.245065
# INFO:src.pipeline:  r2: -0.040290
# INFO:src.pipeline:  mape: 71.770325
# INFO:src.pipeline:  model_rmse_ghi: 2.825459
# INFO:src.pipeline:  nam_rmse_ghi: 32.120222
# INFO:src.pipeline:  model_mae_ghi: 2.356552
# INFO:src.pipeline:  nam_mae_ghi: 30.741089
# INFO:src.pipeline:  model_mape_ghi: 89.296779
# INFO:src.pipeline:  nam_mape_ghi: 1061.061250
# INFO:src.pipeline:  model_rmse_csi: 0.360243
# INFO:src.pipeline:  model_mae_csi: 0.245065
# INFO:src.pipeline:  model_mape_csi: 71.770325
# INFO:src.pipeline:  nam_rmse_csi: 3.625350
# INFO:src.pipeline:  nam_mae_csi: 3.027441
# INFO:src.pipeline:  nam_mape_csi: 1229.109594
# INFO:src.pipeline:  rmse_skill_ghi_pct: 91.203487
# INFO:src.pipeline:  rmse_skill_csi_pct: 90.063232
# INFO:src.pipeline:  mae_skill_ghi_pct: 92.334196
# INFO:src.pipeline:  mae_skill_csi_pct: 91.905194
# INFO:src.pipeline:  mape_skill_ghi_pct: 91.584201
# INFO:src.pipeline:  mape_skill_csi_pct: 94.160787
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 24.000000
# INFO:src.pipeline:
# === Running Fold 11 ===
# INFO:src.pipeline:Train samples: 311, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043197, Val Loss: 0.089523, Train MAE: 0.140964, Val MAE: 0.237456, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.031839, Val Loss: 0.129030, Train MAE: 0.115929, Val MAE: 0.270763, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# INFO:src.pipeline:Fold 11 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.125222
# INFO:src.pipeline:  rmse: 0.353867
# INFO:src.pipeline:  mae: 0.260236
# INFO:src.pipeline:  r2: 0.077461
# INFO:src.pipeline:  mape: 101.530930
# INFO:src.pipeline:  model_rmse_ghi: 1.431484
# INFO:src.pipeline:  nam_rmse_ghi: 29.946906
# INFO:src.pipeline:  model_mae_ghi: 1.084271
# INFO:src.pipeline:  nam_mae_ghi: 27.822608
# INFO:src.pipeline:  model_mape_ghi: 52.619026
# INFO:src.pipeline:  nam_mape_ghi: 1340.377721
# INFO:src.pipeline:  model_rmse_csi: 0.353867
# INFO:src.pipeline:  model_mae_csi: 0.260236
# INFO:src.pipeline:  model_mape_csi: 101.530930
# INFO:src.pipeline:  nam_rmse_csi: 4.982339
# INFO:src.pipeline:  nam_mae_csi: 4.351954
# INFO:src.pipeline:  nam_mape_csi: 2454.787116
# INFO:src.pipeline:  rmse_skill_ghi_pct: 95.219927
# INFO:src.pipeline:  rmse_skill_csi_pct: 92.897581
# INFO:src.pipeline:  mae_skill_ghi_pct: 96.102914
# INFO:src.pipeline:  mae_skill_csi_pct: 94.020249
# INFO:src.pipeline:  mape_skill_ghi_pct: 96.074314
# INFO:src.pipeline:  mape_skill_csi_pct: 95.863962
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 11.000000
# INFO:src.pipeline:
# === Running Fold 12 ===
# INFO:src.pipeline:Train samples: 342, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045772, Val Loss: 0.066986, Train MAE: 0.146382, Val MAE: 0.202728, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.040621, Val Loss: 0.075004, Train MAE: 0.140350, Val MAE: 0.216574, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.034436, Val Loss: 0.072193, Train MAE: 0.124811, Val MAE: 0.205468, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.023821, Val Loss: 0.140807, Train MAE: 0.102786, Val MAE: 0.264193, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 44
# INFO:src.pipeline:Fold 12 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.198366
# INFO:src.pipeline:  rmse: 0.445383
# INFO:src.pipeline:  mae: 0.313606
# INFO:src.pipeline:  r2: -0.965676
# INFO:src.pipeline:  mape: 40.550400
# INFO:src.pipeline:  model_rmse_ghi: 16.876114
# INFO:src.pipeline:  nam_rmse_ghi: 34.512881
# INFO:src.pipeline:  model_mae_ghi: 11.131496
# INFO:src.pipeline:  nam_mae_ghi: 33.201618
# INFO:src.pipeline:  model_mape_ghi: 43.789735
# INFO:src.pipeline:  nam_mape_ghi: 279.598407
# INFO:src.pipeline:  model_rmse_csi: 0.445383
# INFO:src.pipeline:  model_mae_csi: 0.313606
# INFO:src.pipeline:  model_mape_csi: 40.550400
# INFO:src.pipeline:  nam_rmse_csi: 1.282367
# INFO:src.pipeline:  nam_mae_csi: 1.096885
# INFO:src.pipeline:  nam_mape_csi: 279.598407
# INFO:src.pipeline:  rmse_skill_ghi_pct: 51.101984
# INFO:src.pipeline:  rmse_skill_csi_pct: 65.268710
# INFO:src.pipeline:  mae_skill_ghi_pct: 66.473031
# INFO:src.pipeline:  mae_skill_csi_pct: 71.409418
# INFO:src.pipeline:  mape_skill_ghi_pct: 84.338346
# INFO:src.pipeline:  mape_skill_csi_pct: 85.496913
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 30.000000
# INFO:src.pipeline:
# === Running Fold 13 ===
# INFO:src.pipeline:Train samples: 373, Val samples: 27
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.047483, Val Loss: 0.070795, Train MAE: 0.147024, Val MAE: 0.213330, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038010, Val Loss: 0.078460, Train MAE: 0.134848, Val MAE: 0.205710, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.029219, Val Loss: 0.093882, Train MAE: 0.113605, Val MAE: 0.214009, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# INFO:src.pipeline:Fold 13 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.095432
# INFO:src.pipeline:  rmse: 0.308920
# INFO:src.pipeline:  mae: 0.218128
# INFO:src.pipeline:  r2: 0.207180
# INFO:src.pipeline:  mape: 86.671677
# INFO:src.pipeline:  model_rmse_ghi: 30.168330
# INFO:src.pipeline:  nam_rmse_ghi: 34.915795
# INFO:src.pipeline:  model_mae_ghi: 20.636644
# INFO:src.pipeline:  nam_mae_ghi: 28.073101
# INFO:src.pipeline:  model_mape_ghi: 80.889375
# INFO:src.pipeline:  nam_mape_ghi: 235.612876
# INFO:src.pipeline:  model_rmse_csi: 0.308920
# INFO:src.pipeline:  model_mae_csi: 0.218128
# INFO:src.pipeline:  model_mape_csi: 86.671677
# INFO:src.pipeline:  nam_rmse_csi: 40.391397
# INFO:src.pipeline:  nam_mae_csi: 12.919904
# INFO:src.pipeline:  nam_mape_csi: 13492.524929
# INFO:src.pipeline:  rmse_skill_ghi_pct: 13.596897
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.235183
# INFO:src.pipeline:  mae_skill_ghi_pct: 26.489620
# INFO:src.pipeline:  mae_skill_csi_pct: 98.311692
# INFO:src.pipeline:  mape_skill_ghi_pct: 65.668525
# INFO:src.pipeline:  mape_skill_csi_pct: 99.357632
# INFO:src.pipeline:  n_rows: 378.000000
# INFO:src.pipeline:  n_daylight_rows: 37.000000
# INFO:src.pipeline:
# === Running Fold 14 ===
# INFO:src.pipeline:Train samples: 401, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.047784, Val Loss: 0.040178, Train MAE: 0.154614, Val MAE: 0.148344, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.043817, Val Loss: 0.041922, Train MAE: 0.139636, Val MAE: 0.158931, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.032490, Val Loss: 0.048330, Train MAE: 0.120337, Val MAE: 0.174111, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 30
# INFO:src.pipeline:Fold 14 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.048330
# INFO:src.pipeline:  rmse: 0.219842
# INFO:src.pipeline:  mae: 0.174111
# INFO:src.pipeline:  r2: 0.433994
# INFO:src.pipeline:  mape: 30.631897
# INFO:src.pipeline:  model_rmse_ghi: 31.133758
# INFO:src.pipeline:  nam_rmse_ghi: 27.314497
# INFO:src.pipeline:  model_mae_ghi: 21.227104
# INFO:src.pipeline:  nam_mae_ghi: 20.237865
# INFO:src.pipeline:  model_mape_ghi: 40.755157
# INFO:src.pipeline:  nam_mape_ghi: 49.977180
# INFO:src.pipeline:  model_rmse_csi: 0.219842
# INFO:src.pipeline:  model_mae_csi: 0.174111
# INFO:src.pipeline:  model_mape_csi: 30.631897
# INFO:src.pipeline:  nam_rmse_csi: 0.320300
# INFO:src.pipeline:  nam_mae_csi: 0.209284
# INFO:src.pipeline:  nam_mape_csi: 49.977180
# INFO:src.pipeline:  rmse_skill_ghi_pct: -13.982541
# INFO:src.pipeline:  rmse_skill_csi_pct: 31.363806
# INFO:src.pipeline:  mae_skill_ghi_pct: -4.888061
# INFO:src.pipeline:  mae_skill_csi_pct: 16.806348
# INFO:src.pipeline:  mape_skill_ghi_pct: 18.452466
# INFO:src.pipeline:  mape_skill_csi_pct: 38.708232
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 15 ===
# INFO:src.pipeline:Train samples: 432, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.049387, Val Loss: 0.036980, Train MAE: 0.151325, Val MAE: 0.134939, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.042363, Val Loss: 0.036472, Train MAE: 0.141847, Val MAE: 0.113667, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.030693, Val Loss: 0.043060, Train MAE: 0.116790, Val MAE: 0.109193, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 35
# INFO:src.pipeline:Fold 15 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.040202
# INFO:src.pipeline:  rmse: 0.200504
# INFO:src.pipeline:  mae: 0.104218
# INFO:src.pipeline:  r2: 0.504990
# INFO:src.pipeline:  mape: 31.656504
# INFO:src.pipeline:  model_rmse_ghi: 45.595608
# INFO:src.pipeline:  nam_rmse_ghi: 82.344226
# INFO:src.pipeline:  model_mae_ghi: 23.783770
# INFO:src.pipeline:  nam_mae_ghi: 55.958252
# INFO:src.pipeline:  model_mape_ghi: 31.299599
# INFO:src.pipeline:  nam_mape_ghi: 282.624050
# INFO:src.pipeline:  model_rmse_csi: 0.200504
# INFO:src.pipeline:  model_mae_csi: 0.104218
# INFO:src.pipeline:  model_mape_csi: 31.656504
# INFO:src.pipeline:  nam_rmse_csi: 694.038902
# INFO:src.pipeline:  nam_mae_csi: 112.763228
# INFO:src.pipeline:  nam_mape_csi: 12988.119143
# INFO:src.pipeline:  rmse_skill_ghi_pct: 44.628045
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.971111
# INFO:src.pipeline:  mae_skill_ghi_pct: 57.497296
# INFO:src.pipeline:  mae_skill_csi_pct: 99.907578
# INFO:src.pipeline:  mape_skill_ghi_pct: 88.925359
# INFO:src.pipeline:  mape_skill_csi_pct: 99.756266
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 71.000000
# INFO:src.pipeline:
# === Running Fold 16 ===
# INFO:src.pipeline:Train samples: 462, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043156, Val Loss: 0.040979, Train MAE: 0.144877, Val MAE: 0.135688, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.041573, Val Loss: 0.038311, Train MAE: 0.141821, Val MAE: 0.135372, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.035439, Val Loss: 0.041171, Train MAE: 0.126596, Val MAE: 0.135159, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.024827, Val Loss: 0.042735, Train MAE: 0.103529, Val MAE: 0.144204, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 40
# INFO:src.pipeline:Fold 16 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.042735
# INFO:src.pipeline:  rmse: 0.206725
# INFO:src.pipeline:  mae: 0.144204
# INFO:src.pipeline:  r2: 0.309545
# INFO:src.pipeline:  mape: 73.064056
# INFO:src.pipeline:  model_rmse_ghi: 38.087980
# INFO:src.pipeline:  nam_rmse_ghi: 134.580713
# INFO:src.pipeline:  model_mae_ghi: 22.152747
# INFO:src.pipeline:  nam_mae_ghi: 100.844359
# INFO:src.pipeline:  model_mape_ghi: 146.172355
# INFO:src.pipeline:  nam_mape_ghi: 422.612681
# INFO:src.pipeline:  model_rmse_csi: 0.206725
# INFO:src.pipeline:  model_mae_csi: 0.144204
# INFO:src.pipeline:  model_mape_csi: 73.064056
# INFO:src.pipeline:  nam_rmse_csi: 5.061521
# INFO:src.pipeline:  nam_mae_csi: 2.303061
# INFO:src.pipeline:  nam_mape_csi: 422.612681
# INFO:src.pipeline:  rmse_skill_ghi_pct: 71.698783
# INFO:src.pipeline:  rmse_skill_csi_pct: 95.915755
# INFO:src.pipeline:  mae_skill_ghi_pct: 78.032736
# INFO:src.pipeline:  mae_skill_csi_pct: 93.738596
# INFO:src.pipeline:  mape_skill_ghi_pct: 65.412218
# INFO:src.pipeline:  mape_skill_csi_pct: 82.711343
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 17 ===
# INFO:src.pipeline:Train samples: 493, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045765, Val Loss: 0.039624, Train MAE: 0.149530, Val MAE: 0.138220, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038530, Val Loss: 0.031904, Train MAE: 0.133129, Val MAE: 0.097927, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.034035, Val Loss: 0.031576, Train MAE: 0.124497, Val MAE: 0.102822, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.030071, Val Loss: 0.034622, Train MAE: 0.115738, Val MAE: 0.097322, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.019987, Val Loss: 0.034083, Train MAE: 0.096125, Val MAE: 0.103141, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 50
# INFO:src.pipeline:Fold 17 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.034083
# INFO:src.pipeline:  rmse: 0.184616
# INFO:src.pipeline:  mae: 0.103141
# INFO:src.pipeline:  r2: 0.555004
# INFO:src.pipeline:  mape: 29.350454
# INFO:src.pipeline:  model_rmse_ghi: 57.937445
# INFO:src.pipeline:  nam_rmse_ghi: 168.224025
# INFO:src.pipeline:  model_mae_ghi: 24.457091
# INFO:src.pipeline:  nam_mae_ghi: 131.772201
# INFO:src.pipeline:  model_mape_ghi: 49.563462
# INFO:src.pipeline:  nam_mape_ghi: 245.421946
# INFO:src.pipeline:  model_rmse_csi: 0.184616
# INFO:src.pipeline:  model_mae_csi: 0.103141
# INFO:src.pipeline:  model_mape_csi: 29.350454
# INFO:src.pipeline:  nam_rmse_csi: 1233.440798
# INFO:src.pipeline:  nam_mae_csi: 238.135074
# INFO:src.pipeline:  nam_mape_csi: 50045.008041
# INFO:src.pipeline:  rmse_skill_ghi_pct: 65.559352
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.985032
# INFO:src.pipeline:  mae_skill_ghi_pct: 81.439871
# INFO:src.pipeline:  mae_skill_csi_pct: 99.956688
# INFO:src.pipeline:  mape_skill_ghi_pct: 79.804796
# INFO:src.pipeline:  mape_skill_csi_pct: 99.941352
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 18 ===
# INFO:src.pipeline:Train samples: 523, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042949, Val Loss: 0.030971, Train MAE: 0.144979, Val MAE: 0.103034, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038955, Val Loss: 0.033945, Train MAE: 0.137220, Val MAE: 0.113765, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.037180, Val Loss: 0.029953, Train MAE: 0.131490, Val MAE: 0.117039, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.025211, Val Loss: 0.030346, Train MAE: 0.105725, Val MAE: 0.108844, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 44
# INFO:src.pipeline:Fold 18 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.030431
# INFO:src.pipeline:  rmse: 0.174444
# INFO:src.pipeline:  mae: 0.107108
# INFO:src.pipeline:  r2: 0.507343
# INFO:src.pipeline:  mape: 22.529585
# INFO:src.pipeline:  model_rmse_ghi: 30.524244
# INFO:src.pipeline:  nam_rmse_ghi: 145.080492
# INFO:src.pipeline:  model_mae_ghi: 14.776155
# INFO:src.pipeline:  nam_mae_ghi: 116.494217
# INFO:src.pipeline:  model_mape_ghi: 19.858777
# INFO:src.pipeline:  nam_mape_ghi: 332.422119
# INFO:src.pipeline:  model_rmse_csi: 0.174444
# INFO:src.pipeline:  model_mae_csi: 0.107108
# INFO:src.pipeline:  model_mape_csi: 22.529585
# INFO:src.pipeline:  nam_rmse_csi: 8750.312585
# INFO:src.pipeline:  nam_mae_csi: 898.589462
# INFO:src.pipeline:  nam_mape_csi: 375090.739203
# INFO:src.pipeline:  rmse_skill_ghi_pct: 78.960476
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.998006
# INFO:src.pipeline:  mae_skill_ghi_pct: 87.315975
# INFO:src.pipeline:  mae_skill_csi_pct: 99.988080
# INFO:src.pipeline:  mape_skill_ghi_pct: 94.026036
# INFO:src.pipeline:  mape_skill_csi_pct: 99.993994
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 19 ===
# INFO:src.pipeline:Train samples: 554, Val samples: 28
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044887, Val Loss: 0.021701, Train MAE: 0.144855, Val MAE: 0.121329, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037619, Val Loss: 0.022195, Train MAE: 0.132567, Val MAE: 0.118730, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.028468, Val Loss: 0.028529, Train MAE: 0.113621, Val MAE: 0.136138, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Fold 19 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.029779
# INFO:src.pipeline:  rmse: 0.172566
# INFO:src.pipeline:  mae: 0.132962
# INFO:src.pipeline:  r2: 0.431231
# INFO:src.pipeline:  mape: 16.370605
# INFO:src.pipeline:  model_rmse_ghi: 32.852734
# INFO:src.pipeline:  nam_rmse_ghi: 79.936071
# INFO:src.pipeline:  model_mae_ghi: 19.245224
# INFO:src.pipeline:  nam_mae_ghi: 62.381378
# INFO:src.pipeline:  model_mape_ghi: 19.847889
# INFO:src.pipeline:  nam_mape_ghi: 352.071316
# INFO:src.pipeline:  model_rmse_csi: 0.172566
# INFO:src.pipeline:  model_mae_csi: 0.132962
# INFO:src.pipeline:  model_mape_csi: 16.370605
# INFO:src.pipeline:  nam_rmse_csi: 5332.954517
# INFO:src.pipeline:  nam_mae_csi: 653.905014
# INFO:src.pipeline:  nam_mape_csi: 80875.360650
# INFO:src.pipeline:  rmse_skill_ghi_pct: 58.901240
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.996764
# INFO:src.pipeline:  mae_skill_ghi_pct: 69.149088
# INFO:src.pipeline:  mae_skill_csi_pct: 99.979666
# INFO:src.pipeline:  mape_skill_ghi_pct: 94.362537
# INFO:src.pipeline:  mape_skill_csi_pct: 99.979758
# INFO:src.pipeline:  n_rows: 392.000000
# INFO:src.pipeline:  n_daylight_rows: 83.000000
# INFO:src.pipeline:
# === Running Fold 20 ===
# INFO:src.pipeline:Train samples: 583, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043561, Val Loss: 0.046734, Train MAE: 0.144241, Val MAE: 0.135384, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036562, Val Loss: 0.037390, Train MAE: 0.127723, Val MAE: 0.135971, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.035055, Val Loss: 0.041122, Train MAE: 0.126226, Val MAE: 0.135078, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.025440, Val Loss: 0.069524, Train MAE: 0.104853, Val MAE: 0.176263, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 40
# INFO:src.pipeline:Fold 20 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.069524
# INFO:src.pipeline:  rmse: 0.263674
# INFO:src.pipeline:  mae: 0.176263
# INFO:src.pipeline:  r2: 0.124563
# INFO:src.pipeline:  mape: 33.617802
# INFO:src.pipeline:  model_rmse_ghi: 17.506833
# INFO:src.pipeline:  nam_rmse_ghi: 28.517076
# INFO:src.pipeline:  model_mae_ghi: 10.912610
# INFO:src.pipeline:  nam_mae_ghi: 23.786153
# INFO:src.pipeline:  model_mape_ghi: 26.301800
# INFO:src.pipeline:  nam_mape_ghi: 76.292014
# INFO:src.pipeline:  model_rmse_csi: 0.263674
# INFO:src.pipeline:  model_mae_csi: 0.176263
# INFO:src.pipeline:  model_mape_csi: 33.617802
# INFO:src.pipeline:  nam_rmse_csi: 0.570128
# INFO:src.pipeline:  nam_mae_csi: 0.342846
# INFO:src.pipeline:  nam_mape_csi: 77.457980
# INFO:src.pipeline:  rmse_skill_ghi_pct: 38.609298
# INFO:src.pipeline:  rmse_skill_csi_pct: 53.751841
# INFO:src.pipeline:  mae_skill_ghi_pct: 54.122007
# INFO:src.pipeline:  mae_skill_csi_pct: 48.588450
# INFO:src.pipeline:  mape_skill_ghi_pct: 65.524832
# INFO:src.pipeline:  mape_skill_csi_pct: 56.598660
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 21 ===
# INFO:src.pipeline:Train samples: 613, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044738, Val Loss: 0.036230, Train MAE: 0.147824, Val MAE: 0.155204, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035506, Val Loss: 0.049308, Train MAE: 0.127992, Val MAE: 0.162024, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 26
# INFO:src.pipeline:Fold 21 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.062545
# INFO:src.pipeline:  rmse: 0.250090
# INFO:src.pipeline:  mae: 0.184122
# INFO:src.pipeline:  r2: 0.165059
# INFO:src.pipeline:  mape: 24.822449
# INFO:src.pipeline:  model_rmse_ghi: 23.001720
# INFO:src.pipeline:  nam_rmse_ghi: 34.752485
# INFO:src.pipeline:  model_mae_ghi: 14.480874
# INFO:src.pipeline:  nam_mae_ghi: 32.612153
# INFO:src.pipeline:  model_mape_ghi: 30.581689
# INFO:src.pipeline:  nam_mape_ghi: 106.273663
# INFO:src.pipeline:  model_rmse_csi: 0.250090
# INFO:src.pipeline:  model_mae_csi: 0.184122
# INFO:src.pipeline:  model_mape_csi: 24.822449
# INFO:src.pipeline:  nam_rmse_csi: 209.719011
# INFO:src.pipeline:  nam_mae_csi: 47.320725
# INFO:src.pipeline:  nam_mape_csi: 13109.370468
# INFO:src.pipeline:  rmse_skill_ghi_pct: 33.812734
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.880750
# INFO:src.pipeline:  mae_skill_ghi_pct: 55.596693
# INFO:src.pipeline:  mae_skill_csi_pct: 99.610907
# INFO:src.pipeline:  mape_skill_ghi_pct: 71.223642
# INFO:src.pipeline:  mape_skill_csi_pct: 99.810651
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 22 ===
# INFO:src.pipeline:Train samples: 644, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042062, Val Loss: 0.070006, Train MAE: 0.142752, Val MAE: 0.211602, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038460, Val Loss: 0.071598, Train MAE: 0.131554, Val MAE: 0.210028, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.032398, Val Loss: 0.064612, Train MAE: 0.120416, Val MAE: 0.165353, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.031776, Val Loss: 0.060956, Train MAE: 0.119883, Val MAE: 0.155294, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 49
# INFO:src.pipeline:Fold 22 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.067502
# INFO:src.pipeline:  rmse: 0.259811
# INFO:src.pipeline:  mae: 0.196622
# INFO:src.pipeline:  r2: 0.279363
# INFO:src.pipeline:  mape: 42.433498
# INFO:src.pipeline:  model_rmse_ghi: 3.720629
# INFO:src.pipeline:  nam_rmse_ghi: 32.161632
# INFO:src.pipeline:  model_mae_ghi: 2.385732
# INFO:src.pipeline:  nam_mae_ghi: 30.497916
# INFO:src.pipeline:  model_mape_ghi: 49.525527
# INFO:src.pipeline:  nam_mape_ghi: 522.430553
# INFO:src.pipeline:  model_rmse_csi: 0.259811
# INFO:src.pipeline:  model_mae_csi: 0.196622
# INFO:src.pipeline:  model_mape_csi: 42.433498
# INFO:src.pipeline:  nam_rmse_csi: 4.082251
# INFO:src.pipeline:  nam_mae_csi: 3.331544
# INFO:src.pipeline:  nam_mape_csi: 869.897528
# INFO:src.pipeline:  rmse_skill_ghi_pct: 88.431468
# INFO:src.pipeline:  rmse_skill_csi_pct: 93.635586
# INFO:src.pipeline:  mae_skill_ghi_pct: 92.177393
# INFO:src.pipeline:  mae_skill_csi_pct: 94.098158
# INFO:src.pipeline:  mape_skill_ghi_pct: 90.520170
# INFO:src.pipeline:  mape_skill_csi_pct: 95.122012
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 24.000000
# INFO:src.pipeline:
# === Running Fold 23 ===
# INFO:src.pipeline:Train samples: 674, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044109, Val Loss: 0.087051, Train MAE: 0.147469, Val MAE: 0.228856, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038816, Val Loss: 0.068273, Train MAE: 0.136216, Val MAE: 0.195097, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.036071, Val Loss: 0.065179, Train MAE: 0.129555, Val MAE: 0.192927, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 37
# INFO:src.pipeline:Fold 23 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.074472
# INFO:src.pipeline:  rmse: 0.272895
# INFO:src.pipeline:  mae: 0.197736
# INFO:src.pipeline:  r2: 0.347602
# INFO:src.pipeline:  mape: 77.908913
# INFO:src.pipeline:  model_rmse_ghi: 1.412825
# INFO:src.pipeline:  nam_rmse_ghi: 24.819546
# INFO:src.pipeline:  model_mae_ghi: 1.257234
# INFO:src.pipeline:  nam_mae_ghi: 20.876294
# INFO:src.pipeline:  model_mape_ghi: 149.098358
# INFO:src.pipeline:  nam_mape_ghi: 1072.683416
# INFO:src.pipeline:  model_rmse_csi: 0.272895
# INFO:src.pipeline:  model_mae_csi: 0.197736
# INFO:src.pipeline:  model_mape_csi: 77.908913
# INFO:src.pipeline:  nam_rmse_csi: 5.386778
# INFO:src.pipeline:  nam_mae_csi: 4.706144
# INFO:src.pipeline:  nam_mape_csi: 2108.689560
# INFO:src.pipeline:  rmse_skill_ghi_pct: 94.307612
# INFO:src.pipeline:  rmse_skill_csi_pct: 94.933986
# INFO:src.pipeline:  mae_skill_ghi_pct: 93.977696
# INFO:src.pipeline:  mae_skill_csi_pct: 95.798333
# INFO:src.pipeline:  mape_skill_ghi_pct: 86.100432
# INFO:src.pipeline:  mape_skill_csi_pct: 96.305340
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 10.000000
# INFO:src.pipeline:
# === Running Fold 24 ===
# INFO:src.pipeline:Train samples: 703, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042386, Val Loss: 0.103536, Train MAE: 0.142643, Val MAE: 0.244663, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034696, Val Loss: 0.110241, Train MAE: 0.125756, Val MAE: 0.242304, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.034293, Val Loss: 0.079794, Train MAE: 0.124570, Val MAE: 0.219474, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.021759, Val Loss: 0.117615, Train MAE: 0.097205, Val MAE: 0.249634, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 44
# INFO:src.pipeline:Fold 24 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.115804
# INFO:src.pipeline:  rmse: 0.340300
# INFO:src.pipeline:  mae: 0.253032
# INFO:src.pipeline:  r2: 0.154292
# INFO:src.pipeline:  mape: 97.515564
# INFO:src.pipeline:  model_rmse_ghi: 9.613241
# INFO:src.pipeline:  nam_rmse_ghi: nan
# INFO:src.pipeline:  model_mae_ghi: 7.375562
# INFO:src.pipeline:  nam_mae_ghi: nan
# INFO:src.pipeline:  model_mape_ghi: 69.983880
# INFO:src.pipeline:  nam_mape_ghi: nan
# INFO:src.pipeline:  model_rmse_csi: 0.340300
# INFO:src.pipeline:  model_mae_csi: 0.253032
# INFO:src.pipeline:  model_mape_csi: 97.515564
# INFO:src.pipeline:  nam_rmse_csi: 29.010329
# INFO:src.pipeline:  nam_mae_csi: 6.930307
# INFO:src.pipeline:  nam_mape_csi: 6018.644154
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 98.826971
# INFO:src.pipeline:  mae_skill_ghi_pct: nan
# INFO:src.pipeline:  mae_skill_csi_pct: 96.348901
# INFO:src.pipeline:  mape_skill_ghi_pct: nan
# INFO:src.pipeline:  mape_skill_csi_pct: 98.379775
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 30.000000
# INFO:src.pipeline:
# === Running Fold 25 ===
# INFO:src.pipeline:Train samples: 734, Val samples: 28
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043590, Val Loss: 0.039313, Train MAE: 0.145657, Val MAE: 0.157741, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035497, Val Loss: 0.054901, Train MAE: 0.129338, Val MAE: 0.183964, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# INFO:src.pipeline:Fold 25 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.058149
# INFO:src.pipeline:  rmse: 0.241141
# INFO:src.pipeline:  mae: 0.182166
# INFO:src.pipeline:  r2: 0.286160
# INFO:src.pipeline:  mape: 29.635025
# INFO:src.pipeline:  model_rmse_ghi: 21.057056
# INFO:src.pipeline:  nam_rmse_ghi: nan
# INFO:src.pipeline:  model_mae_ghi: 16.449340
# INFO:src.pipeline:  nam_mae_ghi: nan
# INFO:src.pipeline:  model_mape_ghi: 38.330177
# INFO:src.pipeline:  nam_mape_ghi: nan
# INFO:src.pipeline:  model_rmse_csi: 0.241141
# INFO:src.pipeline:  model_mae_csi: 0.182166
# INFO:src.pipeline:  model_mape_csi: 29.635025
# INFO:src.pipeline:  nam_rmse_csi: 327.138316
# INFO:src.pipeline:  nam_mae_csi: 67.335748
# INFO:src.pipeline:  nam_mape_csi: 15615.030707
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.926288
# INFO:src.pipeline:  mae_skill_ghi_pct: nan
# INFO:src.pipeline:  mae_skill_csi_pct: 99.729466
# INFO:src.pipeline:  mape_skill_ghi_pct: nan
# INFO:src.pipeline:  mape_skill_csi_pct: 99.810215
# INFO:src.pipeline:  n_rows: 392.000000
# INFO:src.pipeline:  n_daylight_rows: 39.000000
# INFO:src.pipeline:
# === Running Fold 26 ===
# INFO:src.pipeline:Train samples: 763, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045290, Val Loss: 0.084640, Train MAE: 0.150274, Val MAE: 0.207935, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.040798, Val Loss: 0.090721, Train MAE: 0.139519, Val MAE: 0.200055, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.028424, Val Loss: 0.099272, Train MAE: 0.114774, Val MAE: 0.200265, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 37
# INFO:src.pipeline:Fold 26 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.089905
# INFO:src.pipeline:  rmse: 0.299842
# INFO:src.pipeline:  mae: 0.195236
# INFO:src.pipeline:  r2: 0.357394
# INFO:src.pipeline:  mape: 91.637711
# INFO:src.pipeline:  model_rmse_ghi: 28.917977
# INFO:src.pipeline:  nam_rmse_ghi: 31.422142
# INFO:src.pipeline:  model_mae_ghi: 16.767143
# INFO:src.pipeline:  nam_mae_ghi: 22.106956
# INFO:src.pipeline:  model_mape_ghi: 51.734703
# INFO:src.pipeline:  nam_mape_ghi: 139.671723
# INFO:src.pipeline:  model_rmse_csi: 0.299842
# INFO:src.pipeline:  model_mae_csi: 0.195236
# INFO:src.pipeline:  model_mape_csi: 91.637711
# INFO:src.pipeline:  nam_rmse_csi: 0.292047
# INFO:src.pipeline:  nam_mae_csi: 0.183863
# INFO:src.pipeline:  nam_mape_csi: 139.671723
# INFO:src.pipeline:  rmse_skill_ghi_pct: 7.969429
# INFO:src.pipeline:  rmse_skill_csi_pct: -2.669039
# INFO:src.pipeline:  mae_skill_ghi_pct: 24.154448
# INFO:src.pipeline:  mae_skill_csi_pct: -6.185794
# INFO:src.pipeline:  mape_skill_ghi_pct: 62.959788
# INFO:src.pipeline:  mape_skill_csi_pct: 34.390649
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 27 ===
# INFO:src.pipeline:Train samples: 794, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044281, Val Loss: 0.057947, Train MAE: 0.149625, Val MAE: 0.167533, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039259, Val Loss: 0.055124, Train MAE: 0.136640, Val MAE: 0.169358, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.033277, Val Loss: 0.057325, Train MAE: 0.122540, Val MAE: 0.165637, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 39
# INFO:src.pipeline:Fold 27 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.060732
# INFO:src.pipeline:  rmse: 0.246438
# INFO:src.pipeline:  mae: 0.147506
# INFO:src.pipeline:  r2: 0.389469
# INFO:src.pipeline:  mape: 49.324123
# INFO:src.pipeline:  model_rmse_ghi: 41.152452
# INFO:src.pipeline:  nam_rmse_ghi: 85.922416
# INFO:src.pipeline:  model_mae_ghi: 23.597847
# INFO:src.pipeline:  nam_mae_ghi: 58.849218
# INFO:src.pipeline:  model_mape_ghi: 44.181777
# INFO:src.pipeline:  nam_mape_ghi: 610.394847
# INFO:src.pipeline:  model_rmse_csi: 0.246438
# INFO:src.pipeline:  model_mae_csi: 0.147506
# INFO:src.pipeline:  model_mape_csi: 49.324123
# INFO:src.pipeline:  nam_rmse_csi: 961.257659
# INFO:src.pipeline:  nam_mae_csi: 147.993450
# INFO:src.pipeline:  nam_mape_csi: 16902.462358
# INFO:src.pipeline:  rmse_skill_ghi_pct: 52.105104
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.974363
# INFO:src.pipeline:  mae_skill_ghi_pct: 59.901171
# INFO:src.pipeline:  mae_skill_csi_pct: 99.900329
# INFO:src.pipeline:  mape_skill_ghi_pct: 92.761771
# INFO:src.pipeline:  mape_skill_csi_pct: 99.708184
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 73.000000
# INFO:src.pipeline:
# === Running Fold 28 ===
# INFO:src.pipeline:Train samples: 824, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045721, Val Loss: 0.049094, Train MAE: 0.149158, Val MAE: 0.161862, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038702, Val Loss: 0.056311, Train MAE: 0.135435, Val MAE: 0.157063, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.028641, Val Loss: 0.042381, Train MAE: 0.113544, Val MAE: 0.143644, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.023727, Val Loss: 0.046488, Train MAE: 0.102442, Val MAE: 0.157744, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.017589, Val Loss: 0.057971, Train MAE: 0.089149, Val MAE: 0.167181, LR: 0.000250
# INFO:src.pipeline:Fold 28 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.057971
# INFO:src.pipeline:  rmse: 0.240772
# INFO:src.pipeline:  mae: 0.167181
# INFO:src.pipeline:  r2: 0.304881
# INFO:src.pipeline:  mape: 44.710777
# INFO:src.pipeline:  model_rmse_ghi: 41.518576
# INFO:src.pipeline:  nam_rmse_ghi: 133.168581
# INFO:src.pipeline:  model_mae_ghi: 24.748689
# INFO:src.pipeline:  nam_mae_ghi: 98.274114
# INFO:src.pipeline:  model_mape_ghi: 56.934741
# INFO:src.pipeline:  nam_mape_ghi: 406.928246
# INFO:src.pipeline:  model_rmse_csi: 0.240772
# INFO:src.pipeline:  model_mae_csi: 0.167181
# INFO:src.pipeline:  model_mape_csi: 44.710777
# INFO:src.pipeline:  nam_rmse_csi: 4.165013
# INFO:src.pipeline:  nam_mae_csi: 1.947558
# INFO:src.pipeline:  nam_mape_csi: 406.928246
# INFO:src.pipeline:  rmse_skill_ghi_pct: 68.822544
# INFO:src.pipeline:  rmse_skill_csi_pct: 94.219185
# INFO:src.pipeline:  mae_skill_ghi_pct: 74.816676
# INFO:src.pipeline:  mae_skill_csi_pct: 91.415886
# INFO:src.pipeline:  mape_skill_ghi_pct: 86.008654
# INFO:src.pipeline:  mape_skill_csi_pct: 89.012614
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 29 ===
# INFO:src.pipeline:Train samples: 855, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044068, Val Loss: 0.018783, Train MAE: 0.148557, Val MAE: 0.107663, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034193, Val Loss: 0.023617, Train MAE: 0.126661, Val MAE: 0.111334, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 27
# INFO:src.pipeline:Fold 29 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.021787
# INFO:src.pipeline:  rmse: 0.147604
# INFO:src.pipeline:  mae: 0.101109
# INFO:src.pipeline:  r2: 0.626952
# INFO:src.pipeline:  mape: 14.759300
# INFO:src.pipeline:  model_rmse_ghi: 31.770872
# INFO:src.pipeline:  nam_rmse_ghi: 166.941379
# INFO:src.pipeline:  model_mae_ghi: 22.393602
# INFO:src.pipeline:  nam_mae_ghi: 130.514742
# INFO:src.pipeline:  model_mape_ghi: 20.721802
# INFO:src.pipeline:  nam_mape_ghi: 202.740561
# INFO:src.pipeline:  model_rmse_csi: 0.147604
# INFO:src.pipeline:  model_mae_csi: 0.101109
# INFO:src.pipeline:  model_mape_csi: 14.759300
# INFO:src.pipeline:  nam_rmse_csi: 1742.136105
# INFO:src.pipeline:  nam_mae_csi: 314.197475
# INFO:src.pipeline:  nam_mape_csi: 159449.823308
# INFO:src.pipeline:  rmse_skill_ghi_pct: 80.968845
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.991527
# INFO:src.pipeline:  mae_skill_ghi_pct: 82.842090
# INFO:src.pipeline:  mae_skill_csi_pct: 99.967820
# INFO:src.pipeline:  mape_skill_ghi_pct: 89.779153
# INFO:src.pipeline:  mape_skill_csi_pct: 99.990744
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 30 ===
# INFO:src.pipeline:Train samples: 885, Val samples: 27
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043634, Val Loss: 0.003378, Train MAE: 0.146358, Val MAE: 0.048904, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036644, Val Loss: 0.002529, Train MAE: 0.131426, Val MAE: 0.040529, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.034185, Val Loss: 0.001495, Train MAE: 0.123877, Val MAE: 0.027403, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.021949, Val Loss: 0.002641, Train MAE: 0.098617, Val MAE: 0.043565, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.018531, Val Loss: 0.001678, Train MAE: 0.091846, Val MAE: 0.029354, LR: 0.000500
# INFO:src.pipeline:Fold 30 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.001678
# INFO:src.pipeline:  rmse: 0.040963
# INFO:src.pipeline:  mae: 0.029354
# INFO:src.pipeline:  r2: 0.955393
# INFO:src.pipeline:  mape: 3.447986
# INFO:src.pipeline:  model_rmse_ghi: 14.370291
# INFO:src.pipeline:  nam_rmse_ghi: 158.851647
# INFO:src.pipeline:  model_mae_ghi: 8.278374
# INFO:src.pipeline:  nam_mae_ghi: 128.009580
# INFO:src.pipeline:  model_mape_ghi: 5.578982
# INFO:src.pipeline:  nam_mape_ghi: 368.703288
# INFO:src.pipeline:  model_rmse_csi: 0.040963
# INFO:src.pipeline:  model_mae_csi: 0.029354
# INFO:src.pipeline:  model_mape_csi: 3.447986
# INFO:src.pipeline:  nam_rmse_csi: 2324.382922
# INFO:src.pipeline:  nam_mae_csi: 343.365065
# INFO:src.pipeline:  nam_mape_csi: 68595.502221
# INFO:src.pipeline:  rmse_skill_ghi_pct: 90.953640
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.998238
# INFO:src.pipeline:  mae_skill_ghi_pct: 93.533005
# INFO:src.pipeline:  mae_skill_csi_pct: 99.991451
# INFO:src.pipeline:  mape_skill_ghi_pct: 98.486864
# INFO:src.pipeline:  mape_skill_csi_pct: 99.994973
# INFO:src.pipeline:  n_rows: 378.000000
# INFO:src.pipeline:  n_daylight_rows: 108.000000
# INFO:src.pipeline:
# === Running Fold 31 ===
# INFO:src.pipeline:Train samples: 913, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041503, Val Loss: 0.011417, Train MAE: 0.139981, Val MAE: 0.058645, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037323, Val Loss: 0.011526, Train MAE: 0.131005, Val MAE: 0.057803, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.027569, Val Loss: 0.009156, Train MAE: 0.110760, Val MAE: 0.049346, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Fold 31 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.010381
# INFO:src.pipeline:  rmse: 0.101887
# INFO:src.pipeline:  mae: 0.059153
# INFO:src.pipeline:  r2: 0.752742
# INFO:src.pipeline:  mape: 8.011910
# INFO:src.pipeline:  model_rmse_ghi: 20.428099
# INFO:src.pipeline:  nam_rmse_ghi: 89.471777
# INFO:src.pipeline:  model_mae_ghi: 11.084358
# INFO:src.pipeline:  nam_mae_ghi: 65.181749
# INFO:src.pipeline:  model_mape_ghi: 9.813582
# INFO:src.pipeline:  nam_mape_ghi: 330.764257
# INFO:src.pipeline:  model_rmse_csi: 0.101887
# INFO:src.pipeline:  model_mae_csi: 0.059153
# INFO:src.pipeline:  model_mape_csi: 8.011910
# INFO:src.pipeline:  nam_rmse_csi: 2868.743811
# INFO:src.pipeline:  nam_mae_csi: 420.722030
# INFO:src.pipeline:  nam_mape_csi: 47629.901026
# INFO:src.pipeline:  rmse_skill_ghi_pct: 77.168108
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.996448
# INFO:src.pipeline:  mae_skill_ghi_pct: 82.994690
# INFO:src.pipeline:  mae_skill_csi_pct: 99.985940
# INFO:src.pipeline:  mape_skill_ghi_pct: 97.033058
# INFO:src.pipeline:  mape_skill_csi_pct: 99.983179
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 88.000000
# INFO:src.pipeline:
# === Running Fold 32 ===
# INFO:src.pipeline:Train samples: 944, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041479, Val Loss: 0.010934, Train MAE: 0.140796, Val MAE: 0.070217, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036896, Val Loss: 0.009757, Train MAE: 0.129791, Val MAE: 0.057677, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.029609, Val Loss: 0.011083, Train MAE: 0.116058, Val MAE: 0.069456, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.020455, Val Loss: 0.011088, Train MAE: 0.094686, Val MAE: 0.049010, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 45
# INFO:src.pipeline:Fold 32 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.010041
# INFO:src.pipeline:  rmse: 0.100206
# INFO:src.pipeline:  mae: 0.047158
# INFO:src.pipeline:  r2: 0.781675
# INFO:src.pipeline:  mape: 6.359904
# INFO:src.pipeline:  model_rmse_ghi: 9.791299
# INFO:src.pipeline:  nam_rmse_ghi: 20.938126
# INFO:src.pipeline:  model_mae_ghi: 5.957626
# INFO:src.pipeline:  nam_mae_ghi: 16.693148
# INFO:src.pipeline:  model_mape_ghi: 7.333543
# INFO:src.pipeline:  nam_mape_ghi: 67.489418
# INFO:src.pipeline:  model_rmse_csi: 0.100206
# INFO:src.pipeline:  model_mae_csi: 0.047158
# INFO:src.pipeline:  model_mape_csi: 6.359904
# INFO:src.pipeline:  nam_rmse_csi: 0.817794
# INFO:src.pipeline:  nam_mae_csi: 0.380120
# INFO:src.pipeline:  nam_mape_csi: 68.573104
# INFO:src.pipeline:  rmse_skill_ghi_pct: 53.236986
# INFO:src.pipeline:  rmse_skill_csi_pct: 87.746794
# INFO:src.pipeline:  mae_skill_ghi_pct: 64.310950
# INFO:src.pipeline:  mae_skill_csi_pct: 87.593895
# INFO:src.pipeline:  mape_skill_ghi_pct: 89.133789
# INFO:src.pipeline:  mape_skill_csi_pct: 90.725366
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 33 ===
# INFO:src.pipeline:Train samples: 974, Val samples: 30
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.039778, Val Loss: 0.076070, Train MAE: 0.136312, Val MAE: 0.204485, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036280, Val Loss: 0.097607, Train MAE: 0.127266, Val MAE: 0.200061, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.026748, Val Loss: 0.110658, Train MAE: 0.108676, Val MAE: 0.201535, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 30
# INFO:src.pipeline:Fold 33 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.110658
# INFO:src.pipeline:  rmse: 0.332653
# INFO:src.pipeline:  mae: 0.201535
# INFO:src.pipeline:  r2: 0.157924
# INFO:src.pipeline:  mape: 96.684212
# INFO:src.pipeline:  model_rmse_ghi: 14.155962
# INFO:src.pipeline:  nam_rmse_ghi: 33.710817
# INFO:src.pipeline:  model_mae_ghi: 10.761549
# INFO:src.pipeline:  nam_mae_ghi: 28.381508
# INFO:src.pipeline:  model_mape_ghi: 68.432810
# INFO:src.pipeline:  nam_mape_ghi: 147.636336
# INFO:src.pipeline:  model_rmse_csi: 0.332653
# INFO:src.pipeline:  model_mae_csi: 0.201535
# INFO:src.pipeline:  model_mape_csi: 96.684212
# INFO:src.pipeline:  nam_rmse_csi: 141.727556
# INFO:src.pipeline:  nam_mae_csi: 34.996511
# INFO:src.pipeline:  nam_mape_csi: 9581.218096
# INFO:src.pipeline:  rmse_skill_ghi_pct: 58.007657
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.765287
# INFO:src.pipeline:  mae_skill_ghi_pct: 62.082534
# INFO:src.pipeline:  mae_skill_csi_pct: 99.424129
# INFO:src.pipeline:  mape_skill_ghi_pct: 53.647718
# INFO:src.pipeline:  mape_skill_csi_pct: 98.990899
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 34 ===
# INFO:src.pipeline:Train samples: 1005, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041036, Val Loss: 0.056239, Train MAE: 0.139336, Val MAE: 0.179903, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037512, Val Loss: 0.063754, Train MAE: 0.130356, Val MAE: 0.197475, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.028563, Val Loss: 0.076573, Train MAE: 0.111893, Val MAE: 0.214676, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Fold 34 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.082469
# INFO:src.pipeline:  rmse: 0.287174
# INFO:src.pipeline:  mae: 0.216067
# INFO:src.pipeline:  r2: 0.235197
# INFO:src.pipeline:  mape: 44.613327
# INFO:src.pipeline:  model_rmse_ghi: 2.518494
# INFO:src.pipeline:  nam_rmse_ghi: 31.695118
# INFO:src.pipeline:  model_mae_ghi: 2.009664
# INFO:src.pipeline:  nam_mae_ghi: 29.942103
# INFO:src.pipeline:  model_mape_ghi: 50.734665
# INFO:src.pipeline:  nam_mape_ghi: 760.523498
# INFO:src.pipeline:  model_rmse_csi: 0.287174
# INFO:src.pipeline:  model_mae_csi: 0.216067
# INFO:src.pipeline:  model_mape_csi: 44.613327
# INFO:src.pipeline:  nam_rmse_csi: 3.844745
# INFO:src.pipeline:  nam_mae_csi: 3.126345
# INFO:src.pipeline:  nam_mape_csi: 986.974761
# INFO:src.pipeline:  rmse_skill_ghi_pct: 92.054000
# INFO:src.pipeline:  rmse_skill_csi_pct: 92.530741
# INFO:src.pipeline:  mae_skill_ghi_pct: 93.288167
# INFO:src.pipeline:  mae_skill_csi_pct: 93.088833
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.328981
# INFO:src.pipeline:  mape_skill_csi_pct: 95.479790
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 23.000000
# INFO:src.pipeline:
# === Running Fold 35 ===
# INFO:src.pipeline:Train samples: 1035, Val samples: 29
# INFO:src.pipeline:Model parameters: 973,582
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041854, Val Loss: 0.057601, Train MAE: 0.139110, Val MAE: 0.180480, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037867, Val Loss: 0.074199, Train MAE: 0.130514, Val MAE: 0.209641, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.028295, Val Loss: 0.108314, Train MAE: 0.110371, Val MAE: 0.235766, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 30
# INFO:src.pipeline:Fold 35 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.108314
# INFO:src.pipeline:  rmse: 0.329111
# INFO:src.pipeline:  mae: 0.235766
# INFO:src.pipeline:  r2: 0.104084
# INFO:src.pipeline:  mape: 83.654305
# INFO:src.pipeline:  model_rmse_ghi: 1.288715
# INFO:src.pipeline:  nam_rmse_ghi: 30.345306
# INFO:src.pipeline:  model_mae_ghi: 1.103925
# INFO:src.pipeline:  nam_mae_ghi: 29.192504
# INFO:src.pipeline:  model_mape_ghi: 41.939272
# INFO:src.pipeline:  nam_mape_ghi: 1053.923847
# INFO:src.pipeline:  model_rmse_csi: 0.329111
# INFO:src.pipeline:  model_mae_csi: 0.235766
# INFO:src.pipeline:  model_mape_csi: 83.654305
# INFO:src.pipeline:  nam_rmse_csi: 4216.288381
# INFO:src.pipeline:  nam_mae_csi: 902.986886
# INFO:src.pipeline:  nam_mape_csi: 334509.545063
# INFO:src.pipeline:  rmse_skill_ghi_pct: 95.753166
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.992194
# INFO:src.pipeline:  mae_skill_ghi_pct: 96.218464
# INFO:src.pipeline:  mae_skill_csi_pct: 99.973890
# INFO:src.pipeline:  mape_skill_ghi_pct: 96.020654
# INFO:src.pipeline:  mape_skill_csi_pct: 99.974992
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 11.000000
# INFO:src.pipeline:
# === Experiment Summary ===
# INFO:src.pipeline:Average Validation Metrics:
# INFO:src.pipeline:  mse: 0.082726 ± 0.097279
# INFO:src.pipeline:  rmse: 0.260423 ± 0.122089
# INFO:src.pipeline:  mae: 0.184273 ± 0.100026
# INFO:src.pipeline:  r2: 0.128177 ± 0.760057
# INFO:src.pipeline:  mape: 47.199436 ± 30.934003
# INFO:src.pipeline:  model_rmse_ghi: 30.311071 ± 24.354351
# INFO:src.pipeline:  nam_rmse_ghi: nan ± nan
# INFO:src.pipeline:  model_mae_ghi: 18.882313 ± 16.508394
# INFO:src.pipeline:  nam_mae_ghi: nan ± nan
# INFO:src.pipeline:  model_mape_ghi: 50.558546 ± 34.560218
# INFO:src.pipeline:  nam_mape_ghi: nan ± nan
# INFO:src.pipeline:  model_rmse_csi: 0.260423 ± 0.122089
# INFO:src.pipeline:  model_mae_csi: 0.184273 ± 0.100026
# INFO:src.pipeline:  model_mape_csi: 47.199436 ± 30.934003
# INFO:src.pipeline:  nam_rmse_csi: 1899.888090 ± 5082.770758
# INFO:src.pipeline:  nam_mae_csi: 243.899171 ± 530.892522
# INFO:src.pipeline:  nam_mape_csi: 51546.548405 ± 98706.806975
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 87.868420 ± 24.453650
# INFO:src.pipeline:  mae_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  mae_skill_csi_pct: 86.546174 ± 27.398147
# INFO:src.pipeline:  mape_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  mape_skill_csi_pct: 89.086959 ± 21.578755
# INFO:src.pipeline:  n_rows: 404.800000 ± 33.023628
# INFO:src.pipeline:  n_daylight_rows: 64.057143 ± 37.604668

# %% [markdown]
# ----

# %%
selected_columns = ['solar_zenith',
       'hour_progression', 'absolute_hour', 'CSI_ghi',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos',
       'nam_ghi', 'nam_dni', 'nam_cc']


print("\n--- Step 2: Building model arrays (X, Y) ---")
fixed_df = to_fixedgrid_multiindex(df_phase3, timestamp_col="measurement_time", expected_T=None)  # or set T
# Zero-impute everything (features + target)
ph3_X, ph3_Y, ph3_labels_list = build_model_arrays(
        fixed_df,
        feature_cols=selected_columns,  # must include your chosen inputs
        target_col=TARGET_COL,          # target must be present in columns
        history_days=7,
        horizon_days=1,
    )

print(ph3_X.shape, ph3_Y.shape)
# Out:
# --- Step 2: Building model arrays (X, Y) ---
# (1064, 7, 14, 12) (1064, 1, 14)

# %%
print("=====================================\n")

import pandas as pd
from src.utils import DataManager
from src.pipeline import SolarForecastingPipeline


TARGET_COL = 'CSI_ghi'
feature_cols = [c for c in df_phase3.columns.tolist() if c != TARGET_COL]

data_manager = DataManager()
data_manager.save_arrays(
    ph3_X, ph3_Y,
    pd.DataFrame(index=pd.to_datetime(ph3_labels_list, utc=True)),
    filename_prefix='phas3_data',
    feature_cols=feature_cols,
    target_col=TARGET_COL,
    metadata={
        "input_csv": "data/processed/dayTime_NAM_dayahead_features_processed.csv",
        "timestamp_col": "measurement_time",
        "feature_set": feature_cols,     # for traceability
        "history_days": 7,
        "horizon_days": 1,
        "k_bins": None,
    }
)



LSTM_CONFIG = {
    "experiment_name": "phas3_exp_test",
    "model_type": "LSTM",
    "model_config": {
        "hidden_size": 128,
        "num_layers": 2,
        "dropout": 0.2,
        "bidirectional": True,
    },
    "data_prefix": "phas3_data",
    "splits_file": "exp-001/exp-001rolling_origin_splits.json",
    "feature_cols": feature_cols,
    "feature_selection": feature_cols,
    "target_col": TARGET_COL,
    "batch_size": 32,
    "num_epochs": 50,
    "learning_rate": 0.001,
    "early_stopping_patience": 20,
    "max_folds": 35,
}


pipeline = SolarForecastingPipeline(LSTM_CONFIG)
_, summary = pipeline.run()
# Out:
# INFO:src.utils:Saved arrays to data/phas3_data_*.npy
# INFO:src.utils:X shape: (1064, 7, 14, 12), Y shape: (1064, 1, 14)
# INFO:src.pipeline:Loading data...
# INFO:src.utils:Loaded arrays from data/phas3_data_*.npy
# INFO:src.utils:X shape: (1064, 7, 14, 12), Y shape: (1064, 1, 14)
# =====================================
# INFO:src.pipeline:Reference dataframe prepared for NAM comparison (15162 rows).
# INFO:src.utils:Loaded 35 folds from exp-001/exp-001rolling_origin_splits.json
# INFO:src.pipeline:
# === Running Fold 1 ===
# INFO:src.pipeline:Train samples: 19, Val samples: 16
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.050164, Val Loss: 0.188769, Train MAE: 0.147607, Val MAE: 0.370701, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036586, Val Loss: 0.356881, Train MAE: 0.131588, Val MAE: 0.474056, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 27
# INFO:src.pipeline:Fold 1 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.551429
# INFO:src.pipeline:  rmse: 0.742583
# INFO:src.pipeline:  mae: 0.602680
# INFO:src.pipeline:  r2: -2.700127
# INFO:src.pipeline:  mape: 126.177391
# INFO:src.pipeline:  model_rmse_ghi: 115.457624
# INFO:src.pipeline:  nam_rmse_ghi: 47.325744
# INFO:src.pipeline:  model_mae_ghi: 84.649267
# INFO:src.pipeline:  nam_mae_ghi: 39.566995
# INFO:src.pipeline:  model_mape_ghi: 200.408919
# INFO:src.pipeline:  nam_mape_ghi: 337.824906
# INFO:src.pipeline:  model_rmse_csi: 0.742583
# INFO:src.pipeline:  model_mae_csi: 0.602680
# INFO:src.pipeline:  model_mape_csi: 126.177391
# INFO:src.pipeline:  nam_rmse_csi: 59.491574
# INFO:src.pipeline:  nam_mae_csi: 17.255400
# INFO:src.pipeline:  nam_mape_csi: 8727.254750
# INFO:src.pipeline:  rmse_skill_ghi_pct: -143.963675
# INFO:src.pipeline:  rmse_skill_csi_pct: 98.751785
# INFO:src.pipeline:  mae_skill_ghi_pct: -113.939087
# INFO:src.pipeline:  mae_skill_csi_pct: 96.507298
# INFO:src.pipeline:  mape_skill_ghi_pct: 40.676689
# INFO:src.pipeline:  mape_skill_csi_pct: 98.554214
# INFO:src.pipeline:  n_rows: 224.000000
# INFO:src.pipeline:  n_daylight_rows: 25.000000
# INFO:src.pipeline:
# === Running Fold 2 ===
# INFO:src.pipeline:Train samples: 36, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.085617, Val Loss: 0.082220, Train MAE: 0.231423, Val MAE: 0.240475, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.074212, Val Loss: 0.092966, Train MAE: 0.190842, Val MAE: 0.211460, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.037551, Val Loss: 0.132811, Train MAE: 0.142890, Val MAE: 0.262747, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.055248, Val Loss: 0.075752, Train MAE: 0.153851, Val MAE: 0.193900, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.029571, Val Loss: 0.112820, Train MAE: 0.121383, Val MAE: 0.246580, LR: 0.000500
# INFO:src.pipeline:Fold 2 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.112820
# INFO:src.pipeline:  rmse: 0.335887
# INFO:src.pipeline:  mae: 0.246580
# INFO:src.pipeline:  r2: 0.012509
# INFO:src.pipeline:  mape: 70.209976
# INFO:src.pipeline:  model_rmse_ghi: 61.782055
# INFO:src.pipeline:  nam_rmse_ghi: 28.918516
# INFO:src.pipeline:  model_mae_ghi: 41.366083
# INFO:src.pipeline:  nam_mae_ghi: 18.172979
# INFO:src.pipeline:  model_mape_ghi: 96.863434
# INFO:src.pipeline:  nam_mape_ghi: 73.857357
# INFO:src.pipeline:  model_rmse_csi: 0.335887
# INFO:src.pipeline:  model_mae_csi: 0.246580
# INFO:src.pipeline:  model_mape_csi: 70.209976
# INFO:src.pipeline:  nam_rmse_csi: 0.342068
# INFO:src.pipeline:  nam_mae_csi: 0.203361
# INFO:src.pipeline:  nam_mape_csi: 73.857357
# INFO:src.pipeline:  rmse_skill_ghi_pct: -113.641862
# INFO:src.pipeline:  rmse_skill_csi_pct: 1.806821
# INFO:src.pipeline:  mae_skill_ghi_pct: -127.624123
# INFO:src.pipeline:  mae_skill_csi_pct: -21.252496
# INFO:src.pipeline:  mape_skill_ghi_pct: -31.149337
# INFO:src.pipeline:  mape_skill_csi_pct: 4.938412
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 3 ===
# INFO:src.pipeline:Train samples: 67, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.065689, Val Loss: 0.051198, Train MAE: 0.188808, Val MAE: 0.165598, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.049998, Val Loss: 0.159072, Train MAE: 0.173369, Val MAE: 0.346029, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 27
# INFO:src.pipeline:Fold 3 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.142921
# INFO:src.pipeline:  rmse: 0.378049
# INFO:src.pipeline:  mae: 0.332931
# INFO:src.pipeline:  r2: -0.850855
# INFO:src.pipeline:  mape: 41.374199
# INFO:src.pipeline:  model_rmse_ghi: 69.268784
# INFO:src.pipeline:  nam_rmse_ghi: 82.375138
# INFO:src.pipeline:  model_mae_ghi: 52.238364
# INFO:src.pipeline:  nam_mae_ghi: 46.609284
# INFO:src.pipeline:  model_mape_ghi: 38.187949
# INFO:src.pipeline:  nam_mape_ghi: 247.917462
# INFO:src.pipeline:  model_rmse_csi: 0.378049
# INFO:src.pipeline:  model_mae_csi: 0.332931
# INFO:src.pipeline:  model_mape_csi: 41.374199
# INFO:src.pipeline:  nam_rmse_csi: 4233.970265
# INFO:src.pipeline:  nam_mae_csi: 520.457473
# INFO:src.pipeline:  nam_mape_csi: 61476.609638
# INFO:src.pipeline:  rmse_skill_ghi_pct: 15.910570
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.991071
# INFO:src.pipeline:  mae_skill_ghi_pct: -12.077163
# INFO:src.pipeline:  mae_skill_csi_pct: 99.936031
# INFO:src.pipeline:  mape_skill_ghi_pct: 84.596507
# INFO:src.pipeline:  mape_skill_csi_pct: 99.932699
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 71.000000
# INFO:src.pipeline:
# === Running Fold 4 ===
# INFO:src.pipeline:Train samples: 97, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.117543, Val Loss: 0.030289, Train MAE: 0.247390, Val MAE: 0.139686, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.048338, Val Loss: 0.034294, Train MAE: 0.174961, Val MAE: 0.162696, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# INFO:src.pipeline:Fold 4 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.031607
# INFO:src.pipeline:  rmse: 0.177785
# INFO:src.pipeline:  mae: 0.113381
# INFO:src.pipeline:  r2: 0.366795
# INFO:src.pipeline:  mape: 17.082382
# INFO:src.pipeline:  model_rmse_ghi: 38.396451
# INFO:src.pipeline:  nam_rmse_ghi: 177.658241
# INFO:src.pipeline:  model_mae_ghi: 21.930644
# INFO:src.pipeline:  nam_mae_ghi: 119.355573
# INFO:src.pipeline:  model_mape_ghi: 26.506543
# INFO:src.pipeline:  nam_mape_ghi: 404.329564
# INFO:src.pipeline:  model_rmse_csi: 0.177785
# INFO:src.pipeline:  model_mae_csi: 0.113381
# INFO:src.pipeline:  model_mape_csi: 17.082382
# INFO:src.pipeline:  nam_rmse_csi: 6.393005
# INFO:src.pipeline:  nam_mae_csi: 3.094590
# INFO:src.pipeline:  nam_mape_csi: 404.329564
# INFO:src.pipeline:  rmse_skill_ghi_pct: 78.387464
# INFO:src.pipeline:  rmse_skill_csi_pct: 97.219073
# INFO:src.pipeline:  mae_skill_ghi_pct: 81.625789
# INFO:src.pipeline:  mae_skill_csi_pct: 96.336140
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.444322
# INFO:src.pipeline:  mape_skill_csi_pct: 95.775134
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 5 ===
# INFO:src.pipeline:Train samples: 128, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045762, Val Loss: 0.058628, Train MAE: 0.154894, Val MAE: 0.222432, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034464, Val Loss: 0.059754, Train MAE: 0.128416, Val MAE: 0.225918, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 23
# INFO:src.pipeline:Fold 5 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.051544
# INFO:src.pipeline:  rmse: 0.227034
# INFO:src.pipeline:  mae: 0.204472
# INFO:src.pipeline:  r2: -0.325537
# INFO:src.pipeline:  mape: 22.975561
# INFO:src.pipeline:  model_rmse_ghi: 61.374529
# INFO:src.pipeline:  nam_rmse_ghi: 183.386569
# INFO:src.pipeline:  model_mae_ghi: 46.655817
# INFO:src.pipeline:  nam_mae_ghi: 126.617010
# INFO:src.pipeline:  model_mape_ghi: 26.030670
# INFO:src.pipeline:  nam_mape_ghi: 203.539202
# INFO:src.pipeline:  model_rmse_csi: 0.227034
# INFO:src.pipeline:  model_mae_csi: 0.204472
# INFO:src.pipeline:  model_mape_csi: 22.975561
# INFO:src.pipeline:  nam_rmse_csi: 1827.663220
# INFO:src.pipeline:  nam_mae_csi: 405.586491
# INFO:src.pipeline:  nam_mape_csi: 72924.087870
# INFO:src.pipeline:  rmse_skill_ghi_pct: 66.532702
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.987578
# INFO:src.pipeline:  mae_skill_ghi_pct: 63.152014
# INFO:src.pipeline:  mae_skill_csi_pct: 99.949586
# INFO:src.pipeline:  mape_skill_ghi_pct: 87.210980
# INFO:src.pipeline:  mape_skill_csi_pct: 99.968494
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 6 ===
# INFO:src.pipeline:Train samples: 158, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.036395, Val Loss: 0.026320, Train MAE: 0.127285, Val MAE: 0.085503, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.029246, Val Loss: 0.025464, Train MAE: 0.112588, Val MAE: 0.087833, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.025315, Val Loss: 0.025987, Train MAE: 0.104296, Val MAE: 0.082958, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# INFO:src.pipeline:Fold 6 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.025991
# INFO:src.pipeline:  rmse: 0.161217
# INFO:src.pipeline:  mae: 0.084949
# INFO:src.pipeline:  r2: 0.509569
# INFO:src.pipeline:  mape: 19.763924
# INFO:src.pipeline:  model_rmse_ghi: 45.453252
# INFO:src.pipeline:  nam_rmse_ghi: 171.994205
# INFO:src.pipeline:  model_mae_ghi: 17.621767
# INFO:src.pipeline:  nam_mae_ghi: 119.377076
# INFO:src.pipeline:  model_mape_ghi: 33.202478
# INFO:src.pipeline:  nam_mape_ghi: 405.336845
# INFO:src.pipeline:  model_rmse_csi: 0.161217
# INFO:src.pipeline:  model_mae_csi: 0.084949
# INFO:src.pipeline:  model_mape_csi: 19.763924
# INFO:src.pipeline:  nam_rmse_csi: 1700.885180
# INFO:src.pipeline:  nam_mae_csi: 308.745768
# INFO:src.pipeline:  nam_mape_csi: 76197.389556
# INFO:src.pipeline:  rmse_skill_ghi_pct: 73.572800
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.990522
# INFO:src.pipeline:  mae_skill_ghi_pct: 85.238567
# INFO:src.pipeline:  mae_skill_csi_pct: 99.972486
# INFO:src.pipeline:  mape_skill_ghi_pct: 91.808670
# INFO:src.pipeline:  mape_skill_csi_pct: 99.974062
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 7 ===
# INFO:src.pipeline:Train samples: 189, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.037073, Val Loss: 0.049076, Train MAE: 0.124897, Val MAE: 0.135720, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.029685, Val Loss: 0.045832, Train MAE: 0.113838, Val MAE: 0.144965, LR: 0.000500
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.026101, Val Loss: 0.046086, Train MAE: 0.106779, Val MAE: 0.143857, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.022263, Val Loss: 0.043134, Train MAE: 0.096905, Val MAE: 0.136655, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.019684, Val Loss: 0.049615, Train MAE: 0.092210, Val MAE: 0.147168, LR: 0.000500
# INFO:src.pipeline:Fold 7 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.049615
# INFO:src.pipeline:  rmse: 0.222745
# INFO:src.pipeline:  mae: 0.147168
# INFO:src.pipeline:  r2: 0.316086
# INFO:src.pipeline:  mape: 28.755432
# INFO:src.pipeline:  model_rmse_ghi: 34.417259
# INFO:src.pipeline:  nam_rmse_ghi: 88.975472
# INFO:src.pipeline:  model_mae_ghi: 18.804617
# INFO:src.pipeline:  nam_mae_ghi: 57.500647
# INFO:src.pipeline:  model_mape_ghi: 33.026589
# INFO:src.pipeline:  nam_mape_ghi: 721.274585
# INFO:src.pipeline:  model_rmse_csi: 0.222745
# INFO:src.pipeline:  model_mae_csi: 0.147168
# INFO:src.pipeline:  model_mape_csi: 28.755432
# INFO:src.pipeline:  nam_rmse_csi: 29388.587128
# INFO:src.pipeline:  nam_mae_csi: 2977.618492
# INFO:src.pipeline:  nam_mape_csi: 351278.956119
# INFO:src.pipeline:  rmse_skill_ghi_pct: 61.318262
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.999242
# INFO:src.pipeline:  mae_skill_ghi_pct: 67.296686
# INFO:src.pipeline:  mae_skill_csi_pct: 99.995058
# INFO:src.pipeline:  mape_skill_ghi_pct: 95.421080
# INFO:src.pipeline:  mape_skill_csi_pct: 99.991814
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 89.000000
# INFO:src.pipeline:
# === Running Fold 8 ===
# INFO:src.pipeline:Train samples: 220, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.034762, Val Loss: 0.041628, Train MAE: 0.127775, Val MAE: 0.119119, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.025735, Val Loss: 0.042806, Train MAE: 0.105792, Val MAE: 0.104177, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 23
# INFO:src.pipeline:Fold 8 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.043671
# INFO:src.pipeline:  rmse: 0.208977
# INFO:src.pipeline:  mae: 0.105512
# INFO:src.pipeline:  r2: 0.340189
# INFO:src.pipeline:  mape: 26.976650
# INFO:src.pipeline:  model_rmse_ghi: 22.364187
# INFO:src.pipeline:  nam_rmse_ghi: 29.103083
# INFO:src.pipeline:  model_mae_ghi: 13.080779
# INFO:src.pipeline:  nam_mae_ghi: 22.579527
# INFO:src.pipeline:  model_mape_ghi: 19.561266
# INFO:src.pipeline:  nam_mape_ghi: 80.821695
# INFO:src.pipeline:  model_rmse_csi: 0.208977
# INFO:src.pipeline:  model_mae_csi: 0.105512
# INFO:src.pipeline:  model_mape_csi: 26.976650
# INFO:src.pipeline:  nam_rmse_csi: 0.716143
# INFO:src.pipeline:  nam_mae_csi: 0.371663
# INFO:src.pipeline:  nam_mape_csi: 81.764890
# INFO:src.pipeline:  rmse_skill_ghi_pct: 23.155265
# INFO:src.pipeline:  rmse_skill_csi_pct: 70.819086
# INFO:src.pipeline:  mae_skill_ghi_pct: 42.067965
# INFO:src.pipeline:  mae_skill_csi_pct: 71.610776
# INFO:src.pipeline:  mape_skill_ghi_pct: 75.797011
# INFO:src.pipeline:  mape_skill_csi_pct: 67.007049
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 9 ===
# INFO:src.pipeline:Train samples: 250, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.033998, Val Loss: 0.042646, Train MAE: 0.123807, Val MAE: 0.154790, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.026595, Val Loss: 0.042235, Train MAE: 0.104434, Val MAE: 0.161072, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.023922, Val Loss: 0.041698, Train MAE: 0.098962, Val MAE: 0.157679, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.016214, Val Loss: 0.043267, Train MAE: 0.084620, Val MAE: 0.162130, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 45
# INFO:src.pipeline:Fold 9 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.066159
# INFO:src.pipeline:  rmse: 0.257214
# INFO:src.pipeline:  mae: 0.208297
# INFO:src.pipeline:  r2: 0.177945
# INFO:src.pipeline:  mape: 35.531815
# INFO:src.pipeline:  model_rmse_ghi: 13.034736
# INFO:src.pipeline:  nam_rmse_ghi: 32.796185
# INFO:src.pipeline:  model_mae_ghi: 8.996352
# INFO:src.pipeline:  nam_mae_ghi: 30.029067
# INFO:src.pipeline:  model_mape_ghi: 36.433750
# INFO:src.pipeline:  nam_mape_ghi: 119.777834
# INFO:src.pipeline:  model_rmse_csi: 0.257214
# INFO:src.pipeline:  model_mae_csi: 0.208297
# INFO:src.pipeline:  model_mape_csi: 35.531815
# INFO:src.pipeline:  nam_rmse_csi: 372.061651
# INFO:src.pipeline:  nam_mae_csi: 75.969811
# INFO:src.pipeline:  nam_mape_csi: 19967.417197
# INFO:src.pipeline:  rmse_skill_ghi_pct: 60.255330
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.930868
# INFO:src.pipeline:  mae_skill_ghi_pct: 70.041186
# INFO:src.pipeline:  mae_skill_csi_pct: 99.725816
# INFO:src.pipeline:  mape_skill_ghi_pct: 69.582227
# INFO:src.pipeline:  mape_skill_csi_pct: 99.822051
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 10 ===
# INFO:src.pipeline:Train samples: 281, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.035332, Val Loss: 0.072516, Train MAE: 0.119489, Val MAE: 0.198375, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.032355, Val Loss: 0.075274, Train MAE: 0.116531, Val MAE: 0.215519, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.022760, Val Loss: 0.068127, Train MAE: 0.097793, Val MAE: 0.196255, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.019427, Val Loss: 0.067387, Train MAE: 0.090819, Val MAE: 0.187638, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.014057, Val Loss: 0.068836, Train MAE: 0.077346, Val MAE: 0.201786, LR: 0.000500
# INFO:src.pipeline:Fold 10 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.068836
# INFO:src.pipeline:  rmse: 0.262366
# INFO:src.pipeline:  mae: 0.201786
# INFO:src.pipeline:  r2: 0.448204
# INFO:src.pipeline:  mape: 45.197262
# INFO:src.pipeline:  model_rmse_ghi: 3.861638
# INFO:src.pipeline:  nam_rmse_ghi: 32.120222
# INFO:src.pipeline:  model_mae_ghi: 2.356445
# INFO:src.pipeline:  nam_mae_ghi: 30.741089
# INFO:src.pipeline:  model_mape_ghi: 50.447021
# INFO:src.pipeline:  nam_mape_ghi: 1061.061250
# INFO:src.pipeline:  model_rmse_csi: 0.262366
# INFO:src.pipeline:  model_mae_csi: 0.201786
# INFO:src.pipeline:  model_mape_csi: 45.197262
# INFO:src.pipeline:  nam_rmse_csi: 3.625350
# INFO:src.pipeline:  nam_mae_csi: 3.027441
# INFO:src.pipeline:  nam_mape_csi: 1229.109594
# INFO:src.pipeline:  rmse_skill_ghi_pct: 87.977549
# INFO:src.pipeline:  rmse_skill_csi_pct: 92.763022
# INFO:src.pipeline:  mae_skill_ghi_pct: 92.334543
# INFO:src.pipeline:  mae_skill_csi_pct: 93.334779
# INFO:src.pipeline:  mape_skill_ghi_pct: 95.245607
# INFO:src.pipeline:  mape_skill_csi_pct: 96.322764
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 24.000000
# INFO:src.pipeline:
# === Running Fold 11 ===
# INFO:src.pipeline:Train samples: 311, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.036702, Val Loss: 0.141260, Train MAE: 0.131741, Val MAE: 0.297990, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035269, Val Loss: 0.121361, Train MAE: 0.121598, Val MAE: 0.262918, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.024920, Val Loss: 0.121436, Train MAE: 0.103039, Val MAE: 0.250136, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 39
# INFO:src.pipeline:Fold 11 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.123749
# INFO:src.pipeline:  rmse: 0.351780
# INFO:src.pipeline:  mae: 0.251822
# INFO:src.pipeline:  r2: 0.088310
# INFO:src.pipeline:  mape: 111.480400
# INFO:src.pipeline:  model_rmse_ghi: 1.295908
# INFO:src.pipeline:  nam_rmse_ghi: 29.946906
# INFO:src.pipeline:  model_mae_ghi: 0.804827
# INFO:src.pipeline:  nam_mae_ghi: 27.822608
# INFO:src.pipeline:  model_mape_ghi: 46.344077
# INFO:src.pipeline:  nam_mape_ghi: 1340.377721
# INFO:src.pipeline:  model_rmse_csi: 0.351780
# INFO:src.pipeline:  model_mae_csi: 0.251822
# INFO:src.pipeline:  model_mape_csi: 111.480400
# INFO:src.pipeline:  nam_rmse_csi: 4.982339
# INFO:src.pipeline:  nam_mae_csi: 4.351954
# INFO:src.pipeline:  nam_mape_csi: 2454.787116
# INFO:src.pipeline:  rmse_skill_ghi_pct: 95.672649
# INFO:src.pipeline:  rmse_skill_csi_pct: 92.939467
# INFO:src.pipeline:  mae_skill_ghi_pct: 97.107290
# INFO:src.pipeline:  mae_skill_csi_pct: 94.213592
# INFO:src.pipeline:  mape_skill_ghi_pct: 96.542461
# INFO:src.pipeline:  mape_skill_csi_pct: 95.458653
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 11.000000
# INFO:src.pipeline:
# === Running Fold 12 ===
# INFO:src.pipeline:Train samples: 342, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044072, Val Loss: 0.070562, Train MAE: 0.142337, Val MAE: 0.212174, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.031370, Val Loss: 0.110173, Train MAE: 0.116169, Val MAE: 0.252722, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 26
# INFO:src.pipeline:Fold 12 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.162569
# INFO:src.pipeline:  rmse: 0.403198
# INFO:src.pipeline:  mae: 0.300222
# INFO:src.pipeline:  r2: -0.610950
# INFO:src.pipeline:  mape: 36.965275
# INFO:src.pipeline:  model_rmse_ghi: 15.253904
# INFO:src.pipeline:  nam_rmse_ghi: 34.512881
# INFO:src.pipeline:  model_mae_ghi: 10.569358
# INFO:src.pipeline:  nam_mae_ghi: 33.201618
# INFO:src.pipeline:  model_mape_ghi: 43.603691
# INFO:src.pipeline:  nam_mape_ghi: 279.598407
# INFO:src.pipeline:  model_rmse_csi: 0.403198
# INFO:src.pipeline:  model_mae_csi: 0.300222
# INFO:src.pipeline:  model_mape_csi: 36.965275
# INFO:src.pipeline:  nam_rmse_csi: 1.282367
# INFO:src.pipeline:  nam_mae_csi: 1.096885
# INFO:src.pipeline:  nam_mape_csi: 279.598407
# INFO:src.pipeline:  rmse_skill_ghi_pct: 55.802287
# INFO:src.pipeline:  rmse_skill_csi_pct: 68.558304
# INFO:src.pipeline:  mae_skill_ghi_pct: 68.166135
# INFO:src.pipeline:  mae_skill_csi_pct: 72.629594
# INFO:src.pipeline:  mape_skill_ghi_pct: 84.404886
# INFO:src.pipeline:  mape_skill_csi_pct: 86.779154
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 30.000000
# INFO:src.pipeline:
# === Running Fold 13 ===
# INFO:src.pipeline:Train samples: 373, Val samples: 27
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043915, Val Loss: 0.075893, Train MAE: 0.145940, Val MAE: 0.214239, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.033828, Val Loss: 0.081063, Train MAE: 0.123737, Val MAE: 0.206197, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 27
# INFO:src.pipeline:Fold 13 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.094788
# INFO:src.pipeline:  rmse: 0.307876
# INFO:src.pipeline:  mae: 0.206435
# INFO:src.pipeline:  r2: 0.212528
# INFO:src.pipeline:  mape: 87.044167
# INFO:src.pipeline:  model_rmse_ghi: 30.675437
# INFO:src.pipeline:  nam_rmse_ghi: 34.915795
# INFO:src.pipeline:  model_mae_ghi: 18.907110
# INFO:src.pipeline:  nam_mae_ghi: 28.073101
# INFO:src.pipeline:  model_mape_ghi: 83.815230
# INFO:src.pipeline:  nam_mape_ghi: 235.612876
# INFO:src.pipeline:  model_rmse_csi: 0.307876
# INFO:src.pipeline:  model_mae_csi: 0.206435
# INFO:src.pipeline:  model_mape_csi: 87.044167
# INFO:src.pipeline:  nam_rmse_csi: 40.391397
# INFO:src.pipeline:  nam_mae_csi: 12.919904
# INFO:src.pipeline:  nam_mape_csi: 13492.524929
# INFO:src.pipeline:  rmse_skill_ghi_pct: 12.144527
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.237767
# INFO:src.pipeline:  mae_skill_ghi_pct: 32.650440
# INFO:src.pipeline:  mae_skill_csi_pct: 98.402193
# INFO:src.pipeline:  mape_skill_ghi_pct: 64.426719
# INFO:src.pipeline:  mape_skill_csi_pct: 99.354871
# INFO:src.pipeline:  n_rows: 378.000000
# INFO:src.pipeline:  n_daylight_rows: 37.000000
# INFO:src.pipeline:
# === Running Fold 14 ===
# INFO:src.pipeline:Train samples: 401, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042367, Val Loss: 0.038060, Train MAE: 0.143061, Val MAE: 0.150350, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034355, Val Loss: 0.036744, Train MAE: 0.126382, Val MAE: 0.144478, LR: 0.000500
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.028092, Val Loss: 0.040086, Train MAE: 0.111358, Val MAE: 0.143675, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.021885, Val Loss: 0.039751, Train MAE: 0.100637, Val MAE: 0.139844, LR: 0.000250
# INFO:src.engine:Early stopping at epoch 41
# INFO:src.pipeline:Fold 14 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.039605
# INFO:src.pipeline:  rmse: 0.199011
# INFO:src.pipeline:  mae: 0.141019
# INFO:src.pipeline:  r2: 0.536175
# INFO:src.pipeline:  mape: 26.572830
# INFO:src.pipeline:  model_rmse_ghi: 29.307326
# INFO:src.pipeline:  nam_rmse_ghi: 27.314497
# INFO:src.pipeline:  model_mae_ghi: 17.228200
# INFO:src.pipeline:  nam_mae_ghi: 20.237865
# INFO:src.pipeline:  model_mape_ghi: 32.802333
# INFO:src.pipeline:  nam_mape_ghi: 49.977180
# INFO:src.pipeline:  model_rmse_csi: 0.199011
# INFO:src.pipeline:  model_mae_csi: 0.141019
# INFO:src.pipeline:  model_mape_csi: 26.572830
# INFO:src.pipeline:  nam_rmse_csi: 0.320300
# INFO:src.pipeline:  nam_mae_csi: 0.209284
# INFO:src.pipeline:  nam_mape_csi: 49.977180
# INFO:src.pipeline:  rmse_skill_ghi_pct: -7.295864
# INFO:src.pipeline:  rmse_skill_csi_pct: 37.867398
# INFO:src.pipeline:  mae_skill_ghi_pct: 14.871455
# INFO:src.pipeline:  mae_skill_csi_pct: 32.618050
# INFO:src.pipeline:  mape_skill_ghi_pct: 34.365378
# INFO:src.pipeline:  mape_skill_csi_pct: 46.830073
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 15 ===
# INFO:src.pipeline:Train samples: 432, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041566, Val Loss: 0.037704, Train MAE: 0.140448, Val MAE: 0.117000, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036866, Val Loss: 0.037236, Train MAE: 0.131820, Val MAE: 0.116547, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.023984, Val Loss: 0.036354, Train MAE: 0.106475, Val MAE: 0.110528, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.019818, Val Loss: 0.037824, Train MAE: 0.095826, Val MAE: 0.111638, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.015755, Val Loss: 0.037615, Train MAE: 0.085680, Val MAE: 0.113244, LR: 0.000250
# INFO:src.pipeline:Fold 15 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.037615
# INFO:src.pipeline:  rmse: 0.193947
# INFO:src.pipeline:  mae: 0.113244
# INFO:src.pipeline:  r2: 0.536836
# INFO:src.pipeline:  mape: 30.436615
# INFO:src.pipeline:  model_rmse_ghi: 48.592947
# INFO:src.pipeline:  nam_rmse_ghi: 82.344226
# INFO:src.pipeline:  model_mae_ghi: 27.960055
# INFO:src.pipeline:  nam_mae_ghi: 55.958252
# INFO:src.pipeline:  model_mape_ghi: 33.119403
# INFO:src.pipeline:  nam_mape_ghi: 282.624050
# INFO:src.pipeline:  model_rmse_csi: 0.193947
# INFO:src.pipeline:  model_mae_csi: 0.113244
# INFO:src.pipeline:  model_mape_csi: 30.436615
# INFO:src.pipeline:  nam_rmse_csi: 694.038902
# INFO:src.pipeline:  nam_mae_csi: 112.763228
# INFO:src.pipeline:  nam_mape_csi: 12988.119143
# INFO:src.pipeline:  rmse_skill_ghi_pct: 40.988033
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.972055
# INFO:src.pipeline:  mae_skill_ghi_pct: 50.034080
# INFO:src.pipeline:  mae_skill_csi_pct: 99.899573
# INFO:src.pipeline:  mape_skill_ghi_pct: 88.281463
# INFO:src.pipeline:  mape_skill_csi_pct: 99.765658
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 71.000000
# INFO:src.pipeline:
# === Running Fold 16 ===
# INFO:src.pipeline:Train samples: 462, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045821, Val Loss: 0.038927, Train MAE: 0.149526, Val MAE: 0.139600, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036630, Val Loss: 0.037387, Train MAE: 0.132549, Val MAE: 0.134172, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.025907, Val Loss: 0.039549, Train MAE: 0.107171, Val MAE: 0.133472, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 37
# INFO:src.pipeline:Fold 16 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.039497
# INFO:src.pipeline:  rmse: 0.198738
# INFO:src.pipeline:  mae: 0.124239
# INFO:src.pipeline:  r2: 0.361865
# INFO:src.pipeline:  mape: 90.153664
# INFO:src.pipeline:  model_rmse_ghi: 34.371978
# INFO:src.pipeline:  nam_rmse_ghi: 134.580713
# INFO:src.pipeline:  model_mae_ghi: 18.182224
# INFO:src.pipeline:  nam_mae_ghi: 100.844359
# INFO:src.pipeline:  model_mape_ghi: 211.047503
# INFO:src.pipeline:  nam_mape_ghi: 422.612681
# INFO:src.pipeline:  model_rmse_csi: 0.198738
# INFO:src.pipeline:  model_mae_csi: 0.124239
# INFO:src.pipeline:  model_mape_csi: 90.153664
# INFO:src.pipeline:  nam_rmse_csi: 5.061521
# INFO:src.pipeline:  nam_mae_csi: 2.303061
# INFO:src.pipeline:  nam_mape_csi: 422.612681
# INFO:src.pipeline:  rmse_skill_ghi_pct: 74.459953
# INFO:src.pipeline:  rmse_skill_csi_pct: 96.073549
# INFO:src.pipeline:  mae_skill_ghi_pct: 81.970014
# INFO:src.pipeline:  mae_skill_csi_pct: 94.605484
# INFO:src.pipeline:  mape_skill_ghi_pct: 50.061247
# INFO:src.pipeline:  mape_skill_csi_pct: 78.667544
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 17 ===
# INFO:src.pipeline:Train samples: 493, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043338, Val Loss: 0.032627, Train MAE: 0.145763, Val MAE: 0.111314, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036101, Val Loss: 0.035392, Train MAE: 0.127587, Val MAE: 0.115212, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.027455, Val Loss: 0.033792, Train MAE: 0.110776, Val MAE: 0.099366, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 30
# INFO:src.pipeline:Fold 17 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.033792
# INFO:src.pipeline:  rmse: 0.183826
# INFO:src.pipeline:  mae: 0.099366
# INFO:src.pipeline:  r2: 0.558803
# INFO:src.pipeline:  mape: 29.075468
# INFO:src.pipeline:  model_rmse_ghi: 62.181908
# INFO:src.pipeline:  nam_rmse_ghi: 168.224025
# INFO:src.pipeline:  model_mae_ghi: 28.002499
# INFO:src.pipeline:  nam_mae_ghi: 131.772201
# INFO:src.pipeline:  model_mape_ghi: 53.709069
# INFO:src.pipeline:  nam_mape_ghi: 245.421946
# INFO:src.pipeline:  model_rmse_csi: 0.183826
# INFO:src.pipeline:  model_mae_csi: 0.099366
# INFO:src.pipeline:  model_mape_csi: 29.075468
# INFO:src.pipeline:  nam_rmse_csi: 1233.440798
# INFO:src.pipeline:  nam_mae_csi: 238.135074
# INFO:src.pipeline:  nam_mape_csi: 50045.008041
# INFO:src.pipeline:  rmse_skill_ghi_pct: 63.036250
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.985096
# INFO:src.pipeline:  mae_skill_ghi_pct: 78.749312
# INFO:src.pipeline:  mae_skill_csi_pct: 99.958273
# INFO:src.pipeline:  mape_skill_ghi_pct: 78.115621
# INFO:src.pipeline:  mape_skill_csi_pct: 99.941901
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 18 ===
# INFO:src.pipeline:Train samples: 523, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041031, Val Loss: 0.036604, Train MAE: 0.139136, Val MAE: 0.147946, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037793, Val Loss: 0.031100, Train MAE: 0.134119, Val MAE: 0.097586, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.024064, Val Loss: 0.031776, Train MAE: 0.103699, Val MAE: 0.107343, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 36
# INFO:src.pipeline:Fold 18 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.033217
# INFO:src.pipeline:  rmse: 0.182255
# INFO:src.pipeline:  mae: 0.095913
# INFO:src.pipeline:  r2: 0.462240
# INFO:src.pipeline:  mape: 23.203491
# INFO:src.pipeline:  model_rmse_ghi: 28.689680
# INFO:src.pipeline:  nam_rmse_ghi: 145.080492
# INFO:src.pipeline:  model_mae_ghi: 13.317255
# INFO:src.pipeline:  nam_mae_ghi: 116.494217
# INFO:src.pipeline:  model_mape_ghi: 19.827167
# INFO:src.pipeline:  nam_mape_ghi: 332.422119
# INFO:src.pipeline:  model_rmse_csi: 0.182255
# INFO:src.pipeline:  model_mae_csi: 0.095913
# INFO:src.pipeline:  model_mape_csi: 23.203491
# INFO:src.pipeline:  nam_rmse_csi: 8750.312585
# INFO:src.pipeline:  nam_mae_csi: 898.589462
# INFO:src.pipeline:  nam_mape_csi: 375090.739203
# INFO:src.pipeline:  rmse_skill_ghi_pct: 80.224991
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.997917
# INFO:src.pipeline:  mae_skill_ghi_pct: 88.568313
# INFO:src.pipeline:  mae_skill_csi_pct: 99.989326
# INFO:src.pipeline:  mape_skill_ghi_pct: 94.035545
# INFO:src.pipeline:  mape_skill_csi_pct: 99.993814
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 19 ===
# INFO:src.pipeline:Train samples: 554, Val samples: 28
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.038864, Val Loss: 0.020113, Train MAE: 0.136865, Val MAE: 0.103858, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034520, Val Loss: 0.018357, Train MAE: 0.124919, Val MAE: 0.094307, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.025967, Val Loss: 0.030057, Train MAE: 0.107014, Val MAE: 0.133463, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.020830, Val Loss: 0.027334, Train MAE: 0.096225, Val MAE: 0.112751, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.016508, Val Loss: 0.028180, Train MAE: 0.087408, Val MAE: 0.113988, LR: 0.000250
# INFO:src.pipeline:Fold 19 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.028180
# INFO:src.pipeline:  rmse: 0.167869
# INFO:src.pipeline:  mae: 0.113988
# INFO:src.pipeline:  r2: 0.461770
# INFO:src.pipeline:  mape: 14.710683
# INFO:src.pipeline:  model_rmse_ghi: 41.211859
# INFO:src.pipeline:  nam_rmse_ghi: 79.936071
# INFO:src.pipeline:  model_mae_ghi: 23.677279
# INFO:src.pipeline:  nam_mae_ghi: 62.381378
# INFO:src.pipeline:  model_mape_ghi: 21.742148
# INFO:src.pipeline:  nam_mape_ghi: 352.071316
# INFO:src.pipeline:  model_rmse_csi: 0.167869
# INFO:src.pipeline:  model_mae_csi: 0.113988
# INFO:src.pipeline:  model_mape_csi: 14.710683
# INFO:src.pipeline:  nam_rmse_csi: 5332.954517
# INFO:src.pipeline:  nam_mae_csi: 653.905014
# INFO:src.pipeline:  nam_mape_csi: 80875.360650
# INFO:src.pipeline:  rmse_skill_ghi_pct: 48.443977
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.996852
# INFO:src.pipeline:  mae_skill_ghi_pct: 62.044316
# INFO:src.pipeline:  mae_skill_csi_pct: 99.982568
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.824505
# INFO:src.pipeline:  mape_skill_csi_pct: 99.981811
# INFO:src.pipeline:  n_rows: 392.000000
# INFO:src.pipeline:  n_daylight_rows: 83.000000
# INFO:src.pipeline:
# === Running Fold 20 ===
# INFO:src.pipeline:Train samples: 583, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.038013, Val Loss: 0.041386, Train MAE: 0.135975, Val MAE: 0.129312, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.033942, Val Loss: 0.045267, Train MAE: 0.127070, Val MAE: 0.128479, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 27
# INFO:src.pipeline:Fold 20 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.045013
# INFO:src.pipeline:  rmse: 0.212163
# INFO:src.pipeline:  mae: 0.125850
# INFO:src.pipeline:  r2: 0.433196
# INFO:src.pipeline:  mape: 29.003191
# INFO:src.pipeline:  model_rmse_ghi: 32.691069
# INFO:src.pipeline:  nam_rmse_ghi: 28.517076
# INFO:src.pipeline:  model_mae_ghi: 17.531680
# INFO:src.pipeline:  nam_mae_ghi: 23.786153
# INFO:src.pipeline:  model_mape_ghi: 43.710837
# INFO:src.pipeline:  nam_mape_ghi: 76.292014
# INFO:src.pipeline:  model_rmse_csi: 0.212163
# INFO:src.pipeline:  model_mae_csi: 0.125850
# INFO:src.pipeline:  model_mape_csi: 29.003191
# INFO:src.pipeline:  nam_rmse_csi: 0.570128
# INFO:src.pipeline:  nam_mae_csi: 0.342846
# INFO:src.pipeline:  nam_mape_csi: 77.457980
# INFO:src.pipeline:  rmse_skill_ghi_pct: -14.636821
# INFO:src.pipeline:  rmse_skill_csi_pct: 62.786678
# INFO:src.pipeline:  mae_skill_ghi_pct: 26.294597
# INFO:src.pipeline:  mae_skill_csi_pct: 63.292587
# INFO:src.pipeline:  mape_skill_ghi_pct: 42.705882
# INFO:src.pipeline:  mape_skill_csi_pct: 62.556226
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 21 ===
# INFO:src.pipeline:Train samples: 613, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041004, Val Loss: 0.033850, Train MAE: 0.137543, Val MAE: 0.121612, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.033213, Val Loss: 0.052232, Train MAE: 0.121545, Val MAE: 0.160712, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# INFO:src.pipeline:Fold 21 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.063211
# INFO:src.pipeline:  rmse: 0.251419
# INFO:src.pipeline:  mae: 0.181663
# INFO:src.pipeline:  r2: 0.156168
# INFO:src.pipeline:  mape: 25.456451
# INFO:src.pipeline:  model_rmse_ghi: 21.158733
# INFO:src.pipeline:  nam_rmse_ghi: 34.752485
# INFO:src.pipeline:  model_mae_ghi: 12.197989
# INFO:src.pipeline:  nam_mae_ghi: 32.612153
# INFO:src.pipeline:  model_mape_ghi: 28.852928
# INFO:src.pipeline:  nam_mape_ghi: 106.273663
# INFO:src.pipeline:  model_rmse_csi: 0.251419
# INFO:src.pipeline:  model_mae_csi: 0.181663
# INFO:src.pipeline:  model_mape_csi: 25.456451
# INFO:src.pipeline:  nam_rmse_csi: 209.719011
# INFO:src.pipeline:  nam_mae_csi: 47.320725
# INFO:src.pipeline:  nam_mape_csi: 13109.370468
# INFO:src.pipeline:  rmse_skill_ghi_pct: 39.115912
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.880116
# INFO:src.pipeline:  mae_skill_ghi_pct: 62.596801
# INFO:src.pipeline:  mae_skill_csi_pct: 99.616103
# INFO:src.pipeline:  mape_skill_ghi_pct: 72.850349
# INFO:src.pipeline:  mape_skill_csi_pct: 99.805815
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 22 ===
# INFO:src.pipeline:Train samples: 644, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.040592, Val Loss: 0.062124, Train MAE: 0.139218, Val MAE: 0.173058, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035544, Val Loss: 0.059694, Train MAE: 0.127764, Val MAE: 0.164292, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.030182, Val Loss: 0.056166, Train MAE: 0.116236, Val MAE: 0.174268, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.023808, Val Loss: 0.058422, Train MAE: 0.104613, Val MAE: 0.160394, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.019984, Val Loss: 0.062348, Train MAE: 0.094584, Val MAE: 0.164805, LR: 0.001000
# INFO:src.pipeline:Fold 22 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.062348
# INFO:src.pipeline:  rmse: 0.249696
# INFO:src.pipeline:  mae: 0.164805
# INFO:src.pipeline:  r2: 0.334386
# INFO:src.pipeline:  mape: 44.276279
# INFO:src.pipeline:  model_rmse_ghi: 2.988700
# INFO:src.pipeline:  nam_rmse_ghi: 32.161632
# INFO:src.pipeline:  model_mae_ghi: 2.377886
# INFO:src.pipeline:  nam_mae_ghi: 30.497916
# INFO:src.pipeline:  model_mape_ghi: 40.327135
# INFO:src.pipeline:  nam_mape_ghi: 522.430553
# INFO:src.pipeline:  model_rmse_csi: 0.249696
# INFO:src.pipeline:  model_mae_csi: 0.164805
# INFO:src.pipeline:  model_mape_csi: 44.276279
# INFO:src.pipeline:  nam_rmse_csi: 4.082251
# INFO:src.pipeline:  nam_mae_csi: 3.331544
# INFO:src.pipeline:  nam_mape_csi: 869.897528
# INFO:src.pipeline:  rmse_skill_ghi_pct: 90.707251
# INFO:src.pipeline:  rmse_skill_csi_pct: 93.883380
# INFO:src.pipeline:  mae_skill_ghi_pct: 92.203120
# INFO:src.pipeline:  mae_skill_csi_pct: 95.053206
# INFO:src.pipeline:  mape_skill_ghi_pct: 92.280862
# INFO:src.pipeline:  mape_skill_csi_pct: 94.910173
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 24.000000
# INFO:src.pipeline:
# === Running Fold 23 ===
# INFO:src.pipeline:Train samples: 674, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041010, Val Loss: 0.073180, Train MAE: 0.138272, Val MAE: 0.207143, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034191, Val Loss: 0.086000, Train MAE: 0.122866, Val MAE: 0.212539, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 26
# INFO:src.pipeline:Fold 23 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.091917
# INFO:src.pipeline:  rmse: 0.303178
# INFO:src.pipeline:  mae: 0.215199
# INFO:src.pipeline:  r2: 0.194776
# INFO:src.pipeline:  mape: 86.745644
# INFO:src.pipeline:  model_rmse_ghi: 1.009192
# INFO:src.pipeline:  nam_rmse_ghi: 24.819546
# INFO:src.pipeline:  model_mae_ghi: 0.800957
# INFO:src.pipeline:  nam_mae_ghi: 20.876294
# INFO:src.pipeline:  model_mape_ghi: 175.493749
# INFO:src.pipeline:  nam_mape_ghi: 1072.683416
# INFO:src.pipeline:  model_rmse_csi: 0.303178
# INFO:src.pipeline:  model_mae_csi: 0.215199
# INFO:src.pipeline:  model_mape_csi: 86.745644
# INFO:src.pipeline:  nam_rmse_csi: 5.386778
# INFO:src.pipeline:  nam_mae_csi: 4.706144
# INFO:src.pipeline:  nam_mape_csi: 2108.689560
# INFO:src.pipeline:  rmse_skill_ghi_pct: 95.933882
# INFO:src.pipeline:  rmse_skill_csi_pct: 94.371816
# INFO:src.pipeline:  mae_skill_ghi_pct: 96.163318
# INFO:src.pipeline:  mae_skill_csi_pct: 95.427281
# INFO:src.pipeline:  mape_skill_ghi_pct: 83.639744
# INFO:src.pipeline:  mape_skill_csi_pct: 95.886277
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 10.000000
# INFO:src.pipeline:
# === Running Fold 24 ===
# INFO:src.pipeline:Train samples: 703, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.040932, Val Loss: 0.086773, Train MAE: 0.139044, Val MAE: 0.228233, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034231, Val Loss: 0.090831, Train MAE: 0.124001, Val MAE: 0.230650, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.026676, Val Loss: 0.086531, Train MAE: 0.109564, Val MAE: 0.223737, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.019462, Val Loss: 0.104660, Train MAE: 0.094126, Val MAE: 0.237128, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 42
# INFO:src.pipeline:Fold 24 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.120729
# INFO:src.pipeline:  rmse: 0.347460
# INFO:src.pipeline:  mae: 0.252492
# INFO:src.pipeline:  r2: 0.118326
# INFO:src.pipeline:  mape: 94.796654
# INFO:src.pipeline:  model_rmse_ghi: 9.898695
# INFO:src.pipeline:  nam_rmse_ghi: nan
# INFO:src.pipeline:  model_mae_ghi: 7.089767
# INFO:src.pipeline:  nam_mae_ghi: nan
# INFO:src.pipeline:  model_mape_ghi: 58.914885
# INFO:src.pipeline:  nam_mape_ghi: nan
# INFO:src.pipeline:  model_rmse_csi: 0.347460
# INFO:src.pipeline:  model_mae_csi: 0.252492
# INFO:src.pipeline:  model_mape_csi: 94.796654
# INFO:src.pipeline:  nam_rmse_csi: 29.010329
# INFO:src.pipeline:  nam_mae_csi: 6.930307
# INFO:src.pipeline:  nam_mape_csi: 6018.644154
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 98.802287
# INFO:src.pipeline:  mae_skill_ghi_pct: nan
# INFO:src.pipeline:  mae_skill_csi_pct: 96.356693
# INFO:src.pipeline:  mape_skill_ghi_pct: nan
# INFO:src.pipeline:  mape_skill_csi_pct: 98.424950
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 30.000000
# INFO:src.pipeline:
# === Running Fold 25 ===
# INFO:src.pipeline:Train samples: 734, Val samples: 28
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043923, Val Loss: 0.041849, Train MAE: 0.146040, Val MAE: 0.167865, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036202, Val Loss: 0.046703, Train MAE: 0.130915, Val MAE: 0.165397, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# INFO:src.pipeline:Fold 25 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.048924
# INFO:src.pipeline:  rmse: 0.221188
# INFO:src.pipeline:  mae: 0.157863
# INFO:src.pipeline:  r2: 0.399404
# INFO:src.pipeline:  mape: 27.876413
# INFO:src.pipeline:  model_rmse_ghi: 19.742395
# INFO:src.pipeline:  nam_rmse_ghi: nan
# INFO:src.pipeline:  model_mae_ghi: 14.712414
# INFO:src.pipeline:  nam_mae_ghi: nan
# INFO:src.pipeline:  model_mape_ghi: 36.930094
# INFO:src.pipeline:  nam_mape_ghi: nan
# INFO:src.pipeline:  model_rmse_csi: 0.221188
# INFO:src.pipeline:  model_mae_csi: 0.157863
# INFO:src.pipeline:  model_mape_csi: 27.876413
# INFO:src.pipeline:  nam_rmse_csi: 327.138316
# INFO:src.pipeline:  nam_mae_csi: 67.335748
# INFO:src.pipeline:  nam_mape_csi: 15615.030707
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.932387
# INFO:src.pipeline:  mae_skill_ghi_pct: nan
# INFO:src.pipeline:  mae_skill_csi_pct: 99.765558
# INFO:src.pipeline:  mape_skill_ghi_pct: nan
# INFO:src.pipeline:  mape_skill_csi_pct: 99.821477
# INFO:src.pipeline:  n_rows: 392.000000
# INFO:src.pipeline:  n_daylight_rows: 39.000000
# INFO:src.pipeline:
# === Running Fold 26 ===
# INFO:src.pipeline:Train samples: 763, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042046, Val Loss: 0.073325, Train MAE: 0.142077, Val MAE: 0.195160, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.032697, Val Loss: 0.093175, Train MAE: 0.121707, Val MAE: 0.204654, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 24
# INFO:src.pipeline:Fold 26 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.092798
# INFO:src.pipeline:  rmse: 0.304628
# INFO:src.pipeline:  mae: 0.200837
# INFO:src.pipeline:  r2: 0.336716
# INFO:src.pipeline:  mape: 108.270027
# INFO:src.pipeline:  model_rmse_ghi: 38.129862
# INFO:src.pipeline:  nam_rmse_ghi: 31.422142
# INFO:src.pipeline:  model_mae_ghi: 25.975140
# INFO:src.pipeline:  nam_mae_ghi: 22.106956
# INFO:src.pipeline:  model_mape_ghi: 138.248261
# INFO:src.pipeline:  nam_mape_ghi: 139.671723
# INFO:src.pipeline:  model_rmse_csi: 0.304628
# INFO:src.pipeline:  model_mae_csi: 0.200837
# INFO:src.pipeline:  model_mape_csi: 108.270027
# INFO:src.pipeline:  nam_rmse_csi: 0.292047
# INFO:src.pipeline:  nam_mae_csi: 0.183863
# INFO:src.pipeline:  nam_mape_csi: 139.671723
# INFO:src.pipeline:  rmse_skill_ghi_pct: -21.347115
# INFO:src.pipeline:  rmse_skill_csi_pct: -4.307759
# INFO:src.pipeline:  mae_skill_ghi_pct: -17.497590
# INFO:src.pipeline:  mae_skill_csi_pct: -9.232061
# INFO:src.pipeline:  mape_skill_ghi_pct: 1.019148
# INFO:src.pipeline:  mape_skill_csi_pct: 22.482501
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 27 ===
# INFO:src.pipeline:Train samples: 794, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042931, Val Loss: 0.051219, Train MAE: 0.142943, Val MAE: 0.164945, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037764, Val Loss: 0.056383, Train MAE: 0.133884, Val MAE: 0.154020, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# INFO:src.pipeline:Fold 27 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.060296
# INFO:src.pipeline:  rmse: 0.245552
# INFO:src.pipeline:  mae: 0.171984
# INFO:src.pipeline:  r2: 0.393853
# INFO:src.pipeline:  mape: 41.413548
# INFO:src.pipeline:  model_rmse_ghi: 41.044788
# INFO:src.pipeline:  nam_rmse_ghi: 85.922416
# INFO:src.pipeline:  model_mae_ghi: 26.241934
# INFO:src.pipeline:  nam_mae_ghi: 58.849218
# INFO:src.pipeline:  model_mape_ghi: 41.471026
# INFO:src.pipeline:  nam_mape_ghi: 610.394847
# INFO:src.pipeline:  model_rmse_csi: 0.245552
# INFO:src.pipeline:  model_mae_csi: 0.171984
# INFO:src.pipeline:  model_mape_csi: 41.413548
# INFO:src.pipeline:  nam_rmse_csi: 961.257659
# INFO:src.pipeline:  nam_mae_csi: 147.993450
# INFO:src.pipeline:  nam_mape_csi: 16902.462358
# INFO:src.pipeline:  rmse_skill_ghi_pct: 52.230408
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.974455
# INFO:src.pipeline:  mae_skill_ghi_pct: 55.408186
# INFO:src.pipeline:  mae_skill_csi_pct: 99.883789
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.205869
# INFO:src.pipeline:  mape_skill_csi_pct: 99.754985
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 73.000000
# INFO:src.pipeline:
# === Running Fold 28 ===
# INFO:src.pipeline:Train samples: 824, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043517, Val Loss: 0.046653, Train MAE: 0.145543, Val MAE: 0.149245, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038116, Val Loss: 0.042801, Train MAE: 0.132937, Val MAE: 0.158659, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.029798, Val Loss: 0.044175, Train MAE: 0.117435, Val MAE: 0.141556, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.018703, Val Loss: 0.047439, Train MAE: 0.094051, Val MAE: 0.144772, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 41
# INFO:src.pipeline:Fold 28 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.055576
# INFO:src.pipeline:  rmse: 0.235746
# INFO:src.pipeline:  mae: 0.149122
# INFO:src.pipeline:  r2: 0.333598
# INFO:src.pipeline:  mape: 47.073826
# INFO:src.pipeline:  model_rmse_ghi: 40.733657
# INFO:src.pipeline:  nam_rmse_ghi: 133.168581
# INFO:src.pipeline:  model_mae_ghi: 18.682364
# INFO:src.pipeline:  nam_mae_ghi: 98.274114
# INFO:src.pipeline:  model_mape_ghi: 62.636346
# INFO:src.pipeline:  nam_mape_ghi: 406.928246
# INFO:src.pipeline:  model_rmse_csi: 0.235746
# INFO:src.pipeline:  model_mae_csi: 0.149122
# INFO:src.pipeline:  model_mape_csi: 47.073826
# INFO:src.pipeline:  nam_rmse_csi: 4.165013
# INFO:src.pipeline:  nam_mae_csi: 1.947558
# INFO:src.pipeline:  nam_mape_csi: 406.928246
# INFO:src.pipeline:  rmse_skill_ghi_pct: 69.411961
# INFO:src.pipeline:  rmse_skill_csi_pct: 94.339854
# INFO:src.pipeline:  mae_skill_ghi_pct: 80.989537
# INFO:src.pipeline:  mae_skill_csi_pct: 92.343141
# INFO:src.pipeline:  mape_skill_ghi_pct: 84.607521
# INFO:src.pipeline:  mape_skill_csi_pct: 88.431910
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 29 ===
# INFO:src.pipeline:Train samples: 855, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042608, Val Loss: 0.022556, Train MAE: 0.144531, Val MAE: 0.098622, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037785, Val Loss: 0.021616, Train MAE: 0.132980, Val MAE: 0.110900, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.028811, Val Loss: 0.019465, Train MAE: 0.114629, Val MAE: 0.092323, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.019714, Val Loss: 0.016772, Train MAE: 0.097503, Val MAE: 0.088349, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 41
# INFO:src.pipeline:Fold 29 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.020110
# INFO:src.pipeline:  rmse: 0.141811
# INFO:src.pipeline:  mae: 0.097491
# INFO:src.pipeline:  r2: 0.655659
# INFO:src.pipeline:  mape: 15.281032
# INFO:src.pipeline:  model_rmse_ghi: 38.202848
# INFO:src.pipeline:  nam_rmse_ghi: 166.941379
# INFO:src.pipeline:  model_mae_ghi: 21.084179
# INFO:src.pipeline:  nam_mae_ghi: 130.514742
# INFO:src.pipeline:  model_mape_ghi: 20.983233
# INFO:src.pipeline:  nam_mape_ghi: 202.740561
# INFO:src.pipeline:  model_rmse_csi: 0.141811
# INFO:src.pipeline:  model_mae_csi: 0.097491
# INFO:src.pipeline:  model_mape_csi: 15.281032
# INFO:src.pipeline:  nam_rmse_csi: 1742.136105
# INFO:src.pipeline:  nam_mae_csi: 314.197475
# INFO:src.pipeline:  nam_mape_csi: 159449.823308
# INFO:src.pipeline:  rmse_skill_ghi_pct: 77.116010
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.991860
# INFO:src.pipeline:  mae_skill_ghi_pct: 83.845366
# INFO:src.pipeline:  mae_skill_csi_pct: 99.968971
# INFO:src.pipeline:  mape_skill_ghi_pct: 89.650205
# INFO:src.pipeline:  mape_skill_csi_pct: 99.990416
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 30 ===
# INFO:src.pipeline:Train samples: 885, Val samples: 27
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042398, Val Loss: 0.002048, Train MAE: 0.142529, Val MAE: 0.035968, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035332, Val Loss: 0.004059, Train MAE: 0.129133, Val MAE: 0.042231, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.029062, Val Loss: 0.006685, Train MAE: 0.115735, Val MAE: 0.075701, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.017906, Val Loss: 0.002461, Train MAE: 0.091190, Val MAE: 0.042366, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.014494, Val Loss: 0.003876, Train MAE: 0.082059, Val MAE: 0.054136, LR: 0.000500
# INFO:src.pipeline:Fold 30 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.003876
# INFO:src.pipeline:  rmse: 0.062261
# INFO:src.pipeline:  mae: 0.054136
# INFO:src.pipeline:  r2: 0.896949
# INFO:src.pipeline:  mape: 5.927256
# INFO:src.pipeline:  model_rmse_ghi: 11.888494
# INFO:src.pipeline:  nam_rmse_ghi: 158.851647
# INFO:src.pipeline:  model_mae_ghi: 7.304046
# INFO:src.pipeline:  nam_mae_ghi: 128.009580
# INFO:src.pipeline:  model_mape_ghi: 6.254723
# INFO:src.pipeline:  nam_mape_ghi: 368.703288
# INFO:src.pipeline:  model_rmse_csi: 0.062261
# INFO:src.pipeline:  model_mae_csi: 0.054136
# INFO:src.pipeline:  model_mape_csi: 5.927256
# INFO:src.pipeline:  nam_rmse_csi: 2324.382922
# INFO:src.pipeline:  nam_mae_csi: 343.365065
# INFO:src.pipeline:  nam_mape_csi: 68595.502221
# INFO:src.pipeline:  rmse_skill_ghi_pct: 92.515977
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.997321
# INFO:src.pipeline:  mae_skill_ghi_pct: 94.294141
# INFO:src.pipeline:  mae_skill_csi_pct: 99.984234
# INFO:src.pipeline:  mape_skill_ghi_pct: 98.303589
# INFO:src.pipeline:  mape_skill_csi_pct: 99.991359
# INFO:src.pipeline:  n_rows: 378.000000
# INFO:src.pipeline:  n_daylight_rows: 108.000000
# INFO:src.pipeline:
# === Running Fold 31 ===
# INFO:src.pipeline:Train samples: 913, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041196, Val Loss: 0.012846, Train MAE: 0.139457, Val MAE: 0.085715, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035408, Val Loss: 0.010193, Train MAE: 0.126718, Val MAE: 0.047928, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.029255, Val Loss: 0.012025, Train MAE: 0.115527, Val MAE: 0.063450, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.019167, Val Loss: 0.009636, Train MAE: 0.092421, Val MAE: 0.053766, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 42
# INFO:src.pipeline:Fold 31 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.009865
# INFO:src.pipeline:  rmse: 0.099325
# INFO:src.pipeline:  mae: 0.049252
# INFO:src.pipeline:  r2: 0.765020
# INFO:src.pipeline:  mape: 7.530930
# INFO:src.pipeline:  model_rmse_ghi: 20.577692
# INFO:src.pipeline:  nam_rmse_ghi: 89.471777
# INFO:src.pipeline:  model_mae_ghi: 9.952677
# INFO:src.pipeline:  nam_mae_ghi: 65.181749
# INFO:src.pipeline:  model_mape_ghi: 10.742808
# INFO:src.pipeline:  nam_mape_ghi: 330.764257
# INFO:src.pipeline:  model_rmse_csi: 0.099325
# INFO:src.pipeline:  model_mae_csi: 0.049252
# INFO:src.pipeline:  model_mape_csi: 7.530930
# INFO:src.pipeline:  nam_rmse_csi: 2868.743811
# INFO:src.pipeline:  nam_mae_csi: 420.722030
# INFO:src.pipeline:  nam_mape_csi: 47629.901026
# INFO:src.pipeline:  rmse_skill_ghi_pct: 77.000913
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.996538
# INFO:src.pipeline:  mae_skill_ghi_pct: 84.730883
# INFO:src.pipeline:  mae_skill_csi_pct: 99.988294
# INFO:src.pipeline:  mape_skill_ghi_pct: 96.752126
# INFO:src.pipeline:  mape_skill_csi_pct: 99.984189
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 88.000000
# INFO:src.pipeline:
# === Running Fold 32 ===
# INFO:src.pipeline:Train samples: 944, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.039088, Val Loss: 0.010685, Train MAE: 0.135068, Val MAE: 0.058949, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.033001, Val Loss: 0.009513, Train MAE: 0.121577, Val MAE: 0.058273, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.023688, Val Loss: 0.009788, Train MAE: 0.102621, Val MAE: 0.048601, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Fold 32 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.009222
# INFO:src.pipeline:  rmse: 0.096029
# INFO:src.pipeline:  mae: 0.050172
# INFO:src.pipeline:  r2: 0.799498
# INFO:src.pipeline:  mape: 6.524977
# INFO:src.pipeline:  model_rmse_ghi: 7.818541
# INFO:src.pipeline:  nam_rmse_ghi: 20.938126
# INFO:src.pipeline:  model_mae_ghi: 5.254990
# INFO:src.pipeline:  nam_mae_ghi: 16.693148
# INFO:src.pipeline:  model_mape_ghi: 5.439997
# INFO:src.pipeline:  nam_mape_ghi: 67.489418
# INFO:src.pipeline:  model_rmse_csi: 0.096029
# INFO:src.pipeline:  model_mae_csi: 0.050172
# INFO:src.pipeline:  model_mape_csi: 6.524977
# INFO:src.pipeline:  nam_rmse_csi: 0.817794
# INFO:src.pipeline:  nam_mae_csi: 0.380120
# INFO:src.pipeline:  nam_mape_csi: 68.573104
# INFO:src.pipeline:  rmse_skill_ghi_pct: 62.658832
# INFO:src.pipeline:  rmse_skill_csi_pct: 88.257580
# INFO:src.pipeline:  mae_skill_ghi_pct: 68.520076
# INFO:src.pipeline:  mae_skill_csi_pct: 86.801124
# INFO:src.pipeline:  mape_skill_ghi_pct: 91.939481
# INFO:src.pipeline:  mape_skill_csi_pct: 90.484641
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 33 ===
# INFO:src.pipeline:Train samples: 974, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.039503, Val Loss: 0.079332, Train MAE: 0.135405, Val MAE: 0.204496, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.030449, Val Loss: 0.099277, Train MAE: 0.115640, Val MAE: 0.188843, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# INFO:src.pipeline:Fold 33 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.105721
# INFO:src.pipeline:  rmse: 0.325147
# INFO:src.pipeline:  mae: 0.200467
# INFO:src.pipeline:  r2: 0.195496
# INFO:src.pipeline:  mape: 94.490936
# INFO:src.pipeline:  model_rmse_ghi: 15.668727
# INFO:src.pipeline:  nam_rmse_ghi: 33.710817
# INFO:src.pipeline:  model_mae_ghi: 12.751665
# INFO:src.pipeline:  nam_mae_ghi: 28.381508
# INFO:src.pipeline:  model_mape_ghi: 66.586391
# INFO:src.pipeline:  nam_mape_ghi: 147.636336
# INFO:src.pipeline:  model_rmse_csi: 0.325147
# INFO:src.pipeline:  model_mae_csi: 0.200467
# INFO:src.pipeline:  model_mape_csi: 94.490936
# INFO:src.pipeline:  nam_rmse_csi: 141.727556
# INFO:src.pipeline:  nam_mae_csi: 34.996511
# INFO:src.pipeline:  nam_mape_csi: 9581.218096
# INFO:src.pipeline:  rmse_skill_ghi_pct: 53.520179
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.770583
# INFO:src.pipeline:  mae_skill_ghi_pct: 55.070515
# INFO:src.pipeline:  mae_skill_csi_pct: 99.427180
# INFO:src.pipeline:  mape_skill_ghi_pct: 54.898372
# INFO:src.pipeline:  mape_skill_csi_pct: 99.013790
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 34 ===
# INFO:src.pipeline:Train samples: 1005, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.040097, Val Loss: 0.057227, Train MAE: 0.135990, Val MAE: 0.186393, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035267, Val Loss: 0.065830, Train MAE: 0.123949, Val MAE: 0.206777, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.023868, Val Loss: 0.090913, Train MAE: 0.101643, Val MAE: 0.237921, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Fold 34 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.072958
# INFO:src.pipeline:  rmse: 0.270107
# INFO:src.pipeline:  mae: 0.212961
# INFO:src.pipeline:  r2: 0.323400
# INFO:src.pipeline:  mape: 43.387836
# INFO:src.pipeline:  model_rmse_ghi: 2.268721
# INFO:src.pipeline:  nam_rmse_ghi: 31.695118
# INFO:src.pipeline:  model_mae_ghi: 1.924216
# INFO:src.pipeline:  nam_mae_ghi: 29.942103
# INFO:src.pipeline:  model_mape_ghi: 67.507396
# INFO:src.pipeline:  nam_mape_ghi: 760.523498
# INFO:src.pipeline:  model_rmse_csi: 0.270107
# INFO:src.pipeline:  model_mae_csi: 0.212961
# INFO:src.pipeline:  model_mape_csi: 43.387836
# INFO:src.pipeline:  nam_rmse_csi: 3.844745
# INFO:src.pipeline:  nam_mae_csi: 3.126345
# INFO:src.pipeline:  nam_mape_csi: 986.974761
# INFO:src.pipeline:  rmse_skill_ghi_pct: 92.842047
# INFO:src.pipeline:  rmse_skill_csi_pct: 92.974639
# INFO:src.pipeline:  mae_skill_ghi_pct: 93.573545
# INFO:src.pipeline:  mae_skill_csi_pct: 93.188170
# INFO:src.pipeline:  mape_skill_ghi_pct: 91.123562
# INFO:src.pipeline:  mape_skill_csi_pct: 95.603957
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 23.000000
# INFO:src.pipeline:
# === Running Fold 35 ===
# INFO:src.pipeline:Train samples: 1035, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.040737, Val Loss: 0.070411, Train MAE: 0.137750, Val MAE: 0.198976, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.033481, Val Loss: 0.075739, Train MAE: 0.121242, Val MAE: 0.215083, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 22
# INFO:src.pipeline:Fold 35 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.073525
# INFO:src.pipeline:  rmse: 0.271155
# INFO:src.pipeline:  mae: 0.203623
# INFO:src.pipeline:  r2: 0.391842
# INFO:src.pipeline:  mape: 81.098648
# INFO:src.pipeline:  model_rmse_ghi: 1.052842
# INFO:src.pipeline:  nam_rmse_ghi: 30.345306
# INFO:src.pipeline:  model_mae_ghi: 0.827780
# INFO:src.pipeline:  nam_mae_ghi: 29.192504
# INFO:src.pipeline:  model_mape_ghi: 53.622816
# INFO:src.pipeline:  nam_mape_ghi: 1053.923847
# INFO:src.pipeline:  model_rmse_csi: 0.271155
# INFO:src.pipeline:  model_mae_csi: 0.203623
# INFO:src.pipeline:  model_mape_csi: 81.098648
# INFO:src.pipeline:  nam_rmse_csi: 4216.288381
# INFO:src.pipeline:  nam_mae_csi: 902.986886
# INFO:src.pipeline:  nam_mape_csi: 334509.545063
# INFO:src.pipeline:  rmse_skill_ghi_pct: 96.530461
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.993569
# INFO:src.pipeline:  mae_skill_ghi_pct: 97.164407
# INFO:src.pipeline:  mae_skill_csi_pct: 99.977450
# INFO:src.pipeline:  mape_skill_ghi_pct: 94.912079
# INFO:src.pipeline:  mape_skill_csi_pct: 99.975756
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 11.000000
# INFO:src.pipeline:
# === Experiment Summary ===
# INFO:src.pipeline:Average Validation Metrics:
# INFO:src.pipeline:  mse: 0.076391 ± 0.089806
# INFO:src.pipeline:  rmse: 0.251406 ± 0.114831
# INFO:src.pipeline:  mae: 0.176626 ± 0.099376
# INFO:src.pipeline:  r2: 0.218018 ± 0.605731
# INFO:src.pipeline:  mape: 46.938310 ± 33.122593
# INFO:src.pipeline:  model_rmse_ghi: 30.339040 ± 23.916744
# INFO:src.pipeline:  nam_rmse_ghi: nan ± nan
# INFO:src.pipeline:  model_mae_ghi: 18.601675 ± 16.654796
# INFO:src.pipeline:  nam_mae_ghi: nan ± nan
# INFO:src.pipeline:  model_mape_ghi: 56.125768 ± 49.961882
# INFO:src.pipeline:  nam_mape_ghi: nan ± nan
# INFO:src.pipeline:  model_rmse_csi: 0.251406 ± 0.114831
# INFO:src.pipeline:  model_mae_csi: 0.176626 ± 0.099376
# INFO:src.pipeline:  model_mape_csi: 46.938310 ± 33.122593
# INFO:src.pipeline:  nam_rmse_csi: 1899.888090 ± 5082.770758
# INFO:src.pipeline:  nam_mae_csi: 243.899171 ± 530.892522
# INFO:src.pipeline:  nam_mape_csi: 51546.548405 ± 98706.806975
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 87.900937 ± 25.579704
# INFO:src.pipeline:  mae_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  mae_skill_csi_pct: 86.864453 ± 28.541392
# INFO:src.pipeline:  mape_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  mape_skill_csi_pct: 89.033674 ± 22.122215
# INFO:src.pipeline:  n_rows: 404.800000 ± 33.023628
# INFO:src.pipeline:  n_daylight_rows: 64.057143 ± 37.604668

# %% [markdown]
# ----

# %% [markdown]
# USING HUBER LOSS FUCNTION

# %%
selected_columns = ['solar_zenith',
       'hour_progression', 'absolute_hour', 'CSI_ghi',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos',
       'nam_ghi', 'nam_dni', 'nam_cc']


print("\n--- Step 2: Building model arrays (X, Y) ---")
fixed_df = to_fixedgrid_multiindex(df_phase3, timestamp_col="measurement_time", expected_T=None)  # or set T
# Zero-impute everything (features + target)
ph3_X, ph3_Y, ph3_labels_list = build_model_arrays(
        fixed_df,
        feature_cols=selected_columns,  # must include your chosen inputs
        target_col=TARGET_COL,          # target must be present in columns
        history_days=7,
        horizon_days=1,
    )

print(ph3_X.shape, ph3_Y.shape)
# Out:
# --- Step 2: Building model arrays (X, Y) ---
# (1064, 7, 14, 12) (1064, 1, 14)

# %%
print("=====================================\n")

import pandas as pd
from src.utils import DataManager
from src.pipeline import SolarForecastingPipeline


TARGET_COL = 'CSI_ghi'
feature_cols = [c for c in df_phase3.columns.tolist() if c != TARGET_COL]

data_manager = DataManager()
data_manager.save_arrays(
    ph3_X, ph3_Y,
    pd.DataFrame(index=pd.to_datetime(ph3_labels_list, utc=True)),
    filename_prefix='phas3_data',
    feature_cols=feature_cols,
    target_col=TARGET_COL,
    metadata={
        "input_csv": "data/processed/dayTime_NAM_dayahead_features_processed.csv",
        "timestamp_col": "measurement_time",
        "feature_set": feature_cols,     # for traceability
        "history_days": 7,
        "horizon_days": 1,
        "k_bins": None,
    }
)



LSTM_CONFIG = {
    "experiment_name": "phas3_exp_test",
    "model_type": "LSTM",
    "model_config": {
        "hidden_size": 128,
        "num_layers": 2,
        "dropout": 0.2,
        "bidirectional": True,
    },
    "data_prefix": "phas3_data",
    "splits_file": "exp-001/exp-001rolling_origin_splits.json",
    "feature_cols": feature_cols,
    "feature_selection": feature_cols,
    "target_col": TARGET_COL,
    "batch_size": 32,
    "loss_function": "Huber",
    "num_epochs": 50,
    "learning_rate": 0.001,
    "early_stopping_patience": 20,
    "max_folds": 35,
}


pipeline = SolarForecastingPipeline(LSTM_CONFIG)
_, summary = pipeline.run()
# Out:
# INFO:src.utils:Saved arrays to data/phas3_data_*.npy
# INFO:src.utils:X shape: (1064, 7, 14, 12), Y shape: (1064, 1, 14)
# INFO:src.pipeline:Loading data...
# INFO:src.utils:Loaded arrays from data/phas3_data_*.npy
# INFO:src.utils:X shape: (1064, 7, 14, 12), Y shape: (1064, 1, 14)
# =====================================
# INFO:src.pipeline:Reference dataframe prepared for NAM comparison (15162 rows).
# INFO:src.utils:Loaded 35 folds from exp-001/exp-001rolling_origin_splits.json
# INFO:src.pipeline:
# === Running Fold 1 ===
# INFO:src.pipeline:Train samples: 19, Val samples: 16
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.048711, Val Loss: 0.135200, Train MAE: 0.142769, Val MAE: 0.298243, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034094, Val Loss: 0.429463, Train MAE: 0.116191, Val MAE: 0.500429, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.031853, Val Loss: 0.853458, Train MAE: 0.116793, Val MAE: 0.742078, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 30
# INFO:src.pipeline:Fold 1 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.853458
# INFO:src.pipeline:  rmse: 0.923828
# INFO:src.pipeline:  mae: 0.742078
# INFO:src.pipeline:  r2: -4.726761
# INFO:src.pipeline:  mape: 178.220566
# INFO:src.pipeline:  model_rmse_ghi: 133.039244
# INFO:src.pipeline:  nam_rmse_ghi: 47.325744
# INFO:src.pipeline:  model_mae_ghi: 99.847529
# INFO:src.pipeline:  nam_mae_ghi: 39.566995
# INFO:src.pipeline:  model_mape_ghi: 257.144151
# INFO:src.pipeline:  nam_mape_ghi: 337.824906
# INFO:src.pipeline:  model_rmse_csi: 0.923828
# INFO:src.pipeline:  model_mae_csi: 0.742078
# INFO:src.pipeline:  model_mape_csi: 178.220566
# INFO:src.pipeline:  nam_rmse_csi: 59.491574
# INFO:src.pipeline:  nam_mae_csi: 17.255400
# INFO:src.pipeline:  nam_mape_csi: 8727.254750
# INFO:src.pipeline:  rmse_skill_ghi_pct: -181.113900
# INFO:src.pipeline:  rmse_skill_csi_pct: 98.447128
# INFO:src.pipeline:  mae_skill_ghi_pct: -152.350552
# INFO:src.pipeline:  mae_skill_csi_pct: 95.699443
# INFO:src.pipeline:  mape_skill_ghi_pct: 23.882418
# INFO:src.pipeline:  mape_skill_csi_pct: 97.957885
# INFO:src.pipeline:  n_rows: 224.000000
# INFO:src.pipeline:  n_daylight_rows: 25.000000
# INFO:src.pipeline:
# === Running Fold 2 ===
# INFO:src.pipeline:Train samples: 36, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.058878, Val Loss: 0.082730, Train MAE: 0.183027, Val MAE: 0.240874, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.050315, Val Loss: 0.094037, Train MAE: 0.183205, Val MAE: 0.246176, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.032959, Val Loss: 0.079644, Train MAE: 0.124638, Val MAE: 0.208797, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.025056, Val Loss: 0.101503, Train MAE: 0.107587, Val MAE: 0.237936, LR: 0.000250
# INFO:src.engine:Early stopping at epoch 46
# INFO:src.pipeline:Fold 2 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.099944
# INFO:src.pipeline:  rmse: 0.316139
# INFO:src.pipeline:  mae: 0.234925
# INFO:src.pipeline:  r2: 0.125213
# INFO:src.pipeline:  mape: 65.775436
# INFO:src.pipeline:  model_rmse_ghi: 55.099585
# INFO:src.pipeline:  nam_rmse_ghi: 28.918516
# INFO:src.pipeline:  model_mae_ghi: 37.835177
# INFO:src.pipeline:  nam_mae_ghi: 18.172979
# INFO:src.pipeline:  model_mape_ghi: 87.117401
# INFO:src.pipeline:  nam_mape_ghi: 73.857357
# INFO:src.pipeline:  model_rmse_csi: 0.316139
# INFO:src.pipeline:  model_mae_csi: 0.234925
# INFO:src.pipeline:  model_mape_csi: 65.775436
# INFO:src.pipeline:  nam_rmse_csi: 0.342068
# INFO:src.pipeline:  nam_mae_csi: 0.203361
# INFO:src.pipeline:  nam_mape_csi: 73.857357
# INFO:src.pipeline:  rmse_skill_ghi_pct: -90.533931
# INFO:src.pipeline:  rmse_skill_csi_pct: 7.580032
# INFO:src.pipeline:  mae_skill_ghi_pct: -108.194691
# INFO:src.pipeline:  mae_skill_csi_pct: -15.521488
# INFO:src.pipeline:  mape_skill_ghi_pct: -17.953587
# INFO:src.pipeline:  mape_skill_csi_pct: 10.942607
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 3 ===
# INFO:src.pipeline:Train samples: 67, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.063843, Val Loss: 0.064036, Train MAE: 0.198322, Val MAE: 0.192719, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.050577, Val Loss: 0.112657, Train MAE: 0.169274, Val MAE: 0.284918, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 26
# INFO:src.pipeline:Fold 3 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.139855
# INFO:src.pipeline:  rmse: 0.373972
# INFO:src.pipeline:  mae: 0.320240
# INFO:src.pipeline:  r2: -0.811152
# INFO:src.pipeline:  mape: 41.037144
# INFO:src.pipeline:  model_rmse_ghi: 78.549252
# INFO:src.pipeline:  nam_rmse_ghi: 82.375138
# INFO:src.pipeline:  model_mae_ghi: 60.257086
# INFO:src.pipeline:  nam_mae_ghi: 46.609284
# INFO:src.pipeline:  model_mape_ghi: 42.575483
# INFO:src.pipeline:  nam_mape_ghi: 247.917462
# INFO:src.pipeline:  model_rmse_csi: 0.373972
# INFO:src.pipeline:  model_mae_csi: 0.320240
# INFO:src.pipeline:  model_mape_csi: 41.037144
# INFO:src.pipeline:  nam_rmse_csi: 4233.970265
# INFO:src.pipeline:  nam_mae_csi: 520.457473
# INFO:src.pipeline:  nam_mape_csi: 61476.609638
# INFO:src.pipeline:  rmse_skill_ghi_pct: 4.644468
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.991167
# INFO:src.pipeline:  mae_skill_ghi_pct: -29.281295
# INFO:src.pipeline:  mae_skill_csi_pct: 99.938470
# INFO:src.pipeline:  mape_skill_ghi_pct: 82.826751
# INFO:src.pipeline:  mape_skill_csi_pct: 99.933248
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 71.000000
# INFO:src.pipeline:
# === Running Fold 4 ===
# INFO:src.pipeline:Train samples: 97, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.055573, Val Loss: 0.037447, Train MAE: 0.179113, Val MAE: 0.167630, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.048461, Val Loss: 0.028565, Train MAE: 0.154334, Val MAE: 0.115795, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.055776, Val Loss: 0.029420, Train MAE: 0.177512, Val MAE: 0.128539, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 37
# INFO:src.pipeline:Fold 4 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.033750
# INFO:src.pipeline:  rmse: 0.183711
# INFO:src.pipeline:  mae: 0.144310
# INFO:src.pipeline:  r2: 0.323878
# INFO:src.pipeline:  mape: 19.105181
# INFO:src.pipeline:  model_rmse_ghi: 36.796187
# INFO:src.pipeline:  nam_rmse_ghi: 177.658241
# INFO:src.pipeline:  model_mae_ghi: 26.314075
# INFO:src.pipeline:  nam_mae_ghi: 119.355573
# INFO:src.pipeline:  model_mape_ghi: 27.868612
# INFO:src.pipeline:  nam_mape_ghi: 404.329564
# INFO:src.pipeline:  model_rmse_csi: 0.183711
# INFO:src.pipeline:  model_mae_csi: 0.144310
# INFO:src.pipeline:  model_mape_csi: 19.105181
# INFO:src.pipeline:  nam_rmse_csi: 6.393005
# INFO:src.pipeline:  nam_mae_csi: 3.094590
# INFO:src.pipeline:  nam_mape_csi: 404.329564
# INFO:src.pipeline:  rmse_skill_ghi_pct: 79.288218
# INFO:src.pipeline:  rmse_skill_csi_pct: 97.126376
# INFO:src.pipeline:  mae_skill_ghi_pct: 77.953208
# INFO:src.pipeline:  mae_skill_csi_pct: 95.336693
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.107451
# INFO:src.pipeline:  mape_skill_csi_pct: 95.274849
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 5 ===
# INFO:src.pipeline:Train samples: 128, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044817, Val Loss: 0.047306, Train MAE: 0.144022, Val MAE: 0.200980, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034510, Val Loss: 0.035246, Train MAE: 0.127963, Val MAE: 0.173340, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 23
# INFO:src.pipeline:Fold 5 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.039466
# INFO:src.pipeline:  rmse: 0.198659
# INFO:src.pipeline:  mae: 0.184988
# INFO:src.pipeline:  r2: -0.014915
# INFO:src.pipeline:  mape: 20.907063
# INFO:src.pipeline:  model_rmse_ghi: 50.269807
# INFO:src.pipeline:  nam_rmse_ghi: 183.386569
# INFO:src.pipeline:  model_mae_ghi: 38.954874
# INFO:src.pipeline:  nam_mae_ghi: 126.617010
# INFO:src.pipeline:  model_mape_ghi: 23.267919
# INFO:src.pipeline:  nam_mape_ghi: 203.539202
# INFO:src.pipeline:  model_rmse_csi: 0.198659
# INFO:src.pipeline:  model_mae_csi: 0.184988
# INFO:src.pipeline:  model_mape_csi: 20.907063
# INFO:src.pipeline:  nam_rmse_csi: 1827.663220
# INFO:src.pipeline:  nam_mae_csi: 405.586491
# INFO:src.pipeline:  nam_mape_csi: 72924.087870
# INFO:src.pipeline:  rmse_skill_ghi_pct: 72.588065
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.989130
# INFO:src.pipeline:  mae_skill_ghi_pct: 69.234091
# INFO:src.pipeline:  mae_skill_csi_pct: 99.954390
# INFO:src.pipeline:  mape_skill_ghi_pct: 88.568335
# INFO:src.pipeline:  mape_skill_csi_pct: 99.971330
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 6 ===
# INFO:src.pipeline:Train samples: 158, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.036580, Val Loss: 0.025325, Train MAE: 0.125206, Val MAE: 0.086856, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.031267, Val Loss: 0.026470, Train MAE: 0.115093, Val MAE: 0.085929, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.024399, Val Loss: 0.025541, Train MAE: 0.102132, Val MAE: 0.086494, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 31
# INFO:src.pipeline:Fold 6 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.025189
# INFO:src.pipeline:  rmse: 0.158710
# INFO:src.pipeline:  mae: 0.084365
# INFO:src.pipeline:  r2: 0.524704
# INFO:src.pipeline:  mape: 19.391558
# INFO:src.pipeline:  model_rmse_ghi: 41.577912
# INFO:src.pipeline:  nam_rmse_ghi: 171.994205
# INFO:src.pipeline:  model_mae_ghi: 17.923915
# INFO:src.pipeline:  nam_mae_ghi: 119.377076
# INFO:src.pipeline:  model_mape_ghi: 31.273749
# INFO:src.pipeline:  nam_mape_ghi: 405.336845
# INFO:src.pipeline:  model_rmse_csi: 0.158710
# INFO:src.pipeline:  model_mae_csi: 0.084365
# INFO:src.pipeline:  model_mape_csi: 19.391558
# INFO:src.pipeline:  nam_rmse_csi: 1700.885180
# INFO:src.pipeline:  nam_mae_csi: 308.745768
# INFO:src.pipeline:  nam_mape_csi: 76197.389556
# INFO:src.pipeline:  rmse_skill_ghi_pct: 75.825981
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.990669
# INFO:src.pipeline:  mae_skill_ghi_pct: 84.985463
# INFO:src.pipeline:  mae_skill_csi_pct: 99.972675
# INFO:src.pipeline:  mape_skill_ghi_pct: 92.284504
# INFO:src.pipeline:  mape_skill_csi_pct: 99.974551
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 7 ===
# INFO:src.pipeline:Train samples: 189, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.031735, Val Loss: 0.050417, Train MAE: 0.122582, Val MAE: 0.137968, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.026933, Val Loss: 0.047871, Train MAE: 0.109073, Val MAE: 0.148411, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.023755, Val Loss: 0.042328, Train MAE: 0.101119, Val MAE: 0.138132, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.023246, Val Loss: 0.040317, Train MAE: 0.102357, Val MAE: 0.137251, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.018011, Val Loss: 0.047719, Train MAE: 0.089057, Val MAE: 0.162853, LR: 0.001000
# INFO:src.pipeline:Fold 7 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.047719
# INFO:src.pipeline:  rmse: 0.218446
# INFO:src.pipeline:  mae: 0.162853
# INFO:src.pipeline:  r2: 0.342233
# INFO:src.pipeline:  mape: 31.350952
# INFO:src.pipeline:  model_rmse_ghi: 25.875857
# INFO:src.pipeline:  nam_rmse_ghi: 88.975472
# INFO:src.pipeline:  model_mae_ghi: 14.100942
# INFO:src.pipeline:  nam_mae_ghi: 57.500647
# INFO:src.pipeline:  model_mape_ghi: 33.673657
# INFO:src.pipeline:  nam_mape_ghi: 721.274585
# INFO:src.pipeline:  model_rmse_csi: 0.218446
# INFO:src.pipeline:  model_mae_csi: 0.162853
# INFO:src.pipeline:  model_mape_csi: 31.350952
# INFO:src.pipeline:  nam_rmse_csi: 29388.587128
# INFO:src.pipeline:  nam_mae_csi: 2977.618492
# INFO:src.pipeline:  nam_mape_csi: 351278.956119
# INFO:src.pipeline:  rmse_skill_ghi_pct: 70.917989
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.999257
# INFO:src.pipeline:  mae_skill_ghi_pct: 75.476899
# INFO:src.pipeline:  mae_skill_csi_pct: 99.994531
# INFO:src.pipeline:  mape_skill_ghi_pct: 95.331368
# INFO:src.pipeline:  mape_skill_csi_pct: 99.991075
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 89.000000
# INFO:src.pipeline:
# === Running Fold 8 ===
# INFO:src.pipeline:Train samples: 220, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.032410, Val Loss: 0.049817, Train MAE: 0.118479, Val MAE: 0.132923, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.026483, Val Loss: 0.046626, Train MAE: 0.104440, Val MAE: 0.110045, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 22
# INFO:src.pipeline:Fold 8 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.046284
# INFO:src.pipeline:  rmse: 0.215137
# INFO:src.pipeline:  mae: 0.109490
# INFO:src.pipeline:  r2: 0.300719
# INFO:src.pipeline:  mape: 27.253740
# INFO:src.pipeline:  model_rmse_ghi: 23.726168
# INFO:src.pipeline:  nam_rmse_ghi: 29.103083
# INFO:src.pipeline:  model_mae_ghi: 13.531093
# INFO:src.pipeline:  nam_mae_ghi: 22.579527
# INFO:src.pipeline:  model_mape_ghi: 19.817742
# INFO:src.pipeline:  nam_mape_ghi: 80.821695
# INFO:src.pipeline:  model_rmse_csi: 0.215137
# INFO:src.pipeline:  model_mae_csi: 0.109490
# INFO:src.pipeline:  model_mape_csi: 27.253740
# INFO:src.pipeline:  nam_rmse_csi: 0.716143
# INFO:src.pipeline:  nam_mae_csi: 0.371663
# INFO:src.pipeline:  nam_mape_csi: 81.764890
# INFO:src.pipeline:  rmse_skill_ghi_pct: 18.475413
# INFO:src.pipeline:  rmse_skill_csi_pct: 69.958972
# INFO:src.pipeline:  mae_skill_ghi_pct: 40.073621
# INFO:src.pipeline:  mae_skill_csi_pct: 70.540611
# INFO:src.pipeline:  mape_skill_ghi_pct: 75.479675
# INFO:src.pipeline:  mape_skill_csi_pct: 66.668162
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 9 ===
# INFO:src.pipeline:Train samples: 250, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.036714, Val Loss: 0.043195, Train MAE: 0.126274, Val MAE: 0.162865, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.028310, Val Loss: 0.043552, Train MAE: 0.109179, Val MAE: 0.169994, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# INFO:src.pipeline:Fold 9 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.051583
# INFO:src.pipeline:  rmse: 0.227118
# INFO:src.pipeline:  mae: 0.190600
# INFO:src.pipeline:  r2: 0.359062
# INFO:src.pipeline:  mape: 36.703205
# INFO:src.pipeline:  model_rmse_ghi: 15.362588
# INFO:src.pipeline:  nam_rmse_ghi: 32.796185
# INFO:src.pipeline:  model_mae_ghi: 11.661584
# INFO:src.pipeline:  nam_mae_ghi: 30.029067
# INFO:src.pipeline:  model_mape_ghi: 40.244202
# INFO:src.pipeline:  nam_mape_ghi: 119.777834
# INFO:src.pipeline:  model_rmse_csi: 0.227118
# INFO:src.pipeline:  model_mae_csi: 0.190600
# INFO:src.pipeline:  model_mape_csi: 36.703205
# INFO:src.pipeline:  nam_rmse_csi: 372.061651
# INFO:src.pipeline:  nam_mae_csi: 75.969811
# INFO:src.pipeline:  nam_mape_csi: 19967.417197
# INFO:src.pipeline:  rmse_skill_ghi_pct: 53.157394
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.938957
# INFO:src.pipeline:  mae_skill_ghi_pct: 61.165680
# INFO:src.pipeline:  mae_skill_csi_pct: 99.749111
# INFO:src.pipeline:  mape_skill_ghi_pct: 66.400960
# INFO:src.pipeline:  mape_skill_csi_pct: 99.816185
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 10 ===
# INFO:src.pipeline:Train samples: 281, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.033302, Val Loss: 0.077206, Train MAE: 0.117765, Val MAE: 0.197840, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.029250, Val Loss: 0.074901, Train MAE: 0.109596, Val MAE: 0.201404, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.024966, Val Loss: 0.063702, Train MAE: 0.100945, Val MAE: 0.192753, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.021331, Val Loss: 0.077298, Train MAE: 0.093617, Val MAE: 0.196004, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.015458, Val Loss: 0.098580, Train MAE: 0.078452, Val MAE: 0.218995, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 50
# INFO:src.pipeline:Fold 10 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.098580
# INFO:src.pipeline:  rmse: 0.313974
# INFO:src.pipeline:  mae: 0.218995
# INFO:src.pipeline:  r2: 0.209773
# INFO:src.pipeline:  mape: 63.835453
# INFO:src.pipeline:  model_rmse_ghi: 3.277880
# INFO:src.pipeline:  nam_rmse_ghi: 32.120222
# INFO:src.pipeline:  model_mae_ghi: 2.752230
# INFO:src.pipeline:  nam_mae_ghi: 30.741089
# INFO:src.pipeline:  model_mape_ghi: 95.258221
# INFO:src.pipeline:  nam_mape_ghi: 1061.061250
# INFO:src.pipeline:  model_rmse_csi: 0.313974
# INFO:src.pipeline:  model_mae_csi: 0.218995
# INFO:src.pipeline:  model_mape_csi: 63.835453
# INFO:src.pipeline:  nam_rmse_csi: 3.625350
# INFO:src.pipeline:  nam_mae_csi: 3.027441
# INFO:src.pipeline:  nam_mape_csi: 1229.109594
# INFO:src.pipeline:  rmse_skill_ghi_pct: 89.794964
# INFO:src.pipeline:  rmse_skill_csi_pct: 91.339479
# INFO:src.pipeline:  mae_skill_ghi_pct: 91.047063
# INFO:src.pipeline:  mae_skill_csi_pct: 92.766325
# INFO:src.pipeline:  mape_skill_ghi_pct: 91.022364
# INFO:src.pipeline:  mape_skill_csi_pct: 94.806366
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 24.000000
# INFO:src.pipeline:
# === Running Fold 11 ===
# INFO:src.pipeline:Train samples: 311, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.036082, Val Loss: 0.104827, Train MAE: 0.125386, Val MAE: 0.248837, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.032530, Val Loss: 0.140103, Train MAE: 0.119520, Val MAE: 0.280274, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.025391, Val Loss: 0.140290, Train MAE: 0.103839, Val MAE: 0.273772, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Fold 11 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.126886
# INFO:src.pipeline:  rmse: 0.356211
# INFO:src.pipeline:  mae: 0.263067
# INFO:src.pipeline:  r2: 0.065196
# INFO:src.pipeline:  mape: 115.230453
# INFO:src.pipeline:  model_rmse_ghi: 1.159994
# INFO:src.pipeline:  nam_rmse_ghi: 29.946906
# INFO:src.pipeline:  model_mae_ghi: 0.809987
# INFO:src.pipeline:  nam_mae_ghi: 27.822608
# INFO:src.pipeline:  model_mape_ghi: 55.183608
# INFO:src.pipeline:  nam_mape_ghi: 1340.377721
# INFO:src.pipeline:  model_rmse_csi: 0.356211
# INFO:src.pipeline:  model_mae_csi: 0.263067
# INFO:src.pipeline:  model_mape_csi: 115.230453
# INFO:src.pipeline:  nam_rmse_csi: 4.982339
# INFO:src.pipeline:  nam_mae_csi: 4.351954
# INFO:src.pipeline:  nam_mape_csi: 2454.787116
# INFO:src.pipeline:  rmse_skill_ghi_pct: 96.126499
# INFO:src.pipeline:  rmse_skill_csi_pct: 92.850525
# INFO:src.pipeline:  mae_skill_ghi_pct: 97.088745
# INFO:src.pipeline:  mae_skill_csi_pct: 93.955202
# INFO:src.pipeline:  mape_skill_ghi_pct: 95.882981
# INFO:src.pipeline:  mape_skill_csi_pct: 95.305888
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 11.000000
# INFO:src.pipeline:
# === Running Fold 12 ===
# INFO:src.pipeline:Train samples: 342, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041334, Val Loss: 0.078037, Train MAE: 0.134610, Val MAE: 0.229516, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.032617, Val Loss: 0.131372, Train MAE: 0.118383, Val MAE: 0.274897, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# INFO:src.pipeline:Fold 12 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.093696
# INFO:src.pipeline:  rmse: 0.306097
# INFO:src.pipeline:  mae: 0.236364
# INFO:src.pipeline:  r2: 0.071537
# INFO:src.pipeline:  mape: 34.868587
# INFO:src.pipeline:  model_rmse_ghi: 12.498697
# INFO:src.pipeline:  nam_rmse_ghi: 34.512881
# INFO:src.pipeline:  model_mae_ghi: 8.489538
# INFO:src.pipeline:  nam_mae_ghi: 33.201618
# INFO:src.pipeline:  model_mape_ghi: 40.805114
# INFO:src.pipeline:  nam_mape_ghi: 279.598407
# INFO:src.pipeline:  model_rmse_csi: 0.306097
# INFO:src.pipeline:  model_mae_csi: 0.236364
# INFO:src.pipeline:  model_mape_csi: 34.868587
# INFO:src.pipeline:  nam_rmse_csi: 1.282367
# INFO:src.pipeline:  nam_mae_csi: 1.096885
# INFO:src.pipeline:  nam_mape_csi: 279.598407
# INFO:src.pipeline:  rmse_skill_ghi_pct: 63.785414
# INFO:src.pipeline:  rmse_skill_csi_pct: 76.130292
# INFO:src.pipeline:  mae_skill_ghi_pct: 74.430348
# INFO:src.pipeline:  mae_skill_csi_pct: 78.451378
# INFO:src.pipeline:  mape_skill_ghi_pct: 85.405813
# INFO:src.pipeline:  mape_skill_csi_pct: 87.529046
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 30.000000
# INFO:src.pipeline:
# === Running Fold 13 ===
# INFO:src.pipeline:Train samples: 373, Val samples: 27
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042754, Val Loss: 0.065879, Train MAE: 0.146412, Val MAE: 0.188811, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034601, Val Loss: 0.076826, Train MAE: 0.126516, Val MAE: 0.207394, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 28
# INFO:src.pipeline:Fold 13 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.074426
# INFO:src.pipeline:  rmse: 0.272812
# INFO:src.pipeline:  mae: 0.200370
# INFO:src.pipeline:  r2: 0.381686
# INFO:src.pipeline:  mape: 75.464188
# INFO:src.pipeline:  model_rmse_ghi: 25.166277
# INFO:src.pipeline:  nam_rmse_ghi: 34.915795
# INFO:src.pipeline:  model_mae_ghi: 17.392948
# INFO:src.pipeline:  nam_mae_ghi: 28.073101
# INFO:src.pipeline:  model_mape_ghi: 70.109523
# INFO:src.pipeline:  nam_mape_ghi: 235.612876
# INFO:src.pipeline:  model_rmse_csi: 0.272812
# INFO:src.pipeline:  model_mae_csi: 0.200370
# INFO:src.pipeline:  model_mape_csi: 75.464188
# INFO:src.pipeline:  nam_rmse_csi: 40.391397
# INFO:src.pipeline:  nam_mae_csi: 12.919904
# INFO:src.pipeline:  nam_mape_csi: 13492.524929
# INFO:src.pipeline:  rmse_skill_ghi_pct: 27.922944
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.324579
# INFO:src.pipeline:  mae_skill_ghi_pct: 38.044079
# INFO:src.pipeline:  mae_skill_csi_pct: 98.449134
# INFO:src.pipeline:  mape_skill_ghi_pct: 70.243764
# INFO:src.pipeline:  mape_skill_csi_pct: 99.440696
# INFO:src.pipeline:  n_rows: 378.000000
# INFO:src.pipeline:  n_daylight_rows: 37.000000
# INFO:src.pipeline:
# === Running Fold 14 ===
# INFO:src.pipeline:Train samples: 401, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043695, Val Loss: 0.038449, Train MAE: 0.144142, Val MAE: 0.147065, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036662, Val Loss: 0.035907, Train MAE: 0.129036, Val MAE: 0.136209, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.032096, Val Loss: 0.039421, Train MAE: 0.119654, Val MAE: 0.135153, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.020950, Val Loss: 0.039995, Train MAE: 0.097895, Val MAE: 0.144570, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 48
# INFO:src.pipeline:Fold 14 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.040182
# INFO:src.pipeline:  rmse: 0.200454
# INFO:src.pipeline:  mae: 0.148510
# INFO:src.pipeline:  r2: 0.529421
# INFO:src.pipeline:  mape: 28.874620
# INFO:src.pipeline:  model_rmse_ghi: 38.631470
# INFO:src.pipeline:  nam_rmse_ghi: 27.314497
# INFO:src.pipeline:  model_mae_ghi: 26.006325
# INFO:src.pipeline:  nam_mae_ghi: 20.237865
# INFO:src.pipeline:  model_mape_ghi: 44.268925
# INFO:src.pipeline:  nam_mape_ghi: 49.977180
# INFO:src.pipeline:  model_rmse_csi: 0.200454
# INFO:src.pipeline:  model_mae_csi: 0.148510
# INFO:src.pipeline:  model_mape_csi: 28.874620
# INFO:src.pipeline:  nam_rmse_csi: 0.320300
# INFO:src.pipeline:  nam_mae_csi: 0.209284
# INFO:src.pipeline:  nam_mape_csi: 49.977180
# INFO:src.pipeline:  rmse_skill_ghi_pct: -41.432110
# INFO:src.pipeline:  rmse_skill_csi_pct: 37.416622
# INFO:src.pipeline:  mae_skill_ghi_pct: -28.503302
# INFO:src.pipeline:  mae_skill_csi_pct: 29.039019
# INFO:src.pipeline:  mape_skill_ghi_pct: 11.421722
# INFO:src.pipeline:  mape_skill_csi_pct: 42.224390
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 15 ===
# INFO:src.pipeline:Train samples: 432, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042928, Val Loss: 0.038975, Train MAE: 0.142795, Val MAE: 0.132258, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.033783, Val Loss: 0.036832, Train MAE: 0.127221, Val MAE: 0.119667, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.029579, Val Loss: 0.036160, Train MAE: 0.114470, Val MAE: 0.114674, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.021313, Val Loss: 0.036057, Train MAE: 0.097338, Val MAE: 0.107440, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.017731, Val Loss: 0.036811, Train MAE: 0.090477, Val MAE: 0.107762, LR: 0.000500
# INFO:src.pipeline:Fold 15 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.036811
# INFO:src.pipeline:  rmse: 0.191863
# INFO:src.pipeline:  mae: 0.107762
# INFO:src.pipeline:  r2: 0.546738
# INFO:src.pipeline:  mape: 30.403530
# INFO:src.pipeline:  model_rmse_ghi: 47.395815
# INFO:src.pipeline:  nam_rmse_ghi: 82.344226
# INFO:src.pipeline:  model_mae_ghi: 25.753106
# INFO:src.pipeline:  nam_mae_ghi: 55.958252
# INFO:src.pipeline:  model_mape_ghi: 31.817812
# INFO:src.pipeline:  nam_mape_ghi: 282.624050
# INFO:src.pipeline:  model_rmse_csi: 0.191863
# INFO:src.pipeline:  model_mae_csi: 0.107762
# INFO:src.pipeline:  model_mape_csi: 30.403530
# INFO:src.pipeline:  nam_rmse_csi: 694.038902
# INFO:src.pipeline:  nam_mae_csi: 112.763228
# INFO:src.pipeline:  nam_mape_csi: 12988.119143
# INFO:src.pipeline:  rmse_skill_ghi_pct: 42.441847
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.972356
# INFO:src.pipeline:  mae_skill_ghi_pct: 53.978002
# INFO:src.pipeline:  mae_skill_csi_pct: 99.904435
# INFO:src.pipeline:  mape_skill_ghi_pct: 88.742001
# INFO:src.pipeline:  mape_skill_csi_pct: 99.765913
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 71.000000
# INFO:src.pipeline:
# === Running Fold 16 ===
# INFO:src.pipeline:Train samples: 462, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042978, Val Loss: 0.042001, Train MAE: 0.141658, Val MAE: 0.131956, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036095, Val Loss: 0.040881, Train MAE: 0.130244, Val MAE: 0.123421, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# INFO:src.pipeline:Fold 16 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.041702
# INFO:src.pipeline:  rmse: 0.204212
# INFO:src.pipeline:  mae: 0.123992
# INFO:src.pipeline:  r2: 0.326230
# INFO:src.pipeline:  mape: 90.794640
# INFO:src.pipeline:  model_rmse_ghi: 37.905700
# INFO:src.pipeline:  nam_rmse_ghi: 134.580713
# INFO:src.pipeline:  model_mae_ghi: 18.317900
# INFO:src.pipeline:  nam_mae_ghi: 100.844359
# INFO:src.pipeline:  model_mape_ghi: 209.152494
# INFO:src.pipeline:  nam_mape_ghi: 422.612681
# INFO:src.pipeline:  model_rmse_csi: 0.204212
# INFO:src.pipeline:  model_mae_csi: 0.123992
# INFO:src.pipeline:  model_mape_csi: 90.794640
# INFO:src.pipeline:  nam_rmse_csi: 5.061521
# INFO:src.pipeline:  nam_mae_csi: 2.303061
# INFO:src.pipeline:  nam_mape_csi: 422.612681
# INFO:src.pipeline:  rmse_skill_ghi_pct: 71.834226
# INFO:src.pipeline:  rmse_skill_csi_pct: 95.965407
# INFO:src.pipeline:  mae_skill_ghi_pct: 81.835474
# INFO:src.pipeline:  mae_skill_csi_pct: 94.616219
# INFO:src.pipeline:  mape_skill_ghi_pct: 50.509650
# INFO:src.pipeline:  mape_skill_csi_pct: 78.515874
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 17 ===
# INFO:src.pipeline:Train samples: 493, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041254, Val Loss: 0.033490, Train MAE: 0.141117, Val MAE: 0.116316, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035618, Val Loss: 0.035356, Train MAE: 0.128806, Val MAE: 0.108398, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.025261, Val Loss: 0.034272, Train MAE: 0.106440, Val MAE: 0.102536, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.021650, Val Loss: 0.033358, Train MAE: 0.099874, Val MAE: 0.108178, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.016134, Val Loss: 0.031479, Train MAE: 0.087254, Val MAE: 0.112670, LR: 0.000500
# INFO:src.pipeline:Fold 17 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.031479
# INFO:src.pipeline:  rmse: 0.177422
# INFO:src.pipeline:  mae: 0.112670
# INFO:src.pipeline:  r2: 0.589010
# INFO:src.pipeline:  mape: 27.233589
# INFO:src.pipeline:  model_rmse_ghi: 51.739061
# INFO:src.pipeline:  nam_rmse_ghi: 168.224025
# INFO:src.pipeline:  model_mae_ghi: 33.172026
# INFO:src.pipeline:  nam_mae_ghi: 131.772201
# INFO:src.pipeline:  model_mape_ghi: 44.180249
# INFO:src.pipeline:  nam_mape_ghi: 245.421946
# INFO:src.pipeline:  model_rmse_csi: 0.177422
# INFO:src.pipeline:  model_mae_csi: 0.112670
# INFO:src.pipeline:  model_mape_csi: 27.233589
# INFO:src.pipeline:  nam_rmse_csi: 1233.440798
# INFO:src.pipeline:  nam_mae_csi: 238.135074
# INFO:src.pipeline:  nam_mape_csi: 50045.008041
# INFO:src.pipeline:  rmse_skill_ghi_pct: 69.243953
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.985616
# INFO:src.pipeline:  mae_skill_ghi_pct: 74.826234
# INFO:src.pipeline:  mae_skill_csi_pct: 99.952686
# INFO:src.pipeline:  mape_skill_ghi_pct: 81.998248
# INFO:src.pipeline:  mape_skill_csi_pct: 99.945582
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 18 ===
# INFO:src.pipeline:Train samples: 523, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041359, Val Loss: 0.035093, Train MAE: 0.140163, Val MAE: 0.140350, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037904, Val Loss: 0.031484, Train MAE: 0.131761, Val MAE: 0.117710, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.025438, Val Loss: 0.035690, Train MAE: 0.106346, Val MAE: 0.102579, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# INFO:src.pipeline:Fold 18 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.033964
# INFO:src.pipeline:  rmse: 0.184293
# INFO:src.pipeline:  mae: 0.106499
# INFO:src.pipeline:  r2: 0.450142
# INFO:src.pipeline:  mape: 24.171074
# INFO:src.pipeline:  model_rmse_ghi: 32.559496
# INFO:src.pipeline:  nam_rmse_ghi: 145.080492
# INFO:src.pipeline:  model_mae_ghi: 18.471549
# INFO:src.pipeline:  nam_mae_ghi: 116.494217
# INFO:src.pipeline:  model_mape_ghi: 22.047800
# INFO:src.pipeline:  nam_mape_ghi: 332.422119
# INFO:src.pipeline:  model_rmse_csi: 0.184293
# INFO:src.pipeline:  model_mae_csi: 0.106499
# INFO:src.pipeline:  model_mape_csi: 24.171074
# INFO:src.pipeline:  nam_rmse_csi: 8750.312585
# INFO:src.pipeline:  nam_mae_csi: 898.589462
# INFO:src.pipeline:  nam_mape_csi: 375090.739203
# INFO:src.pipeline:  rmse_skill_ghi_pct: 77.557634
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.997894
# INFO:src.pipeline:  mae_skill_ghi_pct: 84.143806
# INFO:src.pipeline:  mae_skill_csi_pct: 99.988148
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.367529
# INFO:src.pipeline:  mape_skill_csi_pct: 99.993556
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 19 ===
# INFO:src.pipeline:Train samples: 554, Val samples: 28
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.039934, Val Loss: 0.022508, Train MAE: 0.137559, Val MAE: 0.110154, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034496, Val Loss: 0.021150, Train MAE: 0.124855, Val MAE: 0.115954, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.028156, Val Loss: 0.054585, Train MAE: 0.112336, Val MAE: 0.187014, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.019855, Val Loss: 0.030685, Train MAE: 0.095567, Val MAE: 0.130937, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 43
# INFO:src.pipeline:Fold 19 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.027946
# INFO:src.pipeline:  rmse: 0.167172
# INFO:src.pipeline:  mae: 0.117483
# INFO:src.pipeline:  r2: 0.466231
# INFO:src.pipeline:  mape: 15.047608
# INFO:src.pipeline:  model_rmse_ghi: 45.519496
# INFO:src.pipeline:  nam_rmse_ghi: 79.936071
# INFO:src.pipeline:  model_mae_ghi: 24.963550
# INFO:src.pipeline:  nam_mae_ghi: 62.381378
# INFO:src.pipeline:  model_mape_ghi: 21.289389
# INFO:src.pipeline:  nam_mape_ghi: 352.071316
# INFO:src.pipeline:  model_rmse_csi: 0.167172
# INFO:src.pipeline:  model_mae_csi: 0.117483
# INFO:src.pipeline:  model_mape_csi: 15.047608
# INFO:src.pipeline:  nam_rmse_csi: 5332.954517
# INFO:src.pipeline:  nam_mae_csi: 653.905014
# INFO:src.pipeline:  nam_mape_csi: 80875.360650
# INFO:src.pipeline:  rmse_skill_ghi_pct: 43.055124
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.996865
# INFO:src.pipeline:  mae_skill_ghi_pct: 59.982369
# INFO:src.pipeline:  mae_skill_csi_pct: 99.982034
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.953103
# INFO:src.pipeline:  mape_skill_csi_pct: 99.981394
# INFO:src.pipeline:  n_rows: 392.000000
# INFO:src.pipeline:  n_daylight_rows: 83.000000
# INFO:src.pipeline:
# === Running Fold 20 ===
# INFO:src.pipeline:Train samples: 583, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.038551, Val Loss: 0.036616, Train MAE: 0.135621, Val MAE: 0.124056, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034651, Val Loss: 0.037042, Train MAE: 0.123725, Val MAE: 0.131711, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.027318, Val Loss: 0.037732, Train MAE: 0.109020, Val MAE: 0.116593, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Fold 20 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.043548
# INFO:src.pipeline:  rmse: 0.208681
# INFO:src.pipeline:  mae: 0.137014
# INFO:src.pipeline:  r2: 0.451649
# INFO:src.pipeline:  mape: 29.336798
# INFO:src.pipeline:  model_rmse_ghi: 28.240065
# INFO:src.pipeline:  nam_rmse_ghi: 28.517076
# INFO:src.pipeline:  model_mae_ghi: 14.872133
# INFO:src.pipeline:  nam_mae_ghi: 23.786153
# INFO:src.pipeline:  model_mape_ghi: 43.027321
# INFO:src.pipeline:  nam_mape_ghi: 76.292014
# INFO:src.pipeline:  model_rmse_csi: 0.208681
# INFO:src.pipeline:  model_mae_csi: 0.137014
# INFO:src.pipeline:  model_mape_csi: 29.336798
# INFO:src.pipeline:  nam_rmse_csi: 0.570128
# INFO:src.pipeline:  nam_mae_csi: 0.342846
# INFO:src.pipeline:  nam_mape_csi: 77.457980
# INFO:src.pipeline:  rmse_skill_ghi_pct: 0.971385
# INFO:src.pipeline:  rmse_skill_csi_pct: 63.397457
# INFO:src.pipeline:  mae_skill_ghi_pct: 37.475671
# INFO:src.pipeline:  mae_skill_csi_pct: 60.036302
# INFO:src.pipeline:  mape_skill_ghi_pct: 43.601802
# INFO:src.pipeline:  mape_skill_csi_pct: 62.125532
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 21 ===
# INFO:src.pipeline:Train samples: 613, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.037174, Val Loss: 0.032954, Train MAE: 0.130917, Val MAE: 0.126903, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034475, Val Loss: 0.038200, Train MAE: 0.127273, Val MAE: 0.140536, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 22
# INFO:src.pipeline:Fold 21 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.042952
# INFO:src.pipeline:  rmse: 0.207250
# INFO:src.pipeline:  mae: 0.149297
# INFO:src.pipeline:  r2: 0.426611
# INFO:src.pipeline:  mape: 22.608904
# INFO:src.pipeline:  model_rmse_ghi: 23.691800
# INFO:src.pipeline:  nam_rmse_ghi: 34.752485
# INFO:src.pipeline:  model_mae_ghi: 13.558560
# INFO:src.pipeline:  nam_mae_ghi: 32.612153
# INFO:src.pipeline:  model_mape_ghi: 29.873749
# INFO:src.pipeline:  nam_mape_ghi: 106.273663
# INFO:src.pipeline:  model_rmse_csi: 0.207250
# INFO:src.pipeline:  model_mae_csi: 0.149297
# INFO:src.pipeline:  model_mape_csi: 22.608904
# INFO:src.pipeline:  nam_rmse_csi: 209.719011
# INFO:src.pipeline:  nam_mae_csi: 47.320725
# INFO:src.pipeline:  nam_mape_csi: 13109.370468
# INFO:src.pipeline:  rmse_skill_ghi_pct: 31.827033
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.901177
# INFO:src.pipeline:  mae_skill_ghi_pct: 58.424825
# INFO:src.pipeline:  mae_skill_csi_pct: 99.684501
# INFO:src.pipeline:  mape_skill_ghi_pct: 71.889791
# INFO:src.pipeline:  mape_skill_csi_pct: 99.827536
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 22 ===
# INFO:src.pipeline:Train samples: 644, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.040059, Val Loss: 0.061368, Train MAE: 0.134818, Val MAE: 0.182731, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036905, Val Loss: 0.059988, Train MAE: 0.127648, Val MAE: 0.180099, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.030088, Val Loss: 0.056396, Train MAE: 0.114103, Val MAE: 0.183913, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.023871, Val Loss: 0.060739, Train MAE: 0.102204, Val MAE: 0.188597, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.016292, Val Loss: 0.063507, Train MAE: 0.085820, Val MAE: 0.196160, LR: 0.000500
# INFO:src.pipeline:Fold 22 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.063507
# INFO:src.pipeline:  rmse: 0.252006
# INFO:src.pipeline:  mae: 0.196160
# INFO:src.pipeline:  r2: 0.322010
# INFO:src.pipeline:  mape: 39.941414
# INFO:src.pipeline:  model_rmse_ghi: 2.929024
# INFO:src.pipeline:  nam_rmse_ghi: 32.161632
# INFO:src.pipeline:  model_mae_ghi: 1.523934
# INFO:src.pipeline:  nam_mae_ghi: 30.497916
# INFO:src.pipeline:  model_mape_ghi: 33.812768
# INFO:src.pipeline:  nam_mape_ghi: 522.430553
# INFO:src.pipeline:  model_rmse_csi: 0.252006
# INFO:src.pipeline:  model_mae_csi: 0.196160
# INFO:src.pipeline:  model_mape_csi: 39.941414
# INFO:src.pipeline:  nam_rmse_csi: 4.082251
# INFO:src.pipeline:  nam_mae_csi: 3.331544
# INFO:src.pipeline:  nam_mape_csi: 869.897528
# INFO:src.pipeline:  rmse_skill_ghi_pct: 90.892801
# INFO:src.pipeline:  rmse_skill_csi_pct: 93.826779
# INFO:src.pipeline:  mae_skill_ghi_pct: 95.003153
# INFO:src.pipeline:  mae_skill_csi_pct: 94.112037
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.527797
# INFO:src.pipeline:  mape_skill_csi_pct: 95.408492
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 24.000000
# INFO:src.pipeline:
# === Running Fold 23 ===
# INFO:src.pipeline:Train samples: 674, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041202, Val Loss: 0.065585, Train MAE: 0.138529, Val MAE: 0.194468, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036834, Val Loss: 0.085005, Train MAE: 0.128335, Val MAE: 0.209524, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 24
# INFO:src.pipeline:Fold 23 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.102014
# INFO:src.pipeline:  rmse: 0.319396
# INFO:src.pipeline:  mae: 0.223845
# INFO:src.pipeline:  r2: 0.106322
# INFO:src.pipeline:  mape: 88.334618
# INFO:src.pipeline:  model_rmse_ghi: 1.066076
# INFO:src.pipeline:  nam_rmse_ghi: 24.819546
# INFO:src.pipeline:  model_mae_ghi: 0.927470
# INFO:src.pipeline:  nam_mae_ghi: 20.876294
# INFO:src.pipeline:  model_mape_ghi: 153.109897
# INFO:src.pipeline:  nam_mape_ghi: 1072.683416
# INFO:src.pipeline:  model_rmse_csi: 0.319396
# INFO:src.pipeline:  model_mae_csi: 0.223845
# INFO:src.pipeline:  model_mape_csi: 88.334618
# INFO:src.pipeline:  nam_rmse_csi: 5.386778
# INFO:src.pipeline:  nam_mae_csi: 4.706144
# INFO:src.pipeline:  nam_mape_csi: 2108.689560
# INFO:src.pipeline:  rmse_skill_ghi_pct: 95.704691
# INFO:src.pipeline:  rmse_skill_csi_pct: 94.070739
# INFO:src.pipeline:  mae_skill_ghi_pct: 95.557306
# INFO:src.pipeline:  mae_skill_csi_pct: 95.243563
# INFO:src.pipeline:  mape_skill_ghi_pct: 85.726460
# INFO:src.pipeline:  mape_skill_csi_pct: 95.810924
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 10.000000
# INFO:src.pipeline:
# === Running Fold 24 ===
# INFO:src.pipeline:Train samples: 703, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.040136, Val Loss: 0.083573, Train MAE: 0.137419, Val MAE: 0.225488, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034319, Val Loss: 0.104856, Train MAE: 0.126632, Val MAE: 0.240713, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.027627, Val Loss: 0.081893, Train MAE: 0.110496, Val MAE: 0.217917, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.019728, Val Loss: 0.090618, Train MAE: 0.094026, Val MAE: 0.225224, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 41
# INFO:src.pipeline:Fold 24 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.096413
# INFO:src.pipeline:  rmse: 0.310505
# INFO:src.pipeline:  mae: 0.223861
# INFO:src.pipeline:  r2: 0.295902
# INFO:src.pipeline:  mape: 80.058159
# INFO:src.pipeline:  model_rmse_ghi: 9.885177
# INFO:src.pipeline:  nam_rmse_ghi: nan
# INFO:src.pipeline:  model_mae_ghi: 6.602767
# INFO:src.pipeline:  nam_mae_ghi: nan
# INFO:src.pipeline:  model_mape_ghi: 50.180552
# INFO:src.pipeline:  nam_mape_ghi: nan
# INFO:src.pipeline:  model_rmse_csi: 0.310505
# INFO:src.pipeline:  model_mae_csi: 0.223861
# INFO:src.pipeline:  model_mape_csi: 80.058159
# INFO:src.pipeline:  nam_rmse_csi: 29.010329
# INFO:src.pipeline:  nam_mae_csi: 6.930307
# INFO:src.pipeline:  nam_mape_csi: 6018.644154
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 98.929676
# INFO:src.pipeline:  mae_skill_ghi_pct: nan
# INFO:src.pipeline:  mae_skill_csi_pct: 96.769829
# INFO:src.pipeline:  mape_skill_ghi_pct: nan
# INFO:src.pipeline:  mape_skill_csi_pct: 98.669831
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 30.000000
# INFO:src.pipeline:
# === Running Fold 25 ===
# INFO:src.pipeline:Train samples: 734, Val samples: 28
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043851, Val Loss: 0.035189, Train MAE: 0.146336, Val MAE: 0.142911, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036768, Val Loss: 0.033042, Train MAE: 0.130455, Val MAE: 0.138260, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.026452, Val Loss: 0.046917, Train MAE: 0.110128, Val MAE: 0.166207, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.017940, Val Loss: 0.053260, Train MAE: 0.090787, Val MAE: 0.168943, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 40
# INFO:src.pipeline:Fold 25 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.053260
# INFO:src.pipeline:  rmse: 0.230781
# INFO:src.pipeline:  mae: 0.168943
# INFO:src.pipeline:  r2: 0.346178
# INFO:src.pipeline:  mape: 26.623577
# INFO:src.pipeline:  model_rmse_ghi: 17.264604
# INFO:src.pipeline:  nam_rmse_ghi: nan
# INFO:src.pipeline:  model_mae_ghi: 12.950238
# INFO:src.pipeline:  nam_mae_ghi: nan
# INFO:src.pipeline:  model_mape_ghi: 31.817980
# INFO:src.pipeline:  nam_mape_ghi: nan
# INFO:src.pipeline:  model_rmse_csi: 0.230781
# INFO:src.pipeline:  model_mae_csi: 0.168943
# INFO:src.pipeline:  model_mape_csi: 26.623577
# INFO:src.pipeline:  nam_rmse_csi: 327.138316
# INFO:src.pipeline:  nam_mae_csi: 67.335748
# INFO:src.pipeline:  nam_mape_csi: 15615.030707
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.929455
# INFO:src.pipeline:  mae_skill_ghi_pct: nan
# INFO:src.pipeline:  mae_skill_csi_pct: 99.749104
# INFO:src.pipeline:  mape_skill_ghi_pct: nan
# INFO:src.pipeline:  mape_skill_csi_pct: 99.829500
# INFO:src.pipeline:  n_rows: 392.000000
# INFO:src.pipeline:  n_daylight_rows: 39.000000
# INFO:src.pipeline:
# === Running Fold 26 ===
# INFO:src.pipeline:Train samples: 763, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041496, Val Loss: 0.105976, Train MAE: 0.142099, Val MAE: 0.214635, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.033960, Val Loss: 0.103639, Train MAE: 0.123679, Val MAE: 0.211091, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 22
# INFO:src.pipeline:Fold 26 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.101611
# INFO:src.pipeline:  rmse: 0.318765
# INFO:src.pipeline:  mae: 0.209624
# INFO:src.pipeline:  r2: 0.273725
# INFO:src.pipeline:  mape: 124.793480
# INFO:src.pipeline:  model_rmse_ghi: 42.570531
# INFO:src.pipeline:  nam_rmse_ghi: 31.422142
# INFO:src.pipeline:  model_mae_ghi: 28.965794
# INFO:src.pipeline:  nam_mae_ghi: 22.106956
# INFO:src.pipeline:  model_mape_ghi: 143.753212
# INFO:src.pipeline:  nam_mape_ghi: 139.671723
# INFO:src.pipeline:  model_rmse_csi: 0.318765
# INFO:src.pipeline:  model_mae_csi: 0.209624
# INFO:src.pipeline:  model_mape_csi: 124.793480
# INFO:src.pipeline:  nam_rmse_csi: 0.292047
# INFO:src.pipeline:  nam_mae_csi: 0.183863
# INFO:src.pipeline:  nam_mape_csi: 139.671723
# INFO:src.pipeline:  rmse_skill_ghi_pct: -35.479406
# INFO:src.pipeline:  rmse_skill_csi_pct: -9.148424
# INFO:src.pipeline:  mae_skill_ghi_pct: -31.025702
# INFO:src.pipeline:  mae_skill_csi_pct: -14.011110
# INFO:src.pipeline:  mape_skill_ghi_pct: -2.922201
# INFO:src.pipeline:  mape_skill_csi_pct: 10.652295
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 60.000000
# INFO:src.pipeline:
# === Running Fold 27 ===
# INFO:src.pipeline:Train samples: 794, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043487, Val Loss: 0.049525, Train MAE: 0.146116, Val MAE: 0.164808, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036671, Val Loss: 0.054698, Train MAE: 0.130567, Val MAE: 0.165404, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.026277, Val Loss: 0.058239, Train MAE: 0.111184, Val MAE: 0.168171, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 35
# INFO:src.pipeline:Fold 27 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.060704
# INFO:src.pipeline:  rmse: 0.246382
# INFO:src.pipeline:  mae: 0.173075
# INFO:src.pipeline:  r2: 0.389747
# INFO:src.pipeline:  mape: 42.897079
# INFO:src.pipeline:  model_rmse_ghi: 33.438794
# INFO:src.pipeline:  nam_rmse_ghi: 85.922416
# INFO:src.pipeline:  model_mae_ghi: 24.525011
# INFO:src.pipeline:  nam_mae_ghi: 58.849218
# INFO:src.pipeline:  model_mape_ghi: 38.926314
# INFO:src.pipeline:  nam_mape_ghi: 610.394847
# INFO:src.pipeline:  model_rmse_csi: 0.246382
# INFO:src.pipeline:  model_mae_csi: 0.173075
# INFO:src.pipeline:  model_mape_csi: 42.897079
# INFO:src.pipeline:  nam_rmse_csi: 961.257659
# INFO:src.pipeline:  nam_mae_csi: 147.993450
# INFO:src.pipeline:  nam_mape_csi: 16902.462358
# INFO:src.pipeline:  rmse_skill_ghi_pct: 61.082572
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.974369
# INFO:src.pipeline:  mae_skill_ghi_pct: 58.325681
# INFO:src.pipeline:  mae_skill_csi_pct: 99.883052
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.622765
# INFO:src.pipeline:  mape_skill_csi_pct: 99.746208
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 73.000000
# INFO:src.pipeline:
# === Running Fold 28 ===
# INFO:src.pipeline:Train samples: 824, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044625, Val Loss: 0.045234, Train MAE: 0.148055, Val MAE: 0.138505, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036742, Val Loss: 0.057424, Train MAE: 0.130747, Val MAE: 0.159763, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.025734, Val Loss: 0.054186, Train MAE: 0.109443, Val MAE: 0.158999, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Fold 28 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.057238
# INFO:src.pipeline:  rmse: 0.239245
# INFO:src.pipeline:  mae: 0.157207
# INFO:src.pipeline:  r2: 0.313668
# INFO:src.pipeline:  mape: 44.358433
# INFO:src.pipeline:  model_rmse_ghi: 36.889981
# INFO:src.pipeline:  nam_rmse_ghi: 133.168581
# INFO:src.pipeline:  model_mae_ghi: 19.787067
# INFO:src.pipeline:  nam_mae_ghi: 98.274114
# INFO:src.pipeline:  model_mape_ghi: 54.702453
# INFO:src.pipeline:  nam_mape_ghi: 406.928246
# INFO:src.pipeline:  model_rmse_csi: 0.239245
# INFO:src.pipeline:  model_mae_csi: 0.157207
# INFO:src.pipeline:  model_mape_csi: 44.358433
# INFO:src.pipeline:  nam_rmse_csi: 4.165013
# INFO:src.pipeline:  nam_mae_csi: 1.947558
# INFO:src.pipeline:  nam_mape_csi: 406.928246
# INFO:src.pipeline:  rmse_skill_ghi_pct: 72.298285
# INFO:src.pipeline:  rmse_skill_csi_pct: 94.255838
# INFO:src.pipeline:  mae_skill_ghi_pct: 79.865433
# INFO:src.pipeline:  mae_skill_csi_pct: 91.927967
# INFO:src.pipeline:  mape_skill_ghi_pct: 86.557224
# INFO:src.pipeline:  mape_skill_csi_pct: 89.099200
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 120.000000
# INFO:src.pipeline:
# === Running Fold 29 ===
# INFO:src.pipeline:Train samples: 855, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043884, Val Loss: 0.021062, Train MAE: 0.145927, Val MAE: 0.116476, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035487, Val Loss: 0.021981, Train MAE: 0.128403, Val MAE: 0.118282, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# INFO:src.pipeline:Fold 29 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.017999
# INFO:src.pipeline:  rmse: 0.134162
# INFO:src.pipeline:  mae: 0.089736
# INFO:src.pipeline:  r2: 0.691808
# INFO:src.pipeline:  mape: 14.418700
# INFO:src.pipeline:  model_rmse_ghi: 38.408710
# INFO:src.pipeline:  nam_rmse_ghi: 166.941379
# INFO:src.pipeline:  model_mae_ghi: 20.187995
# INFO:src.pipeline:  nam_mae_ghi: 130.514742
# INFO:src.pipeline:  model_mape_ghi: 20.089745
# INFO:src.pipeline:  nam_mape_ghi: 202.740561
# INFO:src.pipeline:  model_rmse_csi: 0.134162
# INFO:src.pipeline:  model_mae_csi: 0.089736
# INFO:src.pipeline:  model_mape_csi: 14.418700
# INFO:src.pipeline:  nam_rmse_csi: 1742.136105
# INFO:src.pipeline:  nam_mae_csi: 314.197475
# INFO:src.pipeline:  nam_mape_csi: 159449.823308
# INFO:src.pipeline:  rmse_skill_ghi_pct: 76.992696
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.992299
# INFO:src.pipeline:  mae_skill_ghi_pct: 84.532019
# INFO:src.pipeline:  mae_skill_csi_pct: 99.971440
# INFO:src.pipeline:  mape_skill_ghi_pct: 90.090910
# INFO:src.pipeline:  mape_skill_csi_pct: 99.990957
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 116.000000
# INFO:src.pipeline:
# === Running Fold 30 ===
# INFO:src.pipeline:Train samples: 885, Val samples: 27
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041855, Val Loss: 0.003130, Train MAE: 0.141377, Val MAE: 0.046921, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034577, Val Loss: 0.004507, Train MAE: 0.125383, Val MAE: 0.059709, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.025646, Val Loss: 0.005236, Train MAE: 0.108454, Val MAE: 0.067046, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.018733, Val Loss: 0.004327, Train MAE: 0.092644, Val MAE: 0.060045, LR: 0.000250
# INFO:src.engine:Early stopping at epoch 47
# INFO:src.pipeline:Fold 30 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.004966
# INFO:src.pipeline:  rmse: 0.070471
# INFO:src.pipeline:  mae: 0.062710
# INFO:src.pipeline:  r2: 0.867981
# INFO:src.pipeline:  mape: 6.673095
# INFO:src.pipeline:  model_rmse_ghi: 10.064943
# INFO:src.pipeline:  nam_rmse_ghi: 158.851647
# INFO:src.pipeline:  model_mae_ghi: 6.402611
# INFO:src.pipeline:  nam_mae_ghi: 128.009580
# INFO:src.pipeline:  model_mape_ghi: 6.280307
# INFO:src.pipeline:  nam_mape_ghi: 368.703288
# INFO:src.pipeline:  model_rmse_csi: 0.070471
# INFO:src.pipeline:  model_mae_csi: 0.062710
# INFO:src.pipeline:  model_mape_csi: 6.673095
# INFO:src.pipeline:  nam_rmse_csi: 2324.382922
# INFO:src.pipeline:  nam_mae_csi: 343.365065
# INFO:src.pipeline:  nam_mape_csi: 68595.502221
# INFO:src.pipeline:  rmse_skill_ghi_pct: 93.663935
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.996968
# INFO:src.pipeline:  mae_skill_ghi_pct: 94.998335
# INFO:src.pipeline:  mae_skill_csi_pct: 99.981737
# INFO:src.pipeline:  mape_skill_ghi_pct: 98.296650
# INFO:src.pipeline:  mape_skill_csi_pct: 99.990272
# INFO:src.pipeline:  n_rows: 378.000000
# INFO:src.pipeline:  n_daylight_rows: 108.000000
# INFO:src.pipeline:
# === Running Fold 31 ===
# INFO:src.pipeline:Train samples: 913, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041845, Val Loss: 0.013485, Train MAE: 0.140133, Val MAE: 0.076076, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.033641, Val Loss: 0.009833, Train MAE: 0.122303, Val MAE: 0.054365, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.024689, Val Loss: 0.011456, Train MAE: 0.105446, Val MAE: 0.052233, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 38
# INFO:src.pipeline:Fold 31 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.014741
# INFO:src.pipeline:  rmse: 0.121412
# INFO:src.pipeline:  mae: 0.056815
# INFO:src.pipeline:  r2: 0.648897
# INFO:src.pipeline:  mape: 8.049193
# INFO:src.pipeline:  model_rmse_ghi: 22.766766
# INFO:src.pipeline:  nam_rmse_ghi: 89.471777
# INFO:src.pipeline:  model_mae_ghi: 12.039258
# INFO:src.pipeline:  nam_mae_ghi: 65.181749
# INFO:src.pipeline:  model_mape_ghi: 10.035699
# INFO:src.pipeline:  nam_mape_ghi: 330.764257
# INFO:src.pipeline:  model_rmse_csi: 0.121412
# INFO:src.pipeline:  model_mae_csi: 0.056815
# INFO:src.pipeline:  model_mape_csi: 8.049193
# INFO:src.pipeline:  nam_rmse_csi: 2868.743811
# INFO:src.pipeline:  nam_mae_csi: 420.722030
# INFO:src.pipeline:  nam_mape_csi: 47629.901026
# INFO:src.pipeline:  rmse_skill_ghi_pct: 74.554249
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.995768
# INFO:src.pipeline:  mae_skill_ghi_pct: 81.529710
# INFO:src.pipeline:  mae_skill_csi_pct: 99.986496
# INFO:src.pipeline:  mape_skill_ghi_pct: 96.965906
# INFO:src.pipeline:  mape_skill_csi_pct: 99.983101
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 88.000000
# INFO:src.pipeline:
# === Running Fold 32 ===
# INFO:src.pipeline:Train samples: 944, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.039659, Val Loss: 0.011067, Train MAE: 0.134366, Val MAE: 0.057432, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035080, Val Loss: 0.011024, Train MAE: 0.125601, Val MAE: 0.071736, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.027326, Val Loss: 0.009056, Train MAE: 0.110027, Val MAE: 0.059445, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.018855, Val Loss: 0.012584, Train MAE: 0.091462, Val MAE: 0.070366, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 48
# INFO:src.pipeline:Fold 32 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.009000
# INFO:src.pipeline:  rmse: 0.094870
# INFO:src.pipeline:  mae: 0.046983
# INFO:src.pipeline:  r2: 0.804310
# INFO:src.pipeline:  mape: 6.101279
# INFO:src.pipeline:  model_rmse_ghi: 6.432606
# INFO:src.pipeline:  nam_rmse_ghi: 20.938126
# INFO:src.pipeline:  model_mae_ghi: 3.941300
# INFO:src.pipeline:  nam_mae_ghi: 16.693148
# INFO:src.pipeline:  model_mape_ghi: 3.959465
# INFO:src.pipeline:  nam_mape_ghi: 67.489418
# INFO:src.pipeline:  model_rmse_csi: 0.094870
# INFO:src.pipeline:  model_mae_csi: 0.046983
# INFO:src.pipeline:  model_mape_csi: 6.101279
# INFO:src.pipeline:  nam_rmse_csi: 0.817794
# INFO:src.pipeline:  nam_mae_csi: 0.380120
# INFO:src.pipeline:  nam_mape_csi: 68.573104
# INFO:src.pipeline:  rmse_skill_ghi_pct: 69.278024
# INFO:src.pipeline:  rmse_skill_csi_pct: 88.399343
# INFO:src.pipeline:  mae_skill_ghi_pct: 76.389715
# INFO:src.pipeline:  mae_skill_csi_pct: 87.639935
# INFO:src.pipeline:  mape_skill_ghi_pct: 94.133207
# INFO:src.pipeline:  mape_skill_csi_pct: 91.102519
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 58.000000
# INFO:src.pipeline:
# === Running Fold 33 ===
# INFO:src.pipeline:Train samples: 974, Val samples: 30
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.038054, Val Loss: 0.092852, Train MAE: 0.132907, Val MAE: 0.198976, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.031859, Val Loss: 0.107734, Train MAE: 0.117886, Val MAE: 0.201190, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 23
# INFO:src.pipeline:Fold 33 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.117288
# INFO:src.pipeline:  rmse: 0.342474
# INFO:src.pipeline:  mae: 0.207218
# INFO:src.pipeline:  r2: 0.107468
# INFO:src.pipeline:  mape: 95.805565
# INFO:src.pipeline:  model_rmse_ghi: 18.956608
# INFO:src.pipeline:  nam_rmse_ghi: 33.710817
# INFO:src.pipeline:  model_mae_ghi: 15.206381
# INFO:src.pipeline:  nam_mae_ghi: 28.381508
# INFO:src.pipeline:  model_mape_ghi: 71.131826
# INFO:src.pipeline:  nam_mape_ghi: 147.636336
# INFO:src.pipeline:  model_rmse_csi: 0.342474
# INFO:src.pipeline:  model_mae_csi: 0.207218
# INFO:src.pipeline:  model_mape_csi: 95.805565
# INFO:src.pipeline:  nam_rmse_csi: 141.727556
# INFO:src.pipeline:  nam_mae_csi: 34.996511
# INFO:src.pipeline:  nam_mape_csi: 9581.218096
# INFO:src.pipeline:  rmse_skill_ghi_pct: 43.766988
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.758357
# INFO:src.pipeline:  mae_skill_ghi_pct: 46.421517
# INFO:src.pipeline:  mae_skill_csi_pct: 99.407890
# INFO:src.pipeline:  mape_skill_ghi_pct: 51.819567
# INFO:src.pipeline:  mape_skill_csi_pct: 99.000069
# INFO:src.pipeline:  n_rows: 420.000000
# INFO:src.pipeline:  n_daylight_rows: 31.000000
# INFO:src.pipeline:
# === Running Fold 34 ===
# INFO:src.pipeline:Train samples: 1005, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.039315, Val Loss: 0.060038, Train MAE: 0.134184, Val MAE: 0.169632, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035042, Val Loss: 0.075337, Train MAE: 0.124944, Val MAE: 0.217143, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.024593, Val Loss: 0.080702, Train MAE: 0.102492, Val MAE: 0.217712, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 31
# INFO:src.pipeline:Fold 34 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.160262
# INFO:src.pipeline:  rmse: 0.400328
# INFO:src.pipeline:  mae: 0.302593
# INFO:src.pipeline:  r2: -0.486249
# INFO:src.pipeline:  mape: 44.766769
# INFO:src.pipeline:  model_rmse_ghi: 2.295846
# INFO:src.pipeline:  nam_rmse_ghi: 31.695118
# INFO:src.pipeline:  model_mae_ghi: 1.660367
# INFO:src.pipeline:  nam_mae_ghi: 29.942103
# INFO:src.pipeline:  model_mape_ghi: 44.514321
# INFO:src.pipeline:  nam_mape_ghi: 760.523498
# INFO:src.pipeline:  model_rmse_csi: 0.400328
# INFO:src.pipeline:  model_mae_csi: 0.302593
# INFO:src.pipeline:  model_mape_csi: 44.766769
# INFO:src.pipeline:  nam_rmse_csi: 3.844745
# INFO:src.pipeline:  nam_mae_csi: 3.126345
# INFO:src.pipeline:  nam_mape_csi: 986.974761
# INFO:src.pipeline:  rmse_skill_ghi_pct: 92.756468
# INFO:src.pipeline:  rmse_skill_csi_pct: 89.587659
# INFO:src.pipeline:  mae_skill_ghi_pct: 94.454742
# INFO:src.pipeline:  mae_skill_csi_pct: 90.321204
# INFO:src.pipeline:  mape_skill_ghi_pct: 94.146884
# INFO:src.pipeline:  mape_skill_csi_pct: 95.464244
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 23.000000
# INFO:src.pipeline:
# === Running Fold 35 ===
# INFO:src.pipeline:Train samples: 1035, Val samples: 29
# INFO:src.pipeline:Model parameters: 978,958
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.040894, Val Loss: 0.072284, Train MAE: 0.138141, Val MAE: 0.198555, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034264, Val Loss: 0.069976, Train MAE: 0.122053, Val MAE: 0.192881, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 24
# INFO:src.pipeline:Fold 35 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.078252
# INFO:src.pipeline:  rmse: 0.279736
# INFO:src.pipeline:  mae: 0.203174
# INFO:src.pipeline:  r2: 0.352740
# INFO:src.pipeline:  mape: 96.412361
# INFO:src.pipeline:  model_rmse_ghi: 1.147354
# INFO:src.pipeline:  nam_rmse_ghi: 30.345306
# INFO:src.pipeline:  model_mae_ghi: 0.838828
# INFO:src.pipeline:  nam_mae_ghi: 29.192504
# INFO:src.pipeline:  model_mape_ghi: 65.281219
# INFO:src.pipeline:  nam_mape_ghi: 1053.923847
# INFO:src.pipeline:  model_rmse_csi: 0.279736
# INFO:src.pipeline:  model_mae_csi: 0.203174
# INFO:src.pipeline:  model_mape_csi: 96.412361
# INFO:src.pipeline:  nam_rmse_csi: 4216.288381
# INFO:src.pipeline:  nam_mae_csi: 902.986886
# INFO:src.pipeline:  nam_mape_csi: 334509.545063
# INFO:src.pipeline:  rmse_skill_ghi_pct: 96.219008
# INFO:src.pipeline:  rmse_skill_csi_pct: 99.993365
# INFO:src.pipeline:  mae_skill_ghi_pct: 97.126565
# INFO:src.pipeline:  mae_skill_csi_pct: 99.977500
# INFO:src.pipeline:  mape_skill_ghi_pct: 93.805888
# INFO:src.pipeline:  mape_skill_csi_pct: 99.971178
# INFO:src.pipeline:  n_rows: 406.000000
# INFO:src.pipeline:  n_daylight_rows: 11.000000
# INFO:src.pipeline:
# === Experiment Summary ===
# INFO:src.pipeline:Average Validation Metrics:
# INFO:src.pipeline:  mse: 0.084762 ± 0.137162
# INFO:src.pipeline:  rmse: 0.256191 ± 0.138305
# INFO:src.pipeline:  mae: 0.183366 ± 0.115732
# INFO:src.pipeline:  r2: 0.170620 ± 0.895569
# INFO:src.pipeline:  mape: 49.052800 ± 38.443876
# INFO:src.pipeline:  model_rmse_ghi: 30.062839 ± 25.464596
# INFO:src.pipeline:  nam_rmse_ghi: nan ± nan
# INFO:src.pipeline:  model_mae_ghi: 19.444147 ± 18.720764
# INFO:src.pipeline:  nam_mae_ghi: nan ± nan
# INFO:src.pipeline:  model_mape_ghi: 57.074082 ± 54.290178
# INFO:src.pipeline:  nam_mape_ghi: nan ± nan
# INFO:src.pipeline:  model_rmse_csi: 0.256191 ± 0.138305
# INFO:src.pipeline:  model_mae_csi: 0.183366 ± 0.115732
# INFO:src.pipeline:  model_mape_csi: 49.052800 ± 38.443876
# INFO:src.pipeline:  nam_rmse_csi: 1899.888090 ± 5082.770758
# INFO:src.pipeline:  nam_mae_csi: 243.899171 ± 530.892522
# INFO:src.pipeline:  nam_mape_csi: 51546.548405 ± 98706.806975
# INFO:src.pipeline:  rmse_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  rmse_skill_csi_pct: 87.967490 ± 25.422226
# INFO:src.pipeline:  mae_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  mae_skill_csi_pct: 86.670013 ± 28.600622
# INFO:src.pipeline:  mape_skill_ghi_pct: nan ± nan
# INFO:src.pipeline:  mape_skill_csi_pct: 88.706013 ± 22.857598
# INFO:src.pipeline:  n_rows: 404.800000 ± 33.023628
# INFO:src.pipeline:  n_daylight_rows: 64.057143 ± 37.604668

# %% [markdown]
# -----

# %%
from src.preprocessing import KBinConfig, process_splits_to_kbins, build_model_arrays, to_fixedgrid_multiindex

selected_columns = ['solar_zenith',
       'hour_progression', 'absolute_hour', 'CSI_ghi',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos',
       'nam_ghi', 'nam_dni', 'nam_cc']


TARGET_COL = 'CSI_ghi'
feature_cols = [c for c in df_phase3.columns.tolist() if c != TARGET_COL]

print("\n--- Step 2: Building model arrays (X, Y) ---")
fixed_df = to_fixedgrid_multiindex(df_phase3, timestamp_col="measurement_time", expected_T=None)  # or set T
# Zero-impute everything (features + target)
ph3_X, ph3_Y, ph3_labels_list = build_model_arrays(
        fixed_df,
        feature_cols=selected_columns,  # must include your chosen inputs
        target_col=TARGET_COL,          # target must be present in columns
        history_days=7,
        horizon_days=5,
    )

print(ph3_X.shape, ph3_Y.shape)



print("=====================================\n")

import pandas as pd
from src.utils import DataManager
from src.pipeline import SolarForecastingPipeline



data_manager = DataManager()
data_manager.save_arrays(
    ph3_X, ph3_Y,
    pd.DataFrame(index=pd.to_datetime(ph3_labels_list, utc=True)),
    filename_prefix='phas3_data',
    feature_cols=selected_columns,
    target_col=TARGET_COL,
    metadata={
        "input_csv": "data/processed/dayTime_NAM_dayahead_features_processed.csv",
        "timestamp_col": "measurement_time",
        "feature_set": selected_columns,     # for traceability
        "history_days": 7,
        "horizon_days": 5,
        "k_bins": None,
    }
)



LSTM_CONFIG = {
    "experiment_name": "phas3_exp_test",
    "model_type": "LSTM",
    "model_config": {
        "hidden_size": 64,
        "num_layers": 2,
        "dropout": 0.2,
        "bidirectional": True,
    },
    "data_prefix": "phas3_data",
    "splits_file": "exp-001/exp-001rolling_origin_splits.json",
    "feature_cols": selected_columns,
    "feature_selection": selected_columns,
    "target_col": TARGET_COL,
    "batch_size": 32,
    "loss_function": "Huber",
    "num_epochs": 50,
    "learning_rate": 0.001,
    "early_stopping_patience": 20,
    "max_folds": 35,
}


pipeline = SolarForecastingPipeline(LSTM_CONFIG)
_, summary = pipeline.run()
# Out:
# INFO:src.utils:Saved arrays to data/phas3_data_*.npy
# INFO:src.utils:X shape: (1060, 7, 14, 12), Y shape: (1060, 5, 14)
# INFO:src.pipeline:Loading data...
# INFO:src.utils:Loaded arrays from data/phas3_data_*.npy
# INFO:src.utils:X shape: (1060, 7, 14, 12), Y shape: (1060, 5, 14)
# --- Step 2: Building model arrays (X, Y) ---
# (1060, 7, 14, 12) (1060, 5, 14)
# =====================================
# INFO:src.pipeline:Reference dataframe prepared for NAM comparison (15162 rows).
# INFO:src.utils:Loaded 35 folds from exp-001/exp-001rolling_origin_splits.json
# INFO:src.pipeline:
# === Running Fold 1 ===
# INFO:src.pipeline:Train samples: 15, Val samples: 16
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.015084, Val Loss: 0.083551, Train MAE: 0.122177, Val MAE: 0.303775, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.010508, Val Loss: 0.091602, Train MAE: 0.097487, Val MAE: 0.340067, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.008677, Val Loss: 0.098078, Train MAE: 0.082239, Val MAE: 0.346897, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 36
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 1: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 1 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.248999
# INFO:src.pipeline:  rmse: 0.498998
# INFO:src.pipeline:  mae: 0.390676
# INFO:src.pipeline:  r2: -0.731214
# INFO:src.pipeline:  mape: 116.896164
# INFO:src.pipeline:
# === Running Fold 2 ===
# INFO:src.pipeline:Train samples: 32, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043338, Val Loss: 0.050270, Train MAE: 0.235841, Val MAE: 0.256872, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.022263, Val Loss: 0.061268, Train MAE: 0.160726, Val MAE: 0.271064, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.016783, Val Loss: 0.055550, Train MAE: 0.135271, Val MAE: 0.257604, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 2: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 2 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.097880
# INFO:src.pipeline:  rmse: 0.312858
# INFO:src.pipeline:  mae: 0.238060
# INFO:src.pipeline:  r2: 0.142958
# INFO:src.pipeline:  mape: 61.682106
# INFO:src.pipeline:
# === Running Fold 3 ===
# INFO:src.pipeline:Train samples: 63, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.033436, Val Loss: 0.034237, Train MAE: 0.200695, Val MAE: 0.206196, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.023088, Val Loss: 0.059220, Train MAE: 0.157166, Val MAE: 0.273302, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 27
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 3: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 3 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.130507
# INFO:src.pipeline:  rmse: 0.361257
# INFO:src.pipeline:  mae: 0.289138
# INFO:src.pipeline:  r2: -0.421978
# INFO:src.pipeline:  mape: 52.447311
# INFO:src.pipeline:
# === Running Fold 4 ===
# INFO:src.pipeline:Train samples: 93, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.031414, Val Loss: 0.016390, Train MAE: 0.188185, Val MAE: 0.142874, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.020877, Val Loss: 0.013646, Train MAE: 0.146598, Val MAE: 0.121961, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.019408, Val Loss: 0.015260, Train MAE: 0.134934, Val MAE: 0.131383, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 33
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 4: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 4 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.030428
# INFO:src.pipeline:  rmse: 0.174437
# INFO:src.pipeline:  mae: 0.131486
# INFO:src.pipeline:  r2: 0.400149
# INFO:src.pipeline:  mape: 18.118807
# INFO:src.pipeline:
# === Running Fold 5 ===
# INFO:src.pipeline:Train samples: 124, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.023949, Val Loss: 0.095874, Train MAE: 0.155962, Val MAE: 0.378602, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018635, Val Loss: 0.097516, Train MAE: 0.136642, Val MAE: 0.379064, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 5: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 5 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.176956
# INFO:src.pipeline:  rmse: 0.420662
# INFO:src.pipeline:  mae: 0.359384
# INFO:src.pipeline:  r2: -3.554745
# INFO:src.pipeline:  mape: 37.738800
# INFO:src.pipeline:
# === Running Fold 6 ===
# INFO:src.pipeline:Train samples: 154, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.019970, Val Loss: 0.017094, Train MAE: 0.143190, Val MAE: 0.113995, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.015359, Val Loss: 0.014340, Train MAE: 0.119255, Val MAE: 0.089152, LR: 0.000500
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.014178, Val Loss: 0.014683, Train MAE: 0.114546, Val MAE: 0.091081, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.013608, Val Loss: 0.014413, Train MAE: 0.110921, Val MAE: 0.089942, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.013352, Val Loss: 0.013584, Train MAE: 0.109355, Val MAE: 0.083132, LR: 0.000500
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 6: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 6 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.027169
# INFO:src.pipeline:  rmse: 0.164829
# INFO:src.pipeline:  mae: 0.083132
# INFO:src.pipeline:  r2: 0.466595
# INFO:src.pipeline:  mape: 19.196302
# INFO:src.pipeline:
# === Running Fold 7 ===
# INFO:src.pipeline:Train samples: 185, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.018254, Val Loss: 0.026587, Train MAE: 0.131566, Val MAE: 0.148695, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.014386, Val Loss: 0.026175, Train MAE: 0.111305, Val MAE: 0.157363, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 26
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 7: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 7 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.053248
# INFO:src.pipeline:  rmse: 0.230755
# INFO:src.pipeline:  mae: 0.154349
# INFO:src.pipeline:  r2: 0.260665
# INFO:src.pipeline:  mape: 36.992779
# INFO:src.pipeline:
# === Running Fold 8 ===
# INFO:src.pipeline:Train samples: 216, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.019142, Val Loss: 0.019353, Train MAE: 0.130562, Val MAE: 0.126140, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.015234, Val Loss: 0.019697, Train MAE: 0.116878, Val MAE: 0.104574, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 8: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 8 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.039360
# INFO:src.pipeline:  rmse: 0.198394
# INFO:src.pipeline:  mae: 0.102178
# INFO:src.pipeline:  r2: 0.387670
# INFO:src.pipeline:  mape: 24.844742
# INFO:src.pipeline:
# === Running Fold 9 ===
# INFO:src.pipeline:Train samples: 246, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.018799, Val Loss: 0.018367, Train MAE: 0.129198, Val MAE: 0.135986, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.014634, Val Loss: 0.025715, Train MAE: 0.112331, Val MAE: 0.191963, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 23
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 9: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 9 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.056580
# INFO:src.pipeline:  rmse: 0.237867
# INFO:src.pipeline:  mae: 0.200593
# INFO:src.pipeline:  r2: 0.241558
# INFO:src.pipeline:  mape: 30.130600
# INFO:src.pipeline:
# === Running Fold 10 ===
# INFO:src.pipeline:Train samples: 277, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.018104, Val Loss: 0.045829, Train MAE: 0.124892, Val MAE: 0.205997, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.014746, Val Loss: 0.048664, Train MAE: 0.111629, Val MAE: 0.201817, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 24
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 10: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 10 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.094297
# INFO:src.pipeline:  rmse: 0.307079
# INFO:src.pipeline:  mae: 0.203734
# INFO:src.pipeline:  r2: 0.240467
# INFO:src.pipeline:  mape: 75.168457
# INFO:src.pipeline:
# === Running Fold 11 ===
# INFO:src.pipeline:Train samples: 307, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.019718, Val Loss: 0.063794, Train MAE: 0.132393, Val MAE: 0.276600, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.016059, Val Loss: 0.054851, Train MAE: 0.118914, Val MAE: 0.254599, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 11: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 11 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.131463
# INFO:src.pipeline:  rmse: 0.362579
# INFO:src.pipeline:  mae: 0.272625
# INFO:src.pipeline:  r2: 0.020880
# INFO:src.pipeline:  mape: 129.548019
# INFO:src.pipeline:
# === Running Fold 12 ===
# INFO:src.pipeline:Train samples: 338, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.022070, Val Loss: 0.054094, Train MAE: 0.142880, Val MAE: 0.268242, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017474, Val Loss: 0.050584, Train MAE: 0.124248, Val MAE: 0.257808, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 12: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 12 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.100317
# INFO:src.pipeline:  rmse: 0.316728
# INFO:src.pipeline:  mae: 0.255026
# INFO:src.pipeline:  r2: 0.015024
# INFO:src.pipeline:  mape: 46.629082
# INFO:src.pipeline:
# === Running Fold 13 ===
# INFO:src.pipeline:Train samples: 369, Val samples: 27
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.022483, Val Loss: 0.043125, Train MAE: 0.147272, Val MAE: 0.232201, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018066, Val Loss: 0.043614, Train MAE: 0.128777, Val MAE: 0.240900, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 27
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 13: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 13 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.098336
# INFO:src.pipeline:  rmse: 0.313585
# INFO:src.pipeline:  mae: 0.254878
# INFO:src.pipeline:  r2: 0.172524
# INFO:src.pipeline:  mape: 90.294716
# INFO:src.pipeline:
# === Running Fold 14 ===
# INFO:src.pipeline:Train samples: 397, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.024367, Val Loss: 0.025886, Train MAE: 0.154921, Val MAE: 0.183528, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018462, Val Loss: 0.027783, Train MAE: 0.132105, Val MAE: 0.182290, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015740, Val Loss: 0.029693, Train MAE: 0.118895, Val MAE: 0.180318, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 14: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 14 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.059175
# INFO:src.pipeline:  rmse: 0.243260
# INFO:src.pipeline:  mae: 0.181009
# INFO:src.pipeline:  r2: 0.315077
# INFO:src.pipeline:  mape: 31.569168
# INFO:src.pipeline:
# === Running Fold 15 ===
# INFO:src.pipeline:Train samples: 428, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.023673, Val Loss: 0.018868, Train MAE: 0.152255, Val MAE: 0.127649, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018391, Val Loss: 0.018635, Train MAE: 0.129604, Val MAE: 0.141365, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.016065, Val Loss: 0.020089, Train MAE: 0.120800, Val MAE: 0.133377, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.013441, Val Loss: 0.019949, Train MAE: 0.108861, Val MAE: 0.126225, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 44
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 15: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 15 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.040013
# INFO:src.pipeline:  rmse: 0.200034
# INFO:src.pipeline:  mae: 0.126945
# INFO:src.pipeline:  r2: 0.512721
# INFO:src.pipeline:  mape: 32.798054
# INFO:src.pipeline:
# === Running Fold 16 ===
# INFO:src.pipeline:Train samples: 458, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.022838, Val Loss: 0.019814, Train MAE: 0.150371, Val MAE: 0.128489, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017380, Val Loss: 0.019856, Train MAE: 0.127552, Val MAE: 0.123423, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 27
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 16: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 16 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.041125
# INFO:src.pipeline:  rmse: 0.202792
# INFO:src.pipeline:  mae: 0.119701
# INFO:src.pipeline:  r2: 0.322910
# INFO:src.pipeline:  mape: 119.453773
# INFO:src.pipeline:
# === Running Fold 17 ===
# INFO:src.pipeline:Train samples: 489, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021760, Val Loss: 0.020112, Train MAE: 0.144514, Val MAE: 0.125968, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017483, Val Loss: 0.020356, Train MAE: 0.127828, Val MAE: 0.133238, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015701, Val Loss: 0.017942, Train MAE: 0.117215, Val MAE: 0.129443, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.013467, Val Loss: 0.018446, Train MAE: 0.109835, Val MAE: 0.128179, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.012678, Val Loss: 0.017500, Train MAE: 0.105593, Val MAE: 0.116989, LR: 0.000250
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 17: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 17 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.034999
# INFO:src.pipeline:  rmse: 0.187081
# INFO:src.pipeline:  mae: 0.116989
# INFO:src.pipeline:  r2: 0.545486
# INFO:src.pipeline:  mape: 32.006870
# INFO:src.pipeline:
# === Running Fold 18 ===
# INFO:src.pipeline:Train samples: 519, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021903, Val Loss: 0.017056, Train MAE: 0.143961, Val MAE: 0.140579, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018869, Val Loss: 0.016148, Train MAE: 0.132929, Val MAE: 0.109819, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 18: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 18 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.050450
# INFO:src.pipeline:  rmse: 0.224611
# INFO:src.pipeline:  mae: 0.178718
# INFO:src.pipeline:  r2: 0.161662
# INFO:src.pipeline:  mape: 29.032145
# INFO:src.pipeline:
# === Running Fold 19 ===
# INFO:src.pipeline:Train samples: 550, Val samples: 28
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021116, Val Loss: 0.013431, Train MAE: 0.142831, Val MAE: 0.115629, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017431, Val Loss: 0.013605, Train MAE: 0.126008, Val MAE: 0.098214, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015284, Val Loss: 0.014232, Train MAE: 0.117694, Val MAE: 0.126126, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 31
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 19: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 19 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.027134
# INFO:src.pipeline:  rmse: 0.164725
# INFO:src.pipeline:  mae: 0.108757
# INFO:src.pipeline:  r2: 0.494471
# INFO:src.pipeline:  mape: 15.764797
# INFO:src.pipeline:
# === Running Fold 20 ===
# INFO:src.pipeline:Train samples: 579, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021617, Val Loss: 0.020037, Train MAE: 0.145090, Val MAE: 0.124332, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017352, Val Loss: 0.019474, Train MAE: 0.126615, Val MAE: 0.118666, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.016747, Val Loss: 0.018348, Train MAE: 0.122354, Val MAE: 0.129333, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.014236, Val Loss: 0.019332, Train MAE: 0.112339, Val MAE: 0.114505, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 46
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 20: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 20 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.038066
# INFO:src.pipeline:  rmse: 0.195105
# INFO:src.pipeline:  mae: 0.113553
# INFO:src.pipeline:  r2: 0.480099
# INFO:src.pipeline:  mape: 25.191671
# INFO:src.pipeline:
# === Running Fold 21 ===
# INFO:src.pipeline:Train samples: 609, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.024322, Val Loss: 0.019613, Train MAE: 0.155940, Val MAE: 0.154078, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017714, Val Loss: 0.025128, Train MAE: 0.128198, Val MAE: 0.176484, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 26
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 21: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 21 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.071372
# INFO:src.pipeline:  rmse: 0.267156
# INFO:src.pipeline:  mae: 0.211559
# INFO:src.pipeline:  r2: 0.129739
# INFO:src.pipeline:  mape: 31.561152
# INFO:src.pipeline:
# === Running Fold 22 ===
# INFO:src.pipeline:Train samples: 640, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020039, Val Loss: 0.036998, Train MAE: 0.137886, Val MAE: 0.183230, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.016051, Val Loss: 0.038856, Train MAE: 0.121390, Val MAE: 0.175547, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.013754, Val Loss: 0.037629, Train MAE: 0.110091, Val MAE: 0.188660, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 38
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 22: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 22 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.077211
# INFO:src.pipeline:  rmse: 0.277868
# INFO:src.pipeline:  mae: 0.189656
# INFO:src.pipeline:  r2: 0.187669
# INFO:src.pipeline:  mape: 49.874088
# INFO:src.pipeline:
# === Running Fold 23 ===
# INFO:src.pipeline:Train samples: 670, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020948, Val Loss: 0.046166, Train MAE: 0.141491, Val MAE: 0.235693, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.016104, Val Loss: 0.046648, Train MAE: 0.121336, Val MAE: 0.225739, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 23
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 23: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 23 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.095296
# INFO:src.pipeline:  rmse: 0.308700
# INFO:src.pipeline:  mae: 0.233578
# INFO:src.pipeline:  r2: 0.176762
# INFO:src.pipeline:  mape: 91.277039
# INFO:src.pipeline:
# === Running Fold 24 ===
# INFO:src.pipeline:Train samples: 699, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020672, Val Loss: 0.043661, Train MAE: 0.141285, Val MAE: 0.228700, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.016265, Val Loss: 0.043722, Train MAE: 0.121799, Val MAE: 0.225080, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 28
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 24: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 24 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.092848
# INFO:src.pipeline:  rmse: 0.304710
# INFO:src.pipeline:  mae: 0.231680
# INFO:src.pipeline:  r2: 0.300942
# INFO:src.pipeline:  mape: 75.375000
# INFO:src.pipeline:
# === Running Fold 25 ===
# INFO:src.pipeline:Train samples: 730, Val samples: 28
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021553, Val Loss: 0.030013, Train MAE: 0.145373, Val MAE: 0.198061, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017227, Val Loss: 0.037120, Train MAE: 0.126908, Val MAE: 0.210282, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 25: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 25 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.082067
# INFO:src.pipeline:  rmse: 0.286473
# INFO:src.pipeline:  mae: 0.218744
# INFO:src.pipeline:  r2: 0.047333
# INFO:src.pipeline:  mape: 35.878887
# INFO:src.pipeline:
# === Running Fold 26 ===
# INFO:src.pipeline:Train samples: 759, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021516, Val Loss: 0.057427, Train MAE: 0.145035, Val MAE: 0.232661, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017288, Val Loss: 0.058980, Train MAE: 0.126071, Val MAE: 0.238483, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 21
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 26: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 26 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.127266
# INFO:src.pipeline:  rmse: 0.356743
# INFO:src.pipeline:  mae: 0.246668
# INFO:src.pipeline:  r2: 0.084387
# INFO:src.pipeline:  mape: 166.698273
# INFO:src.pipeline:
# === Running Fold 27 ===
# INFO:src.pipeline:Train samples: 790, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.022267, Val Loss: 0.031733, Train MAE: 0.148918, Val MAE: 0.151433, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018194, Val Loss: 0.031139, Train MAE: 0.131798, Val MAE: 0.157178, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015142, Val Loss: 0.031759, Train MAE: 0.117229, Val MAE: 0.159160, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 33
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 27: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 27 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.062132
# INFO:src.pipeline:  rmse: 0.249263
# INFO:src.pipeline:  mae: 0.158584
# INFO:src.pipeline:  r2: 0.371528
# INFO:src.pipeline:  mape: 51.043297
# INFO:src.pipeline:
# === Running Fold 28 ===
# INFO:src.pipeline:Train samples: 820, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.022156, Val Loss: 0.027392, Train MAE: 0.147731, Val MAE: 0.170527, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.018247, Val Loss: 0.026459, Train MAE: 0.130928, Val MAE: 0.168351, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015280, Val Loss: 0.029755, Train MAE: 0.118196, Val MAE: 0.176983, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 38
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 28: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 28 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.062144
# INFO:src.pipeline:  rmse: 0.249286
# INFO:src.pipeline:  mae: 0.179264
# INFO:src.pipeline:  r2: 0.258915
# INFO:src.pipeline:  mape: 45.229073
# INFO:src.pipeline:
# === Running Fold 29 ===
# INFO:src.pipeline:Train samples: 851, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.022631, Val Loss: 0.011841, Train MAE: 0.150209, Val MAE: 0.124219, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017903, Val Loss: 0.009011, Train MAE: 0.129346, Val MAE: 0.097264, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.014975, Val Loss: 0.010404, Train MAE: 0.116834, Val MAE: 0.109674, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 29: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 29 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.019178
# INFO:src.pipeline:  rmse: 0.138484
# INFO:src.pipeline:  mae: 0.100768
# INFO:src.pipeline:  r2: 0.672265
# INFO:src.pipeline:  mape: 15.302170
# INFO:src.pipeline:
# === Running Fold 30 ===
# INFO:src.pipeline:Train samples: 881, Val samples: 27
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.022633, Val Loss: 0.003284, Train MAE: 0.149277, Val MAE: 0.059537, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.017787, Val Loss: 0.002647, Train MAE: 0.129357, Val MAE: 0.062251, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.015409, Val Loss: 0.002636, Train MAE: 0.118051, Val MAE: 0.063148, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 39
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 30: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 30 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.005935
# INFO:src.pipeline:  rmse: 0.077041
# INFO:src.pipeline:  mae: 0.067732
# INFO:src.pipeline:  r2: 0.842506
# INFO:src.pipeline:  mape: 7.482271
# INFO:src.pipeline:
# === Running Fold 31 ===
# INFO:src.pipeline:Train samples: 909, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020615, Val Loss: 0.006844, Train MAE: 0.140960, Val MAE: 0.062982, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.016026, Val Loss: 0.010220, Train MAE: 0.120637, Val MAE: 0.090312, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 26
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 31: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 31 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.013004
# INFO:src.pipeline:  rmse: 0.114034
# INFO:src.pipeline:  mae: 0.049981
# INFO:src.pipeline:  r2: 0.676142
# INFO:src.pipeline:  mape: 6.588249
# INFO:src.pipeline:
# === Running Fold 32 ===
# INFO:src.pipeline:Train samples: 940, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021224, Val Loss: 0.009535, Train MAE: 0.142832, Val MAE: 0.095868, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.016595, Val Loss: 0.013782, Train MAE: 0.122773, Val MAE: 0.129351, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 32: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 32 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.029287
# INFO:src.pipeline:  rmse: 0.171134
# INFO:src.pipeline:  mae: 0.126168
# INFO:src.pipeline:  r2: 0.380857
# INFO:src.pipeline:  mape: 14.430800
# INFO:src.pipeline:
# === Running Fold 33 ===
# INFO:src.pipeline:Train samples: 970, Val samples: 30
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.020980, Val Loss: 0.050275, Train MAE: 0.139746, Val MAE: 0.203980, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.015697, Val Loss: 0.051301, Train MAE: 0.117359, Val MAE: 0.218804, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 25
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 33: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 33 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.105072
# INFO:src.pipeline:  rmse: 0.324148
# INFO:src.pipeline:  mae: 0.214511
# INFO:src.pipeline:  r2: 0.170063
# INFO:src.pipeline:  mape: 97.119492
# INFO:src.pipeline:
# === Running Fold 34 ===
# INFO:src.pipeline:Train samples: 1001, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021993, Val Loss: 0.044104, Train MAE: 0.144931, Val MAE: 0.230299, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.016421, Val Loss: 0.046265, Train MAE: 0.120936, Val MAE: 0.227784, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 23
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 34: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 34 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.086560
# INFO:src.pipeline:  rmse: 0.294211
# INFO:src.pipeline:  mae: 0.227017
# INFO:src.pipeline:  r2: 0.202445
# INFO:src.pipeline:  mape: 52.325619
# INFO:src.pipeline:
# === Running Fold 35 ===
# INFO:src.pipeline:Train samples: 1031, Val samples: 29
# INFO:src.pipeline:Model parameters: 986,182
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.021464, Val Loss: 0.042845, Train MAE: 0.143454, Val MAE: 0.222350, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.016809, Val Loss: 0.047078, Train MAE: 0.122158, Val MAE: 0.236615, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 23
# WARNING:src.pipeline:Failed to compute NAM comparison metrics for fold 35: Comparison metrics currently support horizon_days == 1.
# INFO:src.pipeline:Fold 35 - Validation Metrics:
# INFO:src.pipeline:  mse: 0.094479
# INFO:src.pipeline:  rmse: 0.307375
# INFO:src.pipeline:  mae: 0.236961
# INFO:src.pipeline:  r2: 0.217298
# INFO:src.pipeline:  mape: 98.053398
# INFO:src.pipeline:
# === Experiment Summary ===
# INFO:src.pipeline:Average Validation Metrics:
# INFO:src.pipeline:  mse: 0.074296 ± 0.048679
# INFO:src.pipeline:  rmse: 0.258408 ± 0.086726
# INFO:src.pipeline:  mae: 0.187823 ± 0.076948
# INFO:src.pipeline:  r2: 0.148338 ± 0.694394
# INFO:src.pipeline:  mape: 53.249805 ± 38.319209

# %% [markdown]
# ---
