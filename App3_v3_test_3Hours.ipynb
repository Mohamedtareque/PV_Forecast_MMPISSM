# %%
# Loading Data
from src.data_preparation import load_data
import matplotlib.pyplot as plt
plt.ioff()
PROCESSED_DATA_PATH = "data/processed/df_3h_lag_BLV_spatial_images.csv"
df = load_data(PROCESSED_DATA_PATH, date_col="measurement_time")
# Out:
# Loaded 10,510 records
# Date range: 2014-01-03 14:00:00+00:00 to 2016-12-30 23:00:00+00:00
# Timezone: UTC

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ghi', 'dni', 'PST_Time_meas', 'solar_zenith',
#        'time_gap_hours', 'time_gap_norm', 'day_boundary_flag',
#        'hour_progression', 'absolute_hour', 'GHI_cs', 'DNI_cs', 'CSI_ghi',
#        'CSI_dni', 'season_flag', 'hour_sin', 'hour_cos', 'month_sin',
#        'month_cos', 'nam_ghi', 'nam_dni', 'nam_cc', 'PST_Time_nam',
#        'nam_target_time', 'B_CSI_ghi_8h', 'V_CSI_ghi_8h', 'L_CSI_ghi_8h',
#        'B_CSI_ghi_9h', 'V_CSI_ghi_9h', 'L_CSI_ghi_9h', 'B_CSI_ghi_10h',
#        'V_CSI_ghi_10h', 'L_CSI_ghi_10h', 'B_CSI_ghi_11h', 'V_CSI_ghi_11h',
#        'L_CSI_ghi_11h', 'B_CSI_ghi_12h', 'V_CSI_ghi_12h', 'L_CSI_ghi_12h',
#        'B_CSI_ghi_13h', 'V_CSI_ghi_13h', 'L_CSI_ghi_13h', 'B_CSI_ghi_14h',
#        'V_CSI_ghi_14h', 'L_CSI_ghi_14h', 'B_CSI_ghi_15h', 'V_CSI_ghi_15h',
#        'L_CSI_ghi_15h', 'B_CSI_ghi_16h', 'V_CSI_ghi_16h', 'L_CSI_ghi_16h',
#        'B_CSI_ghi_17h', 'V_CSI_ghi_17h', 'L_CSI_ghi_17h', 'B_CSI_ghi_18h',
#        'V_CSI_ghi_18h', 'L_CSI_ghi_18h', 'B_CSI_ghi_19h', 'V_CSI_ghi_19h',
#        'L_CSI_ghi_19h', '80_dwsw', 'valtime', '80_cloud_cover', '56_dwsw',
#        '56_cloud_cover', '20_dwsw', '20_cloud_cover', '88_dwsw',
#        '88_cloud_cover', 'timestamp', 'AVG(R)', 'STD(R)', 'ENT(R)', 'AVG(G)',
#        'STD(G)', 'ENT(G)', 'AVG(B)', 'STD(B)', 'ENT(B)', 'AVG(RB)', 'STD(RB)',
#        'ENT(RB)', 'AVG(NRB)', 'STD(NRB)', 'ENT(NRB)'],
#       dtype='object')

# %%
df.drop(columns=["Unnamed: 0", "timestamp"], inplace=True)

# %%
# 2. Rolling Origin Split (More Suitable in TimeSeries) like K-Folds
from src.data_preparation import fixed_holdout_split, rolling_origin_evaluation,save_splits_info

rollingSplits_df_3h = rolling_origin_evaluation(df=df, start_train = '2014-01-2',
    end_train = '2016-12-31')
save_splits_info({}, rollingSplits_df_3h, experiment_name="exp-005")
# Out:
# ============================================================
# ROLLING ORIGIN EVALUATION
# ============================================================
# Total folds: 35
# Frequency: MS
# Data range: 2014-01-03 to 2016-12-30
#
# Fold Summary:
#   Fold 1: Train [2014-01-03 to 2014-02-01] (270 records) → Val [2014-02-02 to 2014-02-28] (170 records)
#   Fold 2: Train [2014-01-03 to 2014-03-01] (450 records) → Val [2014-03-02 to 2014-03-31] (290 records)
#   Fold 3: Train [2014-01-03 to 2014-04-01] (760 records) → Val [2014-04-02 to 2014-04-30] (280 records)
#   Fold 4: Train [2014-01-03 to 2014-05-01] (1,060 records) → Val [2014-05-02 to 2014-05-31] (290 records)
#   Fold 5: Train [2014-01-03 to 2014-06-01] (1,370 records) → Val [2014-06-02 to 2014-06-30] (280 records)
#   Fold 6: Train [2014-01-03 to 2014-07-01] (1,670 records) → Val [2014-07-02 to 2014-07-31] (290 records)
#   Fold 7: Train [2014-01-03 to 2014-08-01] (1,980 records) → Val [2014-08-02 to 2014-08-31] (290 records)
#   Fold 8: Train [2014-01-03 to 2014-09-01] (2,290 records) → Val [2014-09-02 to 2014-09-30] (280 records)
#   Fold 9: Train [2014-01-03 to 2014-10-01] (2,590 records) → Val [2014-10-02 to 2014-10-31] (290 records)
#   Fold 10: Train [2014-01-03 to 2014-11-01] (2,900 records) → Val [2014-11-02 to 2014-11-30] (280 records)
#   Fold 11: Train [2014-01-03 to 2014-12-01] (3,200 records) → Val [2014-12-02 to 2014-12-31] (290 records)
#   Fold 12: Train [2014-01-03 to 2015-01-01] (3,510 records) → Val [2015-01-02 to 2015-01-31] (290 records)
#   Fold 13: Train [2014-01-03 to 2015-02-01] (3,820 records) → Val [2015-02-02 to 2015-02-28] (260 records)
#   Fold 14: Train [2014-01-03 to 2015-03-01] (4,100 records) → Val [2015-03-02 to 2015-03-31] (290 records)
#   Fold 15: Train [2014-01-03 to 2015-04-01] (4,410 records) → Val [2015-04-02 to 2015-04-30] (280 records)
#   Fold 16: Train [2014-01-03 to 2015-05-01] (4,710 records) → Val [2015-05-02 to 2015-05-31] (290 records)
#   Fold 17: Train [2014-01-03 to 2015-06-01] (5,020 records) → Val [2015-06-02 to 2015-06-30] (280 records)
#   Fold 18: Train [2014-01-03 to 2015-07-01] (5,320 records) → Val [2015-07-02 to 2015-07-31] (290 records)
#   Fold 19: Train [2014-01-03 to 2015-08-01] (5,630 records) → Val [2015-08-02 to 2015-08-31] (280 records)
#   Fold 20: Train [2014-01-03 to 2015-09-01] (5,930 records) → Val [2015-09-02 to 2015-09-30] (280 records)
#   Fold 21: Train [2014-01-03 to 2015-10-01] (6,230 records) → Val [2015-10-02 to 2015-10-31] (290 records)
#   Fold 22: Train [2014-01-03 to 2015-11-01] (6,540 records) → Val [2015-11-02 to 2015-11-30] (280 records)
#   Fold 23: Train [2014-01-03 to 2015-12-01] (6,840 records) → Val [2015-12-02 to 2015-12-31] (290 records)
#   Fold 24: Train [2014-01-03 to 2016-01-01] (7,140 records) → Val [2016-01-02 to 2016-01-31] (200 records)
#   Fold 25: Train [2014-01-03 to 2016-02-01] (7,360 records) → Val [2016-02-02 to 2016-02-29] (210 records)
#   Fold 26: Train [2014-01-03 to 2016-03-01] (7,590 records) → Val [2016-03-02 to 2016-03-31] (290 records)
#   Fold 27: Train [2014-01-03 to 2016-04-01] (7,900 records) → Val [2016-04-02 to 2016-04-30] (280 records)
#   Fold 28: Train [2014-01-03 to 2016-05-01] (8,200 records) → Val [2016-05-02 to 2016-05-31] (290 records)
#   Fold 29: Train [2014-01-03 to 2016-06-01] (8,510 records) → Val [2016-06-02 to 2016-06-30] (280 records)
#   Fold 30: Train [2014-01-03 to 2016-07-01] (8,810 records) → Val [2016-07-02 to 2016-07-31] (270 records)
#   Fold 31: Train [2014-01-03 to 2016-08-01] (9,100 records) → Val [2016-08-02 to 2016-08-31] (290 records)
#   Fold 32: Train [2014-01-03 to 2016-09-01] (9,410 records) → Val [2016-09-02 to 2016-09-30] (280 records)
#   Fold 33: Train [2014-01-03 to 2016-10-01] (9,710 records) → Val [2016-10-02 to 2016-10-31] (290 records)
#   Fold 34: Train [2014-01-03 to 2016-11-01] (10,020 records) → Val [2016-11-02 to 2016-11-30] (280 records)
#   Fold 35: Train [2014-01-03 to 2016-12-01] (10,320 records) → Val [2016-12-02 to 2016-12-31] (190 records)
# ============================================================
#
# Split metadata saved to 'splits/exp-005/' directory

# %%
df_interpolated = df.interpolate(method='linear')

df_interpolated.fillna(0, inplace=True)

features_to_check = ['ghi', 'dni', 'solar_zenith', 'GHI_cs', 'DNI_cs', 'CSI_ghi', 
                                   'CSI_dni',
                                   'nam_ghi', 'nam_dni', 'nam_cc', 'B_CSI_ghi_8h', 'V_CSI_ghi_8h', 'L_CSI_ghi_8h', 'B_CSI_ghi_9h',
       'V_CSI_ghi_9h', 'L_CSI_ghi_9h', 'B_CSI_ghi_10h', 'V_CSI_ghi_10h',
       'L_CSI_ghi_10h', 'B_CSI_ghi_11h', 'V_CSI_ghi_11h', 'L_CSI_ghi_11h',
       'B_CSI_ghi_12h', 'V_CSI_ghi_12h', 'L_CSI_ghi_12h', 'B_CSI_ghi_13h',
       'V_CSI_ghi_13h', 'L_CSI_ghi_13h', 'B_CSI_ghi_14h', 'V_CSI_ghi_14h',
       'L_CSI_ghi_14h', 'B_CSI_ghi_15h', 'V_CSI_ghi_15h', 'L_CSI_ghi_15h',
       'B_CSI_ghi_16h', 'V_CSI_ghi_16h', 'L_CSI_ghi_16h', 'B_CSI_ghi_17h',
       'V_CSI_ghi_17h', 'L_CSI_ghi_17h', 'B_CSI_ghi_18h', 'V_CSI_ghi_18h',
       'L_CSI_ghi_18h', 'B_CSI_ghi_19h', 'V_CSI_ghi_19h', 'L_CSI_ghi_19h',
       '80_dwsw', '80_cloud_cover', '56_dwsw', '56_cloud_cover',
       '20_dwsw', '20_cloud_cover', '88_dwsw', '88_cloud_cover', 'AVG(R)',
       'STD(R)', 'ENT(R)', 'AVG(G)', 'STD(G)', 'ENT(G)', 'AVG(B)', 'STD(B)',
       'ENT(B)', 'AVG(RB)', 'STD(RB)', 'ENT(RB)', 'AVG(NRB)', 'STD(NRB)',
       'ENT(NRB)']

# 2. Calculate the number of NaN values for each feature
# We use .isna() instead of == 0
nans_per_feature = df_interpolated[features_to_check].isna().sum()

# 3. Filter to get only features that actually have NaN values
features_with_nans = nans_per_feature[nans_per_feature > 0]

# 4. Report the findings for which features have NaNs
if features_with_nans.empty:
    print("No NaN (missing) values found in any of the specified features.")
else:
    print("--- Features With NaN Values ---")
    print("The following features have NaN values, with the total count for each:")
    # Sort for clearer output
    print(features_with_nans.sort_values(ascending=False))
    print("\n" + "="*40 + "\n")

    # 5. Analyze the distribution of hours for rows containing NaNs
    print("--- Distribution of NaN-Value Records by Hour ---")
    
    # Create a boolean mask for rows that contain *at least one* NaN
    # in the specified columns
    rows_with_any_nan = df_interpolated[features_to_check].isna().any(axis=1)
    
    if rows_with_any_nan.sum() > 0:
        # Get the index for these rows
        nan_rows_index = df_interpolated.index[rows_with_any_nan]
        
        # Extract the hour from the DatetimeIndex and get the value counts
        hour_distribution = nan_rows_index.hour.value_counts().sort_index()
        
        print("Distribution of records (rows) containing at least one NaN, by hour:")
        print(hour_distribution)
        
        # Optional: Print total number of affected rows
        print(f"\nTotal number of rows with at least one NaN: {rows_with_any_nan.sum()}")
    else:
        # This case shouldn't be hit if features_with_nans was not empty,
        # but it's good practice to include.
        print("No rows found with NaN values (this is unexpected, check logic).")
# Out:
# No NaN (missing) values found in any of the specified features.
# /tmp/ipykernel_836440/1640297138.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_interpolated = df.interpolate(method='linear')

# %%
import torch
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if hasattr(torch.backends, "mps") and torch.backends.mps.is_available()
    else "cpu"
)

device
# Out:
# 'cuda'

# %%
df_phase1 = df_interpolated[['CSI_ghi','time_gap_hours',
       'time_gap_norm',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos']]


df_phase2 = df_interpolated[['solar_zenith', 'CSI_ghi','time_gap_hours',
       'time_gap_norm', 'day_boundary_flag', 'hour_progression',
       'absolute_hour',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'B_CSI_ghi_8h', 'V_CSI_ghi_8h', 'L_CSI_ghi_8h', 'B_CSI_ghi_9h',
       'V_CSI_ghi_9h', 'L_CSI_ghi_9h', 'B_CSI_ghi_10h', 'V_CSI_ghi_10h',
       'L_CSI_ghi_10h', 'B_CSI_ghi_11h', 'V_CSI_ghi_11h', 'L_CSI_ghi_11h',
       'B_CSI_ghi_12h', 'V_CSI_ghi_12h', 'L_CSI_ghi_12h', 'B_CSI_ghi_13h',
       'V_CSI_ghi_13h', 'L_CSI_ghi_13h', 'B_CSI_ghi_14h', 'V_CSI_ghi_14h',
       'L_CSI_ghi_14h', 'B_CSI_ghi_15h', 'V_CSI_ghi_15h', 'L_CSI_ghi_15h',
       'B_CSI_ghi_16h', 'V_CSI_ghi_16h', 'L_CSI_ghi_16h', 'B_CSI_ghi_17h',
       'V_CSI_ghi_17h', 'L_CSI_ghi_17h', 'B_CSI_ghi_18h', 'V_CSI_ghi_18h',
       'L_CSI_ghi_18h', 'B_CSI_ghi_19h', 'V_CSI_ghi_19h', 'L_CSI_ghi_19h']]

df_phase3 = df_interpolated[['solar_zenith', 'CSI_ghi','time_gap_hours',
       'time_gap_norm', 'day_boundary_flag', 'hour_progression',
       'absolute_hour',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'B_CSI_ghi_8h', 'V_CSI_ghi_8h', 'L_CSI_ghi_8h', 'B_CSI_ghi_9h',
       'V_CSI_ghi_9h', 'L_CSI_ghi_9h', 'B_CSI_ghi_10h', 'V_CSI_ghi_10h',
       'L_CSI_ghi_10h', 'B_CSI_ghi_11h', 'V_CSI_ghi_11h', 'L_CSI_ghi_11h',
       'B_CSI_ghi_12h', 'V_CSI_ghi_12h', 'L_CSI_ghi_12h', 'B_CSI_ghi_13h',
       'V_CSI_ghi_13h', 'L_CSI_ghi_13h', 'B_CSI_ghi_14h', 'V_CSI_ghi_14h',
       'L_CSI_ghi_14h', 'B_CSI_ghi_15h', 'V_CSI_ghi_15h', 'L_CSI_ghi_15h',
       'B_CSI_ghi_16h', 'V_CSI_ghi_16h', 'L_CSI_ghi_16h', 'B_CSI_ghi_17h',
       'V_CSI_ghi_17h', 'L_CSI_ghi_17h', 'B_CSI_ghi_18h', 'V_CSI_ghi_18h',
       'L_CSI_ghi_18h', 'B_CSI_ghi_19h', 'V_CSI_ghi_19h', 'L_CSI_ghi_19h',
       'nam_ghi', 'nam_cc']]

df_phase4 = df_interpolated[['solar_zenith', 'CSI_ghi','time_gap_hours',
       'time_gap_norm', 'day_boundary_flag', 'hour_progression',
       'absolute_hour',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'B_CSI_ghi_8h', 'V_CSI_ghi_8h', 'L_CSI_ghi_8h', 'B_CSI_ghi_9h',
       'V_CSI_ghi_9h', 'L_CSI_ghi_9h', 'B_CSI_ghi_10h', 'V_CSI_ghi_10h',
       'L_CSI_ghi_10h', 'B_CSI_ghi_11h', 'V_CSI_ghi_11h', 'L_CSI_ghi_11h',
       'B_CSI_ghi_12h', 'V_CSI_ghi_12h', 'L_CSI_ghi_12h', 'B_CSI_ghi_13h',
       'V_CSI_ghi_13h', 'L_CSI_ghi_13h', 'B_CSI_ghi_14h', 'V_CSI_ghi_14h',
       'L_CSI_ghi_14h', 'B_CSI_ghi_15h', 'V_CSI_ghi_15h', 'L_CSI_ghi_15h',
       'B_CSI_ghi_16h', 'V_CSI_ghi_16h', 'L_CSI_ghi_16h', 'B_CSI_ghi_17h',
       'V_CSI_ghi_17h', 'L_CSI_ghi_17h', 'B_CSI_ghi_18h', 'V_CSI_ghi_18h',
       'L_CSI_ghi_18h', 'B_CSI_ghi_19h', 'V_CSI_ghi_19h', 'L_CSI_ghi_19h',
       'nam_ghi', 'nam_cc', '80_dwsw', '80_cloud_cover', '56_dwsw', '56_cloud_cover',
       '20_dwsw', '20_cloud_cover', '88_dwsw', '88_cloud_cover']]

df_phase5 = df_interpolated[['solar_zenith', 'CSI_ghi','time_gap_hours',
       'time_gap_norm', 'day_boundary_flag', 'hour_progression',
       'absolute_hour',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'B_CSI_ghi_8h', 'V_CSI_ghi_8h', 'L_CSI_ghi_8h', 'B_CSI_ghi_9h',
       'V_CSI_ghi_9h', 'L_CSI_ghi_9h', 'B_CSI_ghi_10h', 'V_CSI_ghi_10h',
       'L_CSI_ghi_10h', 'B_CSI_ghi_11h', 'V_CSI_ghi_11h', 'L_CSI_ghi_11h',
       'B_CSI_ghi_12h', 'V_CSI_ghi_12h', 'L_CSI_ghi_12h', 'B_CSI_ghi_13h',
       'V_CSI_ghi_13h', 'L_CSI_ghi_13h', 'B_CSI_ghi_14h', 'V_CSI_ghi_14h',
       'L_CSI_ghi_14h', 'B_CSI_ghi_15h', 'V_CSI_ghi_15h', 'L_CSI_ghi_15h',
       'B_CSI_ghi_16h', 'V_CSI_ghi_16h', 'L_CSI_ghi_16h', 'B_CSI_ghi_17h',
       'V_CSI_ghi_17h', 'L_CSI_ghi_17h', 'B_CSI_ghi_18h', 'V_CSI_ghi_18h',
       'L_CSI_ghi_18h', 'B_CSI_ghi_19h', 'V_CSI_ghi_19h', 'L_CSI_ghi_19h',
       'nam_ghi', 'nam_cc','80_cloud_cover',  '56_cloud_cover',
        '20_cloud_cover', '88_cloud_cover']]

df_phase6 = df_interpolated[['solar_zenith', 'CSI_ghi','time_gap_hours',
       'time_gap_norm', 'day_boundary_flag', 'hour_progression',
       'absolute_hour',
       'season_flag', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'B_CSI_ghi_8h', 'V_CSI_ghi_8h', 'L_CSI_ghi_8h', 'B_CSI_ghi_9h',
       'V_CSI_ghi_9h', 'L_CSI_ghi_9h', 'B_CSI_ghi_10h', 'V_CSI_ghi_10h',
       'L_CSI_ghi_10h', 'B_CSI_ghi_11h', 'V_CSI_ghi_11h', 'L_CSI_ghi_11h',
       'B_CSI_ghi_12h', 'V_CSI_ghi_12h', 'L_CSI_ghi_12h', 'B_CSI_ghi_13h',
       'V_CSI_ghi_13h', 'L_CSI_ghi_13h', 'B_CSI_ghi_14h', 'V_CSI_ghi_14h',
       'L_CSI_ghi_14h', 'B_CSI_ghi_15h', 'V_CSI_ghi_15h', 'L_CSI_ghi_15h',
       'B_CSI_ghi_16h', 'V_CSI_ghi_16h', 'L_CSI_ghi_16h', 'B_CSI_ghi_17h',
       'V_CSI_ghi_17h', 'L_CSI_ghi_17h', 'B_CSI_ghi_18h', 'V_CSI_ghi_18h',
       'L_CSI_ghi_18h', 'B_CSI_ghi_19h', 'V_CSI_ghi_19h', 'L_CSI_ghi_19h',
       'nam_ghi', 'nam_cc', '80_dwsw', '80_cloud_cover', '56_dwsw', '56_cloud_cover',
       '20_dwsw', '20_cloud_cover', '88_dwsw', '88_cloud_cover', 'AVG(R)',
       'STD(R)', 'ENT(R)', 'AVG(G)', 'STD(G)', 'ENT(G)', 'AVG(B)', 'STD(B)',
       'ENT(B)', 'AVG(RB)', 'STD(RB)', 'ENT(RB)', 'AVG(NRB)', 'STD(NRB)',
       'ENT(NRB)'
      ]]

# %%
from src.preprocessing import build_model_arrays, to_fixedgrid_multiindex
import pandas as pd
from src.utils import DataManager
from src.pipeline import SolarForecastingPipeline

# --- Block 1: Define variables ---

TARGET_COL = "CSI_ghi"  # <-- FIX 1: Define Target FIRST
history_days = 7
horizon_days = 1

# This list now correctly excludes the target
feature_cols = [c for c in df_phase1.columns.tolist() if c != TARGET_COL]

# --- Block 2: Build model arrays (Your code was correct here) ---


print("\n--- Step 2: Building model arrays (X, Y) ---")
fixed_df = to_fixedgrid_multiindex(df_phase1, timestamp_col="measurement_time", expected_T=None)  # or set T
    


# You correctly passed the filtered 'feature_cols' here, fixing the data leak!
ph1_3h_X, ph1_3h_Y, ph1_3h_labels_list = build_model_arrays(
        fixed_df,
        feature_cols=feature_cols,  
        target_col=TARGET_COL,
        history_days=history_days,
        horizon_days=horizon_days,
    )

# --- Block 3: Save arrays ---
data_manager = DataManager()
data_manager.save_arrays(
    ph1_3h_X, ph1_3h_Y,
    pd.DataFrame(index=pd.to_datetime(ph1_3h_labels_list, utc=True)),
    filename_prefix='phas1_3h_data',  # <-- You are saving as 'phas2_data'
    feature_cols=feature_cols,
    target_col=TARGET_COL,
    metadata={
        "input_csv": "data/processed/df_3h_lag_BLV_spatial_images.csv",
        "timestamp_col": "measurement_time",
        "feature_set": feature_cols,
        "history_days": 7,
        "horizon_days": 1,
    }
)

# --- Block 4: Configure and Run ---
LSTM_CONFIG = {
    "experiment_name": "BiLSTM_p1_ReLU_exp01_3H_essentialF",
    "model_type": "LSTM",
    "model_config": {
        "hidden_size": 64,
        "num_layers": 2,
        "dropout": 0.35,
        "bidirectional": True,
        "use_attention": False,
        # "steps_per_day": 11,
        "activation_function": "ReLU"

    },
    "data_prefix": "phas1_3h_data",  # <-- FIX 2: Match the filename_prefix
    "splits_file": "exp-005/exp-005rolling_origin_splits.json",
    "feature_cols": feature_cols,
    "feature_selection": feature_cols, # <-- This is correct!
    "target_col": TARGET_COL,
    "batch_size": 32,
    "num_epochs": 50,
    "learning_rate": 0.001,
    "loss_function": "Huber", 
    "early_stopping_patience": 20,
    "max_folds": 35,
    "scale_target": False,

}

pipeline = SolarForecastingPipeline(LSTM_CONFIG)
LSTM_CONFIG.update({
    "truth_csi_col": "actual_csi",
    "truth_ghi_col": None,     # or None to reconstruct as CSI * clear_sky_ghi
    "ghi_cs_col":    "clear_sky_ghi",
    "nam_ghi_col":   "nam_ghi",
    "nam_csi_col":   None,        # optional; benchmark will derive if missing
})



pipeline = SolarForecastingPipeline(LSTM_CONFIG)
ph1_exp01_3h_results, summary = pipeline.run()
# Out:
# INFO:src.utils:Saved arrays to data/phas1_3h_data_*.npy
# INFO:src.utils:X shape: (1044, 7, 10, 7), Y shape: (1044, 1, 10)
# INFO:src.pipeline:Loading data...
# INFO:src.utils:Loaded arrays from data/phas1_3h_data_*.npy
# INFO:src.utils:X shape: (1044, 7, 10, 7), Y shape: (1044, 1, 10)
# --- Step 2: Building model arrays (X, Y) ---
# INFO:src.pipeline:Building simple reference from existing columns (no pvlib, no regridding)...
# /home/muhammadhassan/App_v02/src/evaluation_utils.py:132: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ref["nam_csi"].replace([np.inf, -np.inf], np.nan, inplace=True)
# INFO:src.pipeline:Reference dataframe prepared (10510 rows).
# INFO:src.utils:Loaded 35 folds from exp-005/exp-005rolling_origin_splits.json
# INFO:src.pipeline:
# === Running Fold 1 ===
# INFO:src.pipeline:Train samples: 20, Val samples: 17
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.368107, Val Loss: 0.278997, Train MAE: 0.778245, Val MAE: 0.645728, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.159613, Val Loss: 0.158975, Train MAE: 0.444689, Val MAE: 0.437349, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.082292, Val Loss: 0.100589, Train MAE: 0.329395, Val MAE: 0.337222, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.073584, Val Loss: 0.111633, Train MAE: 0.303043, Val MAE: 0.328154, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.058442, Val Loss: 0.105324, Train MAE: 0.276890, Val MAE: 0.336860, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 170  | y_true: 170 | y_pred: 170
# INFO:src.pipeline:
# === Running Fold 2 ===
# INFO:src.pipeline:Train samples: 38, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.126145, Val Loss: 0.105721, Train MAE: 0.399047, Val MAE: 0.364599, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.118445, Val Loss: 0.140113, Train MAE: 0.418958, Val MAE: 0.475816, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.084725, Val Loss: 0.151083, Train MAE: 0.343536, Val MAE: 0.492683, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 3 ===
# INFO:src.pipeline:Train samples: 69, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.098706, Val Loss: 0.063990, Train MAE: 0.373537, Val MAE: 0.334824, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.088178, Val Loss: 0.034956, Train MAE: 0.353270, Val MAE: 0.236580, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.090087, Val Loss: 0.031234, Train MAE: 0.355735, Val MAE: 0.210373, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.077917, Val Loss: 0.035472, Train MAE: 0.326418, Val MAE: 0.238134, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.057991, Val Loss: 0.033162, Train MAE: 0.278411, Val MAE: 0.223487, LR: 0.000250
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 4 ===
# INFO:src.pipeline:Train samples: 99, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.097495, Val Loss: 0.027742, Train MAE: 0.360605, Val MAE: 0.218699, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.126302, Val Loss: 0.023859, Train MAE: 0.396710, Val MAE: 0.204654, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.067694, Val Loss: 0.013210, Train MAE: 0.289320, Val MAE: 0.131128, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.066127, Val Loss: 0.013172, Train MAE: 0.301434, Val MAE: 0.127278, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.060233, Val Loss: 0.012040, Train MAE: 0.274389, Val MAE: 0.120022, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 5 ===
# INFO:src.pipeline:Train samples: 130, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.085362, Val Loss: 0.270030, Train MAE: 0.335454, Val MAE: 0.710124, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.066809, Val Loss: 0.170487, Train MAE: 0.290989, Val MAE: 0.561215, LR: 0.000500
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.054397, Val Loss: 0.056324, Train MAE: 0.265363, Val MAE: 0.279071, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.053812, Val Loss: 0.054956, Train MAE: 0.260792, Val MAE: 0.231092, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.052677, Val Loss: 0.077967, Train MAE: 0.268081, Val MAE: 0.279253, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 6 ===
# INFO:src.pipeline:Train samples: 160, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.071216, Val Loss: 0.015148, Train MAE: 0.297170, Val MAE: 0.143575, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.060134, Val Loss: 0.012478, Train MAE: 0.276264, Val MAE: 0.080556, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.053101, Val Loss: 0.011649, Train MAE: 0.248695, Val MAE: 0.080073, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.044953, Val Loss: 0.013295, Train MAE: 0.237466, Val MAE: 0.082582, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.044230, Val Loss: 0.016524, Train MAE: 0.236441, Val MAE: 0.108895, LR: 0.000250
# INFO:src.engine:Early stopping at epoch 50
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 7 ===
# INFO:src.pipeline:Train samples: 191, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.058368, Val Loss: 0.021625, Train MAE: 0.268121, Val MAE: 0.113405, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.051834, Val Loss: 0.021281, Train MAE: 0.251852, Val MAE: 0.110550, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.050767, Val Loss: 0.020862, Train MAE: 0.245060, Val MAE: 0.121073, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.043836, Val Loss: 0.022133, Train MAE: 0.228996, Val MAE: 0.114794, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.039788, Val Loss: 0.022733, Train MAE: 0.218398, Val MAE: 0.114963, LR: 0.000250
# INFO:src.engine:Early stopping at epoch 50
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 8 ===
# INFO:src.pipeline:Train samples: 222, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.059745, Val Loss: 0.021525, Train MAE: 0.278877, Val MAE: 0.131607, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.045539, Val Loss: 0.023062, Train MAE: 0.239959, Val MAE: 0.158284, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.045252, Val Loss: 0.024043, Train MAE: 0.239353, Val MAE: 0.162763, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 30
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 9 ===
# INFO:src.pipeline:Train samples: 252, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.053852, Val Loss: 0.023123, Train MAE: 0.254594, Val MAE: 0.195002, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.046538, Val Loss: 0.027240, Train MAE: 0.239541, Val MAE: 0.213338, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.040900, Val Loss: 0.027299, Train MAE: 0.217284, Val MAE: 0.198831, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 10 ===
# INFO:src.pipeline:Train samples: 283, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.058356, Val Loss: 0.051365, Train MAE: 0.272805, Val MAE: 0.273691, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.045536, Val Loss: 0.050732, Train MAE: 0.232902, Val MAE: 0.264725, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.038223, Val Loss: 0.060836, Train MAE: 0.214984, Val MAE: 0.275996, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 39
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# /home/muhammadhassan/.venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:580: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
# INFO:src.pipeline:
# === Running Fold 11 ===
# INFO:src.pipeline:Train samples: 313, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.050638, Val Loss: 0.103272, Train MAE: 0.246355, Val MAE: 0.389712, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.046727, Val Loss: 0.103138, Train MAE: 0.242318, Val MAE: 0.385370, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 23
# /home/muhammadhassan/App_v02/src/utils.py:433: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
# /home/muhammadhassan/App_v02/src/utils.py:497: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# /home/muhammadhassan/App_v02/src/benchmarking.py:205: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(14, 4))
# /home/muhammadhassan/App_v02/src/benchmarking.py:205: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(14, 4))
# /home/muhammadhassan/App_v02/src/benchmarking.py:205: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(14, 4))
# /home/muhammadhassan/App_v02/src/benchmarking.py:205: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(14, 4))
# /home/muhammadhassan/App_v02/src/benchmarking.py:221: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(4.8, 4.8))
# /home/muhammadhassan/App_v02/src/benchmarking.py:243: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(8, 4))
# INFO:src.pipeline:
# === Running Fold 12 ===
# INFO:src.pipeline:Train samples: 344, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.063268, Val Loss: 0.075069, Train MAE: 0.286700, Val MAE: 0.336551, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.049276, Val Loss: 0.047100, Train MAE: 0.250963, Val MAE: 0.264270, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.041894, Val Loss: 0.042861, Train MAE: 0.224048, Val MAE: 0.242230, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.040395, Val Loss: 0.042026, Train MAE: 0.219226, Val MAE: 0.238164, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 48
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 13 ===
# INFO:src.pipeline:Train samples: 375, Val samples: 26
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.053389, Val Loss: 0.061496, Train MAE: 0.259206, Val MAE: 0.303760, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.046346, Val Loss: 0.058872, Train MAE: 0.236296, Val MAE: 0.291919, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.042429, Val Loss: 0.058383, Train MAE: 0.227784, Val MAE: 0.276776, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.039825, Val Loss: 0.055333, Train MAE: 0.216417, Val MAE: 0.281068, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.040575, Val Loss: 0.056515, Train MAE: 0.223160, Val MAE: 0.272468, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 260  | y_true: 260 | y_pred: 260
# INFO:src.pipeline:
# === Running Fold 14 ===
# INFO:src.pipeline:Train samples: 403, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.055506, Val Loss: 0.021623, Train MAE: 0.265866, Val MAE: 0.172462, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.047150, Val Loss: 0.020147, Train MAE: 0.242998, Val MAE: 0.166726, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.044411, Val Loss: 0.033561, Train MAE: 0.233715, Val MAE: 0.231526, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.043827, Val Loss: 0.025597, Train MAE: 0.230654, Val MAE: 0.194484, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.038407, Val Loss: 0.024432, Train MAE: 0.216306, Val MAE: 0.194798, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 15 ===
# INFO:src.pipeline:Train samples: 434, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.059270, Val Loss: 0.026004, Train MAE: 0.270821, Val MAE: 0.188330, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.049457, Val Loss: 0.025807, Train MAE: 0.242989, Val MAE: 0.188579, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.042487, Val Loss: 0.022583, Train MAE: 0.224243, Val MAE: 0.137430, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.042958, Val Loss: 0.022716, Train MAE: 0.227701, Val MAE: 0.147124, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.039984, Val Loss: 0.022825, Train MAE: 0.218658, Val MAE: 0.148793, LR: 0.000250
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 16 ===
# INFO:src.pipeline:Train samples: 464, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.052382, Val Loss: 0.020021, Train MAE: 0.261654, Val MAE: 0.139594, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.042344, Val Loss: 0.019157, Train MAE: 0.224990, Val MAE: 0.137679, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 28
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 17 ===
# INFO:src.pipeline:Train samples: 495, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.051032, Val Loss: 0.016526, Train MAE: 0.249721, Val MAE: 0.114893, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.043835, Val Loss: 0.016377, Train MAE: 0.229045, Val MAE: 0.115646, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.039535, Val Loss: 0.016294, Train MAE: 0.219294, Val MAE: 0.108998, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.038327, Val Loss: 0.016295, Train MAE: 0.209414, Val MAE: 0.101877, LR: 0.000250
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.038373, Val Loss: 0.016259, Train MAE: 0.209470, Val MAE: 0.103845, LR: 0.000250
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 18 ===
# INFO:src.pipeline:Train samples: 525, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.050033, Val Loss: 0.016105, Train MAE: 0.250028, Val MAE: 0.118517, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.043068, Val Loss: 0.017652, Train MAE: 0.225424, Val MAE: 0.084352, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.039904, Val Loss: 0.017737, Train MAE: 0.213949, Val MAE: 0.085837, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 37
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 19 ===
# INFO:src.pipeline:Train samples: 556, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.048195, Val Loss: 0.007477, Train MAE: 0.246139, Val MAE: 0.058518, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039662, Val Loss: 0.009267, Train MAE: 0.218325, Val MAE: 0.119502, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.038719, Val Loss: 0.007287, Train MAE: 0.212682, Val MAE: 0.089138, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 37
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 20 ===
# INFO:src.pipeline:Train samples: 586, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.050525, Val Loss: 0.015722, Train MAE: 0.248926, Val MAE: 0.123814, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039480, Val Loss: 0.015616, Train MAE: 0.216742, Val MAE: 0.130764, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.038670, Val Loss: 0.015882, Train MAE: 0.210969, Val MAE: 0.136920, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.036799, Val Loss: 0.015697, Train MAE: 0.204272, Val MAE: 0.120478, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 49
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 21 ===
# INFO:src.pipeline:Train samples: 616, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.046157, Val Loss: 0.016893, Train MAE: 0.235131, Val MAE: 0.147619, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.041420, Val Loss: 0.016058, Train MAE: 0.218085, Val MAE: 0.137267, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.036007, Val Loss: 0.015509, Train MAE: 0.206959, Val MAE: 0.120001, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.037569, Val Loss: 0.015461, Train MAE: 0.208583, Val MAE: 0.126171, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.033724, Val Loss: 0.015514, Train MAE: 0.194239, Val MAE: 0.127229, LR: 0.000250
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 22 ===
# INFO:src.pipeline:Train samples: 647, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045241, Val Loss: 0.045190, Train MAE: 0.234234, Val MAE: 0.248359, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038317, Val Loss: 0.053308, Train MAE: 0.213019, Val MAE: 0.287972, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 22
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 23 ===
# INFO:src.pipeline:Train samples: 677, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.046083, Val Loss: 0.045288, Train MAE: 0.236895, Val MAE: 0.246370, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.041356, Val Loss: 0.044223, Train MAE: 0.218312, Val MAE: 0.247643, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.035723, Val Loss: 0.042084, Train MAE: 0.197871, Val MAE: 0.234844, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.034977, Val Loss: 0.041492, Train MAE: 0.198361, Val MAE: 0.227216, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.033354, Val Loss: 0.041743, Train MAE: 0.191922, Val MAE: 0.235831, LR: 0.001000
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 24 ===
# INFO:src.pipeline:Train samples: 707, Val samples: 20
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.046669, Val Loss: 0.051901, Train MAE: 0.237878, Val MAE: 0.268139, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.040427, Val Loss: 0.052642, Train MAE: 0.217873, Val MAE: 0.253472, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.037157, Val Loss: 0.053188, Train MAE: 0.207116, Val MAE: 0.253839, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.034558, Val Loss: 0.053094, Train MAE: 0.198793, Val MAE: 0.258517, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 43
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 200  | y_true: 200 | y_pred: 200
# INFO:src.pipeline:
# === Running Fold 25 ===
# INFO:src.pipeline:Train samples: 729, Val samples: 21
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045729, Val Loss: 0.056690, Train MAE: 0.237337, Val MAE: 0.292024, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.040948, Val Loss: 0.035857, Train MAE: 0.220200, Val MAE: 0.213823, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.038880, Val Loss: 0.034907, Train MAE: 0.213668, Val MAE: 0.224474, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 210  | y_true: 210 | y_pred: 210
# INFO:src.pipeline:
# === Running Fold 26 ===
# INFO:src.pipeline:Train samples: 752, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044857, Val Loss: 0.052885, Train MAE: 0.233300, Val MAE: 0.247687, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039509, Val Loss: 0.061404, Train MAE: 0.216948, Val MAE: 0.233873, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.037812, Val Loss: 0.054803, Train MAE: 0.209469, Val MAE: 0.243344, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.037467, Val Loss: 0.052009, Train MAE: 0.205130, Val MAE: 0.250855, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 49
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 27 ===
# INFO:src.pipeline:Train samples: 783, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045716, Val Loss: 0.036915, Train MAE: 0.233921, Val MAE: 0.196806, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039396, Val Loss: 0.038128, Train MAE: 0.211375, Val MAE: 0.169553, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 28
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 28 ===
# INFO:src.pipeline:Train samples: 813, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.047317, Val Loss: 0.031714, Train MAE: 0.239774, Val MAE: 0.191963, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.041889, Val Loss: 0.034623, Train MAE: 0.223766, Val MAE: 0.175752, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 26
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 29 ===
# INFO:src.pipeline:Train samples: 844, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045743, Val Loss: 0.008552, Train MAE: 0.236057, Val MAE: 0.112854, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038543, Val Loss: 0.006320, Train MAE: 0.213853, Val MAE: 0.068230, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.038892, Val Loss: 0.006819, Train MAE: 0.212746, Val MAE: 0.085586, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 38
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 30 ===
# INFO:src.pipeline:Train samples: 874, Val samples: 27
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042649, Val Loss: 0.002477, Train MAE: 0.225111, Val MAE: 0.065535, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039423, Val Loss: 0.002732, Train MAE: 0.215712, Val MAE: 0.068618, LR: 0.000500
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.037319, Val Loss: 0.003744, Train MAE: 0.208540, Val MAE: 0.082754, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.037613, Val Loss: 0.001048, Train MAE: 0.211115, Val MAE: 0.038950, LR: 0.000250
# INFO:src.engine:Early stopping at epoch 43
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 270  | y_true: 270 | y_pred: 270
# INFO:src.pipeline:
# === Running Fold 31 ===
# INFO:src.pipeline:Train samples: 903, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042910, Val Loss: 0.007004, Train MAE: 0.227114, Val MAE: 0.097902, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039314, Val Loss: 0.005582, Train MAE: 0.212457, Val MAE: 0.078934, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.035750, Val Loss: 0.005264, Train MAE: 0.201215, Val MAE: 0.071742, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 38
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 32 ===
# INFO:src.pipeline:Train samples: 934, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043020, Val Loss: 0.005920, Train MAE: 0.224927, Val MAE: 0.082770, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038212, Val Loss: 0.006931, Train MAE: 0.210253, Val MAE: 0.097634, LR: 0.000500
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.037410, Val Loss: 0.007209, Train MAE: 0.208016, Val MAE: 0.100137, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.035713, Val Loss: 0.007120, Train MAE: 0.197935, Val MAE: 0.099501, LR: 0.000250
# INFO:src.engine:Early stopping at epoch 45
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 33 ===
# INFO:src.pipeline:Train samples: 964, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041247, Val Loss: 0.068350, Train MAE: 0.222516, Val MAE: 0.246784, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038289, Val Loss: 0.063940, Train MAE: 0.210266, Val MAE: 0.257850, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 23
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 34 ===
# INFO:src.pipeline:Train samples: 995, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044973, Val Loss: 0.046315, Train MAE: 0.232320, Val MAE: 0.260839, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038158, Val Loss: 0.044760, Train MAE: 0.208751, Val MAE: 0.243559, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.033953, Val Loss: 0.045314, Train MAE: 0.191749, Val MAE: 0.254806, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.033531, Val Loss: 0.045586, Train MAE: 0.190688, Val MAE: 0.258151, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.034315, Val Loss: 0.044169, Train MAE: 0.195016, Val MAE: 0.234793, LR: 0.000250
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 35 ===
# INFO:src.pipeline:Train samples: 1025, Val samples: 19
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043225, Val Loss: 0.051721, Train MAE: 0.228119, Val MAE: 0.278789, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037672, Val Loss: 0.067622, Train MAE: 0.204906, Val MAE: 0.336883, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.037562, Val Loss: 0.044504, Train MAE: 0.208552, Val MAE: 0.241935, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 39
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 190  | y_true: 190 | y_pred: 190
# INFO:src.pipeline:
# === Experiment Summary ===
# INFO:src.pipeline:Average Validation Metrics:
# INFO:src.pipeline:  MAE: 0.195462 ± 0.096790
# INFO:src.pipeline:  RMSE: 0.257979 ± 0.110240
# INFO:src.pipeline:  per_horizon_MAE: 0.195462 ± 0.096790
# INFO:src.pipeline:  GHI_RMSE_skill_Ours_vs_SP: -0.264505 ± 1.034744
# INFO:src.pipeline:  GHI_MAE_skill_Ours_vs_SP: -0.951981 ± 1.937086
# INFO:src.pipeline:  CSI_RMSE_skill_Ours_vs_SP: -0.333414 ± 1.008292
# INFO:src.pipeline:  CSI_MAE_skill_Ours_vs_SP: -1.126155 ± 2.004465
# INFO:src.pipeline:  GHI_RMSE_skill_NAM_vs_SP: -2.231082 ± 3.863240
# INFO:src.pipeline:  GHI_MAE_skill_NAM_vs_SP: -4.784376 ± 7.218421
# INFO:src.pipeline:  CSI_RMSE_skill_NAM_vs_SP: -2.084155 ± 4.100858
# INFO:src.pipeline:  CSI_MAE_skill_NAM_vs_SP: -4.418878 ± 7.606558

# %%
from src.preprocessing import build_model_arrays, to_fixedgrid_multiindex
import pandas as pd
from src.utils import DataManager
from src.pipeline import SolarForecastingPipeline

# --- Block 1: Define variables ---

TARGET_COL = "CSI_ghi"  # <-- FIX 1: Define Target FIRST
history_days = 7
horizon_days = 1

# This list now correctly excludes the target
feature_cols = [c for c in df_phase6.columns.tolist() if c != TARGET_COL]

# --- Block 2: Build model arrays (Your code was correct here) ---


print("\n--- Step 2: Building model arrays (X, Y) ---")
fixed_df = to_fixedgrid_multiindex(df_phase6, timestamp_col="measurement_time", expected_T=None)  # or set T
    


# You correctly passed the filtered 'feature_cols' here, fixing the data leak!
ph6_3h_X, ph6_3h_Y, ph6_3h_labels_list = build_model_arrays(
        fixed_df,
        feature_cols=feature_cols,  
        target_col=TARGET_COL,
        history_days=history_days,
        horizon_days=horizon_days,
    )

# --- Block 3: Save arrays ---
data_manager = DataManager()
data_manager.save_arrays(
    ph1_3h_X, ph1_3h_Y,
    pd.DataFrame(index=pd.to_datetime(ph1_3h_labels_list, utc=True)),
    filename_prefix='phas6_3h_data',  # <-- You are saving as 'phas2_data'
    feature_cols=feature_cols,
    target_col=TARGET_COL,
    metadata={
        "input_csv": "data/processed/df_3h_lag_BLV_spatial_images.csv",
        "timestamp_col": "measurement_time",
        "feature_set": feature_cols,
        "history_days": 7,
        "horizon_days": 1,
    }
)

# --- Block 4: Configure and Run ---
LSTM_CONFIG = {
    "experiment_name": "BiLSTM_p6_Tanh_exp01_3H_Essn_BLV_5NAM_CCANDGHI_images",
    "model_type": "LSTM",
    "model_config": {
        "hidden_size": 64,
        "num_layers": 2,
        "dropout": 0.35,
        "bidirectional": True,
        "use_attention": False,
        # "steps_per_day": 11,
        "activation_function": "Tanh"

    },
    "data_prefix": "phas6_3h_data",  # <-- FIX 2: Match the filename_prefix
    "splits_file": "exp-005/exp-005rolling_origin_splits.json",
    "feature_cols": feature_cols,
    "feature_selection": feature_cols, # <-- This is correct!
    "target_col": TARGET_COL,
    "batch_size": 32,
    "num_epochs": 50,
    "learning_rate": 0.001,
    "loss_function": "Huber", 
    "early_stopping_patience": 20,
    "max_folds": 35,
    "scale_target": False,

}

pipeline = SolarForecastingPipeline(LSTM_CONFIG)
LSTM_CONFIG.update({
    "truth_csi_col": "actual_csi",
    "truth_ghi_col": None,     # or None to reconstruct as CSI * clear_sky_ghi
    "ghi_cs_col":    "clear_sky_ghi",
    "nam_ghi_col":   "nam_ghi",
    "nam_csi_col":   None,        # optional; benchmark will derive if missing
})



pipeline = SolarForecastingPipeline(LSTM_CONFIG)
ph6_exp01_3h_results, summary = pipeline.run()
# Out:
# --- Step 2: Building model arrays (X, Y) ---
# INFO:src.utils:Saved arrays to data/phas6_3h_data_*.npy
# INFO:src.utils:X shape: (1044, 7, 10, 7), Y shape: (1044, 1, 10)
# INFO:src.pipeline:Loading data...
# INFO:src.utils:Loaded arrays from data/phas6_3h_data_*.npy
# INFO:src.utils:X shape: (1044, 7, 10, 7), Y shape: (1044, 1, 10)
# INFO:src.pipeline:Building simple reference from existing columns (no pvlib, no regridding)...
# /home/muhammadhassan/App_v02/src/evaluation_utils.py:132: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ref["nam_csi"].replace([np.inf, -np.inf], np.nan, inplace=True)
# INFO:src.pipeline:Reference dataframe prepared (10510 rows).
# INFO:src.utils:Loaded 35 folds from exp-005/exp-005rolling_origin_splits.json
# INFO:src.pipeline:
# === Running Fold 1 ===
# INFO:src.pipeline:Train samples: 20, Val samples: 17
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.214414, Val Loss: 0.160075, Train MAE: 0.573281, Val MAE: 0.473865, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.067962, Val Loss: 0.151025, Train MAE: 0.281294, Val MAE: 0.380971, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.083183, Val Loss: 0.103340, Train MAE: 0.339531, Val MAE: 0.328576, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.055156, Val Loss: 0.116636, Train MAE: 0.261955, Val MAE: 0.330022, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.046096, Val Loss: 0.117986, Train MAE: 0.243522, Val MAE: 0.340263, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 170  | y_true: 170 | y_pred: 170
# INFO:src.pipeline:
# === Running Fold 2 ===
# INFO:src.pipeline:Train samples: 38, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.097027, Val Loss: 0.170543, Train MAE: 0.363440, Val MAE: 0.529016, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.078023, Val Loss: 0.227823, Train MAE: 0.325810, Val MAE: 0.616588, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 3 ===
# INFO:src.pipeline:Train samples: 69, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.086340, Val Loss: 0.056838, Train MAE: 0.362120, Val MAE: 0.313346, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.062869, Val Loss: 0.031695, Train MAE: 0.298391, Val MAE: 0.206189, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.064820, Val Loss: 0.027184, Train MAE: 0.299760, Val MAE: 0.174524, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.056252, Val Loss: 0.026977, Train MAE: 0.266307, Val MAE: 0.175376, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.053192, Val Loss: 0.026105, Train MAE: 0.262412, Val MAE: 0.168078, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 4 ===
# INFO:src.pipeline:Train samples: 99, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.068701, Val Loss: 0.020792, Train MAE: 0.304857, Val MAE: 0.181725, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.063141, Val Loss: 0.013802, Train MAE: 0.278179, Val MAE: 0.131081, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.065057, Val Loss: 0.012807, Train MAE: 0.278574, Val MAE: 0.124530, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 5 ===
# INFO:src.pipeline:Train samples: 130, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.060701, Val Loss: 0.081603, Train MAE: 0.277121, Val MAE: 0.381056, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.052788, Val Loss: 0.071911, Train MAE: 0.256504, Val MAE: 0.217072, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.049444, Val Loss: 0.062412, Train MAE: 0.258876, Val MAE: 0.182488, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.054208, Val Loss: 0.055980, Train MAE: 0.258962, Val MAE: 0.163852, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 42
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 6 ===
# INFO:src.pipeline:Train samples: 160, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.067577, Val Loss: 0.013058, Train MAE: 0.284620, Val MAE: 0.121229, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.057159, Val Loss: 0.013024, Train MAE: 0.272720, Val MAE: 0.078875, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.047436, Val Loss: 0.015313, Train MAE: 0.241715, Val MAE: 0.100032, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 7 ===
# INFO:src.pipeline:Train samples: 191, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.058670, Val Loss: 0.021442, Train MAE: 0.262233, Val MAE: 0.122676, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.046973, Val Loss: 0.020777, Train MAE: 0.244112, Val MAE: 0.119268, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.040962, Val Loss: 0.024783, Train MAE: 0.217519, Val MAE: 0.110061, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 36
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 8 ===
# INFO:src.pipeline:Train samples: 222, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.050539, Val Loss: 0.021931, Train MAE: 0.247273, Val MAE: 0.120579, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.044678, Val Loss: 0.022324, Train MAE: 0.234603, Val MAE: 0.137036, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.039599, Val Loss: 0.028565, Train MAE: 0.211728, Val MAE: 0.176633, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 36
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 9 ===
# INFO:src.pipeline:Train samples: 252, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.050696, Val Loss: 0.019679, Train MAE: 0.250441, Val MAE: 0.169504, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039829, Val Loss: 0.028695, Train MAE: 0.213526, Val MAE: 0.194147, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.035620, Val Loss: 0.041244, Train MAE: 0.199722, Val MAE: 0.193754, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 31
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 10 ===
# INFO:src.pipeline:Train samples: 283, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.049726, Val Loss: 0.050467, Train MAE: 0.239578, Val MAE: 0.251504, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.040020, Val Loss: 0.050931, Train MAE: 0.209476, Val MAE: 0.238363, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.037573, Val Loss: 0.066198, Train MAE: 0.208587, Val MAE: 0.269885, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 11 ===
# INFO:src.pipeline:Train samples: 313, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.051671, Val Loss: 0.095384, Train MAE: 0.250280, Val MAE: 0.373469, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.041153, Val Loss: 0.085919, Train MAE: 0.217103, Val MAE: 0.349482, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.036167, Val Loss: 0.069495, Train MAE: 0.200235, Val MAE: 0.301980, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.034886, Val Loss: 0.082311, Train MAE: 0.197334, Val MAE: 0.317724, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 43
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 12 ===
# INFO:src.pipeline:Train samples: 344, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.052369, Val Loss: 0.065275, Train MAE: 0.252590, Val MAE: 0.332756, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.042130, Val Loss: 0.041897, Train MAE: 0.222920, Val MAE: 0.247064, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.041060, Val Loss: 0.042021, Train MAE: 0.220746, Val MAE: 0.244210, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.038903, Val Loss: 0.043177, Train MAE: 0.208437, Val MAE: 0.252165, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.038643, Val Loss: 0.041492, Train MAE: 0.207343, Val MAE: 0.234923, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 13 ===
# INFO:src.pipeline:Train samples: 375, Val samples: 26
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.051783, Val Loss: 0.062944, Train MAE: 0.254081, Val MAE: 0.301395, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.043749, Val Loss: 0.062311, Train MAE: 0.230444, Val MAE: 0.309017, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.044407, Val Loss: 0.061258, Train MAE: 0.228718, Val MAE: 0.301780, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.036487, Val Loss: 0.065436, Train MAE: 0.202389, Val MAE: 0.315977, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.036401, Val Loss: 0.061860, Train MAE: 0.203585, Val MAE: 0.290992, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 260  | y_true: 260 | y_pred: 260
# INFO:src.pipeline:
# === Running Fold 14 ===
# INFO:src.pipeline:Train samples: 403, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.053393, Val Loss: 0.020422, Train MAE: 0.256127, Val MAE: 0.165055, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.044101, Val Loss: 0.020400, Train MAE: 0.234705, Val MAE: 0.168918, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 28
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 15 ===
# INFO:src.pipeline:Train samples: 434, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.050106, Val Loss: 0.022531, Train MAE: 0.246194, Val MAE: 0.132155, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.042436, Val Loss: 0.023070, Train MAE: 0.227282, Val MAE: 0.122643, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 27
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 16 ===
# INFO:src.pipeline:Train samples: 464, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.049502, Val Loss: 0.020684, Train MAE: 0.248597, Val MAE: 0.121027, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.040661, Val Loss: 0.023243, Train MAE: 0.220561, Val MAE: 0.114894, LR: 0.001000
# INFO:src.engine:Early stopping at epoch 29
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 17 ===
# INFO:src.pipeline:Train samples: 495, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045824, Val Loss: 0.016461, Train MAE: 0.237106, Val MAE: 0.093081, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039409, Val Loss: 0.016375, Train MAE: 0.214645, Val MAE: 0.095346, LR: 0.000500
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.038078, Val Loss: 0.016407, Train MAE: 0.210706, Val MAE: 0.118944, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.037443, Val Loss: 0.016332, Train MAE: 0.210298, Val MAE: 0.096807, LR: 0.000250
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.037957, Val Loss: 0.016701, Train MAE: 0.210587, Val MAE: 0.085919, LR: 0.000250
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 18 ===
# INFO:src.pipeline:Train samples: 525, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045773, Val Loss: 0.016693, Train MAE: 0.231292, Val MAE: 0.093552, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039921, Val Loss: 0.016324, Train MAE: 0.215109, Val MAE: 0.083508, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 28
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 19 ===
# INFO:src.pipeline:Train samples: 556, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042565, Val Loss: 0.006986, Train MAE: 0.227085, Val MAE: 0.079602, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.040038, Val Loss: 0.007452, Train MAE: 0.216387, Val MAE: 0.057847, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.034869, Val Loss: 0.007851, Train MAE: 0.197774, Val MAE: 0.099278, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.036500, Val Loss: 0.007184, Train MAE: 0.204531, Val MAE: 0.059999, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.033304, Val Loss: 0.006910, Train MAE: 0.193605, Val MAE: 0.068730, LR: 0.000250
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 20 ===
# INFO:src.pipeline:Train samples: 586, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043847, Val Loss: 0.015844, Train MAE: 0.229545, Val MAE: 0.139301, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039193, Val Loss: 0.015962, Train MAE: 0.212925, Val MAE: 0.113786, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.036856, Val Loss: 0.015990, Train MAE: 0.206103, Val MAE: 0.111586, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 21 ===
# INFO:src.pipeline:Train samples: 616, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043259, Val Loss: 0.015546, Train MAE: 0.224515, Val MAE: 0.126099, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038131, Val Loss: 0.016517, Train MAE: 0.211866, Val MAE: 0.146070, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.034328, Val Loss: 0.015823, Train MAE: 0.196180, Val MAE: 0.105928, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.033100, Val Loss: 0.015155, Train MAE: 0.189607, Val MAE: 0.119198, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.031768, Val Loss: 0.015079, Train MAE: 0.186328, Val MAE: 0.118459, LR: 0.000250
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 22 ===
# INFO:src.pipeline:Train samples: 647, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043032, Val Loss: 0.043937, Train MAE: 0.227109, Val MAE: 0.232157, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037245, Val Loss: 0.045963, Train MAE: 0.203944, Val MAE: 0.252930, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.034579, Val Loss: 0.044308, Train MAE: 0.196733, Val MAE: 0.239988, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 35
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 23 ===
# INFO:src.pipeline:Train samples: 677, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044651, Val Loss: 0.044166, Train MAE: 0.233515, Val MAE: 0.239064, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037599, Val Loss: 0.052818, Train MAE: 0.209759, Val MAE: 0.259618, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.034174, Val Loss: 0.042410, Train MAE: 0.193943, Val MAE: 0.237866, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.031579, Val Loss: 0.044773, Train MAE: 0.184345, Val MAE: 0.228146, LR: 0.001000
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.032782, Val Loss: 0.041881, Train MAE: 0.189386, Val MAE: 0.232323, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 24 ===
# INFO:src.pipeline:Train samples: 707, Val samples: 20
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.045115, Val Loss: 0.054266, Train MAE: 0.228557, Val MAE: 0.269952, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039628, Val Loss: 0.057565, Train MAE: 0.217290, Val MAE: 0.273153, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.036330, Val Loss: 0.053661, Train MAE: 0.201655, Val MAE: 0.258873, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 200  | y_true: 200 | y_pred: 200
# INFO:src.pipeline:
# === Running Fold 25 ===
# INFO:src.pipeline:Train samples: 729, Val samples: 21
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.040593, Val Loss: 0.030844, Train MAE: 0.218801, Val MAE: 0.207181, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039007, Val Loss: 0.031683, Train MAE: 0.210944, Val MAE: 0.166576, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.035675, Val Loss: 0.031553, Train MAE: 0.201907, Val MAE: 0.200797, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 34
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 210  | y_true: 210 | y_pred: 210
# INFO:src.pipeline:
# === Running Fold 26 ===
# INFO:src.pipeline:Train samples: 752, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044206, Val Loss: 0.053238, Train MAE: 0.229708, Val MAE: 0.243449, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.039199, Val Loss: 0.052000, Train MAE: 0.213365, Val MAE: 0.247345, LR: 0.000500
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.035410, Val Loss: 0.054216, Train MAE: 0.200489, Val MAE: 0.239105, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.036801, Val Loss: 0.051276, Train MAE: 0.200962, Val MAE: 0.247902, LR: 0.000250
# INFO:src.engine:Early stopping at epoch 46
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 27 ===
# INFO:src.pipeline:Train samples: 783, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.044819, Val Loss: 0.037790, Train MAE: 0.235970, Val MAE: 0.171943, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037219, Val Loss: 0.037472, Train MAE: 0.207332, Val MAE: 0.174114, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.036308, Val Loss: 0.041400, Train MAE: 0.202573, Val MAE: 0.163622, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.035973, Val Loss: 0.039846, Train MAE: 0.202621, Val MAE: 0.160241, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 41
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 28 ===
# INFO:src.pipeline:Train samples: 813, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.043028, Val Loss: 0.033191, Train MAE: 0.224813, Val MAE: 0.181046, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038409, Val Loss: 0.031530, Train MAE: 0.209387, Val MAE: 0.193534, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.036613, Val Loss: 0.036352, Train MAE: 0.206121, Val MAE: 0.171534, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.034900, Val Loss: 0.035992, Train MAE: 0.195606, Val MAE: 0.171648, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 40
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 29 ===
# INFO:src.pipeline:Train samples: 844, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041460, Val Loss: 0.008099, Train MAE: 0.222059, Val MAE: 0.106226, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.038381, Val Loss: 0.010517, Train MAE: 0.208326, Val MAE: 0.132243, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.036962, Val Loss: 0.006483, Train MAE: 0.202066, Val MAE: 0.078475, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 30 ===
# INFO:src.pipeline:Train samples: 874, Val samples: 27
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042211, Val Loss: 0.008303, Train MAE: 0.224567, Val MAE: 0.126583, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.037886, Val Loss: 0.001677, Train MAE: 0.207451, Val MAE: 0.053602, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.034585, Val Loss: 0.001332, Train MAE: 0.198659, Val MAE: 0.047445, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.034348, Val Loss: 0.002283, Train MAE: 0.195949, Val MAE: 0.064055, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 46
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 270  | y_true: 270 | y_pred: 270
# INFO:src.pipeline:
# === Running Fold 31 ===
# INFO:src.pipeline:Train samples: 903, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041620, Val Loss: 0.005424, Train MAE: 0.220059, Val MAE: 0.073084, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036775, Val Loss: 0.005702, Train MAE: 0.204123, Val MAE: 0.082161, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.035705, Val Loss: 0.004137, Train MAE: 0.203379, Val MAE: 0.046137, LR: 0.001000
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.033395, Val Loss: 0.003743, Train MAE: 0.192274, Val MAE: 0.031397, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.033391, Val Loss: 0.003923, Train MAE: 0.193998, Val MAE: 0.040820, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 32 ===
# INFO:src.pipeline:Train samples: 934, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.040146, Val Loss: 0.005311, Train MAE: 0.216295, Val MAE: 0.073016, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.035303, Val Loss: 0.006165, Train MAE: 0.199042, Val MAE: 0.087408, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 24
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 33 ===
# INFO:src.pipeline:Train samples: 964, Val samples: 29
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.041847, Val Loss: 0.063062, Train MAE: 0.218696, Val MAE: 0.252526, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.034364, Val Loss: 0.065713, Train MAE: 0.196406, Val MAE: 0.252038, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.032749, Val Loss: 0.060365, Train MAE: 0.189649, Val MAE: 0.266613, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 32
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 290  | y_true: 290 | y_pred: 290
# INFO:src.pipeline:
# === Running Fold 34 ===
# INFO:src.pipeline:Train samples: 995, Val samples: 28
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.040259, Val Loss: 0.049281, Train MAE: 0.216808, Val MAE: 0.276773, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.036974, Val Loss: 0.044334, Train MAE: 0.204483, Val MAE: 0.234915, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.033261, Val Loss: 0.044017, Train MAE: 0.191719, Val MAE: 0.245334, LR: 0.000500
# INFO:src.engine:Epoch [40/50] - Train Loss: 0.033842, Val Loss: 0.045045, Train MAE: 0.191492, Val MAE: 0.255183, LR: 0.000500
# INFO:src.engine:Epoch [50/50] - Train Loss: 0.033364, Val Loss: 0.043455, Train MAE: 0.190295, Val MAE: 0.226486, LR: 0.000500
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 280  | y_true: 280 | y_pred: 280
# INFO:src.pipeline:
# === Running Fold 35 ===
# INFO:src.pipeline:Train samples: 1025, Val samples: 19
# INFO:src.pipeline:X_train scaled range: [-1.000, 1.000]
# INFO:src.pipeline:Y_train scaled range: [0.000, 1.200]
# INFO:src.pipeline:Model parameters: 179,338
# INFO:src.engine:Using HuberLoss (Smooth L1 Loss)
# INFO:src.engine:Epoch [10/50] - Train Loss: 0.042713, Val Loss: 0.048040, Train MAE: 0.224614, Val MAE: 0.258784, LR: 0.001000
# INFO:src.engine:Epoch [20/50] - Train Loss: 0.042056, Val Loss: 0.064184, Train MAE: 0.219182, Val MAE: 0.329184, LR: 0.001000
# INFO:src.engine:Epoch [30/50] - Train Loss: 0.036752, Val Loss: 0.050203, Train MAE: 0.210414, Val MAE: 0.263019, LR: 0.000500
# INFO:src.engine:Early stopping at epoch 31
# INFO:src.pipeline:Benchmark colmap: {'truth_csi': 'actual_csi', 'truth_ghi': None, 'ghi_cs': 'clear_sky_ghi', 'nam_ghi': 'nam_ghi', 'nam_csi': None}
# INFO:src.pipeline:ref_df columns (first 10): ['actual_ghi', 'nam_ghi', 'clear_sky_ghi', 'actual_csi', 'nam_csi']
# INFO:src.pipeline:label_times: 190  | y_true: 190 | y_pred: 190
# INFO:src.pipeline:
# === Experiment Summary ===
# INFO:src.pipeline:Average Validation Metrics:
# INFO:src.pipeline:  MAE: 0.186184 ± 0.098951
# INFO:src.pipeline:  RMSE: 0.257583 ± 0.111250
# INFO:src.pipeline:  per_horizon_MAE: 0.186184 ± 0.098951
# INFO:src.pipeline:  GHI_RMSE_skill_Ours_vs_SP: -0.246349 ± 0.984379
# INFO:src.pipeline:  GHI_MAE_skill_Ours_vs_SP: -0.808714 ± 1.671105
# INFO:src.pipeline:  CSI_RMSE_skill_Ours_vs_SP: -0.333167 ± 0.999408
# INFO:src.pipeline:  CSI_MAE_skill_Ours_vs_SP: -0.995303 ± 1.839234
# INFO:src.pipeline:  GHI_RMSE_skill_NAM_vs_SP: -2.231082 ± 3.863240
# INFO:src.pipeline:  GHI_MAE_skill_NAM_vs_SP: -4.784376 ± 7.218421
# INFO:src.pipeline:  CSI_RMSE_skill_NAM_vs_SP: -2.084155 ± 4.100858
# INFO:src.pipeline:  CSI_MAE_skill_NAM_vs_SP: -4.418878 ± 7.606558
